# %%
import os
import re
import glob
import numpy as np
import pandas as pd

from importlib import reload
from joebvp import cfg, utils, VPmeasure
# Out:
# read_sets: Using set file --
#   C:\Users\Billy\AppData\Local\Programs\Python\Python312\Lib\site-packages\linetools\lists\sets\llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# linetools.lists.parse: Reading linelist ---
#    C:\Users\Billy\AppData\Local\Programs\Python\Python312\Lib\site-packages\linetools/data/lines/morton03_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    C:\Users\Billy\AppData\Local\Programs\Python\Python312\Lib\site-packages\linetools/data/lines/verner96_tab1.fits.gz
# joebvp.makevoigt: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# joebvp.VPmeasure: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# linetools.lists.parse: Reading linelist ---
#    C:\Users\Billy\AppData\Local\Programs\Python\Python312\Lib\site-packages\linetools/data/lines/morton03_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    C:\Users\Billy\AppData\Local\Programs\Python\Python312\Lib\site-packages\linetools/data/lines/verner96_tab1.fits.gz
# joebvp.makevoigt: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# C:\Users\Billy\AppData\Local\Programs\Python\Python312\Lib\site-packages\joebvp
# joebvp.utils: No local joebvp_cfg.py found, using default cfg.py file from joebvp.

# %%
def replace_string(input_str):
    segment = """lt_xspec [dataset_name]_x1d.fits 
lt_continuumfit --redshift 0.0009 [dataset_name]_x1d.fits [dataset_name]_continuumfit.fits
pyigm_igmguesses [dataset_name]_continuumfit.fits -o [dataset_name]_x1dfits_model.json
pyigm_fitdla --out_file [dataset_name]_xfitdla.json [dataset_name]_continuumfit.fits 0"""
    
    modified_segment = segment.replace("[dataset_name]", input_str)
    print(modified_segment)
    
replace_string("oda974010")
# Out:
# lt_xspec oda974010_x1d.fits
# lt_continuumfit --redshift 0.0009 oda974010_x1d.fits oda974010_continuumfit.fits
# pyigm_igmguesses oda974010_continuumfit.fits -o oda974010_x1dfits_model.json
# pyigm_fitdla --out_file oda974010_xfitdla.json oda974010_continuumfit.fits 0

# %%
reload(cfg)

d = pd.DataFrame({
    'instr': ['COS', 'COS', 'COS', 'COS', 'STIS', 'STIS', 'Gaussian'],
    'gratings': ['G130M', 'G160M', 'G185M', 'G225M', 'E230M', 'E140M', 'N/A'],
    'slits': ['NA', 'NA', 'NA', 'NA', '0.2x0.2', '0.2x0.2', 'NA'],
    'lsfranges': [[1100, 1460], [1460, 1800], [1800, 2100], [2100, 2278], [1607, 3129], [1144, 1729], [899, 1191]],
    'lps': ['1', '1', '1', '1', '1', '1', 'NA'],
    'cen_wave': ['1327', '1600', '1953', '2250', '1978', '1425', 'NA'],
    'pixel_scales': [None, None, None, None, None, None, 0.013], 
    'fwhms': [None, None, None, None, None, None, 0.02]
})

num = 4

cfg.lsfs = []
for col in ['instr', 'gratings', 'slits', 'cen_wave', 'pixel_scales', 'fwhms']:
    setattr(cfg, col, [d.at[num, col]])

cfg.lsfranges = np.array([d.at[num, 'lsfranges']])

# %%
base_directory = "C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M"
directories = sorted([d for d in os.listdir(base_directory) if d.startswith("E230M")])

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_models = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))
    continuumfits = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))

    utils.pyigm_to_veeper(igm_models[0], continuumfits[0])

    os.chdir(base_directory)
# Out:
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    component_groups_dir = os.path.join(current_directory, "component_groups")
    output_dir = os.path.join(current_directory, "modified_component_groups")

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    mc_lines_file = "C:/Users/Billy/Desktop/float of dawn/mc_lines_metal_e230m.txt"
    mc_lines_df = pd.read_csv(mc_lines_file, sep = r"\s+", header = None, names = ["line", "wavelength"])
    mc_lines_df["wavelength"] = mc_lines_df["wavelength"].astype(float)

    def is_valid_line(row, line_df):
        trans = row["trans"].strip()
        restwave = row["restwave"]
        matching_lines = line_df[line_df["line"] == trans]
        for wave in matching_lines["wavelength"]:
            if 0.99 * wave <= restwave <= 1.01 * wave:
                return True
        return False

    input_files = glob.glob(os.path.join(component_groups_dir, "*.txt"))

    for file in input_files:
        df = pd.read_csv(file, sep = "|")
        df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    
        df["restwave"] = pd.to_numeric(df["restwave"], errors = "coerce")
        df["bval"] = pd.to_numeric(df["bval"], errors = "coerce")
    
        valid_mask = df.apply(lambda row: is_valid_line(row, mc_lines_df), axis = 1)
        df_filtered = df[valid_mask].copy()

        # df_filtered["col"] = df_filtered["col"] - 0.2
        df_filtered["bval"] = df_filtered["bval"] / 2
    
        output_file = os.path.join(output_dir, os.path.basename(file))
        df_filtered.to_csv(output_file, sep = "|", index = False)
        # print(f"Processed file: {os.path.basename(file)} -> {output_file}")

# %%
# Before fitting, should manually adjust the input group files

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_models = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))
    continuumfits = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))

    component_groups_dir = os.path.join(current_directory, "modified_component_groups")
    
    input_group_files = sorted([f for f in glob.glob(os.path.join(component_groups_dir, "input_group_*.txt")) if re.match(r".*input_group_\d+\.txt$", f)])

    VPmeasure.batch_fit(continuumfits[0], input_group_files, filepath = './modified_component_groups/')

    os.chdir(base_directory)
# Out:
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.6324e+02, final cost 7.3933e+01, first-order optimality 5.10e-04.
#
# Fit results:
#
# 2249.88	 0.000910	 15.343	 15.000	 -2.9866
#  	  	  	 0.022	 1.11	 0.747
#
# 2260.78	 0.000910	 15.343	 15.000	 -2.9866
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.240396
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.6324e+02, final cost 7.3933e+01, first-order optimality 5.10e-04.
#
# Fit results:
#
# 2249.88	 0.000910	 15.343	 15.000	 -2.9866
#  	  	  	 0.022	 1.11	 0.747
#
# 2260.78	 0.000910	 15.343	 15.000	 -2.9866
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.240396
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M10\modified_component_groups\input_group_0.txt
# Line parameters written to:
# C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M10\modified_component_groups\input_group_0.VP
# Wrote spectrum to C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M10\modified_component_groups\input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M10\modified_component_groups\input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 1.0061e+02, final cost 1.9365e+01, first-order optimality 1.27e-02.
#
# Fit results:
#
# 1808.01	 0.000930	 16.374	 12.152	 2.0555
#  	  	  	 0.703	 4.714	 1.295
#
#
# Reduced chi-squared: 1.335519
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 1.0061e+02, final cost 1.9365e+01, first-order optimality 1.27e-02.
#
# Fit results:
#
# 1808.01	 0.000930	 16.374	 12.152	 2.0555
#  	  	  	 0.703	 4.714	 1.295
#
#
# Reduced chi-squared: 1.335519
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M10\modified_component_groups\input_group_1.txt
# Line parameters written to:
# C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M10\modified_component_groups\input_group_1.VP
# Wrote spectrum to C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M10\modified_component_groups\input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M10\modified_component_groups\input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 9.2727e+01, final cost 4.7955e+01, first-order optimality 7.45e-03.
#
# Fit results:
#
# 2062.66	 0.000930	 14.513	 5.5245	 -1.5869
#  	  	  	 2.32	 4.762	 0.783
#
#
# Reduced chi-squared: 3.836429
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 9.2727e+01, final cost 4.7955e+01, first-order optimality 7.45e-03.
#
# Fit results:
#
# 2062.66	 0.000930	 14.513	 5.5245	 -1.5869
#  	  	  	 2.32	 4.762	 0.783
#
#
# Reduced chi-squared: 3.836429
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M10\modified_component_groups\input_group_2.txt
# Line parameters written to:
# C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M10\modified_component_groups\input_group_2.VP
# Wrote spectrum to C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M10\modified_component_groups\input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M10\modified_component_groups\input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.7437e+02, final cost 1.4959e+02, first-order optimality 8.44e-04.
#
# Fit results:
#
# 2056.26	 0.000940	 13.503	 14.191	 0.16845
#  	  	  	 0.034	 1.951	 1.245
#
# 2062.23	 0.000940	 13.503	 14.191	 0.16845
#  	  	  	 0.0	 0.0	 0.0
#
# 2066.16	 0.000940	 13.503	 14.191	 0.16845
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 3.478830
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.7437e+02, final cost 1.4959e+02, first-order optimality 8.44e-04.
#
# Fit results:
#
# 2056.26	 0.000940	 13.503	 14.191	 0.16845
#  	  	  	 0.034	 1.951	 1.245
#
# 2062.23	 0.000940	 13.503	 14.191	 0.16845
#  	  	  	 0.0	 0.0	 0.0
#
# 2066.16	 0.000940	 13.503	 14.191	 0.16845
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 3.478830
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M10\modified_component_groups\input_group_3.txt
# Line parameters written to:
# C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M10\modified_component_groups\input_group_3.VP
# Wrote spectrum to C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M10\modified_component_groups\input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M10\modified_component_groups\input_group_3_inspect.fits
#
# VPmeasure: 4/4 fits converged, 0/4 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 1.4994e+02, final cost 6.3552e+01, first-order optimality 3.16e-03.
#
# Fit results:
#
# 2249.88	 0.000910	 15.286	 14.258	 1.7043
#  	  	  	 0.022	 1.099	 0.737
#
# 2260.78	 0.000910	 15.286	 14.258	 1.7043
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.842078
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 1.4994e+02, final cost 6.3552e+01, first-order optimality 3.16e-03.
#
# Fit results:
#
# 2249.88	 0.000910	 15.286	 14.258	 1.7043
#  	  	  	 0.022	 1.099	 0.737
#
# 2260.78	 0.000910	 15.286	 14.258	 1.7043
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.842078
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M20\modified_component_groups\input_group_0.txt
# Line parameters written to:
# C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M20\modified_component_groups\input_group_0.VP
# Wrote spectrum to C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M20\modified_component_groups\input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M20\modified_component_groups\input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 20, initial cost 8.3768e+01, final cost 2.7370e+01, first-order optimality 1.91e-02.
#
# Fit results:
#
# 1808.01	 0.000910	 16.295	 12.350	 6.0998
#  	  	  	 0.572	 4.253	 1.314
#
#
# Reduced chi-squared: 1.564007
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 20, initial cost 8.3768e+01, final cost 2.7370e+01, first-order optimality 1.91e-02.
#
# Fit results:
#
# 1808.01	 0.000910	 16.295	 12.350	 6.0998
#  	  	  	 0.572	 4.253	 1.314
#
#
# Reduced chi-squared: 1.564007
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M20\modified_component_groups\input_group_1.txt
# Line parameters written to:
# C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M20\modified_component_groups\input_group_1.VP
# Wrote spectrum to C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M20\modified_component_groups\input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M20\modified_component_groups\input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 1.6831e+02, final cost 9.1186e+01, first-order optimality 4.16e-03.
#
# Fit results:
#
# 2062.66	 0.000930	 13.641	 11.444	 -3.691
#  	  	  	 0.078	 1.531	 0.882
#
#
# Reduced chi-squared: 7.294844
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 1.6831e+02, final cost 9.1186e+01, first-order optimality 4.16e-03.
#
# Fit results:
#
# 2062.66	 0.000930	 13.641	 11.444	 -3.691
#  	  	  	 0.078	 1.531	 0.882
#
#
# Reduced chi-squared: 7.294844
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M20\modified_component_groups\input_group_2.txt
# Line parameters written to:
# C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M20\modified_component_groups\input_group_2.VP
# Wrote spectrum to C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M20\modified_component_groups\input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M20\modified_component_groups\input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 3.5133e+02, final cost 3.2437e+02, first-order optimality 1.32e-02.
#
# Fit results:
#
# 2056.26	 0.000960	 13.638	 18.112	 -4.7197
#  	  	  	 0.026	 1.714	 1.137
#
# 2062.23	 0.000960	 13.638	 18.112	 -4.7197
#  	  	  	 0.0	 0.0	 0.0
#
# 2066.16	 0.000960	 13.638	 18.112	 -4.7197
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 5.844559
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 3.5133e+02, final cost 3.2437e+02, first-order optimality 1.32e-02.
#
# Fit results:
#
# 2056.26	 0.000960	 13.638	 18.112	 -4.7197
#  	  	  	 0.026	 1.714	 1.137
#
# 2062.23	 0.000960	 13.638	 18.112	 -4.7197
#  	  	  	 0.0	 0.0	 0.0
#
# 2066.16	 0.000960	 13.638	 18.112	 -4.7197
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 5.844559
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M20\modified_component_groups\input_group_3.txt
# Line parameters written to:
# C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M20\modified_component_groups\input_group_3.VP
# Wrote spectrum to C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M20\modified_component_groups\input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to C:/Users/Billy/Desktop/float of dawn/PGMW3223/E230M\E230M20\modified_component_groups\input_group_3_inspect.fits
#
# VPmeasure: 4/4 fits converged, 0/4 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    df = pd.read_csv('compiledVPoutputs.dat', sep = '|')
    filtered_df = df[df['zsys'] > 0.0004]
    filtered_df = filtered_df[filtered_df['sigcol'] != 0.000]
    result = filtered_df[['col', 'sigcol', 'trans']]

    unique_result = result.drop_duplicates()
    print(unique_result)
    os.chdir(base_directory)
# Out:
#       col  sigcol trans
# 0  15.343   0.022  FeII
# 2  16.374   0.703  SiII
# 3  14.513   2.320  ZnII
# 4  13.503   0.034  CrII
#       col  sigcol trans
# 0  15.286   0.022  FeII
# 2  16.295   0.572  SiII
# 3  13.641   0.078  ZnII
# 4  13.638   0.026  CrII

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)
    component_groups_dir = os.path.join(current_directory, "modified_component_groups")

    os.chdir(component_groups_dir)

    vp_files = glob.glob("*.VP")
    vp_files.sort()

    with open("all.VP", 'w') as outfile:
        for i, vp_file in enumerate(vp_files):
            with open(vp_file, 'r') as infile:
                lines = infile.readlines()
                if i > 1:
                    lines = lines[1:]
                outfile.writelines(lines)

    os.chdir(base_directory)

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_models = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))
    continuumfits = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))

    component_groups_dir = os.path.join(current_directory, "modified_component_groups")
    
    input_group_files = sorted([f for f in glob.glob(os.path.join(component_groups_dir, "input_group_*.txt")) if re.match(r".*input_group_\d+\.txt$", f)])

    print(continuumfits[0])
    print(input_group_files[0])
    
    VPmeasure.go(continuumfits[0], input_group_files[0])
    
    # VPmeasure.batch_fit(continuumfits[0], input_group_files, filepath = './modified_component_groups/')

    os.chdir(base_directory)

# %%
# END
