# %%
# Import packages
import os
import re
import sys
import glob
import toml
import shutil
import textwrap
import subprocess

import numpy as np
import pandas as pd

from pathlib import Path
from astropy.io import fits
from importlib import reload
from astropy.table import Table
from scipy.interpolate import interp1d
from joebvp import cfg, utils, VPmeasure
# Out:
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/morton03_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/verner96_tab1.fits.gz
# joebvp.makevoigt: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# joebvp.VPmeasure: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/morton03_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/verner96_tab1.fits.gz
# joebvp.makevoigt: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/joebvp
# joebvp.utils: No local joebvp_cfg.py found, using default cfg.py file from joebvp.

# %%
# Register directories
notebook_directory = Path().resolve()
base_directory = notebook_directory / "E140M"
python_cmd = sys.executable
model_file = "/Users/billyli/Documents/BillyJessExploratory/powr-OB-lmc-vd3.nc"
runner_path = "/Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py"

# %%
# Generate terminal commands
directories = sorted([d for d in os.listdir(base_directory) if d.startswith("E140M")])

def replace_string(path, dataset_name):
    segment = """lt_xspec [path][dataset_name]_x1d.fits
cd [path] && lt_continuumfit --redshift 0.00087 [dataset_name]_x1d.fits [dataset_name]_continuumfit_original.fits
cd [path] && pyigm_igmguesses [dataset_name]_continuumfit.fits -o [dataset_name]_x1dfits_model.json
cd [path] && pyigm_fitdla --out_file [dataset_name]_xfitdla.json [dataset_name]_continuumfit.fits 0"""
    modified_segment = segment.replace("[dataset_name]", dataset_name)
    modified_segment = modified_segment.replace("[path]", path)
    print(modified_segment)
    
for subdir in directories:
    path = base_directory / subdir
    for file in os.listdir(path):
        if file.endswith("_x1d.fits"):
            dataset_name = file.replace("_x1d.fits", "")
            path = str(path.resolve()) + "/"
            replace_string(path, dataset_name)
            print("\r")
# Out:
# lt_xspec /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/of1n1s010_x1d.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/ && lt_continuumfit --redshift 0.00087 of1n1s010_x1d.fits of1n1s010_continuumfit_original.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/ && pyigm_igmguesses of1n1s010_continuumfit.fits -o of1n1s010_x1dfits_model.json
# cd /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/ && pyigm_fitdla --out_file of1n1s010_xfitdla.json of1n1s010_continuumfit.fits 0
#
# lt_xspec /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/of1n1s020_x1d.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/ && lt_continuumfit --redshift 0.00087 of1n1s020_x1d.fits of1n1s020_continuumfit_original.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/ && pyigm_igmguesses of1n1s020_continuumfit.fits -o of1n1s020_x1dfits_model.json
# cd /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/ && pyigm_fitdla --out_file of1n1s020_xfitdla.json of1n1s020_continuumfit.fits 0
#
# lt_xspec /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/of1n1s030_x1d.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/ && lt_continuumfit --redshift 0.00087 of1n1s030_x1d.fits of1n1s030_continuumfit_original.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/ && pyigm_igmguesses of1n1s030_continuumfit.fits -o of1n1s030_x1dfits_model.json
# cd /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/ && pyigm_fitdla --out_file of1n1s030_xfitdla.json of1n1s030_continuumfit.fits 0
#
# lt_xspec /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/of1n1t010_x1d.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/ && lt_continuumfit --redshift 0.00087 of1n1t010_x1d.fits of1n1t010_continuumfit_original.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/ && pyigm_igmguesses of1n1t010_continuumfit.fits -o of1n1t010_x1dfits_model.json
# cd /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/ && pyigm_fitdla --out_file of1n1t010_xfitdla.json of1n1t010_continuumfit.fits 0
#
# lt_xspec /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/of1n1t020_x1d.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/ && lt_continuumfit --redshift 0.00087 of1n1t020_x1d.fits of1n1t020_continuumfit_original.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/ && pyigm_igmguesses of1n1t020_continuumfit.fits -o of1n1t020_x1dfits_model.json
# cd /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/ && pyigm_fitdla --out_file of1n1t020_xfitdla.json of1n1t020_continuumfit.fits 0

# %%
# Run Kirill's continuum fitting script to replace standard continuum fit between range
for fits_path in sorted(base_directory.rglob("*_x1d.fits")):
    
    dataset = fits_path.stem.replace("_x1d", "")
    cwd_directory = fits_path.parent

    problem = notebook_directory.name.lower()
    target = notebook_directory.name.upper()

    spec_file = fits_path.name
    
    wave_min = 1245
    wave_max = 1615

    toml_content = textwrap.dedent(f"""
    [target_info]
    problem    = "{problem}"
    target     = "{target}"
    spec_file  = "{spec_file}"
    model_file = "{model_file}"
    instrument = "stis_e140m"

    [include_wave_range]
    wave_range = [ {wave_min}, {wave_max},]

    [exclude_wave_ranges]

    [vshift]
    min = 50
    max = 550
    delta = 50

    [vsini]
    min = 50
    max = 350
    delta = 50

    [exclude_vranges.ions]
    linelist = "ISM"
    vrange = [-75, 350]
    drop_species = []

    [target_info.plot_ranges_kwargs.all_merged]
    color = "gainsboro"
    """).lstrip()

    tmp_toml = cwd_directory / f"{problem}.toml"
    tmp_toml.write_text(toml_content)

    subprocess.run([python_cmd, runner_path, str(tmp_toml)], check = True, cwd = cwd_directory)

    csv_path = cwd_directory / f"{problem}.csv"
    model_continuum = Table.read(str(csv_path), format = "csv")
    original = Table.read(fits_path, hdu = 1)

    wave = model_continuum['wave'].data
    flux = model_continuum['flux'].data
    err = model_continuum['err'].data
    wave_model = model_continuum['wave'].data
    best_fit_spec = model_continuum['best_fit_spec'].data

    continuumfit_path = cwd_directory / f"{dataset}_continuumfit_original.fits"
    with fits.open(continuumfit_path, mode = 'readonly') as hdul:
        new_hdul = fits.HDUList([h.copy() for h in hdul])

    flux_original = new_hdul[0].data
    wave_original = new_hdul[2].data
    continuum_hdu = new_hdul[3]
    
    continuum_original = continuum_hdu.data
    
    mask = (wave_original >= wave_min) & (wave_original <= wave_max)
    flux_original_masked = flux_original[mask]

    normalization_factor = flux_original_masked[10000] / flux[10000]
    normalization_factor_2 = flux_original_masked[15000] / flux[15000]
    normalization_factor_3 = flux_original_masked[20000] / flux[20000]

    if not (np.allclose([normalization_factor, normalization_factor_2, normalization_factor_3], normalization_factor, rtol = 0.001)):
        raise ValueError(f"Normalization factors disagree: {normalization_factor:.3f}, {normalization_factor_2:.3f}, {normalization_factor_3:.3f}")
    
    # f = interp1d(wave, best_fit_spec, kind = 'linear') # no need to interp2d
    # continuum_interp_values = f(wave_original[mask]) * normalization_factor

    continuum_hdu.data[mask] = best_fit_spec * normalization_factor # continuum_interp_values

    out_path = str(fits_path).replace("_x1d.fits", "_continuumfit.fits")
    new_hdul.writeto(str(out_path), overwrite = True)
# Out:
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'n11-els-048', 'target': 'N11-ELS-048', 'spec_file': 'of1n1s010_x1d.fits', 'model_file': '/Users/billyli/Documents/BillyJessExploratory/powr-OB-lmc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1245, 1615]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-75, 350], 'drop_species': []}}}
# WARNING: UnitsWarning: 'Angstroms' did not parse as fits unit: At col 0, Unit 'Angstroms' not supported by the FITS standard. Did you mean Angstrom or angstrom? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'n11-els-048', 'target': 'N11-ELS-048', 'spec_file': 'of1n1s020_x1d.fits', 'model_file': '/Users/billyli/Documents/BillyJessExploratory/powr-OB-lmc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1245, 1615]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-75, 350], 'drop_species': []}}}
# WARNING: UnitsWarning: 'Angstroms' did not parse as fits unit: At col 0, Unit 'Angstroms' not supported by the FITS standard. Did you mean Angstrom or angstrom? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'n11-els-048', 'target': 'N11-ELS-048', 'spec_file': 'of1n1s030_x1d.fits', 'model_file': '/Users/billyli/Documents/BillyJessExploratory/powr-OB-lmc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1245, 1615]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-75, 350], 'drop_species': []}}}
# WARNING: UnitsWarning: 'Angstroms' did not parse as fits unit: At col 0, Unit 'Angstroms' not supported by the FITS standard. Did you mean Angstrom or angstrom? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'n11-els-048', 'target': 'N11-ELS-048', 'spec_file': 'of1n1t010_x1d.fits', 'model_file': '/Users/billyli/Documents/BillyJessExploratory/powr-OB-lmc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1245, 1615]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-75, 350], 'drop_species': []}}}
# WARNING: UnitsWarning: 'Angstroms' did not parse as fits unit: At col 0, Unit 'Angstroms' not supported by the FITS standard. Did you mean Angstrom or angstrom? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'n11-els-048', 'target': 'N11-ELS-048', 'spec_file': 'of1n1t020_x1d.fits', 'model_file': '/Users/billyli/Documents/BillyJessExploratory/powr-OB-lmc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1245, 1615]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-75, 350], 'drop_species': []}}}
# WARNING: UnitsWarning: 'Angstroms' did not parse as fits unit: At col 0, Unit 'Angstroms' not supported by the FITS standard. Did you mean Angstrom or angstrom? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]

# %%
reload(cfg)

d = pd.DataFrame({
    'instr': ['COS', 'COS', 'COS', 'COS', 'STIS', 'STIS', 'Gaussian'],
    'gratings': ['G130M', 'G160M', 'G185M', 'G225M', 'E230M', 'E140M', 'N/A'],
    'slits': ['NA', 'NA', 'NA', 'NA', '0.2x0.2', '0.2x0.06', 'NA'],
    'lsfranges': [[1100, 1460], [1400, 1800], [1800, 2100], [2100, 2278], [1607, 3129], [1144, 1729], [899, 1191]],
    'lps': ['1', '1', '1', '1', '1', '1', 'NA'],
    'cen_wave': ['1291', '1611', '1953', '2250', '1978', '1425', 'NA'],
    'pixel_scales': [None, None, None, None, None, None, 0.013], 
    'fwhms': [None, None, None, None, None, None, 0.02]
})

num = 5

cfg.lsfs = []
for col in ['instr', 'gratings', 'slits', 'cen_wave', 'pixel_scales', 'fwhms']:
    setattr(cfg, col, [d.at[num, col]])

cfg.lsfranges = np.array([d.at[num, 'lsfranges']])

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_model = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))[0]
    continuumfit = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))[0]

    utils.pyigm_to_veeper(igm_model, continuumfit)

    os.chdir(base_directory)

os.chdir(notebook_directory)
# Out:
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    component_groups_dir = os.path.join(current_directory, "component_groups")
    output_dir = os.path.join(current_directory, "modified_component_groups")

    if os.path.exists(output_dir):
        shutil.rmtree(output_dir)
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    mc_lines_file = "/Users/billyli/Documents/float-for-morrow/LMC/lmc_e140m.txt"
    mc_lines_df = pd.read_csv(mc_lines_file, sep = r"\s+", header = None, names = ["line", "wavelength"])
    mc_lines_df["wavelength"] = mc_lines_df["wavelength"].astype(float)

    def is_valid_line(row, line_df):
        trans = row["trans"].strip()
        restwave = row["restwave"]
        matching_lines = line_df[line_df["line"] == trans]
        for wave in matching_lines["wavelength"]:
            if 0.999 * wave <= restwave <= 1.001 * wave:
                return True
        return False

    input_files = glob.glob(os.path.join(component_groups_dir, "*.txt"))

    for file in input_files:
        df = pd.read_csv(file, sep = "|")
        df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    
        df["restwave"] = pd.to_numeric(df["restwave"], errors = "coerce")
        df["bval"] = pd.to_numeric(df["bval"], errors = "coerce")
    
        valid_mask = df.apply(lambda row: is_valid_line(row, mc_lines_df), axis = 1)
        df_filtered = df[valid_mask].copy()
    
        # df_filtered["col"] = df_filtered["col"] - 0.2
        df_filtered["bval"] = df_filtered["bval"] / 2
    
        output_file = os.path.join(output_dir, os.path.basename(file))
        df_filtered.to_csv(output_file, sep = "|", index = False)
        # print(f"Processed file: {os.path.basename(file)} -> {output_file}")

# %%
# Before fitting, should manually adjust the input group files

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_models = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))
    continuumfits = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))

    component_groups_dir = os.path.join(current_directory, "modified_component_groups")
    
    input_group_files = sorted([f for f in glob.glob(os.path.join(component_groups_dir, "input_group_*.txt")) if re.match(r".*input_group_\d+\.txt$", f)])

    VPmeasure.batch_fit(continuumfits[0], input_group_files, filepath = './modified_component_groups/')

    os.chdir(base_directory)

os.chdir(notebook_directory)
# Out:
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 2.7259e+02, final cost 7.4490e+01, first-order optimality 8.08e-03.
#
# Fit results:
#
# 1608.45	 0.000930	 15.249	 19.290	 -1.0721
#  	  	  	 0.122	 1.363	 0.956
#
# 1611.2	 0.000930	 15.249	 19.290	 -1.0721
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.673937
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 2.7259e+02, final cost 7.4490e+01, first-order optimality 8.08e-03.
#
# Fit results:
#
# 1608.45	 0.000930	 15.249	 19.290	 -1.0721
#  	  	  	 0.122	 1.363	 0.956
#
# 1611.2	 0.000930	 15.249	 19.290	 -1.0721
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.673937
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# joebvp.joebvpfit: No local joebvp_cfg.py found, using default cfg.py file form joebvp.
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 4.4592e+01, final cost 3.2469e+01, first-order optimality 6.49e-03.
#
# Fit results:
#
# 1239.93	 0.000950	 16.201	 13.737	 -2.2978
#  	  	  	 0.049	 2.085	 1.378
#
# 1240.39	 0.000950	 16.201	 13.737	 -2.2978
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.014643
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 4.4592e+01, final cost 3.2469e+01, first-order optimality 6.49e-03.
#
# Fit results:
#
# 1239.93	 0.000950	 16.201	 13.737	 -2.2978
#  	  	  	 0.049	 2.085	 1.378
#
# 1240.39	 0.000950	 16.201	 13.737	 -2.2978
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.014643
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 2.8502e+02, final cost 9.1861e+01, first-order optimality 3.71e-03.
#
# Fit results:
#
# 1250.58	 0.000930	 15.718	 19.450	 -0.98055
#  	  	  	 0.036	 0.799	 0.589
#
# 1253.8	 0.000930	 15.718	 19.450	 -0.98055
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.018917
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 2.8502e+02, final cost 9.1861e+01, first-order optimality 3.71e-03.
#
# Fit results:
#
# 1250.58	 0.000930	 15.718	 19.450	 -0.98055
#  	  	  	 0.036	 0.799	 0.589
#
# 1253.8	 0.000930	 15.718	 19.450	 -0.98055
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.018917
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 2.0680e+02, final cost 1.2095e+02, first-order optimality 2.07e-02.
#
# Fit results:
#
# 1317.22	 0.000950	 13.959	 15.000	 -5.2448
#  	  	  	 0.031	 1.245	 0.902
#
# 1370.13	 0.000950	 13.959	 15.000	 -5.2448
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000950	 13.959	 15.000	 -5.2448
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.573408
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 2.0680e+02, final cost 1.2095e+02, first-order optimality 2.07e-02.
#
# Fit results:
#
# 1317.22	 0.000950	 13.959	 15.000	 -5.2448
#  	  	  	 0.031	 1.245	 0.902
#
# 1370.13	 0.000950	 13.959	 15.000	 -5.2448
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000950	 13.959	 15.000	 -5.2448
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.573408
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M10/modified_component_groups/input_group_3_inspect.fits
#
# VPmeasure: 4/4 fits converged, 0/4 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 2.6923e+02, final cost 8.0729e+01, first-order optimality 3.18e-02.
#
# Fit results:
#
# 1608.45	 0.000900	 15.349	 23.210	 -0.2749
#  	  	  	 0.131	 1.77	 1.244
#
# 1611.2	 0.000900	 15.349	 23.210	 -0.2749
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.523187
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 2.6923e+02, final cost 8.0729e+01, first-order optimality 3.18e-02.
#
# Fit results:
#
# 1608.45	 0.000900	 15.349	 23.210	 -0.2749
#  	  	  	 0.131	 1.77	 1.244
#
# 1611.2	 0.000900	 15.349	 23.210	 -0.2749
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.523187
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 5.4437e+01, final cost 3.6734e+01, first-order optimality 2.06e-03.
#
# Fit results:
#
# 1239.93	 0.000930	 16.472	 6.3581	 3.4811
#  	  	  	 0.307	 2.324	 1.393
#
# 1240.39	 0.000930	 16.472	 6.3581	 3.4811
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.184965
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 5.4437e+01, final cost 3.6734e+01, first-order optimality 2.06e-03.
#
# Fit results:
#
# 1239.93	 0.000930	 16.472	 6.3581	 3.4811
#  	  	  	 0.307	 2.324	 1.393
#
# 1240.39	 0.000930	 16.472	 6.3581	 3.4811
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.184965
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 4.8591e+02, final cost 7.3566e+01, first-order optimality 6.55e-05.
#
# Fit results:
#
# 1250.58	 0.000950	 15.902	 18.910	 -5.430
#  	  	  	 0.074	 1.192	 0.686
#
# 1253.8	 0.000950	 15.902	 18.910	 -5.430
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.910818
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 4.8591e+02, final cost 7.3566e+01, first-order optimality 6.55e-05.
#
# Fit results:
#
# 1250.58	 0.000950	 15.902	 18.910	 -5.430
#  	  	  	 0.074	 1.192	 0.686
#
# 1253.8	 0.000950	 15.902	 18.910	 -5.430
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.910818
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.7387e+02, final cost 9.6929e+01, first-order optimality 1.12e-03.
#
# Fit results:
#
# 1317.22	 0.000930	 14.094	 15.000	 2.2151
#  	  	  	 0.028	 1.582	 1.005
#
# 1370.13	 0.000930	 14.094	 15.000	 2.2151
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000930	 14.094	 15.000	 2.2151
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.228260
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.7387e+02, final cost 9.6929e+01, first-order optimality 1.12e-03.
#
# Fit results:
#
# 1317.22	 0.000930	 14.094	 15.000	 2.2151
#  	  	  	 0.028	 1.582	 1.005
#
# 1370.13	 0.000930	 14.094	 15.000	 2.2151
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000930	 14.094	 15.000	 2.2151
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.228260
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M20/modified_component_groups/input_group_3_inspect.fits
#
# VPmeasure: 4/4 fits converged, 0/4 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 2.1704e+02, final cost 7.4602e+01, first-order optimality 8.79e-03.
#
# Fit results:
#
# 1608.45	 0.000910	 15.271	 24.660	 -1.5204
#  	  	  	 0.136	 2.12	 1.305
#
# 1611.2	 0.000910	 15.271	 24.660	 -1.5204
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.434649
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 2.1704e+02, final cost 7.4602e+01, first-order optimality 8.79e-03.
#
# Fit results:
#
# 1608.45	 0.000910	 15.271	 24.660	 -1.5204
#  	  	  	 0.136	 2.12	 1.305
#
# 1611.2	 0.000910	 15.271	 24.660	 -1.5204
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.434649
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 5.3756e+01, final cost 4.1810e+01, first-order optimality 3.87e-03.
#
# Fit results:
#
# 1239.93	 0.000920	 16.407	 8.7420	 5.9555
#  	  	  	 0.143	 2.494	 1.486
#
# 1240.39	 0.000920	 16.407	 8.7420	 5.9555
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.145486
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 5.3756e+01, final cost 4.1810e+01, first-order optimality 3.87e-03.
#
# Fit results:
#
# 1239.93	 0.000920	 16.407	 8.7420	 5.9555
#  	  	  	 0.143	 2.494	 1.486
#
# 1240.39	 0.000920	 16.407	 8.7420	 5.9555
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.145486
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 20, initial cost 5.0404e+02, final cost 9.0929e+01, first-order optimality 2.18e-02.
#
# Fit results:
#
# 1250.58	 0.000940	 16.176	 16.073	 -2.2869
#  	  	  	 0.213	 1.72	 0.662
#
# 1253.8	 0.000940	 16.176	 16.073	 -2.2869
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.245156
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 20, initial cost 5.0404e+02, final cost 9.0929e+01, first-order optimality 2.18e-02.
#
# Fit results:
#
# 1250.58	 0.000940	 16.176	 16.073	 -2.2869
#  	  	  	 0.213	 1.72	 0.662
#
# 1253.8	 0.000940	 16.176	 16.073	 -2.2869
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.245156
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.4838e+02, final cost 1.2033e+02, first-order optimality 7.96e-03.
#
# Fit results:
#
# 1317.22	 0.000910	 14.115	 15.000	 5.6893
#  	  	  	 0.029	 1.562	 1.0
#
# 1370.13	 0.000910	 14.115	 15.000	 5.6893
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000910	 14.115	 15.000	 5.6893
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.249249
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.4838e+02, final cost 1.2033e+02, first-order optimality 7.96e-03.
#
# Fit results:
#
# 1317.22	 0.000910	 14.115	 15.000	 5.6893
#  	  	  	 0.029	 1.562	 1.0
#
# 1370.13	 0.000910	 14.115	 15.000	 5.6893
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000910	 14.115	 15.000	 5.6893
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.249249
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M30/modified_component_groups/input_group_3_inspect.fits
#
# VPmeasure: 4/4 fits converged, 0/4 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 3.0457e+02, final cost 6.3804e+01, first-order optimality 6.94e-03.
#
# Fit results:
#
# 1608.45	 0.000930	 15.505	 17.920	 -6.134
#  	  	  	 0.119	 1.077	 1.165
#
# 1611.2	 0.000930	 15.505	 17.920	 -6.134
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.537434
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 3.0457e+02, final cost 6.3804e+01, first-order optimality 6.94e-03.
#
# Fit results:
#
# 1608.45	 0.000930	 15.505	 17.920	 -6.134
#  	  	  	 0.119	 1.077	 1.165
#
# 1611.2	 0.000930	 15.505	 17.920	 -6.134
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.537434
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 5.0624e+01, final cost 3.2328e+01, first-order optimality 2.49e-03.
#
# Fit results:
#
# 1239.93	 0.000940	 17.202	 4.0172	 2.7006
#  	  	  	 3.164	 4.354	 1.488
#
# 1240.39	 0.000940	 17.202	 4.0172	 2.7006
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.077601
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 5.0624e+01, final cost 3.2328e+01, first-order optimality 2.49e-03.
#
# Fit results:
#
# 1239.93	 0.000940	 17.202	 4.0172	 2.7006
#  	  	  	 3.164	 4.354	 1.488
#
# 1240.39	 0.000940	 17.202	 4.0172	 2.7006
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.077601
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 2.8390e+02, final cost 6.9352e+01, first-order optimality 5.17e-02.
#
# Fit results:
#
# 1250.58	 0.000920	 15.998	 17.441	 1.1016
#  	  	  	 0.132	 1.537	 0.737
#
# 1253.8	 0.000920	 15.998	 17.441	 1.1016
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.576185
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 2.8390e+02, final cost 6.9352e+01, first-order optimality 5.17e-02.
#
# Fit results:
#
# 1250.58	 0.000920	 15.998	 17.441	 1.1016
#  	  	  	 0.132	 1.537	 0.737
#
# 1253.8	 0.000920	 15.998	 17.441	 1.1016
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.576185
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.0860e+02, final cost 1.3007e+02, first-order optimality 2.84e-03.
#
# Fit results:
#
# 1317.22	 0.000930	 14.079	 15.000	 0.39956
#  	  	  	 0.031	 1.732	 1.085
#
# 1370.13	 0.000930	 14.079	 15.000	 0.39956
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000930	 14.079	 15.000	 0.39956
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.501423
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.0860e+02, final cost 1.3007e+02, first-order optimality 2.84e-03.
#
# Fit results:
#
# 1317.22	 0.000930	 14.079	 15.000	 0.39956
#  	  	  	 0.031	 1.732	 1.085
#
# 1370.13	 0.000930	 14.079	 15.000	 0.39956
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000930	 14.079	 15.000	 0.39956
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.501423
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M40/modified_component_groups/input_group_3_inspect.fits
#
# VPmeasure: 4/4 fits converged, 0/4 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 2.7643e+02, final cost 5.6076e+01, first-order optimality 2.21e-04.
#
# Fit results:
#
# 1608.45	 0.000920	 15.273	 21.980	 -8.0086
#  	  	  	 0.144	 1.902	 1.221
#
# 1611.2	 0.000920	 15.273	 21.980	 -8.0086
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.232446
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 2.7643e+02, final cost 5.6076e+01, first-order optimality 2.21e-04.
#
# Fit results:
#
# 1608.45	 0.000920	 15.273	 21.980	 -8.0086
#  	  	  	 0.144	 1.902	 1.221
#
# 1611.2	 0.000920	 15.273	 21.980	 -8.0086
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.232446
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 4.1067e+01, final cost 2.8636e+01, first-order optimality 5.04e-03.
#
# Fit results:
#
# 1239.93	 0.000950	 16.311	 6.6097	 -4.6224
#  	  	  	 0.197	 2.393	 1.506
#
# 1240.39	 0.000950	 16.311	 6.6097	 -4.6224
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 0.923743
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 4.1067e+01, final cost 2.8636e+01, first-order optimality 5.04e-03.
#
# Fit results:
#
# 1239.93	 0.000950	 16.311	 6.6097	 -4.6224
#  	  	  	 0.197	 2.393	 1.506
#
# 1240.39	 0.000950	 16.311	 6.6097	 -4.6224
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 0.923743
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 3.4593e+02, final cost 6.8609e+01, first-order optimality 8.80e-03.
#
# Fit results:
#
# 1250.58	 0.000930	 15.862	 21.083	 -2.3393
#  	  	  	 0.051	 1.094	 0.726
#
# 1253.8	 0.000930	 15.862	 21.083	 -2.3393
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.577229
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 3.4593e+02, final cost 6.8609e+01, first-order optimality 8.80e-03.
#
# Fit results:
#
# 1250.58	 0.000930	 15.862	 21.083	 -2.3393
#  	  	  	 0.051	 1.094	 0.726
#
# 1253.8	 0.000930	 15.862	 21.083	 -2.3393
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.577229
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 2.5493e+02, final cost 1.1991e+02, first-order optimality 1.18e-02.
#
# Fit results:
#
# 1317.22	 0.000940	 14.115	 15.000	 -5.5747
#  	  	  	 0.027	 1.51	 0.942
#
# 1370.13	 0.000940	 14.115	 15.000	 -5.5747
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000940	 14.115	 15.000	 -5.5747
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.472276
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 2.5493e+02, final cost 1.1991e+02, first-order optimality 1.18e-02.
#
# Fit results:
#
# 1317.22	 0.000940	 14.115	 15.000	 -5.5747
#  	  	  	 0.027	 1.51	 0.942
#
# 1370.13	 0.000940	 14.115	 15.000	 -5.5747
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000940	 14.115	 15.000	 -5.5747
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.472276
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/N11-ELS-048/E140M/E140M50/modified_component_groups/input_group_3_inspect.fits
#
# VPmeasure: 4/4 fits converged, 0/4 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    df = pd.read_csv('compiledVPoutputs.dat', sep = '|')
    filtered_df = df[df['zsys'] > 0.0002]
    filtered_df = filtered_df[filtered_df['sigcol'] != 0.000]
    result = filtered_df[['col', 'sigcol', 'trans']]

    unique_result = result#.drop_duplicates()
    print(unique_result)
    os.chdir(base_directory)

os.chdir(notebook_directory)
# Out:
#       col  sigcol trans
# 0  15.718   0.036  S II
# 2  13.959   0.031  NiII
# 5  15.249   0.122  FeII
# 7  16.201   0.049  MgII
#       col  sigcol trans
# 0  15.902   0.074  S II
# 2  14.094   0.028  NiII
# 5  15.349   0.131  FeII
# 7  16.472   0.307  MgII
#       col  sigcol trans
# 0  16.176   0.213  S II
# 2  14.115   0.029  NiII
# 5  15.271   0.136  FeII
# 7  16.407   0.143  MgII
#       col  sigcol trans
# 0  15.998   0.132  S II
# 2  14.079   0.031  NiII
# 5  15.505   0.119  FeII
# 7  17.202   3.164  MgII
#       col  sigcol trans
# 0  15.862   0.051  S II
# 2  14.115   0.027  NiII
# 5  15.273   0.144  FeII
# 7  16.311   0.197  MgII

# %%
directories = [d for d in os.listdir(base_directory)
               if os.path.isdir(os.path.join(base_directory, d))]

records = []

for specdir in directories:
    fn = os.path.join(base_directory, specdir, "compiledVPoutputs.dat")
    if not os.path.isfile(fn):
        continue

    df = pd.read_csv(fn, sep = "|")
    df = df[(df["zsys"] > 0.0002) & (df["sigcol"] != 0.0)]
    records.append(df[["trans", "col", "sigcol"]])

all_measurements = pd.concat(records, ignore_index = True)

def random_effects_mean(vals, sigmas):
    vals = np.asarray(vals, dtype = float)
    sigmas = np.asarray(sigmas, dtype = float)
    var = sigmas ** 2

    w  = 1.0 / var
    mu = (w * vals).sum() / w.sum()

    Q  = (w * (vals - mu) ** 2).sum()
    df = len(vals) - 1
    c  = w.sum() - (w ** 2).sum() / w.sum()
    T2 = max(0.0, (Q - df) / c) if c > 0 else 0.0

    w_re = 1.0 / (var + T2)
    mean = (w_re * vals).sum() / w_re.sum()
    std  = np.sqrt(1.0 / w_re.sum())
    return mean, std

combined = (
    all_measurements
    .groupby("trans", sort = True)
    .apply(lambda g: random_effects_mean(g["col"], g["sigcol"]))
    .apply(pd.Series)
    .reset_index()
    .rename(columns = {0: "col_combined", 1: "sigcol_combined"})
)

combined = combined.sort_values("trans").reset_index(drop = True)

for _, row in combined.iterrows():
    print(f"{row.trans}  {row.col_combined:.3f} ± {row.sigcol_combined:.3f}")

output_file = os.path.join(notebook_directory, "abundances_e140m.txt")

with open(output_file, "w") as f:
    for _, row in combined.iterrows():
        f.write(f"{row.trans} {row.col_combined:.3f} {row.sigcol_combined:.3f}\n")
# Out:
# FeII  15.337 ± 0.058
# MgII  16.233 ± 0.045
# NiII  14.073 ± 0.028
# S II  15.867 ± 0.062
# /var/folders/7n/v6gcxcpj68q6nnv2znnc85xc0000gn/T/ipykernel_5484/1251576660.py:38: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: random_effects_mean(g["col"], g["sigcol"]))

# %%
# END
