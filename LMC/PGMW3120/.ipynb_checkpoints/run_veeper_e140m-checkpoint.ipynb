# %%
# Import packages
import os
import re
import sys
import glob
import toml
import shutil
import textwrap
import subprocess

import numpy as np
import pandas as pd

from pathlib import Path
from astropy.io import fits
from importlib import reload
from astropy.table import Table
from scipy.interpolate import interp1d
from joebvp import cfg, utils, VPmeasure
# Out:
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/morton03_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/verner96_tab1.fits.gz
# joebvp.makevoigt: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# joebvp.VPmeasure: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/morton03_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/verner96_tab1.fits.gz
# joebvp.makevoigt: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/joebvp
# joebvp.utils: No local joebvp_cfg.py found, using default cfg.py file from joebvp.

# %%
# Register directories
notebook_directory = Path().resolve()
base_directory = notebook_directory / "E140M"
python_cmd = sys.executable
model_file = "/Users/billyli/Documents/BillyJessExploratory/powr-OB-lmc-vd3.nc"
runner_path = Path("/Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py")

# %% [markdown]
# # Run Kirill's continuum fitting script from scratch
# for fits_path in sorted(base_directory.rglob("*_x1d.fits")):
#
#     dataset = fits_path.stem.replace("_x1d", "")
#     cwd_directory = fits_path.parent
#
#     problem = notebook_directory.name.lower()
#     target = notebook_directory.name.upper()
#
#     spec_file = fits_path.name
#
#     toml_content = textwrap.dedent(f"""
#     [target_info]
#     problem    = "{problem}"
#     target     = "{target}"
#     spec_file  = "{spec_file}"
#     model_file = "{model_file}"
#     instrument = "stis_e140m"
#
#     [include_wave_range]
#     wave_range = [ 1238, 1620,]
#
#     [exclude_wave_ranges]
#
#     [vshift]
#     min = 50
#     max = 550
#     delta = 50
#
#     [vsini]
#     min = 50
#     max = 350
#     delta = 50
#
#     [exclude_vranges.ions]
#     linelist = "ISM"
#     vrange = [-75, 350]
#     drop_species = []
#
#     [target_info.plot_ranges_kwargs.all_merged]
#     color = "gainsboro"
#     """).lstrip()
#
#     tmp_toml = cwd_directory / f"{problem}.toml"
#     tmp_toml.write_text(toml_content)
#
#     subprocess.run([python_cmd, str(runner_path), str(tmp_toml)], check = True, cwd = cwd_directory)
#
#     csv_path = cwd_directory / f"{problem}.csv"
#     model_continuum = Table.read(str(csv_path), format = "csv")
#     original = Table.read(fits_path, hdu = 1)
#
#     wave = model_continuum['wave'].data
#     flux = model_continuum['flux'].data
#     err = model_continuum['err'].data
#     wave_model = model_continuum['wave'].data
#     best_fit_spec = model_continuum['best_fit_spec'].data
#
#     new_hdul = fits.HDUList([fits.PrimaryHDU(), fits.ImageHDU(), fits.ImageHDU(), fits.ImageHDU()])
#     new_hdul[0].data = flux
#     new_hdul[0].header['BITPIX'] = -32
#     new_hdul[0].header['NAXIS'] = 1
#     new_hdul[0].header['NAXIS1'] = len(wave)
#     new_hdul[0].header['EXTNAME'] = 'FLUX    '
#     new_hdul[1].data = err
#     new_hdul[1].header['XTENSION'] = 'IMAGE   '
#     new_hdul[1].header['BITPIX'] = -32
#     new_hdul[1].header['NAXIS'] = 1
#     new_hdul[1].header['NAXIS1'] = len(wave)
#     new_hdul[1].header['PCOUNT'] = 0
#     new_hdul[1].header['GCOUNT'] = 1
#     new_hdul[1].header['EXTNAME'] = 'ERROR   '
#     new_hdul[2].data = wave
#     new_hdul[2].header['XTENSION'] = 'IMAGE   '
#     new_hdul[2].header['BITPIX'] = -64
#     new_hdul[2].header['NAXIS'] = 1
#     new_hdul[2].header['NAXIS1'] = len(wave)
#     new_hdul[2].header['PCOUNT'] = 0
#     new_hdul[2].header['GCOUNT'] = 1
#     new_hdul[2].header['EXTNAME'] = 'WAVELENGTH'
#     new_hdul[3].data = best_fit_spec
#     new_hdul[3].header['XTENSION'] = 'IMAGE   '
#     new_hdul[3].header['BITPIX'] = -32
#     new_hdul[3].header['NAXIS'] = 1
#     new_hdul[3].header['NAXIS1'] = len(wave)
#     new_hdul[3].header['PCOUNT'] = 0
#     new_hdul[3].header['GCOUNT'] = 1
#     new_hdul[3].header['EXTNAME'] = 'CONTINUUM'
#
#     out_path = str(fits_path).replace("_x1d.fits", "_continuumfit.fits")
#     new_hdul.writeto(str(out_path), overwrite = True)

# %%
# Generate terminal commands
directories = sorted([d for d in os.listdir(base_directory) if d.startswith("E140M")])

def replace_string(path, dataset_name):
    segment = """lt_xspec [path][dataset_name]_x1d.fits
cd [path] && lt_continuumfit --redshift 0.00087 [dataset_name]_x1d.fits [dataset_name]_continuumfit_original.fits
cd [path] && pyigm_igmguesses [dataset_name]_continuumfit.fits -o [dataset_name]_x1dfits_model.json
cd [path] && pyigm_fitdla --out_file [dataset_name]_xfitdla.json [dataset_name]_continuumfit.fits 0"""
    modified_segment = segment.replace("[dataset_name]", dataset_name)
    modified_segment = modified_segment.replace("[path]", path)
    print(modified_segment)
    
for subdir in directories:
    path = base_directory / subdir
    for file in os.listdir(path):
        if file.endswith("_x1d.fits"):
            dataset_name = file.replace("_x1d.fits", "")
            path = str(path.resolve()) + "/"
            replace_string(path, dataset_name)
            print("\r")
# Out:
# lt_xspec /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/o5ez01010_x1d.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/ && lt_continuumfit --redshift 0.00087 o5ez01010_x1d.fits o5ez01010_continuumfit_original.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/ && pyigm_igmguesses o5ez01010_continuumfit.fits -o o5ez01010_x1dfits_model.json
# cd /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/ && pyigm_fitdla --out_file o5ez01010_xfitdla.json o5ez01010_continuumfit.fits 0
#
# lt_xspec /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/o5ez01020_x1d.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/ && lt_continuumfit --redshift 0.00087 o5ez01020_x1d.fits o5ez01020_continuumfit_original.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/ && pyigm_igmguesses o5ez01020_continuumfit.fits -o o5ez01020_x1dfits_model.json
# cd /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/ && pyigm_fitdla --out_file o5ez01020_xfitdla.json o5ez01020_continuumfit.fits 0
#
# lt_xspec /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/o5ez01030_x1d.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/ && lt_continuumfit --redshift 0.00087 o5ez01030_x1d.fits o5ez01030_continuumfit_original.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/ && pyigm_igmguesses o5ez01030_continuumfit.fits -o o5ez01030_x1dfits_model.json
# cd /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/ && pyigm_fitdla --out_file o5ez01030_xfitdla.json o5ez01030_continuumfit.fits 0

# %%
# Run Kirill's continuum fitting script to replace standard continuum fit between range
for fits_path in sorted(base_directory.rglob("*_x1d.fits")):
    
    dataset = fits_path.stem.replace("_x1d", "")
    cwd_directory = fits_path.parent

    problem = notebook_directory.name.lower()
    target = notebook_directory.name.upper()

    spec_file = fits_path.name
    
    wave_min = 1245
    wave_max = 1615

    toml_content = textwrap.dedent(f"""
    [target_info]
    problem    = "{problem}"
    target     = "{target}"
    spec_file  = "{spec_file}"
    model_file = "{model_file}"
    instrument = "stis_e140m"

    [include_wave_range]
    wave_range = [ {wave_min}, {wave_max},]

    [exclude_wave_ranges]

    [vshift]
    min = 50
    max = 550
    delta = 50

    [vsini]
    min = 50
    max = 350
    delta = 50

    [exclude_vranges.ions]
    linelist = "ISM"
    vrange = [-75, 350]
    drop_species = []

    [target_info.plot_ranges_kwargs.all_merged]
    color = "gainsboro"
    """).lstrip()

    tmp_toml = cwd_directory / f"{problem}.toml"
    tmp_toml.write_text(toml_content)

    subprocess.run([python_cmd, str(runner_path), str(tmp_toml)], check = True, cwd = cwd_directory)

    csv_path = cwd_directory / f"{problem}.csv"
    model_continuum = Table.read(str(csv_path), format = "csv")
    original = Table.read(fits_path, hdu = 1)

    wave = model_continuum['wave'].data
    flux = model_continuum['flux'].data
    err = model_continuum['err'].data
    wave_model = model_continuum['wave'].data
    best_fit_spec = model_continuum['best_fit_spec'].data

    continuumfit_path = cwd_directory / f"{dataset}_continuumfit_original.fits"
    with fits.open(continuumfit_path, mode = 'readonly') as hdul:
        new_hdul = fits.HDUList([h.copy() for h in hdul])

    flux_original = new_hdul[0].data
    wave_original = new_hdul[2].data
    continuum_hdu = new_hdul[3]
    
    continuum_original = continuum_hdu.data
    
    mask = (wave_original >= wave_min) & (wave_original <= wave_max)
    flux_original_masked = flux_original[mask]

    normalization_factor = flux_original_masked[10000] / flux[10000]
    normalization_factor_2 = flux_original_masked[15000] / flux[15000]
    normalization_factor_3 = flux_original_masked[20000] / flux[20000]

    if not (np.allclose([normalization_factor, normalization_factor_2, normalization_factor_3], normalization_factor, rtol = 0.001)):
        raise ValueError(f"Normalization factors disagree: {normalization_factor:.3f}, {normalization_factor_2:.3f}, {normalization_factor_3:.3f}")
    
    # f = interp1d(wave, best_fit_spec, kind = 'linear') # no need to interp2d
    # continuum_interp_values = f(wave_original[mask]) * normalization_factor

    continuum_hdu.data[mask] = best_fit_spec * normalization_factor # continuum_interp_values

    out_path = str(fits_path).replace("_x1d.fits", "_continuumfit.fits")
    new_hdul.writeto(str(out_path), overwrite = True)
# Out:
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'pgmw3120', 'target': 'PGMW3120', 'spec_file': 'o5ez01010_x1d.fits', 'model_file': '/Users/billyli/Documents/BillyJessExploratory/powr-OB-lmc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1245, 1615]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-75, 350], 'drop_species': []}}}
# WARNING: UnitsWarning: 'Angstroms' did not parse as fits unit: At col 0, Unit 'Angstroms' not supported by the FITS standard. Did you mean Angstrom or angstrom? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'pgmw3120', 'target': 'PGMW3120', 'spec_file': 'o5ez01020_x1d.fits', 'model_file': '/Users/billyli/Documents/BillyJessExploratory/powr-OB-lmc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1245, 1615]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-75, 350], 'drop_species': []}}}
# WARNING: UnitsWarning: 'Angstroms' did not parse as fits unit: At col 0, Unit 'Angstroms' not supported by the FITS standard. Did you mean Angstrom or angstrom? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/float-for-morrow/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'pgmw3120', 'target': 'PGMW3120', 'spec_file': 'o5ez01030_x1d.fits', 'model_file': '/Users/billyli/Documents/BillyJessExploratory/powr-OB-lmc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1245, 1615]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-75, 350], 'drop_species': []}}}
# WARNING: UnitsWarning: 'Angstroms' did not parse as fits unit: At col 0, Unit 'Angstroms' not supported by the FITS standard. Did you mean Angstrom or angstrom? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]

# %%
reload(cfg)

d = pd.DataFrame({
    'instr': ['COS', 'COS', 'COS', 'COS', 'STIS', 'STIS', 'Gaussian'],
    'gratings': ['G130M', 'G160M', 'G185M', 'G225M', 'E230M', 'E140M', 'N/A'],
    'slits': ['NA', 'NA', 'NA', 'NA', '0.2x0.2', '0.2x0.06', 'NA'],
    'lsfranges': [[1100, 1460], [1400, 1800], [1800, 2100], [2100, 2278], [1607, 3129], [1144, 1729], [899, 1191]],
    'lps': ['1', '1', '1', '1', '1', '1', 'NA'],
    'cen_wave': ['1291', '1611', '1953', '2250', '1978', '1425', 'NA'],
    'pixel_scales': [None, None, None, None, None, None, 0.013], 
    'fwhms': [None, None, None, None, None, None, 0.02]
})

num = 5

cfg.lsfs = []
for col in ['instr', 'gratings', 'slits', 'cen_wave', 'pixel_scales', 'fwhms']:
    setattr(cfg, col, [d.at[num, col]])

cfg.lsfranges = np.array([d.at[num, 'lsfranges']])

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_model = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))[0]
    continuumfit = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))[0]

    utils.pyigm_to_veeper(igm_model, continuumfit)

    os.chdir(base_directory)

os.chdir(notebook_directory)
# Out:
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    component_groups_dir = os.path.join(current_directory, "component_groups")
    output_dir = os.path.join(current_directory, "modified_component_groups")

    if os.path.exists(output_dir):
        shutil.rmtree(output_dir)
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    mc_lines_file = "/Users/billyli/Documents/float-for-morrow/LMC/lmc_e140m.txt"
    mc_lines_df = pd.read_csv(mc_lines_file, sep = r"\s+", header = None, names = ["line", "wavelength"])
    mc_lines_df["wavelength"] = mc_lines_df["wavelength"].astype(float)

    def is_valid_line(row, line_df):
        trans = row["trans"].strip()
        restwave = row["restwave"]
        matching_lines = line_df[line_df["line"] == trans]
        for wave in matching_lines["wavelength"]:
            if 0.999 * wave <= restwave <= 1.001 * wave:
                return True
        return False

    input_files = glob.glob(os.path.join(component_groups_dir, "*.txt"))

    for file in input_files:
        df = pd.read_csv(file, sep = "|")
        df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    
        df["restwave"] = pd.to_numeric(df["restwave"], errors = "coerce")
        df["bval"] = pd.to_numeric(df["bval"], errors = "coerce")
    
        valid_mask = df.apply(lambda row: is_valid_line(row, mc_lines_df), axis = 1)
        df_filtered = df[valid_mask].copy()
    
        # df_filtered["col"] = df_filtered["col"] - 0.2
        df_filtered["bval"] = df_filtered["bval"] / 2
    
        output_file = os.path.join(output_dir, os.path.basename(file))
        df_filtered.to_csv(output_file, sep = "|", index = False)
        # print(f"Processed file: {os.path.basename(file)} -> {output_file}")

# %%
# Before fitting, should manually adjust the input group files

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_models = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))
    continuumfits = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))

    component_groups_dir = os.path.join(current_directory, "modified_component_groups")
    
    input_group_files = sorted([f for f in glob.glob(os.path.join(component_groups_dir, "input_group_*.txt")) if re.match(r".*input_group_\d+\.txt$", f)])

    VPmeasure.batch_fit(continuumfits[0], input_group_files, filepath = './modified_component_groups/')

    os.chdir(base_directory)

os.chdir(notebook_directory)
# Out:
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 4.1986e+01, final cost 3.1936e+01, first-order optimality 4.64e-03.
#
# Fit results:
#
# 1239.93	 0.000950	 16.179	 13.044	 -7.3377
#  	  	  	 0.076	 2.607	 1.922
#
# 1240.39	 0.000950	 16.179	 13.044	 -7.3377
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 0.874955
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 4.1986e+01, final cost 3.1936e+01, first-order optimality 4.64e-03.
#
# Fit results:
#
# 1239.93	 0.000950	 16.179	 13.044	 -7.3377
#  	  	  	 0.076	 2.607	 1.922
#
# 1240.39	 0.000950	 16.179	 13.044	 -7.3377
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 0.874955
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# joebvp.joebvpfit: No local joebvp_cfg.py found, using default cfg.py file form joebvp.
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 3.0007e+02, final cost 6.3131e+01, first-order optimality 6.16e-03.
#
# Fit results:
#
# 1250.58	 0.000960	 15.756	 17.416	 -7.4789
#  	  	  	 0.063	 1.129	 0.789
#
# 1253.8	 0.000960	 15.756	 17.416	 -7.4789
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.468171
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 3.0007e+02, final cost 6.3131e+01, first-order optimality 6.16e-03.
#
# Fit results:
#
# 1250.58	 0.000960	 15.756	 17.416	 -7.4789
#  	  	  	 0.063	 1.129	 0.789
#
# 1253.8	 0.000960	 15.756	 17.416	 -7.4789
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.468171
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 4.4593e+02, final cost 1.0009e+02, first-order optimality 1.44e-02.
#
# Fit results:
#
# 1608.45	 0.000860	 15.173	 25.370	 9.4446
#  	  	  	 0.125	 2.418	 1.352
#
# 1611.2	 0.000860	 15.173	 25.370	 9.4446
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.853540
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 4.4593e+02, final cost 1.0009e+02, first-order optimality 1.44e-02.
#
# Fit results:
#
# 1608.45	 0.000860	 15.173	 25.370	 9.4446
#  	  	  	 0.125	 2.418	 1.352
#
# 1611.2	 0.000860	 15.173	 25.370	 9.4446
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.853540
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 9.4561e+01, final cost 7.6157e+01, first-order optimality 2.39e-03.
#
# Fit results:
#
# 1317.22	 0.000920	 13.966	 16.450	 -0.691
#  	  	  	 0.045	 2.061	 1.482
#
# 1370.13	 0.000920	 13.966	 16.450	 -0.691
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000920	 13.966	 16.450	 -0.691
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.508055
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 9.4561e+01, final cost 7.6157e+01, first-order optimality 2.39e-03.
#
# Fit results:
#
# 1317.22	 0.000920	 13.966	 16.450	 -0.691
#  	  	  	 0.045	 2.061	 1.482
#
# 1370.13	 0.000920	 13.966	 16.450	 -0.691
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000920	 13.966	 16.450	 -0.691
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.508055
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M10/modified_component_groups/input_group_3_inspect.fits
#
# VPmeasure: 4/4 fits converged, 0/4 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 4.9376e+01, final cost 4.8606e+01, first-order optimality 1.82e-03.
#
# Fit results:
#
# 1239.93	 0.000920	 16.440	 8.1023	 0.89048
#  	  	  	 0.235	 3.177	 1.767
#
# 1240.39	 0.000920	 16.440	 8.1023	 0.89048
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.331663
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 4.9376e+01, final cost 4.8606e+01, first-order optimality 1.82e-03.
#
# Fit results:
#
# 1239.93	 0.000920	 16.440	 8.1023	 0.89048
#  	  	  	 0.235	 3.177	 1.767
#
# 1240.39	 0.000920	 16.440	 8.1023	 0.89048
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.331663
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 24, initial cost 3.9201e+02, final cost 6.7107e+01, first-order optimality 1.10e-02.
#
# Fit results:
#
# 1250.58	 0.000940	 19.685	 6.7207	 -1.0279
#  	  	  	 0.15	 0.64	 1.048
#
# 1253.8	 0.000940	 19.685	 6.7207	 -1.0279
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.743029
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 24, initial cost 3.9201e+02, final cost 6.7107e+01, first-order optimality 1.10e-02.
#
# Fit results:
#
# 1250.58	 0.000940	 19.685	 6.7207	 -1.0279
#  	  	  	 0.15	 0.64	 1.048
#
# 1253.8	 0.000940	 19.685	 6.7207	 -1.0279
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.743029
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 3.9122e+02, final cost 7.0641e+01, first-order optimality 5.18e-03.
#
# Fit results:
#
# 1608.45	 0.000850	 15.319	 25.460	 11.716
#  	  	  	 0.138	 2.208	 1.404
#
# 1611.2	 0.000850	 15.319	 25.460	 11.716
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.261447
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 3.9122e+02, final cost 7.0641e+01, first-order optimality 5.18e-03.
#
# Fit results:
#
# 1608.45	 0.000850	 15.319	 25.460	 11.716
#  	  	  	 0.138	 2.208	 1.404
#
# 1611.2	 0.000850	 15.319	 25.460	 11.716
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.261447
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 9.8980e+01, final cost 6.3960e+01, first-order optimality 1.50e-03.
#
# Fit results:
#
# 1317.22	 0.000910	 14.068	 12.270	 7.5117
#  	  	  	 0.043	 2.099	 1.273
#
# 1370.13	 0.000910	 14.068	 12.270	 7.5117
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000910	 14.068	 12.270	 7.5117
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.218284
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 9.8980e+01, final cost 6.3960e+01, first-order optimality 1.50e-03.
#
# Fit results:
#
# 1317.22	 0.000910	 14.068	 12.270	 7.5117
#  	  	  	 0.043	 2.099	 1.273
#
# 1370.13	 0.000910	 14.068	 12.270	 7.5117
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000910	 14.068	 12.270	 7.5117
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.218284
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M20/modified_component_groups/input_group_3_inspect.fits
#
# VPmeasure: 4/4 fits converged, 0/4 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 4.3681e+01, final cost 3.6249e+01, first-order optimality 2.46e-02.
#
# Fit results:
#
# 1239.93	 0.000910	 17.499	 4.0000	 6.3632
#  	  	  	 8.897	 10.522	 1.832
#
# 1240.39	 0.000910	 17.499	 4.0000	 6.3632
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.035685
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 4.3681e+01, final cost 3.6249e+01, first-order optimality 2.46e-02.
#
# Fit results:
#
# 1239.93	 0.000910	 17.499	 4.0000	 6.3632
#  	  	  	 8.897	 10.522	 1.832
#
# 1240.39	 0.000910	 17.499	 4.0000	 6.3632
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.035685
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 4.3250e+02, final cost 8.9456e+01, first-order optimality 1.82e-02.
#
# Fit results:
#
# 1250.58	 0.000940	 16.074	 15.000	 -2.8884
#  	  	  	 0.256	 2.135	 0.893
#
# 1253.8	 0.000940	 16.074	 15.000	 -2.8884
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.631058
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 4.3250e+02, final cost 8.9456e+01, first-order optimality 1.82e-02.
#
# Fit results:
#
# 1250.58	 0.000940	 16.074	 15.000	 -2.8884
#  	  	  	 0.256	 2.135	 0.893
#
# 1253.8	 0.000940	 16.074	 15.000	 -2.8884
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.631058
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 2.1856e+02, final cost 7.2680e+01, first-order optimality 3.19e-03.
#
# Fit results:
#
# 1608.45	 0.000890	 15.453	 22.411	 1.2126
#  	  	  	 0.117	 1.466	 1.381
#
# 1611.2	 0.000890	 15.453	 22.411	 1.2126
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.483256
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 2.1856e+02, final cost 7.2680e+01, first-order optimality 3.19e-03.
#
# Fit results:
#
# 1608.45	 0.000890	 15.453	 22.411	 1.2126
#  	  	  	 0.117	 1.466	 1.381
#
# 1611.2	 0.000890	 15.453	 22.411	 1.2126
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.483256
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 6.8848e+01, final cost 4.4178e+01, first-order optimality 1.46e-05.
#
# Fit results:
#
# 1317.22	 0.000950	 14.017	 15.000	 -3.8974
#  	  	  	 0.04	 2.502	 1.544
#
# 1370.13	 0.000950	 14.017	 15.000	 -3.8974
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000950	 14.017	 15.000	 -3.8974
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 0.960392
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 6.8848e+01, final cost 4.4178e+01, first-order optimality 1.46e-05.
#
# Fit results:
#
# 1317.22	 0.000950	 14.017	 15.000	 -3.8974
#  	  	  	 0.04	 2.502	 1.544
#
# 1370.13	 0.000950	 14.017	 15.000	 -3.8974
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000950	 14.017	 15.000	 -3.8974
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 0.960392
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/PGMW3120/E140M/E140M30/modified_component_groups/input_group_3_inspect.fits
#
# VPmeasure: 4/4 fits converged, 0/4 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    df = pd.read_csv('compiledVPoutputs.dat', sep = '|')
    filtered_df = df[df['zsys'] > 0.0002]
    filtered_df = filtered_df[filtered_df['sigcol'] != 0.000]
    result = filtered_df[['col', 'sigcol', 'trans']]

    unique_result = result#.drop_duplicates()
    print(unique_result)
    os.chdir(base_directory)

os.chdir(notebook_directory)
# Out:
#       col  sigcol trans
# 0  15.173   0.125  FeII
# 2  13.966   0.045  NiII
# 5  16.179   0.076  MgII
# 7  15.756   0.063  S II
#       col  sigcol trans
# 0  15.319   0.138  FeII
# 2  14.068   0.043  NiII
# 5  16.440   0.235  MgII
# 7  19.685   0.150  S II
#       col  sigcol trans
# 0  15.453   0.117  FeII
# 2  14.017   0.040  NiII
# 5  17.499   8.897  MgII
# 7  16.074   0.256  S II

# %%
directories = [d for d in os.listdir(base_directory)
               if os.path.isdir(os.path.join(base_directory, d))]

records = []

for specdir in directories:
    fn = os.path.join(base_directory, specdir, "compiledVPoutputs.dat")
    if not os.path.isfile(fn):
        continue

    df = pd.read_csv(fn, sep = "|")
    df = df[(df["zsys"] > 0.0002) & (df["sigcol"] != 0.0)]
    records.append(df[["trans", "col", "sigcol"]])

all_measurements = pd.concat(records, ignore_index = True)

def random_effects_mean(vals, sigmas):
    vals = np.asarray(vals, dtype = float)
    sigmas = np.asarray(sigmas, dtype = float)
    var = sigmas ** 2

    w  = 1.0 / var
    mu = (w * vals).sum() / w.sum()

    Q  = (w * (vals - mu) ** 2).sum()
    df = len(vals) - 1
    c  = w.sum() - (w ** 2).sum() / w.sum()
    T2 = max(0.0, (Q - df) / c) if c > 0 else 0.0

    w_re = 1.0 / (var + T2)
    mean = (w_re * vals).sum() / w_re.sum()
    std  = np.sqrt(1.0 / w_re.sum())
    return mean, std

combined = (
    all_measurements
    .groupby("trans", sort = True)
    .apply(lambda g: random_effects_mean(g["col"], g["sigcol"]))
    .apply(pd.Series)
    .reset_index()
    .rename(columns = {0: "col_combined", 1: "sigcol_combined"})
)

combined = combined.sort_values("trans").reset_index(drop = True)

for _, row in combined.iterrows():
    print(f"{row.trans}  {row.col_combined:.3f} ± {row.sigcol_combined:.3f}")

output_file = os.path.join(notebook_directory, "abundances_e140m.txt")

with open(output_file, "w") as f:
    for _, row in combined.iterrows():
        f.write(f"{row.trans} {row.col_combined:.3f} {row.sigcol_combined:.3f}\n")
# Out:
# FeII  15.320 ± 0.084
# MgII  16.204 ± 0.072
# NiII  14.018 ± 0.028
# S II  17.173 ± 1.391
# /var/folders/7n/v6gcxcpj68q6nnv2znnc85xc0000gn/T/ipykernel_1422/1251576660.py:38: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: random_effects_mean(g["col"], g["sigcol"]))

# %%
# END
