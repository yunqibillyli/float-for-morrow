# %%
import os
import re
import glob
import numpy as np
import pandas as pd

from importlib import reload
from joebvp import cfg, utils, VPmeasure
# Out:
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/morton03_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/verner96_tab1.fits.gz
# joebvp.makevoigt: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# joebvp.VPmeasure: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/morton03_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/verner96_tab1.fits.gz
# joebvp.makevoigt: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/joebvp
# joebvp.utils: No local joebvp_cfg.py found, using default cfg.py file from joebvp.

# %%
def replace_string(dataset_name):
    segment = """lt_xspec [dataset_name]_x1d.fits 
lt_continuumfit --redshift 0.0009 [dataset_name]_x1d.fits [dataset_name]_continuumfit.fits
pyigm_igmguesses [dataset_name]_continuumfit.fits -o [dataset_name]_x1dfits_model.json
pyigm_fitdla --out_file [dataset_name]_xfitdla.json [dataset_name]_continuumfit.fits 0"""
    modified_segment = segment.replace("[dataset_name]", dataset_name)
    print(modified_segment)
    
replace_string("o5ez01030")
# Out:
# lt_xspec o5ez01030_x1d.fits
# lt_continuumfit --redshift 0.0009 o5ez01030_x1d.fits o5ez01030_continuumfit.fits
# pyigm_igmguesses o5ez01030_continuumfit.fits -o o5ez01030_x1dfits_model.json
# pyigm_fitdla --out_file o5ez01030_xfitdla.json o5ez01030_continuumfit.fits 0

# %%
reload(cfg)

d = pd.DataFrame({
    'instr': ['COS', 'COS', 'COS', 'COS', 'STIS', 'STIS', 'Gaussian'],
    'gratings': ['G130M', 'G160M', 'G185M', 'G225M', 'E230M', 'E140M', 'N/A'],
    'slits': ['NA', 'NA', 'NA', 'NA', '0.2x0.2', '0.2x0.2', 'NA'],
    'lsfranges': [[1100, 1460], [1460, 1800], [1800, 2100], [2100, 2278], [1607, 3129], [1144, 1729], [899, 1191]],
    'lps': ['1', '1', '1', '1', '1', '1', 'NA'],
    'cen_wave': ['1327', '1600', '1953', '2250', '1978', '1425', 'NA'],
    'pixel_scales': [None, None, None, None, None, None, 0.013], 
    'fwhms': [None, None, None, None, None, None, 0.02]
})

num = 4

cfg.lsfs = []
for col in ['instr', 'gratings', 'slits', 'cen_wave', 'pixel_scales', 'fwhms']:
    setattr(cfg, col, [d.at[num, col]])

cfg.lsfranges = np.array([d.at[num, 'lsfranges']])

# %%
base_directory = "/Users/billyli/Documents/float-for-morrow/PGMW3120/E230M"
directories = sorted([d for d in os.listdir(base_directory) if d.startswith("E230M")])

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_model = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))[0]
    continuumfit = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))[0]

    utils.pyigm_to_veeper(igm_model, continuumfit)

    os.chdir(base_directory)
# Out:
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    component_groups_dir = os.path.join(current_directory, "component_groups")
    output_dir = os.path.join(current_directory, "modified_component_groups")

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    mc_lines_file = "/Users/billyli/Documents/float-for-morrow/mc_lines_metal_e230m.txt"
    mc_lines_df = pd.read_csv(mc_lines_file, sep = r"\s+", header = None, names = ["line", "wavelength"])
    mc_lines_df["wavelength"] = mc_lines_df["wavelength"].astype(float)

    def is_valid_line(row, line_df):
        trans = row["trans"].strip()
        restwave = row["restwave"]
        matching_lines = line_df[line_df["line"] == trans]
        for wave in matching_lines["wavelength"]:
            if 0.99 * wave <= restwave <= 1.01 * wave:
                return True
        return False

    input_files = glob.glob(os.path.join(component_groups_dir, "*.txt"))

    for file in input_files:
        df = pd.read_csv(file, sep = "|")
        df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    
        df["restwave"] = pd.to_numeric(df["restwave"], errors = "coerce")
        df["bval"] = pd.to_numeric(df["bval"], errors = "coerce")
    
        valid_mask = df.apply(lambda row: is_valid_line(row, mc_lines_df), axis = 1)
        df_filtered = df[valid_mask].copy()

        # df_filtered["col"] = df_filtered["col"] - 0.2
        df_filtered["bval"] = df_filtered["bval"] / 2
    
        output_file = os.path.join(output_dir, os.path.basename(file))
        df_filtered.to_csv(output_file, sep = "|", index = False)
        # print(f"Processed file: {os.path.basename(file)} -> {output_file}")

# %%
# Before fitting, should manually adjust the input group files

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_models = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))
    continuumfits = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))

    component_groups_dir = os.path.join(current_directory, "modified_component_groups")
    
    input_group_files = sorted([f for f in glob.glob(os.path.join(component_groups_dir, "input_group_*.txt")) if re.match(r".*input_group_\d+\.txt$", f)])

    VPmeasure.batch_fit(continuumfits[0], input_group_files, filepath = './modified_component_groups/')

    os.chdir(base_directory)
# Out:
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 9.4384e+01, final cost 4.5678e+01, first-order optimality 4.67e-04.
#
# Fit results:
#
# 2249.88	 0.000940	 15.198	 15.000	 -5.2355
#  	  	  	 0.035	 1.671	 1.109
#
# 2260.78	 0.000940	 15.198	 15.000	 -5.2355
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.661017
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 9.4384e+01, final cost 4.5678e+01, first-order optimality 4.67e-04.
#
# Fit results:
#
# 2249.88	 0.000940	 15.198	 15.000	 -5.2355
#  	  	  	 0.035	 1.671	 1.109
#
# 2260.78	 0.000940	 15.198	 15.000	 -5.2355
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.661017
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# joebvp.joebvpfit: No local joebvp_cfg.py found, using default cfg.py file form joebvp.
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 7.6474e+01, final cost 7.6196e+01, first-order optimality 9.10e-03.
#
# Fit results:
#
# 1703.41	 0.000960	 14.198	 4.0000	 0.48021
#  	  	  	 0.381	 2.219	 1.628
#
# 1709.6	 0.000960	 14.198	 4.0000	 0.48021
#  	  	  	 0.0	 0.0	 0.0
#
# 1741.55	 0.000960	 14.198	 4.0000	 0.48021
#  	  	  	 0.0	 0.0	 0.0
#
# 1751.92	 0.000960	 14.198	 4.0000	 0.48021
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.199933
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 7.6474e+01, final cost 7.6196e+01, first-order optimality 9.10e-03.
#
# Fit results:
#
# 1703.41	 0.000960	 14.198	 4.0000	 0.48021
#  	  	  	 0.381	 2.219	 1.628
#
# 1709.6	 0.000960	 14.198	 4.0000	 0.48021
#  	  	  	 0.0	 0.0	 0.0
#
# 1741.55	 0.000960	 14.198	 4.0000	 0.48021
#  	  	  	 0.0	 0.0	 0.0
#
# 1751.92	 0.000960	 14.198	 4.0000	 0.48021
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.199933
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.8167e+01, final cost 1.6468e+01, first-order optimality 1.80e-03.
#
# Fit results:
#
# 1808.01	 0.000950	 15.989	 11.249	 -6.244
#  	  	  	 0.331	 3.598	 1.632
#
#
# Reduced chi-squared: 1.135751
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.8167e+01, final cost 1.6468e+01, first-order optimality 1.80e-03.
#
# Fit results:
#
# 1808.01	 0.000950	 15.989	 11.249	 -6.244
#  	  	  	 0.331	 3.598	 1.632
#
#
# Reduced chi-squared: 1.135751
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 3.5117e+01, final cost 1.8343e+01, first-order optimality 1.17e-03.
#
# Fit results:
#
# 2062.66	 0.000950	 13.272	 13.238	 -4.3549
#  	  	  	 0.057	 2.38	 1.582
#
#
# Reduced chi-squared: 1.667530
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 3.5117e+01, final cost 1.8343e+01, first-order optimality 1.17e-03.
#
# Fit results:
#
# 2062.66	 0.000950	 13.272	 13.238	 -4.3549
#  	  	  	 0.057	 2.38	 1.582
#
#
# Reduced chi-squared: 1.667530
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 1.2238e+02, final cost 9.9248e+01, first-order optimality 7.43e-03.
#
# Fit results:
#
# 2056.26	 0.000950	 13.232	 6.8030	 -7.6403
#  	  	  	 0.069	 2.487	 1.307
#
# 2062.23	 0.000950	 13.232	 6.8030	 -7.6403
#  	  	  	 0.0	 0.0	 0.0
#
# 2066.16	 0.000950	 13.232	 6.8030	 -7.6403
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.481205
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 1.2238e+02, final cost 9.9248e+01, first-order optimality 7.43e-03.
#
# Fit results:
#
# 2056.26	 0.000950	 13.232	 6.8030	 -7.6403
#  	  	  	 0.069	 2.487	 1.307
#
# 2062.23	 0.000950	 13.232	 6.8030	 -7.6403
#  	  	  	 0.0	 0.0	 0.0
#
# 2066.16	 0.000950	 13.232	 6.8030	 -7.6403
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.481205
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_4.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_4_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_4_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 8.2368e+01, final cost 7.3702e+01, first-order optimality 5.72e-03.
#
# Fit results:
#
# 2056.26	 0.000940	 13.236	 6.4822	 -5.1094
#  	  	  	 0.07	 2.461	 1.265
#
# 2062.23	 0.000940	 13.236	 6.4822	 -5.1094
#  	  	  	 0.0	 0.0	 0.0
#
# 2066.16	 0.000940	 13.236	 6.4822	 -5.1094
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.842538
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 8.2368e+01, final cost 7.3702e+01, first-order optimality 5.72e-03.
#
# Fit results:
#
# 2056.26	 0.000940	 13.236	 6.4822	 -5.1094
#  	  	  	 0.07	 2.461	 1.265
#
# 2062.23	 0.000940	 13.236	 6.4822	 -5.1094
#  	  	  	 0.0	 0.0	 0.0
#
# 2066.16	 0.000940	 13.236	 6.4822	 -5.1094
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.842538
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_5.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_5.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_5_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M10/modified_component_groups/input_group_5_inspect.fits
#
# VPmeasure: 6/6 fits converged, 0/6 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 8.4085e+01, final cost 4.9875e+01, first-order optimality 1.65e-03.
#
# Fit results:
#
# 2249.88	 0.000900	 15.337	 16.490	 1.8779
#  	  	  	 0.037	 1.986	 1.367
#
# 2260.78	 0.000900	 15.337	 16.490	 1.8779
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.445649
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 8.4085e+01, final cost 4.9875e+01, first-order optimality 1.65e-03.
#
# Fit results:
#
# 2249.88	 0.000900	 15.337	 16.490	 1.8779
#  	  	  	 0.037	 1.986	 1.367
#
# 2260.78	 0.000900	 15.337	 16.490	 1.8779
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.445649
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 7.3306e+01, final cost 6.6881e+01, first-order optimality 9.63e-04.
#
# Fit results:
#
# 1703.41	 0.000970	 14.306	 15.000	 -7.2173
#  	  	  	 0.091	 4.639	 2.878
#
# 1709.6	 0.000970	 14.306	 15.000	 -7.2173
#  	  	  	 0.0	 0.0	 0.0
#
# 1741.55	 0.000970	 14.306	 15.000	 -7.2173
#  	  	  	 0.0	 0.0	 0.0
#
# 1751.92	 0.000970	 14.306	 15.000	 -7.2173
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.194303
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 7.3306e+01, final cost 6.6881e+01, first-order optimality 9.63e-04.
#
# Fit results:
#
# 1703.41	 0.000970	 14.306	 15.000	 -7.2173
#  	  	  	 0.091	 4.639	 2.878
#
# 1709.6	 0.000970	 14.306	 15.000	 -7.2173
#  	  	  	 0.0	 0.0	 0.0
#
# 1741.55	 0.000970	 14.306	 15.000	 -7.2173
#  	  	  	 0.0	 0.0	 0.0
#
# 1751.92	 0.000970	 14.306	 15.000	 -7.2173
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.194303
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 32, initial cost 1.9194e+01, final cost 1.5558e+01, first-order optimality 1.48e-03.
#
# Fit results:
#
# 1808.01	 0.000780	 15.547	 15.000	 18.590
#  	  	  	 0.145	 10.215	 6.451
#
#
# Reduced chi-squared: 1.152429
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 32, initial cost 1.9194e+01, final cost 1.5558e+01, first-order optimality 1.48e-03.
#
# Fit results:
#
# 1808.01	 0.000780	 15.547	 15.000	 18.590
#  	  	  	 0.145	 10.215	 6.451
#
#
# Reduced chi-squared: 1.152429
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 2.7460e+01, final cost 1.7962e+01, first-order optimality 2.24e-03.
#
# Fit results:
#
# 2062.66	 0.000930	 13.696	 6.1422	 2.7506
#  	  	  	 1.006	 4.998	 1.61
#
#
# Reduced chi-squared: 1.496864
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 2.7460e+01, final cost 1.7962e+01, first-order optimality 2.24e-03.
#
# Fit results:
#
# 2062.66	 0.000930	 13.696	 6.1422	 2.7506
#  	  	  	 1.006	 4.998	 1.61
#
#
# Reduced chi-squared: 1.496864
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 2.6635e+01, final cost 1.6998e+01, first-order optimality 4.98e-04.
#
# Fit results:
#
# 2062.66	 0.000930	 14.055	 5.0307	 0.28344
#  	  	  	 11.661	 21.318	 3.31
#
#
# Reduced chi-squared: 1.478117
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 2.6635e+01, final cost 1.6998e+01, first-order optimality 4.98e-04.
#
# Fit results:
#
# 2062.66	 0.000930	 14.055	 5.0307	 0.28344
#  	  	  	 11.661	 21.318	 3.31
#
#
# Reduced chi-squared: 1.478117
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_4.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_4_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LH10-3020/E230M/E230M20/modified_component_groups/input_group_4_inspect.fits
#
# VPmeasure: 5/5 fits converged, 0/5 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Problems lie in the column densities and b values
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/isgm/abscomponent.py:201: UserWarning: The line measurements for the lines in this component may not be consistent with one another.
#   warnings.warn('The line measurements for the lines in this component'
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    df = pd.read_csv('compiledVPoutputs.dat', sep = '|')
    filtered_df = df[df['zsys'] > 0.0004]
    filtered_df = filtered_df[filtered_df['sigcol'] != 0.000]
    result = filtered_df[['col', 'sigcol', 'trans']]

    unique_result = result.drop_duplicates()
    print(unique_result)
    os.chdir(base_directory)
# Out:
#        col  sigcol trans
# 0   15.989   0.331  SiII
# 1   13.272   0.057  ZnII
# 2   13.232   0.069  CrII
# 5   15.198   0.035  FeII
# 7   14.198   0.381  NiII
# 11  13.236   0.070  CrII
#       col  sigcol trans
# 0  15.547   0.145  SiII
# 1  13.696   1.006  ZnII
# 2  14.055  11.661  ZnII
# 3  15.337   0.037  FeII
# 5  14.306   0.091  NiII

# %% [markdown]
# for spectra_directory in directories:
#
#     current_directory = os.path.join(base_directory, spectra_directory)
#     component_groups_dir = os.path.join(current_directory, "modified_component_groups")
#
#     os.chdir(component_groups_dir)
#
#     vp_files = glob.glob("*.VP")
#     vp_files.sort()
#
#     with open("all.VP", 'w') as outfile:
#         for i, vp_file in enumerate(vp_files):
#             with open(vp_file, 'r') as infile:
#                 lines = infile.readlines()
#                 if i > 1:
#                     lines = lines[1:]
#                 outfile.writelines(lines)
#
#     os.chdir(base_directory)

# %% [markdown]
# for spectra_directory in directories:
#
#     current_directory = os.path.join(base_directory, spectra_directory)
#
#     os.chdir(current_directory)
#
#     igm_models = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))
#     continuumfits = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))
#
#     component_groups_dir = os.path.join(current_directory, "modified_component_groups")
#
#     input_group_files = sorted([f for f in glob.glob(os.path.join(component_groups_dir, "input_group_*.txt")) if re.match(r".*input_group_\d+\.txt$", f)])
#
#     print(continuumfits[0])
#     print(input_group_files[0])
#
#     VPmeasure.go(continuumfits[0], input_group_files[0])
#
#     # VPmeasure.batch_fit(continuumfits[0], input_group_files, filepath = './modified_component_groups/')
#
#     os.chdir(base_directory)

# %%
# END
