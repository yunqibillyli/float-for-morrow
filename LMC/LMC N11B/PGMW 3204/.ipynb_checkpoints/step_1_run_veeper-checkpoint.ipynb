# %%
use_powr = "All" # "All", "STIS", "COS", "None"

# %%
import os
import re
import sys
import glob
import toml
import shutil
import textwrap
import subprocess

import numpy as np
import pandas as pd

from pathlib import Path
from astropy.io import fits
from importlib import reload
from astropy.table import Table
from scipy.interpolate import interp1d
from joebvp import cfg, utils, VPmeasure
# Out:
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/morton03_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/verner96_tab1.fits.gz
# joebvp.makevoigt: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# joebvp.VPmeasure: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/morton03_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/verner96_tab1.fits.gz
# joebvp.makevoigt: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/joebvp
# joebvp.utils: No local joebvp_cfg.py found, using default cfg.py file from joebvp.

# %%
target_directory = Path().resolve()
spectra_directories = sorted([d for d in os.listdir(target_directory) if d.startswith("G") or d.startswith("E")])
galaxy = target_directory.parts[target_directory.parts.index('float-for-morrow') + 1]
print(spectra_directories)
print(galaxy)
python_cmd = sys.executable
if galaxy == "LMC":
    model_file = "/Users/billyli/Documents/stellar template fitting/powr-OB-lmc-vd3.nc"
elif galaxy == "SMC":
    model_file = "/Users/billyli/Documents/stellar template fitting/powr-OB-smc-vd3.nc"
else:
    use_powr = "None"
runner_path = "/Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py"
# Out:
# ['E140M_1425_0.2x0.2_2176.200_16815', 'E140M_1425_0.2x0.2_2548.198_16815', 'E140M_1425_0.2x0.2_2548.199_16815']
# LMC

# %%
def parse_directory(dirname):

    Target = target_directory.name

    parts = dirname.split("_")

    Grating = parts[0]
    Cenwave = int(parts[1])
    T_exp = str(parts[3])
    PID = int(parts[4])

    if Grating.startswith("G"):
        
        Instrument = "COS"
        LP = parts[2]

        return {
            "Target": Target, 
            "Instrument": Instrument, 
            "Grating": Grating, 
            "Cenwave": Cenwave, 
            "LP": LP, 
            "Aperture": None, 
            "T_exp": T_exp, 
            "PID": PID, 
        }
        
    else:
        
        Instrument = "STIS"
        Aperture = parts[2]
        return {
            "Target": Target, 
            "Instrument": Instrument, 
            "Grating": Grating, 
            "Cenwave": Cenwave, 
            "LP": None, 
            "Aperture": Aperture, 
            "T_exp": T_exp, 
            "PID": PID, 
        }

records = [parse_directory(d) for d in spectra_directories]
df = pd.DataFrame.from_records(records)
display(df)
# Out:
#       Target Instrument Grating  Cenwave    LP Aperture     T_exp    PID
# 0  PGMW 3204       STIS   E140M     1425  None  0.2x0.2  2176.200  16815
# 1  PGMW 3204       STIS   E140M     1425  None  0.2x0.2  2548.198  16815
# 2  PGMW 3204       STIS   E140M     1425  None  0.2x0.2  2548.199  16815

# %%
if galaxy == "LMC":
    guess_redshift = 0.00087
elif galaxy == "SMC":
    guess_redshift = 0.00053

def generate_command_continuumfit_cos(path, dataset_name):
    segment = f"""cd "[path]" && lt_continuumfit --redshift {guess_redshift} [dataset_name]_x1dsum.fits [dataset_name]_continuumfit_manual.fits"""
    modified_segment = segment.replace("[dataset_name]", dataset_name)
    modified_segment = modified_segment.replace("[path]", path)
    print(modified_segment)

def generate_command_continuumfit_stis(path, dataset_name):
    segment = f"""cd "[path]" && lt_continuumfit --redshift {guess_redshift} [dataset_name]_x1d.fits [dataset_name]_continuumfit_manual.fits"""
    modified_segment = segment.replace("[dataset_name]", dataset_name)
    modified_segment = modified_segment.replace("[path]", path)
    print(modified_segment)
    
for directory in spectra_directories:
    path = target_directory / directory
    for file in os.listdir(path):
        if file.endswith("_x1dsum.fits"):
            dataset_name = file.replace("_x1dsum.fits", "")
            path = str(path) + "/"
            generate_command_continuumfit_cos(path, dataset_name)
            print("\r")
        elif file.endswith("_x1d.fits"):
            dataset_name = file.replace("_x1d.fits", "")
            path = str(path) + "/"
            generate_command_continuumfit_stis(path, dataset_name)
            print("\r")
# Out:
# cd "/Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/" && lt_continuumfit --redshift 0.00087 of1n1t010_x1d.fits of1n1t010_continuumfit_manual.fits
#
# cd "/Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815//" && lt_continuumfit --redshift 0.00087 of1n1s010_x1d.fits of1n1s010_continuumfit_manual.fits
#
# cd "/Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/" && lt_continuumfit --redshift 0.00087 of1n1s020_x1d.fits of1n1s020_continuumfit_manual.fits
#
# cd "/Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/" && lt_continuumfit --redshift 0.00087 of1n1s030_x1d.fits of1n1s030_continuumfit_manual.fits
#
# cd "/Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815//" && lt_continuumfit --redshift 0.00087 of1n1t020_x1d.fits of1n1t020_continuumfit_manual.fits

# %%
for i in range(len(spectra_directories)):

    directory = spectra_directories[i]
    path = target_directory / directory
    Instrument = df.iloc[i]["Instrument"]

    if Instrument == "COS" and (use_powr == "All" or use_powr == "COS"):

        for file in os.listdir(path):

            Grating = df.iloc[i]["Grating"]
            
            if file.endswith("_continuumfit_manual.fits") and Grating == "G130M":

                dataset_name = file.replace("_continuumfit_manual.fits", "")
                subdir = path / dataset_name
                subdir.mkdir(exist_ok = True)
                src = path / file
                dst = subdir / f"{dataset_name}_continuumfit.fits"

                problem = df.iloc[i]["Target"].lower()
                target = df.iloc[i]["Target"].upper()
            
                spec_file = src
                
                wave_min = 1135
                wave_max = 1420
            
                toml_content = textwrap.dedent(f"""
                [target_info]
                problem    = "{problem}"
                target     = "{target}"
                spec_file  = "{spec_file}"
                model_file = "{model_file}"
                instrument = "cos_g130m"
            
                [include_wave_range]
                wave_range = [ {wave_min}, {wave_max},]
            
                [exclude_wave_ranges]
                dla = [[1180, 1250,] ]
                gap = [[1270, 1290,], [1424, 1425,]]
            
                [vshift]
                min = 50
                max = 550
                delta = 50
            
                [vsini]
                min = 50
                max = 350
                delta = 50
            
                [exclude_vranges.ions]
                linelist = "ISM"
                vrange = [-75, 350]
                drop_species = []
            
                [target_info.plot_ranges_kwargs.all_merged]
                color = "gainsboro"
                """).lstrip()

                tmp_toml = subdir / f"{problem}.toml"
                tmp_toml.write_text(toml_content)
            
                subprocess.run([python_cmd, runner_path, str(tmp_toml)], check = True, cwd = subdir)
            
                csv_path = subdir / f"{problem}.csv"
                model_continuum = Table.read(str(csv_path), format = "csv")
            
                wave = model_continuum['wave'].data
                flux = model_continuum['flux'].data
                err = model_continuum['err'].data
                wave_model = model_continuum['wave'].data
                best_fit_spec = model_continuum['best_fit_spec'].data
            
                with fits.open(src, mode = 'readonly') as hdul:
                    new_hdul = fits.HDUList([h.copy() for h in hdul])
            
                flux_original = new_hdul[0].data
                wave_original = new_hdul[2].data
                continuum_hdu = new_hdul[3]
                
                continuum_original = continuum_hdu.data
                
                mask = (wave_original >= wave_min) & (wave_original <= wave_max)
                flux_original_masked = flux_original[mask]
            
                normalization_factor = flux_original_masked[1000] / flux[1000]
                normalization_factor_2 = flux_original_masked[1500] / flux[1500]
                normalization_factor_3 = flux_original_masked[2000] / flux[2000]
            
                if not (np.allclose([normalization_factor, normalization_factor_2, normalization_factor_3], normalization_factor, rtol = 0.001)):
                    raise ValueError(f"Normalization factors disagree: {normalization_factor:.3f}, {normalization_factor_2:.3f}, {normalization_factor_3:.3f}")
            
                continuum_hdu.data[mask] = best_fit_spec * normalization_factor
            
                new_hdul.writeto(str(dst), overwrite = True)

            if file.endswith("_continuumfit_manual.fits") and Grating == "G160M":

                dataset_name = file.replace("_continuumfit_manual.fits", "")
                subdir = path / dataset_name
                subdir.mkdir(exist_ok = True)
                src = path / file
                dst = subdir / f"{dataset_name}_continuumfit.fits"

                problem = df.iloc[i]["Target"].lower()
                target = df.iloc[i]["Target"].upper()
            
                spec_file = src
                
                wave_min = 1400
                wave_max = 1800
            
                toml_content = textwrap.dedent(f"""
                [target_info]
                problem    = "{problem}"
                target     = "{target}"
                spec_file  = "{spec_file}"
                model_file = "{model_file}"
                instrument = "cos_g160m"
            
                [include_wave_range]
                wave_range = [ {wave_min}, {wave_max},]
            
                [exclude_wave_ranges]
            
                [vshift]
                min = 50
                max = 550
                delta = 50
            
                [vsini]
                min = 50
                max = 350
                delta = 50
            
                [exclude_vranges.ions]
                linelist = "ISM"
                vrange = [-75, 350]
                drop_species = []
            
                [target_info.plot_ranges_kwargs.all_merged]
                color = "gainsboro"
                """).lstrip()

                tmp_toml = subdir / f"{problem}.toml"
                tmp_toml.write_text(toml_content)
            
                subprocess.run([python_cmd, runner_path, str(tmp_toml)], check = True, cwd = subdir)
            
                csv_path = subdir / f"{problem}.csv"
                model_continuum = Table.read(str(csv_path), format = "csv")
            
                wave = model_continuum['wave'].data
                flux = model_continuum['flux'].data
                err = model_continuum['err'].data
                wave_model = model_continuum['wave'].data
                best_fit_spec = model_continuum['best_fit_spec'].data
            
                with fits.open(src, mode = 'readonly') as hdul:
                    new_hdul = fits.HDUList([h.copy() for h in hdul])
            
                flux_original = new_hdul[0].data
                wave_original = new_hdul[2].data
                continuum_hdu = new_hdul[3]
                
                continuum_original = continuum_hdu.data
                
                mask = (wave_original >= wave_min) & (wave_original <= wave_max)
                flux_original_masked = flux_original[mask]
            
                normalization_factor = flux_original_masked[1000] / flux[1000]
                normalization_factor_2 = flux_original_masked[1500] / flux[1500]
                normalization_factor_3 = flux_original_masked[2000] / flux[2000]
            
                if not (np.allclose([normalization_factor, normalization_factor_2, normalization_factor_3], normalization_factor, rtol = 0.001)):
                    raise ValueError(f"Normalization factors disagree: {normalization_factor:.3f}, {normalization_factor_2:.3f}, {normalization_factor_3:.3f}")
            
                continuum_hdu.data[mask] = best_fit_spec * normalization_factor
            
                new_hdul.writeto(str(dst), overwrite = True)

            if file.endswith("_continuumfit_manual.fits") and Grating == "G185M":

                dataset_name = file.replace("_continuumfit_manual.fits", "")
                subdir = path / dataset_name
                subdir.mkdir(exist_ok = True)
                src = path / file
                dst = subdir / f"{dataset_name}_continuumfit.fits"
                
                problem = df.iloc[i]["Target"].lower()
                target = df.iloc[i]["Target"].upper()
            
                spec_file = src
                
                wave_min = 1800
                wave_max = 2100
            
                toml_content = textwrap.dedent(f"""
                [target_info]
                problem    = "{problem}"
                target     = "{target}"
                spec_file  = "{spec_file}"
                model_file = "{model_file}"
                instrument = "cos_g185m"
            
                [include_wave_range]
                wave_range = [ {wave_min}, {wave_max},]
            
                [exclude_wave_ranges]
                dla = [[1200, 1220,] ]
                gap = [[1270, 1290,] ]
            
                [vshift]
                min = 50
                max = 550
                delta = 50
            
                [vsini]
                min = 50
                max = 350
                delta = 50
            
                [exclude_vranges.ions]
                linelist = "ISM"
                vrange = [-75, 350]
                drop_species = []
            
                [target_info.plot_ranges_kwargs.all_merged]
                color = "gainsboro"
                """).lstrip()

                tmp_toml = subdir / f"{problem}.toml"
                tmp_toml.write_text(toml_content)
            
                subprocess.run([python_cmd, runner_path, str(tmp_toml)], check = True, cwd = subdir)
            
                csv_path = subdir / f"{problem}.csv"
                model_continuum = Table.read(str(csv_path), format = "csv")
            
                wave = model_continuum['wave'].data
                flux = model_continuum['flux'].data
                err = model_continuum['err'].data
                wave_model = model_continuum['wave'].data
                best_fit_spec = model_continuum['best_fit_spec'].data
            
                with fits.open(src, mode = 'readonly') as hdul:
                    new_hdul = fits.HDUList([h.copy() for h in hdul])
            
                flux_original = new_hdul[0].data
                wave_original = new_hdul[2].data
                continuum_hdu = new_hdul[3]
                
                continuum_original = continuum_hdu.data
                
                mask = (wave_original >= wave_min) & (wave_original <= wave_max)
                flux_original_masked = flux_original[mask]
            
                normalization_factor = flux_original_masked[1000] / flux[1000]
                normalization_factor_2 = flux_original_masked[1500] / flux[1500]
                normalization_factor_3 = flux_original_masked[2000] / flux[2000]
            
                if not (np.allclose([normalization_factor, normalization_factor_2, normalization_factor_3], normalization_factor, rtol = 0.001)):
                    raise ValueError(f"Normalization factors disagree: {normalization_factor:.3f}, {normalization_factor_2:.3f}, {normalization_factor_3:.3f}")
            
                continuum_hdu.data[mask] = best_fit_spec * normalization_factor
            
                new_hdul.writeto(str(dst), overwrite = True)
                
    if Instrument == "STIS" and (use_powr == "All" or use_powr == "STIS"):

        for file in os.listdir(path):

            Grating = df.iloc[i]["Grating"]
            
            if file.endswith("_continuumfit_manual.fits") and Grating == "E140M":

                dataset_name = file.replace("_continuumfit_manual.fits", "")
                subdir = path / dataset_name
                subdir.mkdir(exist_ok = True)
                src = path / file
                dst = subdir / f"{dataset_name}_continuumfit.fits"

                problem = df.iloc[i]["Target"].lower()
                target = df.iloc[i]["Target"].upper()
            
                spec_file = src
                
                wave_min = 1250
                wave_max = 1650
            
                toml_content = textwrap.dedent(f"""
                [target_info]
                problem    = "{problem}"
                target     = "{target}"
                spec_file  = "{spec_file}"
                model_file = "{model_file}"
                instrument = "stis_e140m"
            
                [include_wave_range]
                wave_range = [ {wave_min}, {wave_max},]
            
                [exclude_wave_ranges]
                big_abs = [[1530, 1555,] ]
            
                [vshift]
                min = 50
                max = 550
                delta = 50
            
                [vsini]
                min = 50
                max = 350
                delta = 50
            
                [exclude_vranges.ions]
                linelist = "ISM"
                vrange = [-75, 350]
                drop_species = []
            
                [target_info.plot_ranges_kwargs.all_merged]
                color = "gainsboro"
                """).lstrip()

                tmp_toml = subdir / f"{problem}.toml"
                tmp_toml.write_text(toml_content)
            
                subprocess.run([python_cmd, runner_path, str(tmp_toml)], check = True, cwd = subdir)
            
                csv_path = subdir / f"{problem}.csv"
                model_continuum = Table.read(str(csv_path), format = "csv")
            
                wave = model_continuum['wave'].data
                flux = model_continuum['flux'].data
                err = model_continuum['err'].data
                wave_model = model_continuum['wave'].data
                best_fit_spec = model_continuum['best_fit_spec'].data
            
                with fits.open(src, mode = 'readonly') as hdul:
                    new_hdul = fits.HDUList([h.copy() for h in hdul])
            
                flux_original = new_hdul[0].data
                wave_original = new_hdul[2].data
                continuum_hdu = new_hdul[3]
                
                continuum_original = continuum_hdu.data
                
                mask = (wave_original >= wave_min) & (wave_original <= wave_max)
                flux_original_masked = flux_original[mask]
            
                normalization_factor = flux_original_masked[1000] / flux[1000]
                normalization_factor_2 = flux_original_masked[1500] / flux[1500]
                normalization_factor_3 = flux_original_masked[2000] / flux[2000]
            
                if not (np.allclose([normalization_factor, normalization_factor_2, normalization_factor_3], normalization_factor, rtol = 0.001)):
                    raise ValueError(f"Normalization factors disagree: {normalization_factor:.3f}, {normalization_factor_2:.3f}, {normalization_factor_3:.3f}")
            
                continuum_hdu.data[mask] = best_fit_spec * normalization_factor
            
                new_hdul.writeto(str(dst), overwrite = True)

            if file.endswith("_continuumfit_manual.fits") and Grating == "E230M":

                dataset_name = file.replace("_continuumfit_manual.fits", "")
                subdir = path / dataset_name
                subdir.mkdir(exist_ok = True)
                src = path / file
                dst = subdir / f"{dataset_name}_continuumfit.fits"

                problem = df.iloc[i]["Target"].lower()
                target = df.iloc[i]["Target"].upper()
            
                spec_file = src
                
                wave_min = 1600
                wave_max = 3100
            
                toml_content = textwrap.dedent(f"""
                [target_info]
                problem    = "{problem}"
                target     = "{target}"
                spec_file  = "{spec_file}"
                model_file = "{model_file}"
                instrument = "stis_e230m"
            
                [include_wave_range]
                wave_range = [ {wave_min}, {wave_max},]
            
                [exclude_wave_ranges]
            
                [vshift]
                min = 50
                max = 550
                delta = 50
            
                [vsini]
                min = 50
                max = 350
                delta = 50
            
                [exclude_vranges.ions]
                linelist = "ISM"
                vrange = [-75, 350]
                drop_species = []
            
                [target_info.plot_ranges_kwargs.all_merged]
                color = "gainsboro"
                """).lstrip()

                tmp_toml = subdir / f"{problem}.toml"
                tmp_toml.write_text(toml_content)
            
                subprocess.run([python_cmd, runner_path, str(tmp_toml)], check = True, cwd = subdir)
            
                csv_path = subdir / f"{problem}.csv"
                model_continuum = Table.read(str(csv_path), format = "csv")
            
                wave = model_continuum['wave'].data
                flux = model_continuum['flux'].data
                err = model_continuum['err'].data
                wave_model = model_continuum['wave'].data
                best_fit_spec = model_continuum['best_fit_spec'].data
            
                with fits.open(src, mode = 'readonly') as hdul:
                    new_hdul = fits.HDUList([h.copy() for h in hdul])
            
                flux_original = new_hdul[0].data
                wave_original = new_hdul[2].data
                continuum_hdu = new_hdul[3]
                
                continuum_original = continuum_hdu.data
                
                mask = (wave_original >= wave_min) & (wave_original <= wave_max)
                flux_original_masked = flux_original[mask]
            
                normalization_factor = flux_original_masked[1000] / flux[1000]
                normalization_factor_2 = flux_original_masked[1500] / flux[1500]
                normalization_factor_3 = flux_original_masked[2000] / flux[2000]
            
                if not (np.allclose([normalization_factor, normalization_factor_2, normalization_factor_3], normalization_factor, rtol = 0.001)):
                    raise ValueError(f"Normalization factors disagree: {normalization_factor:.3f}, {normalization_factor_2:.3f}, {normalization_factor_3:.3f}")
            
                continuum_hdu.data[mask] = best_fit_spec * normalization_factor
            
                new_hdul.writeto(str(dst), overwrite = True)

    else: 

        for file in os.listdir(path):
            if file.endswith("_continuumfit_manual.fits"):
                
                dataset_name = file.replace("_continuumfit_manual.fits", "")
                subdir = path / dataset_name
                subdir.mkdir(exist_ok = True)
                src = path / file
                dst = subdir / f"{dataset_name}_continuumfit.fits"
                shutil.copy(src, dst)
# Out:
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/trf_linear.py:116: RuntimeWarning: invalid value encountered in multiply
#   r_h = p_h + r_h * r_stride
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'pgmw 3204', 'target': 'PGMW 3204', 'spec_file': '/Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-lmc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1250, 1650]}, 'exclude_wave_ranges': {'big_abs': [[1530, 1555]]}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-75, 350], 'drop_species': []}}}
# Bad METADATA;  proceeding without
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/trf_linear.py:116: RuntimeWarning: invalid value encountered in multiply
#   r_h = p_h + r_h * r_stride
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'pgmw 3204', 'target': 'PGMW 3204', 'spec_file': '/Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1s010_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-lmc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1250, 1650]}, 'exclude_wave_ranges': {'big_abs': [[1530, 1555]]}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-75, 350], 'drop_species': []}}}
# Bad METADATA;  proceeding without
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'pgmw 3204', 'target': 'PGMW 3204', 'spec_file': '/Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-lmc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1250, 1650]}, 'exclude_wave_ranges': {'big_abs': [[1530, 1555]]}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-75, 350], 'drop_species': []}}}
# Bad METADATA;  proceeding without
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'pgmw 3204', 'target': 'PGMW 3204', 'spec_file': '/Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-lmc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1250, 1650]}, 'exclude_wave_ranges': {'big_abs': [[1530, 1555]]}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-75, 350], 'drop_species': []}}}
# Bad METADATA;  proceeding without
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'pgmw 3204', 'target': 'PGMW 3204', 'spec_file': '/Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-lmc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1250, 1650]}, 'exclude_wave_ranges': {'big_abs': [[1530, 1555]]}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-75, 350], 'drop_species': []}}}
# Bad METADATA;  proceeding without

# %%
def generate_command_igmguesses_cos(path, dataset_name):
    segment = f"""cd "[path]" && pyigm_igmguesses [dataset_name]_continuumfit.fits -o [dataset_name]_x1dfits_model.json"""
    modified_segment = segment.replace("[dataset_name]", dataset_name)
    modified_segment = modified_segment.replace("[path]", path)
    print(modified_segment)

def generate_command_igmguesses_stis(path, dataset_name):
    segment = f"""cd "[path]" && pyigm_igmguesses [dataset_name]_continuumfit.fits -o [dataset_name]_x1dfits_model.json"""
    modified_segment = segment.replace("[dataset_name]", dataset_name)
    modified_segment = modified_segment.replace("[path]", path)
    print(modified_segment)


target_directory = Path().resolve()
spectra_directories = sorted([d for d in os.listdir(target_directory) if d.startswith("G") or d.startswith("E")])

for directory in spectra_directories:
    path = target_directory / directory
    for subdir in os.listdir(path):
        subdir_path = path / subdir
        if not subdir_path.is_dir():
            continue
        for file in os.listdir(subdir_path):
            file_path = subdir_path / file
            if file.endswith("_continuumfit.fits"):
                dataset_name = file.replace("_continuumfit.fits", "")
                generate_command_igmguesses_cos(str(subdir_path) + "/", dataset_name)
                print("\r")
# Out:
# cd "/Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1s010/" && pyigm_igmguesses of1n1s010_continuumfit.fits -o of1n1s010_x1dfits_model.json
#
# cd "/Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/" && pyigm_igmguesses of1n1t010_continuumfit.fits -o of1n1t010_x1dfits_model.json
#
# cd "/Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/" && pyigm_igmguesses of1n1s020_continuumfit.fits -o of1n1s020_x1dfits_model.json
#
# cd "/Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/" && pyigm_igmguesses of1n1s030_continuumfit.fits -o of1n1s030_x1dfits_model.json
#
# cd "/Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/" && pyigm_igmguesses of1n1t020_continuumfit.fits -o of1n1t020_x1dfits_model.json

# %%
for i in range(len(spectra_directories)):

    directory = spectra_directories[i]
    path = target_directory / directory

    os.chdir(path)
    
    Instrument = df.iloc[i]["Instrument"]
    Grating = df.iloc[i]["Grating"]
    Cenwave = str(df.iloc[i]["Cenwave"])
    if Instrument == "COS":
        LP = str(df.iloc[i]["LP"].lstrip("LP"))
        Aperture = "NA"
    elif Instrument == "STIS":
        LP = "NA"
        Aperture = df.iloc[i]["Aperture"]

    if Grating == "G130M":
        LSF_Ranges = [1100, 1460]
    elif Grating == "G160M":
        LSF_Ranges = [1400, 1800]
    elif Grating == "G185M":
        LSF_Ranges = [1800, 2100]
    elif Grating == "E140M":
        LSF_Ranges = [1144, 1729]
    elif Grating == "E230M":
        LSF_Ranges = [1607, 3129]

    for subdir in os.listdir(path):
        
        subdir_path = path / subdir
        if not subdir_path.is_dir():
            continue
        os.chdir(subdir_path)
    
        igm_model = glob.glob(os.path.join(subdir_path, "*_x1dfits_model.json"))[0]
        continuumfit = glob.glob(os.path.join(subdir_path, "*_continuumfit.fits"))[0]
    
        utils.pyigm_to_veeper(igm_model, continuumfit)

        component_groups_dir = os.path.join(subdir_path, "component_groups")
        output_dir = os.path.join(subdir_path, "modified_component_groups")
    
        if os.path.exists(output_dir):
            shutil.rmtree(output_dir)
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
    
        mc_lines_file = os.path.join(str(target_directory.parent.parent), f"{Grating}.txt")
        mc_lines_df = pd.read_csv(mc_lines_file, sep = r"\s+", header = None, names = ["line", "wavelength"])
        mc_lines_df["wavelength"] = mc_lines_df["wavelength"].astype(float)
    
        def is_valid_line(row, line_df):
            trans = row["trans"].strip()
            restwave = row["restwave"]
            matching_lines = line_df[line_df["line"] == trans]
            for wave in matching_lines["wavelength"]:
                if wave <= restwave <= 1.001 * wave:
                    return True
            return False
    
        input_files = glob.glob(os.path.join(component_groups_dir, "*.txt"))
    
        for file in input_files:
            df_component = pd.read_csv(file, sep = "|")
            df_component = df_component.loc[:, ~df_component.columns.str.contains('^Unnamed')]
        
            df_component["restwave"] = pd.to_numeric(df_component["restwave"], errors = "coerce")
            df_component["bval"] = pd.to_numeric(df_component["bval"], errors = "coerce")
        
            valid_mask = df_component.apply(lambda row: is_valid_line(row, mc_lines_df), axis = 1)
            df_component_filtered = df_component[valid_mask].copy()
        
            df_component_filtered["bval"] = df_component_filtered["bval"]
        
            output_file = os.path.join(output_dir, os.path.basename(file))
            df_component_filtered.to_csv(output_file, sep = "|", index = False)
    
        input_group_files = sorted([f for f in glob.glob(os.path.join(output_dir, "input_group_*.txt")) if re.match(r".*input_group_\d+\.txt$", f)])
        
        reload(cfg)
        cfg.lsfs = []
        if Instrument == "COS":
            setattr(cfg, 'lps', [LP])
        elif Instrument == "STIS":
            setattr(cfg, 'slits', [Aperture])
        for entry, col in [[Instrument, 'instr'], [Grating, 'gratings'], [Cenwave, 'cen_wave'], [None, 'pixel_scales'], [None, 'fwhms']]:
            setattr(cfg, col, [entry])
        cfg.lsfranges = np.array([LSF_Ranges])
        
        VPmeasure.batch_fit(continuumfit, input_group_files, filepath = './modified_component_groups/')
# Out:
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 7.3726e+01, final cost 4.3747e+01, first-order optimality 5.18e-03.
#
# Fit results:
#
# 1608.45	 0.000920	 14.955	 27.370	 -5.1573
#  	  	  	 0.062	 1.948	 1.277
#
# 1611.2	 0.000920	 14.955	 27.370	 -5.1573
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.232308
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 7.3726e+01, final cost 4.3747e+01, first-order optimality 5.18e-03.
#
# Fit results:
#
# 1608.45	 0.000920	 14.955	 27.370	 -5.1573
#  	  	  	 0.062	 1.948	 1.277
#
# 1611.2	 0.000920	 14.955	 27.370	 -5.1573
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.232308
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1s010/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1s010/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1s010/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1s010/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 3.4046e+01, final cost 3.3273e+01, first-order optimality 1.41e-02.
#
# Fit results:
#
# 1239.93	 0.000930	 16.085	 11.798	 0.29946
#  	  	  	 0.059	 1.971	 1.378
#
# 1240.39	 0.000930	 16.085	 11.798	 0.29946
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.056281
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 3.4046e+01, final cost 3.3273e+01, first-order optimality 1.41e-02.
#
# Fit results:
#
# 1239.93	 0.000930	 16.085	 11.798	 0.29946
#  	  	  	 0.059	 1.971	 1.378
#
# 1240.39	 0.000930	 16.085	 11.798	 0.29946
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.056281
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1s010/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1s010/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1s010/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1s010/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 7.3772e+01, final cost 6.6682e+01, first-order optimality 1.25e-02.
#
# Fit results:
#
# 1250.58	 0.000930	 15.741	 17.604	 -0.22708
#  	  	  	 0.048	 0.864	 0.589
#
# 1253.8	 0.000930	 15.741	 17.604	 -0.22708
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.802204
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 7.3772e+01, final cost 6.6682e+01, first-order optimality 1.25e-02.
#
# Fit results:
#
# 1250.58	 0.000930	 15.741	 17.604	 -0.22708
#  	  	  	 0.048	 0.864	 0.589
#
# 1253.8	 0.000930	 15.741	 17.604	 -0.22708
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.802204
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1s010/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1s010/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1s010/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1s010/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 2.0855e+02, final cost 1.2388e+02, first-order optimality 6.54e-03.
#
# Fit results:
#
# 1317.22	 0.000960	 14.037	 20.000	 -9.7949
#  	  	  	 0.028	 1.548	 1.107
#
# 1370.13	 0.000960	 14.037	 20.000	 -9.7949
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000960	 14.037	 20.000	 -9.7949
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.382307
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 2.0855e+02, final cost 1.2388e+02, first-order optimality 6.54e-03.
#
# Fit results:
#
# 1317.22	 0.000960	 14.037	 20.000	 -9.7949
#  	  	  	 0.028	 1.548	 1.107
#
# 1370.13	 0.000960	 14.037	 20.000	 -9.7949
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000960	 14.037	 20.000	 -9.7949
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.382307
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1s010/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1s010/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1s010/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1s010/modified_component_groups/input_group_3_inspect.fits
#
# VPmeasure: 4/4 fits converged, 0/4 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 9.2415e+01, final cost 5.2258e+01, first-order optimality 2.16e-02.
#
# Fit results:
#
# 1608.45	 0.000880	 14.927	 31.871	 9.4117
#  	  	  	 0.043	 2.1	 1.527
#
# 1611.2	 0.000880	 14.927	 31.871	 9.4117
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.357352
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 9.2415e+01, final cost 5.2258e+01, first-order optimality 2.16e-02.
#
# Fit results:
#
# 1608.45	 0.000880	 14.927	 31.871	 9.4117
#  	  	  	 0.043	 2.1	 1.527
#
# 1611.2	 0.000880	 14.927	 31.871	 9.4117
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.357352
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 4.4239e+01, final cost 2.4680e+01, first-order optimality 3.25e-03.
#
# Fit results:
#
# 1239.93	 0.000930	 16.243	 5.5875	 5.5867
#  	  	  	 0.121	 1.231	 0.762
#
# 1240.39	 0.000930	 16.243	 5.5875	 5.5867
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 0.881419
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 4.4239e+01, final cost 2.4680e+01, first-order optimality 3.25e-03.
#
# Fit results:
#
# 1239.93	 0.000930	 16.243	 5.5875	 5.5867
#  	  	  	 0.121	 1.231	 0.762
#
# 1240.39	 0.000930	 16.243	 5.5875	 5.5867
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 0.881419
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 6.5563e+01, final cost 4.9382e+01, first-order optimality 6.07e-03.
#
# Fit results:
#
# 1250.58	 0.000030	 15.528	 15.568	 0.29247
#  	  	  	 0.037	 0.829	 0.578
#
# 1253.8	 0.000030	 15.528	 15.568	 0.29247
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.431373
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 6.5563e+01, final cost 4.9382e+01, first-order optimality 6.07e-03.
#
# Fit results:
#
# 1250.58	 0.000030	 15.528	 15.568	 0.29247
#  	  	  	 0.037	 0.829	 0.578
#
# 1253.8	 0.000030	 15.528	 15.568	 0.29247
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.431373
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 1.0193e+02, final cost 4.5392e+01, first-order optimality 1.23e-02.
#
# Fit results:
#
# 1250.58	 0.000910	 15.692	 19.172	 4.3502
#  	  	  	 0.036	 0.838	 0.631
#
# 1253.8	 0.000910	 15.692	 19.172	 4.3502
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.335053
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 1.0193e+02, final cost 4.5392e+01, first-order optimality 1.23e-02.
#
# Fit results:
#
# 1250.58	 0.000910	 15.692	 19.172	 4.3502
#  	  	  	 0.036	 0.838	 0.631
#
# 1253.8	 0.000910	 15.692	 19.172	 4.3502
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.335053
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 1.7133e+02, final cost 1.1067e+02, first-order optimality 2.35e-03.
#
# Fit results:
#
# 1317.22	 0.000930	 14.030	 20.000	 -4.0202
#  	  	  	 0.028	 1.565	 1.106
#
# 1370.13	 0.000930	 14.030	 20.000	 -4.0202
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000930	 14.030	 20.000	 -4.0202
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.354710
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 1.7133e+02, final cost 1.1067e+02, first-order optimality 2.35e-03.
#
# Fit results:
#
# 1317.22	 0.000930	 14.030	 20.000	 -4.0202
#  	  	  	 0.028	 1.565	 1.106
#
# 1370.13	 0.000930	 14.030	 20.000	 -4.0202
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000930	 14.030	 20.000	 -4.0202
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.354710
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_4.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_4_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2176.200_16815/of1n1t010/modified_component_groups/input_group_4_inspect.fits
#
# VPmeasure: 5/5 fits converged, 0/5 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 8.6457e+01, final cost 4.5807e+01, first-order optimality 3.79e-03.
#
# Fit results:
#
# 1608.45	 0.000900	 14.998	 29.373	 -1.4521
#  	  	  	 0.06	 2.028	 1.215
#
# 1611.2	 0.000900	 14.998	 29.373	 -1.4521
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.205437
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 8.6457e+01, final cost 4.5807e+01, first-order optimality 3.79e-03.
#
# Fit results:
#
# 1608.45	 0.000900	 14.998	 29.373	 -1.4521
#  	  	  	 0.06	 2.028	 1.215
#
# 1611.2	 0.000900	 14.998	 29.373	 -1.4521
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.205437
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 3.5401e+01, final cost 3.4946e+01, first-order optimality 3.72e-03.
#
# Fit results:
#
# 1239.93	 0.000940	 16.066	 9.8279	 0.66504
#  	  	  	 0.057	 1.692	 1.144
#
# 1240.39	 0.000940	 16.066	 9.8279	 0.66504
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.058964
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 3.5401e+01, final cost 3.4946e+01, first-order optimality 3.72e-03.
#
# Fit results:
#
# 1239.93	 0.000940	 16.066	 9.8279	 0.66504
#  	  	  	 0.057	 1.692	 1.144
#
# 1240.39	 0.000940	 16.066	 9.8279	 0.66504
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.058964
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 9.1141e+01, final cost 6.5970e+01, first-order optimality 1.77e-03.
#
# Fit results:
#
# 1250.58	 0.000050	 15.558	 14.436	 -1.7891
#  	  	  	 0.04	 0.732	 0.501
#
# 1253.8	 0.000050	 15.558	 14.436	 -1.7891
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.858323
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 9.1141e+01, final cost 6.5970e+01, first-order optimality 1.77e-03.
#
# Fit results:
#
# 1250.58	 0.000050	 15.558	 14.436	 -1.7891
#  	  	  	 0.04	 0.732	 0.501
#
# 1253.8	 0.000050	 15.558	 14.436	 -1.7891
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.858323
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.0626e+02, final cost 6.9472e+01, first-order optimality 2.54e-02.
#
# Fit results:
#
# 1250.58	 0.000940	 15.644	 22.078	 -3.3041
#  	  	  	 0.025	 0.828	 0.645
#
# 1253.8	 0.000940	 15.644	 22.078	 -3.3041
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.715362
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.0626e+02, final cost 6.9472e+01, first-order optimality 2.54e-02.
#
# Fit results:
#
# 1250.58	 0.000940	 15.644	 22.078	 -3.3041
#  	  	  	 0.025	 0.828	 0.645
#
# 1253.8	 0.000940	 15.644	 22.078	 -3.3041
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.715362
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 1.6195e+02, final cost 1.0815e+02, first-order optimality 3.00e-03.
#
# Fit results:
#
# 1317.22	 0.000940	 14.052	 20.000	 -2.858
#  	  	  	 0.026	 1.421	 1.027
#
# 1370.13	 0.000940	 14.052	 20.000	 -2.858
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000940	 14.052	 20.000	 -2.858
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.377005
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 1.6195e+02, final cost 1.0815e+02, first-order optimality 3.00e-03.
#
# Fit results:
#
# 1317.22	 0.000940	 14.052	 20.000	 -2.858
#  	  	  	 0.026	 1.421	 1.027
#
# 1370.13	 0.000940	 14.052	 20.000	 -2.858
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000940	 14.052	 20.000	 -2.858
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.377005
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_4.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_4_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.198_16815/of1n1s020/modified_component_groups/input_group_4_inspect.fits
#
# VPmeasure: 5/5 fits converged, 0/5 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.2924e+02, final cost 6.0490e+01, first-order optimality 1.57e-02.
#
# Fit results:
#
# 1608.45	 0.000900	 15.144	 24.930	 -2.944
#  	  	  	 0.105	 1.923	 1.041
#
# 1611.2	 0.000900	 15.144	 24.930	 -2.944
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.680268
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.2924e+02, final cost 6.0490e+01, first-order optimality 1.57e-02.
#
# Fit results:
#
# 1608.45	 0.000900	 15.144	 24.930	 -2.944
#  	  	  	 0.105	 1.923	 1.041
#
# 1611.2	 0.000900	 15.144	 24.930	 -2.944
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.680268
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 4.6526e+01, final cost 4.2692e+01, first-order optimality 2.31e-03.
#
# Fit results:
#
# 1239.93	 0.000930	 16.222	 19.879	 4.6006
#  	  	  	 0.047	 2.49	 1.834
#
# 1240.39	 0.000930	 16.222	 19.879	 4.6006
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.185882
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 4.6526e+01, final cost 4.2692e+01, first-order optimality 2.31e-03.
#
# Fit results:
#
# 1239.93	 0.000930	 16.222	 19.879	 4.6006
#  	  	  	 0.047	 2.49	 1.834
#
# 1240.39	 0.000930	 16.222	 19.879	 4.6006
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.185882
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 9.0176e+01, final cost 5.8700e+01, first-order optimality 4.39e-03.
#
# Fit results:
#
# 1250.58	 0.000030	 15.469	 17.183	 3.1420
#  	  	  	 0.029	 0.837	 0.607
#
# 1253.8	 0.000030	 15.469	 17.183	 3.1420
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.806160
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 9.0176e+01, final cost 5.8700e+01, first-order optimality 4.39e-03.
#
# Fit results:
#
# 1250.58	 0.000030	 15.469	 17.183	 3.1420
#  	  	  	 0.029	 0.837	 0.607
#
# 1253.8	 0.000030	 15.469	 17.183	 3.1420
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.806160
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.0629e+02, final cost 6.8747e+01, first-order optimality 1.38e-02.
#
# Fit results:
#
# 1250.58	 0.000940	 15.801	 17.553	 -3.180
#  	  	  	 0.047	 0.775	 0.536
#
# 1253.8	 0.000940	 15.801	 17.553	 -3.180
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.883490
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.0629e+02, final cost 6.8747e+01, first-order optimality 1.38e-02.
#
# Fit results:
#
# 1250.58	 0.000940	 15.801	 17.553	 -3.180
#  	  	  	 0.047	 0.775	 0.536
#
# 1253.8	 0.000940	 15.801	 17.553	 -3.180
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.883490
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.3243e+02, final cost 1.3283e+02, first-order optimality 7.66e-03.
#
# Fit results:
#
# 1317.22	 0.000910	 14.064	 20.000	 4.0792
#  	  	  	 0.025	 1.392	 1.007
#
# 1370.13	 0.000910	 14.064	 20.000	 4.0792
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000910	 14.064	 20.000	 4.0792
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.482859
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.3243e+02, final cost 1.3283e+02, first-order optimality 7.66e-03.
#
# Fit results:
#
# 1317.22	 0.000910	 14.064	 20.000	 4.0792
#  	  	  	 0.025	 1.392	 1.007
#
# 1370.13	 0.000910	 14.064	 20.000	 4.0792
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000910	 14.064	 20.000	 4.0792
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.482859
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_4.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_4_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_4_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 8.2401e+00, final cost 7.3375e+00, first-order optimality 7.26e-04.
#
# Fit results:
#
# 1358.77	 0.000930	 12.610	 6.6186	 -2.4148
#  	  	  	 0.157	 4.56	 2.747
#
#
# Reduced chi-squared: 0.506033
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 8.2401e+00, final cost 7.3375e+00, first-order optimality 7.26e-04.
#
# Fit results:
#
# 1358.77	 0.000930	 12.610	 6.6186	 -2.4148
#  	  	  	 0.157	 4.56	 2.747
#
#
# Reduced chi-squared: 0.506033
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_5.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_5.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_5_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1s030/modified_component_groups/input_group_5_inspect.fits
#
# VPmeasure: 6/6 fits converged, 0/6 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 5.6638e+01, final cost 5.2869e+01, first-order optimality 1.20e-02.
#
# Fit results:
#
# 1608.45	 0.000900	 14.944	 28.072	 0.10037
#  	  	  	 0.054	 1.801	 1.177
#
# 1611.2	 0.000900	 14.944	 28.072	 0.10037
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.201560
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 5.6638e+01, final cost 5.2869e+01, first-order optimality 1.20e-02.
#
# Fit results:
#
# 1608.45	 0.000900	 14.944	 28.072	 0.10037
#  	  	  	 0.054	 1.801	 1.177
#
# 1611.2	 0.000900	 14.944	 28.072	 0.10037
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.201560
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 3.3375e+01, final cost 2.7378e+01, first-order optimality 3.53e-03.
#
# Fit results:
#
# 1239.93	 0.000940	 15.938	 8.6238	 -4.8791
#  	  	  	 0.072	 2.15	 1.363
#
# 1240.39	 0.000940	 15.938	 8.6238	 -4.8791
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.013991
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 3.3375e+01, final cost 2.7378e+01, first-order optimality 3.53e-03.
#
# Fit results:
#
# 1239.93	 0.000940	 15.938	 8.6238	 -4.8791
#  	  	  	 0.072	 2.15	 1.363
#
# 1240.39	 0.000940	 15.938	 8.6238	 -4.8791
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.013991
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 8.2151e+01, final cost 7.5215e+01, first-order optimality 5.43e-03.
#
# Fit results:
#
# 1250.58	 0.000030	 15.543	 16.132	 0.089073
#  	  	  	 0.034	 0.756	 0.53
#
# 1253.8	 0.000030	 15.543	 16.132	 0.089073
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.953627
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 8.2151e+01, final cost 7.5215e+01, first-order optimality 5.43e-03.
#
# Fit results:
#
# 1250.58	 0.000030	 15.543	 16.132	 0.089073
#  	  	  	 0.034	 0.756	 0.53
#
# 1253.8	 0.000030	 15.543	 16.132	 0.089073
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.953627
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 8.9836e+01, final cost 5.4671e+01, first-order optimality 1.81e-02.
#
# Fit results:
#
# 1250.58	 0.000910	 15.657	 23.116	 3.3465
#  	  	  	 0.024	 0.82	 0.666
#
# 1253.8	 0.000910	 15.657	 23.116	 3.3465
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.384083
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 8.9836e+01, final cost 5.4671e+01, first-order optimality 1.81e-02.
#
# Fit results:
#
# 1250.58	 0.000910	 15.657	 23.116	 3.3465
#  	  	  	 0.024	 0.82	 0.666
#
# 1253.8	 0.000910	 15.657	 23.116	 3.3465
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.384083
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 2.4491e+02, final cost 1.3464e+02, first-order optimality 1.75e-02.
#
# Fit results:
#
# 1317.22	 0.000930	 14.070	 20.000	 -4.7183
#  	  	  	 0.024	 1.333	 0.954
#
# 1370.13	 0.000930	 14.070	 20.000	 -4.7183
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000930	 14.070	 20.000	 -4.7183
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.666218
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 2.4491e+02, final cost 1.3464e+02, first-order optimality 1.75e-02.
#
# Fit results:
#
# 1317.22	 0.000930	 14.070	 20.000	 -4.7183
#  	  	  	 0.024	 1.333	 0.954
#
# 1370.13	 0.000930	 14.070	 20.000	 -4.7183
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000930	 14.070	 20.000	 -4.7183
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.666218
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_4.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_4_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_4_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.7782e+01, final cost 1.7221e+01, first-order optimality 1.88e-03.
#
# Fit results:
#
# 1358.77	 0.000940	 12.843	 8.1719	 -0.63412
#  	  	  	 0.096	 3.151	 1.915
#
#
# Reduced chi-squared: 1.148086
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.7782e+01, final cost 1.7221e+01, first-order optimality 1.88e-03.
#
# Fit results:
#
# 1358.77	 0.000940	 12.843	 8.1719	 -0.63412
#  	  	  	 0.096	 3.151	 1.915
#
#
# Reduced chi-squared: 1.148086
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_5.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_5.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_5_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/LMC N11B/PGMW 3204/E140M_1425_0.2x0.2_2548.199_16815/of1n1t020/modified_component_groups/input_group_5_inspect.fits
#
# VPmeasure: 6/6 fits converged, 0/6 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.

# %%
records = []

for i in range(len(spectra_directories)):

    directory = spectra_directories[i]
    path = target_directory / directory
    
    for subdir in os.listdir(path):
        
        subdir_path = path / subdir
        if not subdir_path.is_dir():
            continue
        fn = os.path.join(subdir_path, "compiledVPoutputs.dat")
        if not os.path.isfile(fn):
            continue

        df_outputs = pd.read_csv(fn, sep = "|")
        df_outputs = df_outputs[(np.abs(df_outputs["zsys"]) > 0.0001) & (df_outputs["sigcol"] != 0.0)]
        records.append(df_outputs[["trans", "col", "sigcol"]])

all_measurements = pd.concat(records, ignore_index = True)

def random_effects_mean(vals, sigmas):
    vals = np.asarray(vals, dtype = float)
    sigmas = np.asarray(sigmas, dtype = float)
    var = sigmas ** 2

    w  = 1.0 / var
    mu = (w * vals).sum() / w.sum()

    Q  = (w * (vals - mu) ** 2).sum()
    df = len(vals) - 1
    c  = w.sum() - (w ** 2).sum() / w.sum()
    T2 = max(0.0, (Q - df) / c) if c > 0 else 0.0

    w_re = 1.0 / (var + T2)
    mean = (w_re * vals).sum() / w_re.sum()
    std  = np.sqrt(1.0 / w_re.sum())
    return mean, std

combined = (
    all_measurements
    .groupby("trans", sort = True)
    .apply(lambda g: random_effects_mean(g["col"], g["sigcol"]))
    .apply(pd.Series)
    .reset_index()
    .rename(columns = {0: "col_combined", 1: "sigcol_combined"})
)

combined = combined.sort_values("trans").reset_index(drop = True)

for _, row in combined.iterrows():
    print(f"{row.trans}  {row.col_combined:.3f} ± {row.sigcol_combined:.3f}")

output_file = os.path.join(target_directory, "abundances.txt")

with open(output_file, "w") as f:
    for _, row in combined.iterrows():
        f.write(f"{row.trans} {row.col_combined:.3f} {row.sigcol_combined:.3f}\n")
# Out:
# CuII  12.760 ± 0.112
# FeII  14.962 ± 0.026
# MgII  16.104 ± 0.053
# NiII  14.052 ± 0.012
# S II  15.695 ± 0.025
# /var/folders/7n/v6gcxcpj68q6nnv2znnc85xc0000gn/T/ipykernel_8391/817733302.py:44: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: random_effects_mean(g["col"], g["sigcol"]))

# %%
records = []

for i in range(len(spectra_directories)):

    directory = spectra_directories[i]
    path = target_directory / directory
    
    for subdir in os.listdir(path):
        
        subdir_path = path / subdir
        if not subdir_path.is_dir():
            continue
        fn = os.path.join(subdir_path, "compiledVPoutputs.dat")
        if not os.path.isfile(fn):
            continue

        df_SII = pd.read_csv(fn, sep = "|")
        df_SII = df_SII[df_SII["trans"].str.strip() == "S II"]
        df_SII["z_tot"] = df_SII["zsys"] + df_SII["vel"] / 299792.458
        records.append(df_SII[["z_tot", "sigvel"]])

df_SII = pd.concat(records, ignore_index = True)
bin_mw = df_SII[np.abs(df_SII["z_tot"]) <= 0.0001]
bin_sys = df_SII[np.abs(df_SII["z_tot"] - guess_redshift) <= 0.0001]
bin_mw = bin_mw[bin_mw["sigvel"] != 0]
bin_sys = bin_sys[bin_sys["sigvel"] != 0]

z_mw = random_effects_mean(bin_mw["z_tot"].values, bin_mw["sigvel"].values)[0]
z_sys = random_effects_mean(bin_sys["z_tot"].values, bin_sys["sigvel"].values)[0]
        
output_path = os.path.join(target_directory, "heliocentric_velocities.txt")
with open(output_path, "w") as f:
    f.write(f"{z_mw:.8f}\n")
    f.write(f"{z_sys:.8f}\n")       

print(f"{z_mw:.8f}")
print(f"{z_sys:.8f}")
# Out:
# 0.00003667
# 0.00092701

# %%
# END
