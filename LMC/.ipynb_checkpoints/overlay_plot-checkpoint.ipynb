# %%
import os
import numpy as np
import pandas as pd
import astropy.units as u
import matplotlib.pyplot as plt

from pathlib import Path
from astropy.io import fits
from astropy.wcs import WCS
from astroquery.simbad import Simbad
from astroquery.hips2fits import hips2fits
from astropy.coordinates import SkyCoord, Angle

# %%
galaxy_directory = Path().resolve()
galaxy = galaxy_directory.parts[galaxy_directory.parts.index('float-for-morrow') + 1]

# %%
records_O = []
records_S = []
records_Fe = []

for region_name in os.listdir(galaxy_directory):
    region_path = galaxy_directory / region_name
    if region_path.name.startswith('.') or not region_path.is_dir():
        continue

    for target_name in os.listdir(region_path):
        target_path = region_path / target_name
        if target_path.name.startswith('.') or not target_path.is_dir():
            continue
        target = Simbad.query_object(target_name)
        ra_str  = target['ra'][0]
        dec_str = target['dec'][0]
        coord = SkyCoord(ra_str, dec_str, unit = (u.deg, u.deg), frame = 'icrs')
    
        O_path = target_path / "O.txt"
        
        if O_path.is_file():
            
            with open(O_path, "r") as file:
                
                lines = file.readlines()
                OI_H = float(lines[0].strip())
                sigma_OI_H = float(lines[1].strip())
    
            records_O.append({
                    "Target": target_name,
                    "RA": coord.ra.deg,
                    "DEC": coord.dec.deg,
                    "OI_H": OI_H,
                    "sigma_OI_H": sigma_OI_H,
                })
            
        S_path = target_path / "S.txt"
        
        if S_path.is_file():
            
            with open(S_path, "r") as file:
                
                lines = file.readlines()
                SII_H = float(lines[0].strip())
                sigma_SII_H = float(lines[1].strip())
    
            records_S.append({
                    "Target": target_name,
                    "RA": coord.ra.deg,
                    "DEC": coord.dec.deg,
                    "SII_H": SII_H,
                    "sigma_SII_H": sigma_SII_H,
                })
            
        Fe_path = target_path / "Fe.txt"
        
        if Fe_path.is_file():
            
            with open(Fe_path, "r") as file:
                
                lines = file.readlines()
                FeII_H = float(lines[0].strip())
                sigma_FeII_H = float(lines[1].strip())
    
            records_Fe.append({
                    "Region": region_name, 
                    "Target": target_name,
                    "RA": coord.ra.deg,
                    "DEC": coord.dec.deg,
                    "FeII_H": FeII_H,
                    "sigma_FeII_H": sigma_FeII_H,
                })

# %%
df_O = pd.DataFrame.from_records(records_O)
df_S = pd.DataFrame.from_records(records_S)
df_Fe = pd.DataFrame.from_records(records_Fe)

# %%
df_Fe
# Out:
#      Region Target         RA        DEC    FeII_H  sigma_FeII_H
# 0  LMC N11B  BI 42  74.253686 -66.407002  5.869065      0.210425

# %%
region_count = 0
Simbad.add_votable_fields('dimensions')
for region_name in os.listdir(galaxy_directory):
    region_path = galaxy_directory / region_name
    if region_path.name.startswith('.') or not region_path.is_dir():
        continue
    region_count += 1
print(region_count)
# Out:
# 2

# %%
selection = 0

i = 0
for region_name in os.listdir(galaxy_directory):
    region_path = galaxy_directory / region_name
    if region_path.name.startswith('.') or not region_path.is_dir():
        continue
    if i == selection:
        region_query = Simbad.query_object(region_name)
        ra_region = region_query['ra'][0]
        dec_region = region_query['dec'][0]
        majaxis_region = 5 # region_query['galdim_majaxis'][0]
        minaxis_region = 5 # region_query['galdim_minaxis'][0]
        position = SkyCoord(ra_region, dec_region, unit = (u.deg, u.deg), frame = 'icrs')
        
        hdu_list = hips2fits.query(hips = 'CDS/P/DSS2/red', width = 3000, height = 3000, projection = 'TAN', ra = position.ra, dec = position.dec, fov = Angle((np.max(np.array([majaxis_region, minaxis_region])) + 4) * u.arcmin), format = 'fits')
        
        hdu = hdu_list[0]
        wcs = WCS(hdu.header)  
    i += 1

fig = plt.figure(figsize = (6, 6))
ax = fig.add_subplot(111, projection = wcs)

im = ax.imshow(hdu.data, origin = 'lower', cmap = 'afmhot', vmin = np.nanpercentile(hdu.data, 5), vmax = np.nanpercentile(hdu.data, 99))

sc = ax.scatter(df_Fe['RA'], df_Fe['DEC'], transform = ax.get_transform('world'), s = 60, marker = 'x', linewidth = 2, c = 'green')

for _, row in df_Fe.iterrows():
    ax.text(row['RA'] - 0.02, row['DEC'], f"{row['FeII_H']:.3f}", transform = ax.get_transform('world'), fontsize = 12, color = 'green', ha = 'left', va = 'bottom')

ax.set_xlabel('RA')
ax.set_ylabel('Dec')
ax.set_title('Fe/H')
ax.grid(color = 'white', ls = ':', alpha = 0.3)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ProtocolError                             Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     819 try:
# --> 820     yield from self.raw.stream(chunk_size, decode_content=True)
#     821 except ProtocolError as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/urllib3/response.py:1063, in HTTPResponse.stream(self, amt, decode_content)
#    1062 if self.chunked and self.supports_chunked_reads():
# -> 1063     yield from self.read_chunked(amt, decode_content=decode_content)
#    1064 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/urllib3/response.py:1219, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1218 while True:
# -> 1219     self._update_chunk_length()
#    1220     if self.chunk_left == 0:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/urllib3/response.py:1149, in HTTPResponse._update_chunk_length(self)
#    1147 else:
#    1148     # Truncated at start of next chunk
# -> 1149     raise ProtocolError("Response ended prematurely") from None
#
# ProtocolError: Response ended prematurely
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# Cell In[15], line 16
#      13 minaxis_region = 5 # region_query['galdim_minaxis'][0]
#      14 position = SkyCoord(ra_region, dec_region, unit = (u.deg, u.deg), frame = 'icrs')
# ---> 16 hdu_list = hips2fits.query(hips = 'CDS/P/DSS2/red', width = 3000, height = 3000, projection = 'TAN', ra = position.ra, dec = position.dec, fov = Angle((np.max(np.array([majaxis_region, minaxis_region])) + 4) * u.arcmin), format = 'fits')
#      18 hdu = hdu_list[0]
#      19 wcs = WCS(hdu.header)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/astroquery/hips2fits/core.py:272, in hips2fitsClass.query(self, hips, width, height, projection, ra, dec, fov, coordsys, rotation_angle, format, min_cut, max_cut, stretch, cmap, get_query_payload, verbose)
#     170 def query(self, hips, width, height, projection, ra, dec, fov, *,
#     171           coordsys="icrs", rotation_angle=Angle(0 * u.deg), format="fits",
#     172           min_cut=0.5, max_cut=99.5, stretch="linear", cmap="Greys_r",
#     173           get_query_payload=False, verbose=False):
#     174     """
#     175     Query the `CDS hips2fits service <https://alasky.cds.unistra.fr/hips-image-services/hips2fits>`_.
#     176
#    (...)    269     >>> plt.show(im)
#     270     """
# --> 272     response = self.query_async(get_query_payload=get_query_payload, hips=hips, width=width, height=height,
#     273                                 projection=projection, ra=ra, dec=dec, fov=fov, coordsys=coordsys,
#     274                                 rotation_angle=rotation_angle, format=format, min_cut=min_cut,
#     275                                 max_cut=max_cut, stretch=stretch, cmap=cmap)
#     277     if get_query_payload:
#     278         return response
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/astroquery/utils/class_or_instance.py:25, in class_or_instance.__get__.<locals>.f(*args, **kwds)
#      23 def f(*args, **kwds):
#      24     if obj is not None:
# ---> 25         return self.fn(obj, *args, **kwds)
#      26     else:
#      27         return self.fn(cls, *args, **kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/astroquery/hips2fits/core.py:292, in hips2fitsClass.query_async(self, get_query_payload, **kwargs)
#     289 if get_query_payload:
#     290     return request_payload
# --> 292 response = self._request(
#     293     method="GET",
#     294     url=self.server,
#     295     data=kwargs.get('data', None),
#     296     cache=False,
#     297     timeout=self.timeout,
#     298     params=request_payload
#     299 )
#     301 return response
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/astroquery/query.py:372, in BaseQuery._request(self, method, url, params, data, headers, files, save, savedir, timeout, cache, stream, auth, continuation, verify, allow_redirects, json, return_response_on_save)
#     370 if not cache:
#     371     with cache_conf.set_temp("cache_active", False):
# --> 372         response = query.request(self._session, stream=stream,
#     373                                  auth=auth, verify=verify,
#     374                                  allow_redirects=allow_redirects,
#     375                                  json=json)
#     376 else:
#     377     response = query.from_cache(self.cache_location, cache_conf.cache_timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/astroquery/query.py:77, in AstroQuery.request(self, session, cache_location, stream, auth, verify, allow_redirects, json)
#      74 def request(self, session, cache_location=None, stream=False,
#      75             auth=None, verify=True, allow_redirects=True,
#      76             json=None):
# ---> 77     return session.request(self.method, self.url, params=self.params,
#      78                            data=self.data, headers=self.headers,
#      79                            files=self.files, timeout=self.timeout,
#      80                            stream=stream, auth=auth, verify=verify,
#      81                            allow_redirects=allow_redirects,
#      82                            json=json)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/requests/sessions.py:710, in Session.send(self, request, **kwargs)
#     707 r.elapsed = timedelta(seconds=elapsed)
#     709 # Response manipulation hooks
# --> 710 r = dispatch_hook("response", hooks, r, **kwargs)
#     712 # Persist cookies
#     713 if r.history:
#     714     # If the hooks create history then we want those cookies too
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/requests/hooks.py:30, in dispatch_hook(key, hooks, hook_data, **kwargs)
#      28     hooks = [hooks]
#      29 for hook in hooks:
# ---> 30     _hook_data = hook(hook_data, **kwargs)
#      31     if _hook_data is not None:
#      32         hook_data = _hook_data
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/astroquery/query.py:261, in BaseQuery._response_hook(self, response, *args, **kwargs)
#     249     response_log = textwrap.indent(
#     250         f"-----------------------------------------\n"
#     251         f"{response.status_code} {response.reason} {response.url}\n"
#     252         f"{response_hdrs}\n"
#     253         "Streaming Data\n"
#     254         f"-----------------------------------------", '\t')
#     255 else:
#     256     response_log = textwrap.indent(
#     257         f"-----------------------------------------\n"
#     258         f"{response.status_code} {response.reason} {response.url}\n"
#     259         f"{response_hdrs}\n"
#     260         f"\n"
# --> 261         f"{response.text}\n"
#     262         f"-----------------------------------------", '\t')
#     263 log.log(5, f"HTTP response\n{response_log}")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/requests/models.py:926, in Response.text(self)
#     923 content = None
#     924 encoding = self.encoding
# --> 926 if not self.content:
#     927     return ""
#     929 # Fallback to auto-detected encoding.
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/requests/models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/requests/models.py:822, in Response.iter_content.<locals>.generate()
#     820     yield from self.raw.stream(chunk_size, decode_content=True)
#     821 except ProtocolError as e:
# --> 822     raise ChunkedEncodingError(e)
#     823 except DecodeError as e:
#     824     raise ContentDecodingError(e)
#
# ChunkedEncodingError: Response ended prematurely

# %%
# END
