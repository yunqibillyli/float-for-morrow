# %%
# Import packages
import os
import re
import sys
import glob
import toml
import shutil
import textwrap
import subprocess

import numpy as np
import pandas as pd

from pathlib import Path
from astropy.io import fits
from importlib import reload
from astropy.table import Table
from scipy.interpolate import interp1d
from joebvp import cfg, utils, VPmeasure
# Out:
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/morton03_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/verner96_tab1.fits.gz
# joebvp.makevoigt: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# joebvp.VPmeasure: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/morton03_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/verner96_tab1.fits.gz
# joebvp.makevoigt: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/joebvp
# joebvp.utils: No local joebvp_cfg.py found, using default cfg.py file from joebvp.

# %%
# Register directories
notebook_directory = Path().resolve()
base_directory = notebook_directory / "E140M"
python_cmd = sys.executable
model_file = "/Users/billyli/Documents/BillyJessExploratory/powr-OB-lmc-vd3.nc"
runner_path = "/Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py"

# %% [markdown]
# # Run Kirill's continuum fitting script from scratch
# for fits_path in sorted(base_directory.rglob("*_x1d.fits")):
#
#     dataset = fits_path.stem.replace("_x1d", "")
#     cwd_directory = fits_path.parent
#
#     problem = notebook_directory.name.lower()
#     target = notebook_directory.name.upper()
#
#     spec_file = fits_path.name
#
#     toml_content = textwrap.dedent(f"""
#     [target_info]
#     problem    = "{problem}"
#     target     = "{target}"
#     spec_file  = "{spec_file}"
#     model_file = "{model_file}"
#     instrument = "stis_e140m"
#
#     [include_wave_range]
#     wave_range = [ 1238, 1620,]
#
#     [exclude_wave_ranges]
#
#     [vshift]
#     min = 50
#     max = 550
#     delta = 50
#
#     [vsini]
#     min = 50
#     max = 350
#     delta = 50
#
#     [exclude_vranges.ions]
#     linelist = "ISM"
#     vrange = [-75, 350]
#     drop_species = []
#
#     [target_info.plot_ranges_kwargs.all_merged]
#     color = "gainsboro"
#     """).lstrip()
#
#     tmp_toml = cwd_directory / f"{problem}.toml"
#     tmp_toml.write_text(toml_content)
#
#     subprocess.run([python_cmd, runner_path, str(tmp_toml)], check = True, cwd = cwd_directory)
#
#     csv_path = cwd_directory / f"{problem}.csv"
#     model_continuum = Table.read(str(csv_path), format = "csv")
#     original = Table.read(fits_path, hdu = 1)
#
#     wave = model_continuum['wave'].data
#     flux = model_continuum['flux'].data
#     err = model_continuum['err'].data
#     wave_model = model_continuum['wave'].data
#     best_fit_spec = model_continuum['best_fit_spec'].data
#
#     new_hdul = fits.HDUList([fits.PrimaryHDU(), fits.ImageHDU(), fits.ImageHDU(), fits.ImageHDU()])
#     new_hdul[0].data = flux
#     new_hdul[0].header['BITPIX'] = -32
#     new_hdul[0].header['NAXIS'] = 1
#     new_hdul[0].header['NAXIS1'] = len(wave)
#     new_hdul[0].header['EXTNAME'] = 'FLUX    '
#     new_hdul[1].data = err
#     new_hdul[1].header['XTENSION'] = 'IMAGE   '
#     new_hdul[1].header['BITPIX'] = -32
#     new_hdul[1].header['NAXIS'] = 1
#     new_hdul[1].header['NAXIS1'] = len(wave)
#     new_hdul[1].header['PCOUNT'] = 0
#     new_hdul[1].header['GCOUNT'] = 1
#     new_hdul[1].header['EXTNAME'] = 'ERROR   '
#     new_hdul[2].data = wave
#     new_hdul[2].header['XTENSION'] = 'IMAGE   '
#     new_hdul[2].header['BITPIX'] = -64
#     new_hdul[2].header['NAXIS'] = 1
#     new_hdul[2].header['NAXIS1'] = len(wave)
#     new_hdul[2].header['PCOUNT'] = 0
#     new_hdul[2].header['GCOUNT'] = 1
#     new_hdul[2].header['EXTNAME'] = 'WAVELENGTH'
#     new_hdul[3].data = best_fit_spec
#     new_hdul[3].header['XTENSION'] = 'IMAGE   '
#     new_hdul[3].header['BITPIX'] = -32
#     new_hdul[3].header['NAXIS'] = 1
#     new_hdul[3].header['NAXIS1'] = len(wave)
#     new_hdul[3].header['PCOUNT'] = 0
#     new_hdul[3].header['GCOUNT'] = 1
#     new_hdul[3].header['EXTNAME'] = 'CONTINUUM'
#
#     out_path = str(fits_path).replace("_x1d.fits", "_continuumfit.fits")
#     new_hdul.writeto(str(out_path), overwrite = True)

# %%
# Generate terminal commands
directories = sorted([d for d in os.listdir(base_directory) if d.startswith("E140M")])

def replace_string(path, dataset_name):
    segment = """lt_xspec [path][dataset_name]_x1d.fits
cd [path] && lt_continuumfit --redshift 0.00087 [dataset_name]_x1d.fits [dataset_name]_continuumfit_original.fits
cd [path] && pyigm_igmguesses [dataset_name]_continuumfit.fits -o [dataset_name]_x1dfits_model.json
cd [path] && pyigm_fitdla --out_file [dataset_name]_xfitdla.json [dataset_name]_continuumfit.fits 0"""
    modified_segment = segment.replace("[dataset_name]", dataset_name)
    modified_segment = modified_segment.replace("[path]", path)
    print(modified_segment)
    
for subdir in directories:
    path = base_directory / subdir
    for file in os.listdir(path):
        if file.endswith("_x1d.fits"):
            dataset_name = file.replace("_x1d.fits", "")
            path = str(path.resolve()) + "/"
            replace_string(path, dataset_name)
            print("\r")
# Out:
# lt_xspec /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/oeb71s010_x1d.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/ && lt_continuumfit --redshift 0.00087 oeb71s010_x1d.fits oeb71s010_continuumfit_original.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/ && pyigm_igmguesses oeb71s010_continuumfit.fits -o oeb71s010_x1dfits_model.json
# cd /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/ && pyigm_fitdla --out_file oeb71s010_xfitdla.json oeb71s010_continuumfit.fits 0
#
# lt_xspec /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/oeb71s020_x1d.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/ && lt_continuumfit --redshift 0.00087 oeb71s020_x1d.fits oeb71s020_continuumfit_original.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/ && pyigm_igmguesses oeb71s020_continuumfit.fits -o oeb71s020_x1dfits_model.json
# cd /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/ && pyigm_fitdla --out_file oeb71s020_xfitdla.json oeb71s020_continuumfit.fits 0
#
# lt_xspec /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/oeb71t010_x1d.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/ && lt_continuumfit --redshift 0.00087 oeb71t010_x1d.fits oeb71t010_continuumfit_original.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/ && pyigm_igmguesses oeb71t010_continuumfit.fits -o oeb71t010_x1dfits_model.json
# cd /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/ && pyigm_fitdla --out_file oeb71t010_xfitdla.json oeb71t010_continuumfit.fits 0
#
# lt_xspec /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/oeb71t020_x1d.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/ && lt_continuumfit --redshift 0.00087 oeb71t020_x1d.fits oeb71t020_continuumfit_original.fits
# cd /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/ && pyigm_igmguesses oeb71t020_continuumfit.fits -o oeb71t020_x1dfits_model.json
# cd /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/ && pyigm_fitdla --out_file oeb71t020_xfitdla.json oeb71t020_continuumfit.fits 0

# %%
# Run Kirill's continuum fitting script to replace standard continuum fit between range
for fits_path in sorted(base_directory.rglob("*_x1d.fits")):
    
    dataset = fits_path.stem.replace("_x1d", "")
    cwd_directory = fits_path.parent

    problem = notebook_directory.name.lower()
    target = notebook_directory.name.upper()

    spec_file = fits_path.name
    
    wave_min = 1245
    wave_max = 1615

    toml_content = textwrap.dedent(f"""
    [target_info]
    problem    = "{problem}"
    target     = "{target}"
    spec_file  = "{spec_file}"
    model_file = "{model_file}"
    instrument = "stis_e140m"

    [include_wave_range]
    wave_range = [ {wave_min}, {wave_max},]

    [exclude_wave_ranges]

    [vshift]
    min = 50
    max = 550
    delta = 50

    [vsini]
    min = 50
    max = 350
    delta = 50

    [exclude_vranges.ions]
    linelist = "ISM"
    vrange = [-75, 350]
    drop_species = []

    [target_info.plot_ranges_kwargs.all_merged]
    color = "gainsboro"
    """).lstrip()

    tmp_toml = cwd_directory / f"{problem}.toml"
    tmp_toml.write_text(toml_content)

    subprocess.run([python_cmd, runner_path, str(tmp_toml)], check = True, cwd = cwd_directory)

    csv_path = cwd_directory / f"{problem}.csv"
    model_continuum = Table.read(str(csv_path), format = "csv")
    original = Table.read(fits_path, hdu = 1)

    wave = model_continuum['wave'].data
    flux = model_continuum['flux'].data
    err = model_continuum['err'].data
    wave_model = model_continuum['wave'].data
    best_fit_spec = model_continuum['best_fit_spec'].data

    continuumfit_path = cwd_directory / f"{dataset}_continuumfit_original.fits"
    with fits.open(continuumfit_path, mode = 'readonly') as hdul:
        new_hdul = fits.HDUList([h.copy() for h in hdul])

    flux_original = new_hdul[0].data
    wave_original = new_hdul[2].data
    continuum_hdu = new_hdul[3]
    
    continuum_original = continuum_hdu.data
    
    mask = (wave_original >= wave_min) & (wave_original <= wave_max)
    flux_original_masked = flux_original[mask]

    normalization_factor = flux_original_masked[10000] / flux[10000]
    normalization_factor_2 = flux_original_masked[15000] / flux[15000]
    normalization_factor_3 = flux_original_masked[20000] / flux[20000]

    if not (np.allclose([normalization_factor, normalization_factor_2, normalization_factor_3], normalization_factor, rtol = 0.001)):
        raise ValueError(f"Normalization factors disagree: {normalization_factor:.3f}, {normalization_factor_2:.3f}, {normalization_factor_3:.3f}")
    
    # f = interp1d(wave, best_fit_spec, kind = 'linear') # no need to interp2d
    # continuum_interp_values = f(wave_original[mask]) * normalization_factor

    continuum_hdu.data[mask] = best_fit_spec * normalization_factor # continuum_interp_values

    out_path = str(fits_path).replace("_x1d.fits", "_continuumfit.fits")
    new_hdul.writeto(str(out_path), overwrite = True)
# Out:
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'bat99-105', 'target': 'BAT99-105', 'spec_file': 'oeb71s010_x1d.fits', 'model_file': '/Users/billyli/Documents/BillyJessExploratory/powr-OB-lmc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1245, 1615]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-75, 350], 'drop_species': []}}}
# WARNING: UnitsWarning: 'Angstroms' did not parse as fits unit: At col 0, Unit 'Angstroms' not supported by the FITS standard. Did you mean Angstrom or angstrom? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'bat99-105', 'target': 'BAT99-105', 'spec_file': 'oeb71s020_x1d.fits', 'model_file': '/Users/billyli/Documents/BillyJessExploratory/powr-OB-lmc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1245, 1615]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-75, 350], 'drop_species': []}}}
# WARNING: UnitsWarning: 'Angstroms' did not parse as fits unit: At col 0, Unit 'Angstroms' not supported by the FITS standard. Did you mean Angstrom or angstrom? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'bat99-105', 'target': 'BAT99-105', 'spec_file': 'oeb71t010_x1d.fits', 'model_file': '/Users/billyli/Documents/BillyJessExploratory/powr-OB-lmc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1245, 1615]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-75, 350], 'drop_species': []}}}
# WARNING: UnitsWarning: 'Angstroms' did not parse as fits unit: At col 0, Unit 'Angstroms' not supported by the FITS standard. Did you mean Angstrom or angstrom? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/BillyJessExploratory/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'bat99-105', 'target': 'BAT99-105', 'spec_file': 'oeb71t020_x1d.fits', 'model_file': '/Users/billyli/Documents/BillyJessExploratory/powr-OB-lmc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1245, 1615]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-75, 350], 'drop_species': []}}}
# WARNING: UnitsWarning: 'Angstroms' did not parse as fits unit: At col 0, Unit 'Angstroms' not supported by the FITS standard. Did you mean Angstrom or angstrom? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: UnitsWarning: 'Counts/s' did not parse as fits unit: At col 0, Unit 'Counts' not supported by the FITS standard. Did you mean count? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]

# %%
reload(cfg)

d = pd.DataFrame({
    'instr': ['COS', 'COS', 'COS', 'COS', 'STIS', 'STIS', 'Gaussian'],
    'gratings': ['G130M', 'G160M', 'G185M', 'G225M', 'E230M', 'E140M', 'N/A'],
    'slits': ['NA', 'NA', 'NA', 'NA', '0.2x0.2', '0.2x0.06', 'NA'],
    'lsfranges': [[1100, 1460], [1400, 1800], [1800, 2100], [2100, 2278], [1607, 3129], [1144, 1729], [899, 1191]],
    'lps': ['1', '1', '1', '1', '1', '1', 'NA'],
    'cen_wave': ['1291', '1611', '1953', '2250', '1978', '1425', 'NA'],
    'pixel_scales': [None, None, None, None, None, None, 0.013], 
    'fwhms': [None, None, None, None, None, None, 0.02]
})

num = 5

cfg.lsfs = []
for col in ['instr', 'gratings', 'slits', 'cen_wave', 'pixel_scales', 'fwhms']:
    setattr(cfg, col, [d.at[num, col]])

cfg.lsfranges = np.array([d.at[num, 'lsfranges']])

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_model = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))[0]
    continuumfit = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))[0]

    utils.pyigm_to_veeper(igm_model, continuumfit)

    os.chdir(base_directory)

os.chdir(notebook_directory)
# Out:
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    component_groups_dir = os.path.join(current_directory, "component_groups")
    output_dir = os.path.join(current_directory, "modified_component_groups")

    if os.path.exists(output_dir):
        shutil.rmtree(output_dir)
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    mc_lines_file = "/Users/billyli/Documents/float-for-morrow/LMC/lmc_e140m.txt"
    mc_lines_df = pd.read_csv(mc_lines_file, sep = r"\s+", header = None, names = ["line", "wavelength"])
    mc_lines_df["wavelength"] = mc_lines_df["wavelength"].astype(float)

    def is_valid_line(row, line_df):
        trans = row["trans"].strip()
        restwave = row["restwave"]
        matching_lines = line_df[line_df["line"] == trans]
        for wave in matching_lines["wavelength"]:
            if 0.999 * wave <= restwave <= 1.001 * wave:
                return True
        return False

    input_files = glob.glob(os.path.join(component_groups_dir, "*.txt"))

    for file in input_files:
        df = pd.read_csv(file, sep = "|")
        df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    
        df["restwave"] = pd.to_numeric(df["restwave"], errors = "coerce")
        df["bval"] = pd.to_numeric(df["bval"], errors = "coerce")
    
        valid_mask = df.apply(lambda row: is_valid_line(row, mc_lines_df), axis = 1)
        df_filtered = df[valid_mask].copy()
    
        # df_filtered["col"] = df_filtered["col"] - 0.2
        df_filtered["bval"] = df_filtered["bval"]
    
        output_file = os.path.join(output_dir, os.path.basename(file))
        df_filtered.to_csv(output_file, sep = "|", index = False)
        # print(f"Processed file: {os.path.basename(file)} -> {output_file}")

# %%
# Before fitting, should manually adjust the input group files

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_models = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))
    continuumfits = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))

    component_groups_dir = os.path.join(current_directory, "modified_component_groups")
    
    input_group_files = sorted([f for f in glob.glob(os.path.join(component_groups_dir, "input_group_*.txt")) if re.match(r".*input_group_\d+\.txt$", f)])

    VPmeasure.batch_fit(continuumfits[0], input_group_files, filepath = './modified_component_groups/')

    os.chdir(base_directory)

os.chdir(notebook_directory)
# Out:
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 3.4873e+02, final cost 1.0089e+02, first-order optimality 3.32e-02.
#
# Fit results:
#
# 1608.45	 0.000910	 15.755	 33.380	 -10.674
#  	  	  	 0.053	 1.841	 2.316
#
# 1611.2	 0.000910	 15.755	 33.380	 -10.674
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.620477
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 3.4873e+02, final cost 1.0089e+02, first-order optimality 3.32e-02.
#
# Fit results:
#
# 1608.45	 0.000910	 15.755	 33.380	 -10.674
#  	  	  	 0.053	 1.841	 2.316
#
# 1611.2	 0.000910	 15.755	 33.380	 -10.674
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.620477
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 5.0221e+01, final cost 4.3988e+01, first-order optimality 2.47e-03.
#
# Fit results:
#
# 1239.93	 0.000910	 16.540	 20.886	 3.0613
#  	  	  	 0.048	 2.87	 1.973
#
# 1240.39	 0.000910	 16.540	 20.886	 3.0613
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.099708
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 5.0221e+01, final cost 4.3988e+01, first-order optimality 2.47e-03.
#
# Fit results:
#
# 1239.93	 0.000910	 16.540	 20.886	 3.0613
#  	  	  	 0.048	 2.87	 1.973
#
# 1240.39	 0.000910	 16.540	 20.886	 3.0613
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.099708
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.3520e+02, final cost 1.2239e+02, first-order optimality 4.00e-02.
#
# Fit results:
#
# 1250.58	 0.000860	 17.983	 23.362	 -2.3914
#  	  	  	 0.726	 3.154	 0.632
#
# 1253.8	 0.000860	 17.983	 23.362	 -2.3914
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.927361
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.3520e+02, final cost 1.2239e+02, first-order optimality 4.00e-02.
#
# Fit results:
#
# 1250.58	 0.000860	 17.983	 23.362	 -2.3914
#  	  	  	 0.726	 3.154	 0.632
#
# 1253.8	 0.000860	 17.983	 23.362	 -2.3914
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.927361
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 2.7696e+01, final cost 1.8818e+01, first-order optimality 8.29e-04.
#
# Fit results:
#
# 1355.6	 0.000910	 18.441	 20.000	 -2.7245
#  	  	  	 0.073	 5.654	 3.56
#
#
# Reduced chi-squared: 1.297797
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 2.7696e+01, final cost 1.8818e+01, first-order optimality 8.29e-04.
#
# Fit results:
#
# 1355.6	 0.000910	 18.441	 20.000	 -2.7245
#  	  	  	 0.073	 5.654	 3.56
#
#
# Reduced chi-squared: 1.297797
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 5.0330e+02, final cost 1.5430e+02, first-order optimality 7.12e-03.
#
# Fit results:
#
# 1317.22	 0.000910	 14.337	 31.300	 5.9661
#  	  	  	 0.018	 1.838	 1.231
#
# 1370.13	 0.000910	 14.337	 31.300	 5.9661
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000910	 14.337	 31.300	 5.9661
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.449238
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 5.0330e+02, final cost 1.5430e+02, first-order optimality 7.12e-03.
#
# Fit results:
#
# 1317.22	 0.000910	 14.337	 31.300	 5.9661
#  	  	  	 0.018	 1.838	 1.231
#
# 1370.13	 0.000910	 14.337	 31.300	 5.9661
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000910	 14.337	 31.300	 5.9661
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.449238
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_4.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_4_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_4_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.7566e+01, final cost 2.2028e+01, first-order optimality 1.18e-03.
#
# Fit results:
#
# 1358.77	 0.000880	 13.183	 22.910	 2.7992
#  	  	  	 0.065	 5.558	 3.558
#
#
# Reduced chi-squared: 1.295748
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.7566e+01, final cost 2.2028e+01, first-order optimality 1.18e-03.
#
# Fit results:
#
# 1358.77	 0.000880	 13.183	 22.910	 2.7992
#  	  	  	 0.065	 5.558	 3.558
#
#
# Reduced chi-squared: 1.295748
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_5.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_5.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_5_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M40/modified_component_groups/input_group_5_inspect.fits
#
# VPmeasure: 6/6 fits converged, 0/6 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 42, initial cost 7.3844e+02, final cost 1.7829e+02, first-order optimality 1.88e-01.
#
# Fit results:
#
# 1608.45	 0.000910	 15.864	 33.010	 -18.461
#  	  	  	 0.054	 1.507	 2.039
#
# 1611.2	 0.000910	 15.864	 33.010	 -18.461
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 4.006449
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 42, initial cost 7.3844e+02, final cost 1.7829e+02, first-order optimality 1.88e-01.
#
# Fit results:
#
# 1608.45	 0.000910	 15.864	 33.010	 -18.461
#  	  	  	 0.054	 1.507	 2.039
#
# 1611.2	 0.000910	 15.864	 33.010	 -18.461
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 4.006449
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 4.9135e+01, final cost 4.0762e+01, first-order optimality 1.00e-03.
#
# Fit results:
#
# 1239.93	 0.000930	 16.598	 20.390	 -6.6704
#  	  	  	 0.055	 2.876	 1.95
#
# 1240.39	 0.000930	 16.598	 20.390	 -6.6704
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 0.994185
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 4.9135e+01, final cost 4.0762e+01, first-order optimality 1.00e-03.
#
# Fit results:
#
# 1239.93	 0.000930	 16.598	 20.390	 -6.6704
#  	  	  	 0.055	 2.876	 1.95
#
# 1240.39	 0.000930	 16.598	 20.390	 -6.6704
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 0.994185
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 1.8797e+02, final cost 1.5763e+02, first-order optimality 5.60e-02.
#
# Fit results:
#
# 1250.58	 0.000860	 19.992	 17.553	 -2.0929
#  	  	  	 0.206	 0.623	 0.68
#
# 1253.8	 0.000860	 19.992	 17.553	 -2.0929
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.482428
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 1.8797e+02, final cost 1.5763e+02, first-order optimality 5.60e-02.
#
# Fit results:
#
# 1250.58	 0.000860	 19.992	 17.553	 -2.0929
#  	  	  	 0.206	 0.623	 0.68
#
# 1253.8	 0.000860	 19.992	 17.553	 -2.0929
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.482428
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 1.8068e+02, final cost 1.3391e+02, first-order optimality 4.45e-03.
#
# Fit results:
#
# 1317.22	 0.000960	 14.373	 34.520	 -5.060
#  	  	  	 0.019	 2.05	 1.422
#
# 1370.13	 0.000960	 14.373	 34.520	 -5.060
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000960	 14.373	 34.520	 -5.060
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.926737
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 1.8068e+02, final cost 1.3391e+02, first-order optimality 4.45e-03.
#
# Fit results:
#
# 1317.22	 0.000960	 14.373	 34.520	 -5.060
#  	  	  	 0.019	 2.05	 1.422
#
# 1370.13	 0.000960	 14.373	 34.520	 -5.060
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000960	 14.373	 34.520	 -5.060
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.926737
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 1.8589e+02, final cost 1.4843e+02, first-order optimality 2.85e-03.
#
# Fit results:
#
# 1317.22	 0.000940	 14.373	 34.190	 0.90786
#  	  	  	 0.019	 2.033	 1.408
#
# 1370.13	 0.000940	 14.373	 34.190	 0.90786
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000940	 14.373	 34.190	 0.90786
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.151155
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 1.8589e+02, final cost 1.4843e+02, first-order optimality 2.85e-03.
#
# Fit results:
#
# 1317.22	 0.000940	 14.373	 34.190	 0.90786
#  	  	  	 0.019	 2.033	 1.408
#
# 1370.13	 0.000940	 14.373	 34.190	 0.90786
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000940	 14.373	 34.190	 0.90786
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.151155
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_4.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_4_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M30/modified_component_groups/input_group_4_inspect.fits
#
# VPmeasure: 5/5 fits converged, 0/5 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.7262e+01, final cost 1.6849e+01, first-order optimality 2.21e-04.
#
# Fit results:
#
# 1611.2	 0.000910	 15.353	 18.764	 -1.0116
#  	  	  	 0.116	 8.561	 5.379
#
#
# Reduced chi-squared: 0.910779
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.7262e+01, final cost 1.6849e+01, first-order optimality 2.21e-04.
#
# Fit results:
#
# 1611.2	 0.000910	 15.353	 18.764	 -1.0116
#  	  	  	 0.116	 8.561	 5.379
#
#
# Reduced chi-squared: 0.910779
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 4.4437e+01, final cost 3.5525e+01, first-order optimality 1.28e-02.
#
# Fit results:
#
# 1239.93	 0.000920	 16.534	 19.420	 -5.8123
#  	  	  	 0.055	 3.013	 1.975
#
# 1240.39	 0.000920	 16.534	 19.420	 -5.8123
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 0.973292
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 4.4437e+01, final cost 3.5525e+01, first-order optimality 1.28e-02.
#
# Fit results:
#
# 1239.93	 0.000920	 16.534	 19.420	 -5.8123
#  	  	  	 0.055	 3.013	 1.975
#
# 1240.39	 0.000920	 16.534	 19.420	 -5.8123
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 0.973292
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 1.1862e+02, final cost 1.0946e+02, first-order optimality 2.54e-02.
#
# Fit results:
#
# 1250.58	 0.000860	 19.539	 18.398	 -1.8288
#  	  	  	 0.556	 1.403	 0.655
#
# 1253.8	 0.000860	 19.539	 18.398	 -1.8288
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.633740
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 1.1862e+02, final cost 1.0946e+02, first-order optimality 2.54e-02.
#
# Fit results:
#
# 1250.58	 0.000860	 19.539	 18.398	 -1.8288
#  	  	  	 0.556	 1.403	 0.655
#
# 1253.8	 0.000860	 19.539	 18.398	 -1.8288
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.633740
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 1.7202e+01, final cost 1.3836e+01, first-order optimality 3.28e-04.
#
# Fit results:
#
# 1355.6	 0.000950	 18.303	 6.3342	 -2.1822
#  	  	  	 0.103	 5.025	 2.258
#
#
# Reduced chi-squared: 0.922418
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 1.7202e+01, final cost 1.3836e+01, first-order optimality 3.28e-04.
#
# Fit results:
#
# 1355.6	 0.000950	 18.303	 6.3342	 -2.1822
#  	  	  	 0.103	 5.025	 2.258
#
#
# Reduced chi-squared: 0.922418
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 2.6615e+02, final cost 1.2879e+02, first-order optimality 1.98e-03.
#
# Fit results:
#
# 1317.22	 0.000920	 14.348	 31.440	 2.3866
#  	  	  	 0.019	 1.903	 1.286
#
# 1370.13	 0.000920	 14.348	 31.440	 2.3866
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000920	 14.348	 31.440	 2.3866
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.951349
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 2.6615e+02, final cost 1.2879e+02, first-order optimality 1.98e-03.
#
# Fit results:
#
# 1317.22	 0.000920	 14.348	 31.440	 2.3866
#  	  	  	 0.019	 1.903	 1.286
#
# 1370.13	 0.000920	 14.348	 31.440	 2.3866
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000920	 14.348	 31.440	 2.3866
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.951349
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_4.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_4_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_4_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 1.4033e+01, final cost 1.2640e+01, first-order optimality 6.28e-04.
#
# Fit results:
#
# 1358.77	 0.000910	 13.094	 25.790	 -1.2137
#  	  	  	 0.089	 8.231	 5.333
#
#
# Reduced chi-squared: 0.722263
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 1.4033e+01, final cost 1.2640e+01, first-order optimality 6.28e-04.
#
# Fit results:
#
# 1358.77	 0.000910	 13.094	 25.790	 -1.2137
#  	  	  	 0.089	 8.231	 5.333
#
#
# Reduced chi-squared: 0.722263
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_5.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_5.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_5_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M10/modified_component_groups/input_group_5_inspect.fits
#
# VPmeasure: 6/6 fits converged, 0/6 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 3.4608e+02, final cost 1.0840e+02, first-order optimality 6.99e-02.
#
# Fit results:
#
# 1608.45	 0.000910	 15.774	 37.511	 -19.195
#  	  	  	 0.053	 2.37	 3.251
#
# 1611.2	 0.000910	 15.774	 37.511	 -19.195
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.436047
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 3.4608e+02, final cost 1.0840e+02, first-order optimality 6.99e-02.
#
# Fit results:
#
# 1608.45	 0.000910	 15.774	 37.511	 -19.195
#  	  	  	 0.053	 2.37	 3.251
#
# 1611.2	 0.000910	 15.774	 37.511	 -19.195
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.436047
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 5.0243e+01, final cost 4.3830e+01, first-order optimality 2.83e-03.
#
# Fit results:
#
# 1239.93	 0.000920	 16.637	 19.648	 -3.3199
#  	  	  	 0.051	 2.4	 1.598
#
# 1240.39	 0.000920	 16.637	 19.648	 -3.3199
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.138441
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 5.0243e+01, final cost 4.3830e+01, first-order optimality 2.83e-03.
#
# Fit results:
#
# 1239.93	 0.000920	 16.637	 19.648	 -3.3199
#  	  	  	 0.051	 2.4	 1.598
#
# 1240.39	 0.000920	 16.637	 19.648	 -3.3199
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.138441
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 1.2754e+02, final cost 1.1358e+02, first-order optimality 9.98e-03.
#
# Fit results:
#
# 1250.58	 0.000850	 17.437	 26.147	 -1.1743
#  	  	  	 0.395	 2.484	 0.62
#
# 1253.8	 0.000850	 17.437	 26.147	 -1.1743
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.817317
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 1.2754e+02, final cost 1.1358e+02, first-order optimality 9.98e-03.
#
# Fit results:
#
# 1250.58	 0.000850	 17.437	 26.147	 -1.1743
#  	  	  	 0.395	 2.484	 0.62
#
# 1253.8	 0.000850	 17.437	 26.147	 -1.1743
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.817317
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 2.2310e+02, final cost 1.3943e+02, first-order optimality 7.36e-03.
#
# Fit results:
#
# 1317.22	 0.000960	 14.371	 34.070	 -5.5416
#  	  	  	 0.017	 1.821	 1.228
#
# 1370.13	 0.000960	 14.371	 34.070	 -5.5416
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000960	 14.371	 34.070	 -5.5416
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.161740
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 2.2310e+02, final cost 1.3943e+02, first-order optimality 7.36e-03.
#
# Fit results:
#
# 1317.22	 0.000960	 14.371	 34.070	 -5.5416
#  	  	  	 0.017	 1.821	 1.228
#
# 1370.13	 0.000960	 14.371	 34.070	 -5.5416
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000960	 14.371	 34.070	 -5.5416
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.161740
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 2.0164e+01, final cost 1.7387e+01, first-order optimality 2.95e-05.
#
# Fit results:
#
# 1358.77	 0.000910	 13.234	 37.350	 -1.5834
#  	  	  	 0.068	 8.532	 5.393
#
#
# Reduced chi-squared: 0.848161
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 2.0164e+01, final cost 1.7387e+01, first-order optimality 2.95e-05.
#
# Fit results:
#
# 1358.77	 0.000910	 13.234	 37.350	 -1.5834
#  	  	  	 0.068	 8.532	 5.393
#
#
# Reduced chi-squared: 0.848161
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_4.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_4_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/LMC/BAT99-105/E140M/E140M20/modified_component_groups/input_group_4_inspect.fits
#
# VPmeasure: 5/5 fits converged, 0/5 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    df = pd.read_csv('compiledVPoutputs.dat', sep = '|')
    filtered_df = df[df['zsys'] > 0.0002]
    filtered_df = filtered_df[filtered_df['sigcol'] != 0.000]
    result = filtered_df[['col', 'sigcol', 'trans']]

    unique_result = result#.drop_duplicates()
    print(unique_result)
    os.chdir(base_directory)

os.chdir(notebook_directory)
# Out:
#        col  sigcol trans
# 0   17.983   0.726  S II
# 2   18.441   0.073   O I
# 3   14.337   0.018  NiII
# 6   15.755   0.053  FeII
# 8   16.540   0.048  MgII
# 10  13.183   0.065  CuII
#        col  sigcol trans
# 0   19.992   0.206  S II
# 2   14.373   0.019  NiII
# 5   14.373   0.019  NiII
# 8   15.864   0.054  FeII
# 10  16.598   0.055  MgII
#       col  sigcol trans
# 0  19.539   0.556  S II
# 2  18.303   0.103   O I
# 3  14.348   0.019  NiII
# 6  15.353   0.116  FeII
# 7  16.534   0.055  MgII
# 9  13.094   0.089  CuII
#       col  sigcol trans
# 0  17.437   0.395  S II
# 2  14.371   0.017  NiII
# 5  13.234   0.068  CuII
# 6  15.774   0.053  FeII
# 8  16.637   0.051  MgII

# %%
directories = [d for d in os.listdir(base_directory)
               if os.path.isdir(os.path.join(base_directory, d))]

records = []

for specdir in directories:
    fn = os.path.join(base_directory, specdir, "compiledVPoutputs.dat")
    if not os.path.isfile(fn):
        continue

    df = pd.read_csv(fn, sep = "|")
    df = df[(df["zsys"] > 0.0002) & (df["sigcol"] != 0.0)]
    records.append(df[["trans", "col", "sigcol"]])

all_measurements = pd.concat(records, ignore_index = True)

def random_effects_mean(vals, sigmas):
    vals = np.asarray(vals, dtype = float)
    sigmas = np.asarray(sigmas, dtype = float)
    var = sigmas ** 2

    w  = 1.0 / var
    mu = (w * vals).sum() / w.sum()

    Q  = (w * (vals - mu) ** 2).sum()
    df = len(vals) - 1
    c  = w.sum() - (w ** 2).sum() / w.sum()
    T2 = max(0.0, (Q - df) / c) if c > 0 else 0.0

    w_re = 1.0 / (var + T2)
    mean = (w_re * vals).sum() / w_re.sum()
    std  = np.sqrt(1.0 / w_re.sum())
    return mean, std

combined = (
    all_measurements
    .groupby("trans", sort = True)
    .apply(lambda g: random_effects_mean(g["col"], g["sigcol"]))
    .apply(pd.Series)
    .reset_index()
    .rename(columns = {0: "col_combined", 1: "sigcol_combined"})
)

combined = combined.sort_values("trans").reset_index(drop = True)

for _, row in combined.iterrows():
    print(f"{row.trans}  {row.col_combined:.3f} ± {row.sigcol_combined:.3f}")

output_file = os.path.join(notebook_directory, "abundances_e140m.txt")

with open(output_file, "w") as f:
    for _, row in combined.iterrows():
        f.write(f"{row.trans} {row.col_combined:.3f} {row.sigcol_combined:.3f}\n")
# Out:
# CuII  13.183 ± 0.042
# FeII  15.719 ± 0.073
# MgII  16.577 ± 0.026
# NiII  14.360 ± 0.008
# O I  18.391 ± 0.066
# S II  18.772 ± 0.733
# /var/folders/7n/v6gcxcpj68q6nnv2znnc85xc0000gn/T/ipykernel_1320/1251576660.py:38: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: random_effects_mean(g["col"], g["sigcol"]))

# %%
# END
