# %%
import os
import re
import glob
import numpy as np
import pandas as pd

from importlib import reload
from joebvp import cfg, utils, VPmeasure
# Out:
# read_sets: Using set file --
#   C:\Users\Billy\AppData\Local\Programs\Python\Python312\Lib\site-packages\linetools\lists\sets\llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# linetools.lists.parse: Reading linelist ---
#    C:\Users\Billy\AppData\Local\Programs\Python\Python312\Lib\site-packages\linetools/data/lines/morton03_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    C:\Users\Billy\AppData\Local\Programs\Python\Python312\Lib\site-packages\linetools/data/lines/verner96_tab1.fits.gz
# joebvp.makevoigt: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# joebvp.VPmeasure: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# linetools.lists.parse: Reading linelist ---
#    C:\Users\Billy\AppData\Local\Programs\Python\Python312\Lib\site-packages\linetools/data/lines/morton03_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    C:\Users\Billy\AppData\Local\Programs\Python\Python312\Lib\site-packages\linetools/data/lines/verner96_tab1.fits.gz
# joebvp.makevoigt: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# C:\Users\Billy\AppData\Local\Programs\Python\Python312\Lib\site-packages\joebvp
# joebvp.utils: No local joebvp_cfg.py found, using default cfg.py file from joebvp.

# %%
def replace_string(input_str):
    segment = """lt_xspec [dataset_name]_x1d.fits 
lt_continuumfit --redshift 0.0009 [dataset_name]_x1d.fits [dataset_name]_continuumfit.fits
pyigm_igmguesses [dataset_name]_continuumfit.fits -o [dataset_name]_x1dfits_model.json
pyigm_fitdla --out_file [dataset_name]_xfitdla.json [dataset_name]_continuumfit.fits 0"""
    
    modified_segment = segment.replace("[dataset_name]", input_str)
    print(modified_segment)
    
replace_string("o5ez01030")
# Out:
# lt_xspec o5ez01030_x1d.fits
# lt_continuumfit --redshift 0.0009 o5ez01030_x1d.fits o5ez01030_continuumfit.fits
# pyigm_igmguesses o5ez01030_continuumfit.fits -o o5ez01030_x1dfits_model.json
# pyigm_fitdla --out_file o5ez01030_xfitdla.json o5ez01030_continuumfit.fits 0

# %%
reload(cfg)

d = pd.DataFrame({
    'instr': ['COS', 'COS', 'COS', 'COS', 'STIS', 'STIS', 'Gaussian'],
    'gratings': ['G130M', 'G160M', 'G185M', 'G225M', 'E230M', 'E140M', 'N/A'],
    'slits': ['NA', 'NA', 'NA', 'NA', '0.2x0.2', '0.2x0.2', 'NA'],
    'lsfranges': [[1100, 1460], [1400, 1800], [1800, 2100], [2100, 2278], [1607, 3129], [1144, 1729], [899, 1191]],
    'lps': ['1', '1', '1', '1', '1', '1', 'NA'],
    'cen_wave': ['1291', '1611', '1953', '2250', '1978', '1425', 'NA'],
    'pixel_scales': [None, None, None, None, None, None, 0.013], 
    'fwhms': [None, None, None, None, None, None, 0.02]
})

num = 5

cfg.lsfs = []
for col in ['instr', 'gratings', 'slits', 'cen_wave', 'pixel_scales', 'fwhms']:
    setattr(cfg, col, [d.at[num, col]])

cfg.lsfranges = np.array([d.at[num, 'lsfranges']])

# %%
base_directory = "C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M"
directories = sorted([d for d in os.listdir(base_directory) if d.startswith("E140M")])

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_models = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))
    continuumfits = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))

    utils.pyigm_to_veeper(igm_models[0], continuumfits[0])

    os.chdir(base_directory)
# Out:
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    component_groups_dir = os.path.join(current_directory, "component_groups")
    output_dir = os.path.join(current_directory, "modified_component_groups")

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    mc_lines_file = "C:/Users/Billy/Documents/BillyJessExploratory/04232025/mc_lines_metal_e140m.txt"
    mc_lines_df = pd.read_csv(mc_lines_file, sep = r"\s+", header = None, names = ["line", "wavelength"])
    mc_lines_df["wavelength"] = mc_lines_df["wavelength"].astype(float)

    def is_valid_line(row, line_df):
        trans = row["trans"].strip()
        restwave = row["restwave"]
        matching_lines = line_df[line_df["line"] == trans]
        for wave in matching_lines["wavelength"]:
            if 0.997 * wave <= restwave <= 1.003 * wave:
                return True
        return False

    input_files = glob.glob(os.path.join(component_groups_dir, "*.txt"))

    for file in input_files:
        df = pd.read_csv(file, sep = "|")
        df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    
        df["restwave"] = pd.to_numeric(df["restwave"], errors = "coerce")
        df["bval"] = pd.to_numeric(df["bval"], errors = "coerce")
    
        valid_mask = df.apply(lambda row: is_valid_line(row, mc_lines_df), axis = 1)
        df_filtered = df[valid_mask].copy()
    
        # df_filtered["col"] = df_filtered["col"] - 0.2
        df_filtered["bval"] = df_filtered["bval"] / 2
    
        output_file = os.path.join(output_dir, os.path.basename(file))
        df_filtered.to_csv(output_file, sep = "|", index = False)
        # print(f"Processed file: {os.path.basename(file)} -> {output_file}")

# %%
# Before fitting, should manually adjust the input group files

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_models = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))
    continuumfits = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))

    component_groups_dir = os.path.join(current_directory, "modified_component_groups")
    
    input_group_files = sorted([f for f in glob.glob(os.path.join(component_groups_dir, "input_group_*.txt")) if re.match(r".*input_group_\d+\.txt$", f)])

    VPmeasure.batch_fit(continuumfits[0], input_group_files, filepath = './modified_component_groups/')

    os.chdir(base_directory)
# Out:
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 2.8703e+01, final cost 2.0599e+01, first-order optimality 1.77e-03.
#
# Fit results:
#
# 1239.93	 0.000940	 16.189	 11.913	 -2.4527
#  	  	  	 0.077	 2.66	 1.85
#
# 1240.39	 0.000940	 16.189	 11.913	 -2.4527
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 0.749065
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 2.8703e+01, final cost 2.0599e+01, first-order optimality 1.77e-03.
#
# Fit results:
#
# 1239.93	 0.000940	 16.189	 11.913	 -2.4527
#  	  	  	 0.077	 2.66	 1.85
#
# 1240.39	 0.000940	 16.189	 11.913	 -2.4527
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 0.749065
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M10\modified_component_groups\input_group_0.txt
# Line parameters written to:
# C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M10\modified_component_groups\input_group_0.VP
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M10\modified_component_groups\input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M10\modified_component_groups\input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 2.2520e+02, final cost 4.3144e+01, first-order optimality 7.24e-04.
#
# Fit results:
#
# 1250.58	 0.000950	 15.905	 13.738	 -4.7125
#  	  	  	 0.161	 1.546	 0.775
#
# 1253.8	 0.000950	 15.905	 13.738	 -4.7125
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.250556
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 2.2520e+02, final cost 4.3144e+01, first-order optimality 7.24e-04.
#
# Fit results:
#
# 1250.58	 0.000950	 15.905	 13.738	 -4.7125
#  	  	  	 0.161	 1.546	 0.775
#
# 1253.8	 0.000950	 15.905	 13.738	 -4.7125
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.250556
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M10\modified_component_groups\input_group_1.txt
# Line parameters written to:
# C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M10\modified_component_groups\input_group_1.VP
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M10\modified_component_groups\input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M10\modified_component_groups\input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 26, initial cost 7.3091e+01, final cost 6.4194e+01, first-order optimality 6.89e-03.
#
# Fit results:
#
# 1317.22	 0.000920	 13.880	 13.609	 0.88265
#  	  	  	 0.053	 2.276	 1.549
#
# 1370.13	 0.000920	 13.880	 13.609	 0.88265
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000920	 13.880	 13.609	 0.88265
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.565700
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 26, initial cost 7.3091e+01, final cost 6.4194e+01, first-order optimality 6.89e-03.
#
# Fit results:
#
# 1317.22	 0.000920	 13.880	 13.609	 0.88265
#  	  	  	 0.053	 2.276	 1.549
#
# 1370.13	 0.000920	 13.880	 13.609	 0.88265
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000920	 13.880	 13.609	 0.88265
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.565700
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M10\modified_component_groups\input_group_2.txt
# Line parameters written to:
# C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M10\modified_component_groups\input_group_2.VP
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M10\modified_component_groups\input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M10\modified_component_groups\input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 21, initial cost 1.7045e+01, final cost 1.2524e+01, first-order optimality 5.40e-03.
#
# Fit results:
#
# 1358.77	 0.000940	 12.930	 4.0000	 -0.45935
#  	  	  	 0.168	 3.454	 1.941
#
#
# Reduced chi-squared: 1.192783
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 21, initial cost 1.7045e+01, final cost 1.2524e+01, first-order optimality 5.40e-03.
#
# Fit results:
#
# 1358.77	 0.000940	 12.930	 4.0000	 -0.45935
#  	  	  	 0.168	 3.454	 1.941
#
#
# Reduced chi-squared: 1.192783
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M10\modified_component_groups\input_group_3.txt
# Line parameters written to:
# C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M10\modified_component_groups\input_group_3.VP
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M10\modified_component_groups\input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M10\modified_component_groups\input_group_3_inspect.fits
#
# VPmeasure: 4/4 fits converged, 0/4 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 4.8737e+01, final cost 3.6415e+01, first-order optimality 2.26e-03.
#
# Fit results:
#
# 1239.93	 0.000940	 16.370	 7.1314	 -5.2933
#  	  	  	 0.263	 3.27	 1.784
#
# 1240.39	 0.000940	 16.370	 7.1314	 -5.2933
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.428032
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 4.8737e+01, final cost 3.6415e+01, first-order optimality 2.26e-03.
#
# Fit results:
#
# 1239.93	 0.000940	 16.370	 7.1314	 -5.2933
#  	  	  	 0.263	 3.27	 1.784
#
# 1240.39	 0.000940	 16.370	 7.1314	 -5.2933
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.428032
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M20\modified_component_groups\input_group_0.txt
# Line parameters written to:
# C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M20\modified_component_groups\input_group_0.VP
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M20\modified_component_groups\input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M20\modified_component_groups\input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 2.7599e+02, final cost 6.3904e+01, first-order optimality 3.02e-02.
#
# Fit results:
#
# 1250.58	 0.000940	 18.193	 8.2174	 -2.724
#  	  	  	 5.657	 7.404	 0.946
#
# 1253.8	 0.000940	 18.193	 8.2174	 -2.724
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.659856
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 2.7599e+02, final cost 6.3904e+01, first-order optimality 3.02e-02.
#
# Fit results:
#
# 1250.58	 0.000940	 18.193	 8.2174	 -2.724
#  	  	  	 5.657	 7.404	 0.946
#
# 1253.8	 0.000940	 18.193	 8.2174	 -2.724
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.659856
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M20\modified_component_groups\input_group_1.txt
# Line parameters written to:
# C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M20\modified_component_groups\input_group_1.VP
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M20\modified_component_groups\input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M20\modified_component_groups\input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 4.9291e+01, final cost 4.2360e+01, first-order optimality 5.90e-03.
#
# Fit results:
#
# 1317.22	 0.000930	 13.968	 6.9052	 0.58752
#  	  	  	 0.102	 2.497	 1.242
#
# 1370.13	 0.000930	 13.968	 6.9052	 0.58752
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000930	 13.968	 6.9052	 0.58752
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.008566
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 4.9291e+01, final cost 4.2360e+01, first-order optimality 5.90e-03.
#
# Fit results:
#
# 1317.22	 0.000930	 13.968	 6.9052	 0.58752
#  	  	  	 0.102	 2.497	 1.242
#
# 1370.13	 0.000930	 13.968	 6.9052	 0.58752
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000930	 13.968	 6.9052	 0.58752
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.008566
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M20\modified_component_groups\input_group_2.txt
# Line parameters written to:
# C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M20\modified_component_groups\input_group_2.VP
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M20\modified_component_groups\input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M20\modified_component_groups\input_group_2_inspect.fits
#
# VPmeasure: 3/3 fits converged, 0/3 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 4.5801e+01, final cost 3.5945e+01, first-order optimality 6.40e-04.
#
# Fit results:
#
# 1239.93	 0.000920	 16.908	 4.0000	 3.4222
#  	  	  	 1.924	 3.274	 1.699
#
# 1240.39	 0.000920	 16.908	 4.0000	 3.4222
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.307074
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 4.5801e+01, final cost 3.5945e+01, first-order optimality 6.40e-04.
#
# Fit results:
#
# 1239.93	 0.000920	 16.908	 4.0000	 3.4222
#  	  	  	 1.924	 3.274	 1.699
#
# 1240.39	 0.000920	 16.908	 4.0000	 3.4222
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.307074
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M30\modified_component_groups\input_group_0.txt
# Line parameters written to:
# C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M30\modified_component_groups\input_group_0.VP
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M30\modified_component_groups\input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M30\modified_component_groups\input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 3.1570e+02, final cost 6.8049e+01, first-order optimality 2.00e-02.
#
# Fit results:
#
# 1250.58	 0.000950	 18.925	 6.7100	 -5.9993
#  	  	  	 0.821	 1.066	 0.971
#
# 1253.8	 0.000950	 18.925	 6.7100	 -5.9993
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.972434
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 3.1570e+02, final cost 6.8049e+01, first-order optimality 2.00e-02.
#
# Fit results:
#
# 1250.58	 0.000950	 18.925	 6.7100	 -5.9993
#  	  	  	 0.821	 1.066	 0.971
#
# 1253.8	 0.000950	 18.925	 6.7100	 -5.9993
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.972434
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M30\modified_component_groups\input_group_1.txt
# Line parameters written to:
# C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M30\modified_component_groups\input_group_1.VP
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M30\modified_component_groups\input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M30\modified_component_groups\input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 6.5852e+01, final cost 3.6293e+01, first-order optimality 4.10e-03.
#
# Fit results:
#
# 1317.22	 0.000910	 13.916	 10.630	 8.6032
#  	  	  	 0.053	 2.726	 1.525
#
# 1370.13	 0.000910	 13.916	 10.630	 8.6032
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000910	 13.916	 10.630	 8.6032
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 0.896131
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 6.5852e+01, final cost 3.6293e+01, first-order optimality 4.10e-03.
#
# Fit results:
#
# 1317.22	 0.000910	 13.916	 10.630	 8.6032
#  	  	  	 0.053	 2.726	 1.525
#
# 1370.13	 0.000910	 13.916	 10.630	 8.6032
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000910	 13.916	 10.630	 8.6032
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 0.896131
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M30\modified_component_groups\input_group_2.txt
# Line parameters written to:
# C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M30\modified_component_groups\input_group_2.VP
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M30\modified_component_groups\input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to C:/Users/Billy/Documents/BillyJessExploratory/04232025/LH10-3020/E140M\E140M30\modified_component_groups\input_group_2_inspect.fits
#
# VPmeasure: 3/3 fits converged, 0/3 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    df = pd.read_csv('compiledVPoutputs.dat', sep = '|')
    filtered_df = df[df['zsys'] > 0.0004]
    filtered_df = filtered_df[filtered_df['sigcol'] != 0.000]
    result = filtered_df[['col', 'sigcol', 'trans']]

    unique_result = result.drop_duplicates()
    print(unique_result)
    os.chdir(base_directory)
# Out:
#       col  sigcol trans
# 0  16.189   0.077  MgII
# 2  15.905   0.161  S II
# 4  13.880   0.053  NiII
# 7  12.930   0.168  CuII
#       col  sigcol trans
# 0  16.370   0.263  MgII
# 2  18.193   5.657  S II
# 4  13.968   0.102  NiII
#       col  sigcol trans
# 0  16.908   1.924  MgII
# 2  18.925   0.821  S II
# 4  13.916   0.053  NiII

# %%
# END
