# %%
use_powr = "STIS" # "All", "STIS", "COS", "None"

# %%
import os
import re
import sys
import glob
import toml
import shutil
import textwrap
import subprocess

import numpy as np
import pandas as pd

from pathlib import Path
from astropy.io import fits
from importlib import reload
from astropy.table import Table
from scipy.interpolate import interp1d
from joebvp import cfg, utils, VPmeasure
# Out:
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/morton03_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/verner96_tab1.fits.gz
# joebvp.makevoigt: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# joebvp.VPmeasure: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/morton03_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/verner96_tab1.fits.gz
# joebvp.makevoigt: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/joebvp
# joebvp.utils: No local joebvp_cfg.py found, using default cfg.py file from joebvp.

# %%
target_directory = Path().resolve()
spectra_directories = sorted([d for d in os.listdir(target_directory) if d.startswith("G") or d.startswith("E")])
galaxy = target_directory.parts[target_directory.parts.index('float-for-morrow') + 1]
print(spectra_directories)
print(galaxy)
python_cmd = sys.executable
if galaxy == "LMC":
    model_file = "/Users/billyli/Documents/stellar template fitting/powr-OB-lmc-vd3.nc"
elif galaxy == "SMC":
    model_file = "/Users/billyli/Documents/stellar template fitting/powr-OB-smc-vd3.nc"
else:
    use_powr = "None"
runner_path = "/Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py"
# Out:
# ['E140M_1425_0.2x0.2_2028.000_14476', 'E140M_1425_0.2x0.2_2070.000_13373', 'E140M_1425_0.2x0.2_2548.000_11623', 'E140M_1425_0.2x0.2_2608.000_13373', 'E140M_1425_0.2x0.2_2627.000_11623', 'E140M_1425_0.2x0.2_2776.000_9094', 'E140M_1425_0.2x0.2_2837.000_14476', 'E140M_1425_0.2x0.2_3236.000_7480', 'E230M_1978_0.2x0.2_1609.000_9094', 'E230M_2707_0.2x0.2_1300.000_9094']
# SMC

# %%
def parse_directory(dirname):

    Target = target_directory.name

    parts = dirname.split("_")

    Grating = parts[0]
    Cenwave = int(parts[1])
    T_exp = str(parts[3])
    PID = int(parts[4])

    if Grating.startswith("G"):
        
        Instrument = "COS"
        LP = parts[2]

        return {
            "Target": Target, 
            "Instrument": Instrument, 
            "Grating": Grating, 
            "Cenwave": Cenwave, 
            "LP": LP, 
            "Aperture": None, 
            "T_exp": T_exp, 
            "PID": PID, 
        }
        
    else:
        
        Instrument = "STIS"
        Aperture = parts[2]
        return {
            "Target": Target, 
            "Instrument": Instrument, 
            "Grating": Grating, 
            "Cenwave": Cenwave, 
            "LP": None, 
            "Aperture": Aperture, 
            "T_exp": T_exp, 
            "PID": PID, 
        }

records = [parse_directory(d) for d in spectra_directories]
df = pd.DataFrame.from_records(records)
display(df)
# Out:
#     Target Instrument Grating  Cenwave    LP Aperture     T_exp    PID
# 0  HD 5980       STIS   E140M     1425  None  0.2x0.2  2028.000  14476
# 1  HD 5980       STIS   E140M     1425  None  0.2x0.2  2070.000  13373
# 2  HD 5980       STIS   E140M     1425  None  0.2x0.2  2548.000  11623
# 3  HD 5980       STIS   E140M     1425  None  0.2x0.2  2608.000  13373
# 4  HD 5980       STIS   E140M     1425  None  0.2x0.2  2627.000  11623
# 5  HD 5980       STIS   E140M     1425  None  0.2x0.2  2776.000   9094
# 6  HD 5980       STIS   E140M     1425  None  0.2x0.2  2837.000  14476
# 7  HD 5980       STIS   E140M     1425  None  0.2x0.2  3236.000   7480
# 8  HD 5980       STIS   E230M     1978  None  0.2x0.2  1609.000   9094
# 9  HD 5980       STIS   E230M     2707  None  0.2x0.2  1300.000   9094

# %%
if galaxy == "LMC":
    guess_redshift = 0.00087
elif galaxy == "SMC":
    guess_redshift = 0.00053

def generate_command_continuumfit_cos(path, dataset_name):
    segment = f"""cd "[path]" && lt_continuumfit --redshift {guess_redshift} [dataset_name]_x1dsum.fits [dataset_name]_continuumfit_manual.fits"""
    modified_segment = segment.replace("[dataset_name]", dataset_name)
    modified_segment = modified_segment.replace("[path]", path)
    print(modified_segment)

def generate_command_continuumfit_stis(path, dataset_name):
    segment = f"""cd "[path]" && lt_continuumfit --redshift {guess_redshift} [dataset_name]_x1d.fits [dataset_name]_continuumfit_manual.fits"""
    modified_segment = segment.replace("[dataset_name]", dataset_name)
    modified_segment = modified_segment.replace("[path]", path)
    print(modified_segment)
    
for directory in spectra_directories:
    path = target_directory / directory
    for file in os.listdir(path):
        if file.endswith("_x1dsum.fits"):
            dataset_name = file.replace("_x1dsum.fits", "")
            path = str(path) + "/"
            generate_command_continuumfit_cos(path, dataset_name)
            print("\r")
        elif file.endswith("_x1d.fits"):
            dataset_name = file.replace("_x1d.fits", "")
            path = str(path) + "/"
            generate_command_continuumfit_stis(path, dataset_name)
            print("\r")
# Out:
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/" && lt_continuumfit --redshift 0.00053 od3g01020_x1d.fits od3g01020_continuumfit_manual.fits
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/" && lt_continuumfit --redshift 0.00053 ocax01020_x1d.fits ocax01020_continuumfit_manual.fits
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/" && lt_continuumfit --redshift 0.00053 ob2na1010_x1d.fits ob2na1010_continuumfit_manual.fits
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/" && lt_continuumfit --redshift 0.00053 ocax01010_x1d.fits ocax01010_continuumfit_manual.fits
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/" && lt_continuumfit --redshift 0.00053 ob2na1020_x1d.fits ob2na1020_continuumfit_manual.fits
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2776.000_9094/" && lt_continuumfit --redshift 0.00053 o6cd01010_x1d.fits o6cd01010_continuumfit_manual.fits
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2837.000_14476/" && lt_continuumfit --redshift 0.00053 od3g01010_x1d.fits od3g01010_continuumfit_manual.fits
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/" && lt_continuumfit --redshift 0.00053 o55q05070_x1d.fits o55q05070_continuumfit_manual.fits
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480//" && lt_continuumfit --redshift 0.00053 o55q06070_x1d.fits o55q06070_continuumfit_manual.fits
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480///" && lt_continuumfit --redshift 0.00053 o55q03070_x1d.fits o55q03070_continuumfit_manual.fits
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480////" && lt_continuumfit --redshift 0.00053 o55q04070_x1d.fits o55q04070_continuumfit_manual.fits
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/////" && lt_continuumfit --redshift 0.00053 o55q01070_x1d.fits o55q01070_continuumfit_manual.fits
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480//////" && lt_continuumfit --redshift 0.00053 o55q02070_x1d.fits o55q02070_continuumfit_manual.fits
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_1978_0.2x0.2_1609.000_9094/" && lt_continuumfit --redshift 0.00053 o6cd01020_x1d.fits o6cd01020_continuumfit_manual.fits
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_2707_0.2x0.2_1300.000_9094/" && lt_continuumfit --redshift 0.00053 o6cd01030_x1d.fits o6cd01030_continuumfit_manual.fits

# %%
for i in range(len(spectra_directories)):

    directory = spectra_directories[i]
    path = target_directory / directory
    Instrument = df.iloc[i]["Instrument"]

    if Instrument == "COS" and (use_powr == "All" or use_powr == "COS"):

        for file in os.listdir(path):

            Grating = df.iloc[i]["Grating"]
            
            if file.endswith("_continuumfit_manual.fits") and Grating == "G130M":

                dataset_name = file.replace("_continuumfit_manual.fits", "")
                subdir = path / dataset_name
                subdir.mkdir(exist_ok = True)
                src = path / file
                dst = subdir / f"{dataset_name}_continuumfit.fits"

                problem = df.iloc[i]["Target"].lower()
                target = df.iloc[i]["Target"].upper()
            
                spec_file = src
                
                wave_min = 1132
                wave_max = 1420
            
                toml_content = textwrap.dedent(f"""
                [target_info]
                problem    = "{problem}"
                target     = "{target}"
                spec_file  = "{spec_file}"
                model_file = "{model_file}"
                instrument = "cos_g130m"
            
                [include_wave_range]
                wave_range = [ {wave_min}, {wave_max},]
            
                [exclude_wave_ranges]
                dla = [[1200, 1220,] ]
                gap = [[1270, 1290,] ]
            
                [vshift]
                min = 50
                max = 550
                delta = 50
            
                [vsini]
                min = 50
                max = 350
                delta = 50
            
                [exclude_vranges.ions]
                linelist = "ISM"
                vrange = [-75, 350]
                drop_species = []
            
                [target_info.plot_ranges_kwargs.all_merged]
                color = "gainsboro"
                """).lstrip()

                tmp_toml = subdir / f"{problem}.toml"
                tmp_toml.write_text(toml_content)
            
                subprocess.run([python_cmd, runner_path, str(tmp_toml)], check = True, cwd = subdir)
            
                csv_path = subdir / f"{problem}.csv"
                model_continuum = Table.read(str(csv_path), format = "csv")
            
                wave = model_continuum['wave'].data
                flux = model_continuum['flux'].data
                err = model_continuum['err'].data
                wave_model = model_continuum['wave'].data
                best_fit_spec = model_continuum['best_fit_spec'].data
            
                with fits.open(src, mode = 'readonly') as hdul:
                    new_hdul = fits.HDUList([h.copy() for h in hdul])
            
                flux_original = new_hdul[0].data
                wave_original = new_hdul[2].data
                continuum_hdu = new_hdul[3]
                
                continuum_original = continuum_hdu.data
                
                mask = (wave_original >= wave_min) & (wave_original <= wave_max)
                flux_original_masked = flux_original[mask]
            
                normalization_factor = flux_original_masked[1000] / flux[1000]
                normalization_factor_2 = flux_original_masked[1500] / flux[1500]
                normalization_factor_3 = flux_original_masked[2000] / flux[2000]
            
                if not (np.allclose([normalization_factor, normalization_factor_2, normalization_factor_3], normalization_factor, rtol = 0.001)):
                    raise ValueError(f"Normalization factors disagree: {normalization_factor:.3f}, {normalization_factor_2:.3f}, {normalization_factor_3:.3f}")
            
                continuum_hdu.data[mask] = best_fit_spec * normalization_factor
            
                new_hdul.writeto(str(dst), overwrite = True)

            if file.endswith("_continuumfit_manual.fits") and Grating == "G160M":

                dataset_name = file.replace("_continuumfit_manual.fits", "")
                subdir = path / dataset_name
                subdir.mkdir(exist_ok = True)
                src = path / file
                dst = subdir / f"{dataset_name}_continuumfit.fits"

                problem = df.iloc[i]["Target"].lower()
                target = df.iloc[i]["Target"].upper()
            
                spec_file = src
                
                wave_min = 1400
                wave_max = 1800
            
                toml_content = textwrap.dedent(f"""
                [target_info]
                problem    = "{problem}"
                target     = "{target}"
                spec_file  = "{spec_file}"
                model_file = "{model_file}"
                instrument = "cos_g160m"
            
                [include_wave_range]
                wave_range = [ {wave_min}, {wave_max},]
            
                [exclude_wave_ranges]
            
                [vshift]
                min = 50
                max = 550
                delta = 50
            
                [vsini]
                min = 50
                max = 350
                delta = 50
            
                [exclude_vranges.ions]
                linelist = "ISM"
                vrange = [-75, 350]
                drop_species = []
            
                [target_info.plot_ranges_kwargs.all_merged]
                color = "gainsboro"
                """).lstrip()

                tmp_toml = subdir / f"{problem}.toml"
                tmp_toml.write_text(toml_content)
            
                subprocess.run([python_cmd, runner_path, str(tmp_toml)], check = True, cwd = subdir)
            
                csv_path = subdir / f"{problem}.csv"
                model_continuum = Table.read(str(csv_path), format = "csv")
            
                wave = model_continuum['wave'].data
                flux = model_continuum['flux'].data
                err = model_continuum['err'].data
                wave_model = model_continuum['wave'].data
                best_fit_spec = model_continuum['best_fit_spec'].data
            
                with fits.open(src, mode = 'readonly') as hdul:
                    new_hdul = fits.HDUList([h.copy() for h in hdul])
            
                flux_original = new_hdul[0].data
                wave_original = new_hdul[2].data
                continuum_hdu = new_hdul[3]
                
                continuum_original = continuum_hdu.data
                
                mask = (wave_original >= wave_min) & (wave_original <= wave_max)
                flux_original_masked = flux_original[mask]
            
                normalization_factor = flux_original_masked[1000] / flux[1000]
                normalization_factor_2 = flux_original_masked[1500] / flux[1500]
                normalization_factor_3 = flux_original_masked[2000] / flux[2000]
            
                if not (np.allclose([normalization_factor, normalization_factor_2, normalization_factor_3], normalization_factor, rtol = 0.001)):
                    raise ValueError(f"Normalization factors disagree: {normalization_factor:.3f}, {normalization_factor_2:.3f}, {normalization_factor_3:.3f}")
            
                continuum_hdu.data[mask] = best_fit_spec * normalization_factor
            
                new_hdul.writeto(str(dst), overwrite = True)

            if file.endswith("_continuumfit_manual.fits") and Grating == "G185M":

                dataset_name = file.replace("_continuumfit_manual.fits", "")
                subdir = path / dataset_name
                subdir.mkdir(exist_ok = True)
                src = path / file
                dst = subdir / f"{dataset_name}_continuumfit.fits"
                
                problem = df.iloc[i]["Target"].lower()
                target = df.iloc[i]["Target"].upper()
            
                spec_file = src
                
                wave_min = 1800
                wave_max = 2100
            
                toml_content = textwrap.dedent(f"""
                [target_info]
                problem    = "{problem}"
                target     = "{target}"
                spec_file  = "{spec_file}"
                model_file = "{model_file}"
                instrument = "cos_g185m"
            
                [include_wave_range]
                wave_range = [ {wave_min}, {wave_max},]
            
                [exclude_wave_ranges]
                dla = [[1200, 1220,] ]
                gap = [[1270, 1290,] ]
            
                [vshift]
                min = 50
                max = 550
                delta = 50
            
                [vsini]
                min = 50
                max = 350
                delta = 50
            
                [exclude_vranges.ions]
                linelist = "ISM"
                vrange = [-75, 350]
                drop_species = []
            
                [target_info.plot_ranges_kwargs.all_merged]
                color = "gainsboro"
                """).lstrip()

                tmp_toml = subdir / f"{problem}.toml"
                tmp_toml.write_text(toml_content)
            
                subprocess.run([python_cmd, runner_path, str(tmp_toml)], check = True, cwd = subdir)
            
                csv_path = subdir / f"{problem}.csv"
                model_continuum = Table.read(str(csv_path), format = "csv")
            
                wave = model_continuum['wave'].data
                flux = model_continuum['flux'].data
                err = model_continuum['err'].data
                wave_model = model_continuum['wave'].data
                best_fit_spec = model_continuum['best_fit_spec'].data
            
                with fits.open(src, mode = 'readonly') as hdul:
                    new_hdul = fits.HDUList([h.copy() for h in hdul])
            
                flux_original = new_hdul[0].data
                wave_original = new_hdul[2].data
                continuum_hdu = new_hdul[3]
                
                continuum_original = continuum_hdu.data
                
                mask = (wave_original >= wave_min) & (wave_original <= wave_max)
                flux_original_masked = flux_original[mask]
            
                normalization_factor = flux_original_masked[1000] / flux[1000]
                normalization_factor_2 = flux_original_masked[1500] / flux[1500]
                normalization_factor_3 = flux_original_masked[2000] / flux[2000]
            
                if not (np.allclose([normalization_factor, normalization_factor_2, normalization_factor_3], normalization_factor, rtol = 0.001)):
                    raise ValueError(f"Normalization factors disagree: {normalization_factor:.3f}, {normalization_factor_2:.3f}, {normalization_factor_3:.3f}")
            
                continuum_hdu.data[mask] = best_fit_spec * normalization_factor
            
                new_hdul.writeto(str(dst), overwrite = True)
                
    if Instrument == "STIS" and (use_powr == "All" or use_powr == "STIS"):

        for file in os.listdir(path):

            Grating = df.iloc[i]["Grating"]
            
            if file.endswith("_continuumfit_manual.fits") and Grating == "E140M":

                dataset_name = file.replace("_continuumfit_manual.fits", "")
                subdir = path / dataset_name
                subdir.mkdir(exist_ok = True)
                src = path / file
                dst = subdir / f"{dataset_name}_continuumfit.fits"

                problem = df.iloc[i]["Target"].lower()
                target = df.iloc[i]["Target"].upper()
            
                spec_file = src
                
                wave_min = 1250
                wave_max = 1625
            
                toml_content = textwrap.dedent(f"""
                [target_info]
                problem    = "{problem}"
                target     = "{target}"
                spec_file  = "{spec_file}"
                model_file = "{model_file}"
                instrument = "stis_e140m"
            
                [include_wave_range]
                wave_range = [ {wave_min}, {wave_max},]
            
                [exclude_wave_ranges]
            
                [vshift]
                min = 50
                max = 550
                delta = 50
            
                [vsini]
                min = 50
                max = 350
                delta = 50
            
                [exclude_vranges.ions]
                linelist = "ISM"
                vrange = [-25, 150]
                drop_species = []
            
                [target_info.plot_ranges_kwargs.all_merged]
                color = "gainsboro"
                """).lstrip()

                tmp_toml = subdir / f"{problem}.toml"
                tmp_toml.write_text(toml_content)
            
                subprocess.run([python_cmd, runner_path, str(tmp_toml)], check = True, cwd = subdir)
            
                csv_path = subdir / f"{problem}.csv"
                model_continuum = Table.read(str(csv_path), format = "csv")
            
                wave = model_continuum['wave'].data
                flux = model_continuum['flux'].data
                err = model_continuum['err'].data
                wave_model = model_continuum['wave'].data
                best_fit_spec = model_continuum['best_fit_spec'].data
            
                with fits.open(src, mode = 'readonly') as hdul:
                    new_hdul = fits.HDUList([h.copy() for h in hdul])
            
                flux_original = new_hdul[0].data
                wave_original = new_hdul[2].data
                continuum_hdu = new_hdul[3]
                
                continuum_original = continuum_hdu.data
                
                mask = (wave_original >= wave_min) & (wave_original <= wave_max)
                flux_original_masked = flux_original[mask]
            
                normalization_factor = flux_original_masked[1000] / flux[1000]
                normalization_factor_2 = flux_original_masked[1500] / flux[1500]
                normalization_factor_3 = flux_original_masked[2000] / flux[2000]
            
                if not (np.allclose([normalization_factor, normalization_factor_2, normalization_factor_3], normalization_factor, rtol = 0.001)):
                    raise ValueError(f"Normalization factors disagree: {normalization_factor:.3f}, {normalization_factor_2:.3f}, {normalization_factor_3:.3f}")
            
                continuum_hdu.data[mask] = best_fit_spec * normalization_factor
            
                new_hdul.writeto(str(dst), overwrite = True)

            if file.endswith("_continuumfit_manual.fits") and Grating == "E230M":

                dataset_name = file.replace("_continuumfit_manual.fits", "")
                subdir = path / dataset_name
                subdir.mkdir(exist_ok = True)
                src = path / file
                dst = subdir / f"{dataset_name}_continuumfit.fits"

                problem = df.iloc[i]["Target"].lower()
                target = df.iloc[i]["Target"].upper()
            
                spec_file = src
                
                wave_min = 1600
                wave_max = 3100
            
                toml_content = textwrap.dedent(f"""
                [target_info]
                problem    = "{problem}"
                target     = "{target}"
                spec_file  = "{spec_file}"
                model_file = "{model_file}"
                instrument = "stis_e230m"
            
                [include_wave_range]
                wave_range = [ {wave_min}, {wave_max},]
            
                [exclude_wave_ranges]
            
                [vshift]
                min = 50
                max = 550
                delta = 50
            
                [vsini]
                min = 50
                max = 350
                delta = 50
            
                [exclude_vranges.ions]
                linelist = "ISM"
                vrange = [-75, 350]
                drop_species = []
            
                [target_info.plot_ranges_kwargs.all_merged]
                color = "gainsboro"
                """).lstrip()

                tmp_toml = subdir / f"{problem}.toml"
                tmp_toml.write_text(toml_content)
            
                subprocess.run([python_cmd, runner_path, str(tmp_toml)], check = True, cwd = subdir)
            
                csv_path = subdir / f"{problem}.csv"
                model_continuum = Table.read(str(csv_path), format = "csv")
            
                wave = model_continuum['wave'].data
                flux = model_continuum['flux'].data
                err = model_continuum['err'].data
                wave_model = model_continuum['wave'].data
                best_fit_spec = model_continuum['best_fit_spec'].data
            
                with fits.open(src, mode = 'readonly') as hdul:
                    new_hdul = fits.HDUList([h.copy() for h in hdul])
            
                flux_original = new_hdul[0].data
                wave_original = new_hdul[2].data
                continuum_hdu = new_hdul[3]
                
                continuum_original = continuum_hdu.data
                
                mask = (wave_original >= wave_min) & (wave_original <= wave_max)
                flux_original_masked = flux_original[mask]
            
                normalization_factor = flux_original_masked[1000] / flux[1000]
                normalization_factor_2 = flux_original_masked[1500] / flux[1500]
                normalization_factor_3 = flux_original_masked[2000] / flux[2000]
            
                if not (np.allclose([normalization_factor, normalization_factor_2, normalization_factor_3], normalization_factor, rtol = 0.001)):
                    raise ValueError(f"Normalization factors disagree: {normalization_factor:.3f}, {normalization_factor_2:.3f}, {normalization_factor_3:.3f}")
            
                continuum_hdu.data[mask] = best_fit_spec * normalization_factor
            
                new_hdul.writeto(str(dst), overwrite = True)

    else: 

        for file in os.listdir(path):
            if file.endswith("_continuumfit_manual.fits"):
                
                dataset_name = file.replace("_continuumfit_manual.fits", "")
                subdir = path / dataset_name
                subdir.mkdir(exist_ok = True)
                src = path / file
                dst = subdir / f"{dataset_name}_continuumfit.fits"
                shutil.copy(src, dst)
# Out:
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'hd 5980', 'target': 'HD 5980', 'spec_file': '/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-smc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1250, 1625]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-25, 150], 'drop_species': []}}}
# Bad METADATA;  proceeding without
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'hd 5980', 'target': 'HD 5980', 'spec_file': '/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-smc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1250, 1625]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-25, 150], 'drop_species': []}}}
# Bad METADATA;  proceeding without
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'hd 5980', 'target': 'HD 5980', 'spec_file': '/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-smc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1250, 1625]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-25, 150], 'drop_species': []}}}
# Bad METADATA;  proceeding without
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'hd 5980', 'target': 'HD 5980', 'spec_file': '/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-smc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1250, 1625]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-25, 150], 'drop_species': []}}}
# Bad METADATA;  proceeding without
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'hd 5980', 'target': 'HD 5980', 'spec_file': '/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-smc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1250, 1625]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-25, 150], 'drop_species': []}}}
# Bad METADATA;  proceeding without
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'hd 5980', 'target': 'HD 5980', 'spec_file': '/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2776.000_9094/o6cd01010_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-smc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1250, 1625]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-25, 150], 'drop_species': []}}}
# Bad METADATA;  proceeding without
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'hd 5980', 'target': 'HD 5980', 'spec_file': '/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2837.000_14476/od3g01010_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-smc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1250, 1625]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-25, 150], 'drop_species': []}}}
# Bad METADATA;  proceeding without
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'hd 5980', 'target': 'HD 5980', 'spec_file': '/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q02070_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-smc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1250, 1625]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-25, 150], 'drop_species': []}}}
# Bad METADATA;  proceeding without
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'hd 5980', 'target': 'HD 5980', 'spec_file': '/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q03070_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-smc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1250, 1625]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-25, 150], 'drop_species': []}}}
# Bad METADATA;  proceeding without
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'hd 5980', 'target': 'HD 5980', 'spec_file': '/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q06070_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-smc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1250, 1625]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-25, 150], 'drop_species': []}}}
# Bad METADATA;  proceeding without
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'hd 5980', 'target': 'HD 5980', 'spec_file': '/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q05070_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-smc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1250, 1625]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-25, 150], 'drop_species': []}}}
# Bad METADATA;  proceeding without
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'hd 5980', 'target': 'HD 5980', 'spec_file': '/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q01070_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-smc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1250, 1625]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-25, 150], 'drop_species': []}}}
# Bad METADATA;  proceeding without
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: divide by zero encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: overflow encountered in matmul
#   r = A @ x_lsq - b
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/optimize/_lsq/lsq_linear.py:325: RuntimeWarning: invalid value encountered in matmul
#   r = A @ x_lsq - b
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'hd 5980', 'target': 'HD 5980', 'spec_file': '/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-smc-vd3.nc', 'instrument': 'stis_e140m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1250, 1625]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-25, 150], 'drop_species': []}}}
# Bad METADATA;  proceeding without
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'hd 5980', 'target': 'HD 5980', 'spec_file': '/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_1978_0.2x0.2_1609.000_9094/o6cd01020_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-smc-vd3.nc', 'instrument': 'stis_e230m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1600, 3100]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-75, 350], 'drop_species': []}}}
# Bad METADATA;  proceeding without
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_atoms.py:37: RuntimeWarning: invalid value encountered in sqrt
#   kernel = (2 * (1-ld_eps) * np.sqrt((1-x**2)) + 0.5*np.pi*ld_eps * (1-x**2))/(np.pi*(1-ld_eps/3))
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: divide by zero encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: overflow encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:160: RuntimeWarning: invalid value encountered in matmul
#   best_fits.append(design_full @ coeffs)
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: divide by zero encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: overflow encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:188: RuntimeWarning: invalid value encountered in matmul
#   best_fit_spec = design_full @ coeffs
# /Users/billyli/Documents/stellar template fitting/stellar_template_fitting_runner.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_inc_spec['best_fit_spec'] = best_fit_spec
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# {'target_info': {'problem': 'hd 5980', 'target': 'HD 5980', 'spec_file': '/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_2707_0.2x0.2_1300.000_9094/o6cd01030_continuumfit_manual.fits', 'model_file': '/Users/billyli/Documents/stellar template fitting/powr-OB-smc-vd3.nc', 'instrument': 'stis_e230m', 'plot_ranges_kwargs': {'all_merged': {'color': 'gainsboro'}}}, 'include_wave_range': {'wave_range': [1600, 3100]}, 'exclude_wave_ranges': {}, 'vshift': {'min': 50, 'max': 550, 'delta': 50}, 'vsini': {'min': 50, 'max': 350, 'delta': 50}, 'exclude_vranges': {'ions': {'linelist': 'ISM', 'vrange': [-75, 350], 'drop_species': []}}}
# Bad METADATA;  proceeding without

# %%
def generate_command_igmguesses_cos(path, dataset_name):
    segment = f"""cd "[path]" && pyigm_igmguesses [dataset_name]_continuumfit.fits -o [dataset_name]_x1dfits_model.json"""
    modified_segment = segment.replace("[dataset_name]", dataset_name)
    modified_segment = modified_segment.replace("[path]", path)
    print(modified_segment)

def generate_command_igmguesses_stis(path, dataset_name):
    segment = f"""cd "[path]" && pyigm_igmguesses [dataset_name]_continuumfit.fits -o [dataset_name]_x1dfits_model.json"""
    modified_segment = segment.replace("[dataset_name]", dataset_name)
    modified_segment = modified_segment.replace("[path]", path)
    print(modified_segment)


target_directory = Path().resolve()
spectra_directories = sorted([d for d in os.listdir(target_directory) if d.startswith("G") or d.startswith("E")])

for directory in spectra_directories:
    path = target_directory / directory
    for subdir in os.listdir(path):
        subdir_path = path / subdir
        if not subdir_path.is_dir():
            continue
        for file in os.listdir(subdir_path):
            file_path = subdir_path / file
            if file.endswith("_continuumfit.fits"):
                dataset_name = file.replace("_continuumfit.fits", "")
                generate_command_igmguesses_cos(str(subdir_path) + "/", dataset_name)
                print("\r")
# Out:
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/" && pyigm_igmguesses od3g01020_continuumfit.fits -o od3g01020_x1dfits_model.json
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/" && pyigm_igmguesses ocax01020_continuumfit.fits -o ocax01020_x1dfits_model.json
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/" && pyigm_igmguesses ob2na1010_continuumfit.fits -o ob2na1010_x1dfits_model.json
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/" && pyigm_igmguesses ocax01010_continuumfit.fits -o ocax01010_x1dfits_model.json
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020/" && pyigm_igmguesses ob2na1020_continuumfit.fits -o ob2na1020_x1dfits_model.json
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2776.000_9094/o6cd01010/" && pyigm_igmguesses o6cd01010_continuumfit.fits -o o6cd01010_x1dfits_model.json
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2837.000_14476/od3g01010/" && pyigm_igmguesses od3g01010_continuumfit.fits -o od3g01010_x1dfits_model.json
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q03070/" && pyigm_igmguesses o55q03070_continuumfit.fits -o o55q03070_x1dfits_model.json
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q06070/" && pyigm_igmguesses o55q06070_continuumfit.fits -o o55q06070_x1dfits_model.json
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q02070/" && pyigm_igmguesses o55q02070_continuumfit.fits -o o55q02070_x1dfits_model.json
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q05070/" && pyigm_igmguesses o55q05070_continuumfit.fits -o o55q05070_x1dfits_model.json
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q01070/" && pyigm_igmguesses o55q01070_continuumfit.fits -o o55q01070_x1dfits_model.json
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/" && pyigm_igmguesses o55q04070_continuumfit.fits -o o55q04070_x1dfits_model.json
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_1978_0.2x0.2_1609.000_9094/o6cd01020/" && pyigm_igmguesses o6cd01020_continuumfit.fits -o o6cd01020_x1dfits_model.json
#
# cd "/Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_2707_0.2x0.2_1300.000_9094/o6cd01030/" && pyigm_igmguesses o6cd01030_continuumfit.fits -o o6cd01030_x1dfits_model.json

# %%
for i in range(len(spectra_directories)):

    directory = spectra_directories[i]
    path = target_directory / directory

    os.chdir(path)
    
    Instrument = df.iloc[i]["Instrument"]
    Grating = df.iloc[i]["Grating"]
    Cenwave = str(df.iloc[i]["Cenwave"])
    if Instrument == "COS":
        LP = str(df.iloc[i]["LP"].lstrip("LP"))
        Aperture = "NA"
    elif Instrument == "STIS":
        LP = "NA"
        Aperture = df.iloc[i]["Aperture"]

    if Grating == "G130M":
        LSF_Ranges = [1100, 1460]
    elif Grating == "G160M":
        LSF_Ranges = [1400, 1800]
    elif Grating == "G185M":
        LSF_Ranges = [1800, 2100]
    elif Grating == "E140M":
        LSF_Ranges = [1144, 1729]
    elif Grating == "E230M":
        LSF_Ranges = [1607, 3129]

    for subdir in os.listdir(path):
        
        subdir_path = path / subdir
        if not subdir_path.is_dir():
            continue
        os.chdir(subdir_path)
    
        igm_model = glob.glob(os.path.join(subdir_path, "*_x1dfits_model.json"))[0]
        continuumfit = glob.glob(os.path.join(subdir_path, "*_continuumfit.fits"))[0]
    
        utils.pyigm_to_veeper(igm_model, continuumfit)

        component_groups_dir = os.path.join(subdir_path, "component_groups")
        output_dir = os.path.join(subdir_path, "modified_component_groups")
    
        if os.path.exists(output_dir):
            shutil.rmtree(output_dir)
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
    
        mc_lines_file = os.path.join(str(target_directory.parent.parent), f"{Grating}.txt")
        mc_lines_df = pd.read_csv(mc_lines_file, sep = r"\s+", header = None, names = ["line", "wavelength"])
        mc_lines_df["wavelength"] = mc_lines_df["wavelength"].astype(float)
    
        def is_valid_line(row, line_df):
            trans = row["trans"].strip()
            restwave = row["restwave"]
            matching_lines = line_df[line_df["line"] == trans]
            for wave in matching_lines["wavelength"]:
                if wave <= restwave <= 1.001 * wave:
                    return True
            return False
    
        input_files = glob.glob(os.path.join(component_groups_dir, "*.txt"))
    
        for file in input_files:
            df_component = pd.read_csv(file, sep = "|")
            df_component = df_component.loc[:, ~df_component.columns.str.contains('^Unnamed')]
        
            df_component["restwave"] = pd.to_numeric(df_component["restwave"], errors = "coerce")
            df_component["bval"] = pd.to_numeric(df_component["bval"], errors = "coerce")
        
            valid_mask = df_component.apply(lambda row: is_valid_line(row, mc_lines_df), axis = 1)
            df_component_filtered = df_component[valid_mask].copy()
        
            df_component_filtered["bval"] = df_component_filtered["bval"] / 2
        
            output_file = os.path.join(output_dir, os.path.basename(file))
            df_component_filtered.to_csv(output_file, sep = "|", index = False)
    
        input_group_files = sorted([f for f in glob.glob(os.path.join(output_dir, "input_group_*.txt")) if re.match(r".*input_group_\d+\.txt$", f)])
        
        reload(cfg)
        cfg.lsfs = []
        if Instrument == "COS":
            setattr(cfg, 'lps', [LP])
        elif Instrument == "STIS":
            setattr(cfg, 'slits', [Aperture])
        for entry, col in [[Instrument, 'instr'], [Grating, 'gratings'], [Cenwave, 'cen_wave'], [None, 'pixel_scales'], [None, 'fwhms']]:
            setattr(cfg, col, [entry])
        cfg.lsfranges = np.array([LSF_Ranges])
        
        VPmeasure.batch_fit(continuumfit, input_group_files, filepath = './modified_component_groups/')
# Out:
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 3.1393e+01, final cost 2.3372e+01, first-order optimality 3.20e-04.
#
# Fit results:
#
# 1152.82	 0.000450	 13.660	 15.000	 3.8300
#  	  	  	 0.105	 3.769	 2.684
#
#
# Reduced chi-squared: 1.460770
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 3.1393e+01, final cost 2.3372e+01, first-order optimality 3.20e-04.
#
# Fit results:
#
# 1152.82	 0.000450	 13.660	 15.000	 3.8300
#  	  	  	 0.105	 3.769	 2.684
#
#
# Reduced chi-squared: 1.460770
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.3552e+02, final cost 7.3103e+01, first-order optimality 9.09e-03.
#
# Fit results:
#
# 1239.93	 0.000460	 15.504	 15.480	 -2.1175
#  	  	  	 0.041	 1.916	 1.301
#
# 1240.39	 0.000460	 15.504	 15.480	 -2.1175
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.284475
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.3552e+02, final cost 7.3103e+01, first-order optimality 9.09e-03.
#
# Fit results:
#
# 1239.93	 0.000460	 15.504	 15.480	 -2.1175
#  	  	  	 0.041	 1.916	 1.301
#
# 1240.39	 0.000460	 15.504	 15.480	 -2.1175
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.284475
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 9.7509e+02, final cost 1.0988e+02, first-order optimality 1.53e-02.
#
# Fit results:
#
# 1250.58	 0.000030	 15.430	 9.8131	 -0.21187
#  	  	  	 0.019	 0.224	 0.15
#
# 1253.8	 0.000030	 15.430	 9.8131	 -0.21187
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 3.010517
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 9.7509e+02, final cost 1.0988e+02, first-order optimality 1.53e-02.
#
# Fit results:
#
# 1250.58	 0.000030	 15.430	 9.8131	 -0.21187
#  	  	  	 0.019	 0.224	 0.15
#
# 1253.8	 0.000030	 15.430	 9.8131	 -0.21187
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 3.010517
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.3475e+03, final cost 4.2443e+02, first-order optimality 3.67e-02.
#
# Fit results:
#
# 1250.58	 0.000510	 15.478	 20.790	 -6.4791
#  	  	  	 0.008	 0.3	 0.217
#
# 1253.8	 0.000510	 15.478	 20.790	 -6.4791
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 10.882928
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.3475e+03, final cost 4.2443e+02, first-order optimality 3.67e-02.
#
# Fit results:
#
# 1250.58	 0.000510	 15.478	 20.790	 -6.4791
#  	  	  	 0.008	 0.3	 0.217
#
# 1253.8	 0.000510	 15.478	 20.790	 -6.4791
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 10.882928
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.1715e+03, final cost 4.1614e+02, first-order optimality 3.29e-02.
#
# Fit results:
#
# 1250.58	 0.000490	 15.478	 20.760	 -4.6605
#  	  	  	 0.008	 0.3	 0.217
#
# 1253.8	 0.000490	 15.478	 20.760	 -4.6605
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 11.559536
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.1715e+03, final cost 4.1614e+02, first-order optimality 3.29e-02.
#
# Fit results:
#
# 1250.58	 0.000490	 15.478	 20.760	 -4.6605
#  	  	  	 0.008	 0.3	 0.217
#
# 1253.8	 0.000490	 15.478	 20.760	 -4.6605
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 11.559536
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_4.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_4_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_4_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 4.9619e+02, final cost 3.2412e+02, first-order optimality 6.66e-02.
#
# Fit results:
#
# 1317.22	 0.000500	 13.644	 18.590	 -1.7676
#  	  	  	 0.017	 0.959	 0.658
#
# 1370.13	 0.000500	 13.644	 18.590	 -1.7676
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000500	 13.644	 18.590	 -1.7676
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 5.947228
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 4.9619e+02, final cost 3.2412e+02, first-order optimality 6.66e-02.
#
# Fit results:
#
# 1317.22	 0.000500	 13.644	 18.590	 -1.7676
#  	  	  	 0.017	 0.959	 0.658
#
# 1370.13	 0.000500	 13.644	 18.590	 -1.7676
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000500	 13.644	 18.590	 -1.7676
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 5.947228
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_5.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_5.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_5_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2028.000_14476/od3g01020/modified_component_groups/input_group_5_inspect.fits
#
# VPmeasure: 6/6 fits converged, 0/6 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 21, initial cost 1.5443e+01, final cost 1.2510e+01, first-order optimality 5.39e-04.
#
# Fit results:
#
# 1152.82	 0.000450	 13.406	 14.327	 1.2433
#  	  	  	 0.133	 5.771	 3.874
#
#
# Reduced chi-squared: 0.834024
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 21, initial cost 1.5443e+01, final cost 1.2510e+01, first-order optimality 5.39e-04.
#
# Fit results:
#
# 1152.82	 0.000450	 13.406	 14.327	 1.2433
#  	  	  	 0.133	 5.771	 3.874
#
#
# Reduced chi-squared: 0.834024
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 1.3943e+02, final cost 6.5803e+01, first-order optimality 3.25e-03.
#
# Fit results:
#
# 1239.93	 0.000470	 15.631	 17.910	 -5.6914
#  	  	  	 0.038	 2.066	 1.399
#
# 1240.39	 0.000470	 15.631	 17.910	 -5.6914
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.827865
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 1.3943e+02, final cost 6.5803e+01, first-order optimality 3.25e-03.
#
# Fit results:
#
# 1239.93	 0.000470	 15.631	 17.910	 -5.6914
#  	  	  	 0.038	 2.066	 1.399
#
# 1240.39	 0.000470	 15.631	 17.910	 -5.6914
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.827865
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 5.2535e+02, final cost 2.9409e+02, first-order optimality 6.28e-02.
#
# Fit results:
#
# 1317.22	 0.000470	 13.774	 22.640	 2.3557
#  	  	  	 0.016	 1.036	 0.728
#
# 1370.13	 0.000470	 13.774	 22.640	 2.3557
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000470	 13.774	 22.640	 2.3557
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 4.455885
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 5.2535e+02, final cost 2.9409e+02, first-order optimality 6.28e-02.
#
# Fit results:
#
# 1317.22	 0.000470	 13.774	 22.640	 2.3557
#  	  	  	 0.016	 1.036	 0.728
#
# 1370.13	 0.000470	 13.774	 22.640	 2.3557
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000470	 13.774	 22.640	 2.3557
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 4.455885
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 7.6559e+02, final cost 2.2236e+02, first-order optimality 1.06e-02.
#
# Fit results:
#
# 1250.58	 0.000030	 15.463	 8.3754	 0.16262
#  	  	  	 0.032	 0.26	 0.154
#
# 1253.8	 0.000030	 15.463	 8.3754	 0.16262
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 7.059129
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 7.6559e+02, final cost 2.2236e+02, first-order optimality 1.06e-02.
#
# Fit results:
#
# 1250.58	 0.000030	 15.463	 8.3754	 0.16262
#  	  	  	 0.032	 0.26	 0.154
#
# 1253.8	 0.000030	 15.463	 8.3754	 0.16262
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 7.059129
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.1883e+03, final cost 3.0524e+02, first-order optimality 1.71e-02.
#
# Fit results:
#
# 1250.58	 0.000510	 15.448	 21.010	 -9.3439
#  	  	  	 0.008	 0.33	 0.237
#
# 1253.8	 0.000510	 15.448	 21.010	 -9.3439
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 8.721019
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.1883e+03, final cost 3.0524e+02, first-order optimality 1.71e-02.
#
# Fit results:
#
# 1250.58	 0.000510	 15.448	 21.010	 -9.3439
#  	  	  	 0.008	 0.33	 0.237
#
# 1253.8	 0.000510	 15.448	 21.010	 -9.3439
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 8.721019
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_4.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_4_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_4_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 5.2384e+02, final cost 3.1012e+02, first-order optimality 8.13e-02.
#
# Fit results:
#
# 1317.22	 0.000500	 13.713	 18.230	 -1.3261
#  	  	  	 0.017	 0.915	 0.627
#
# 1370.13	 0.000500	 13.713	 18.230	 -1.3261
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000500	 13.713	 18.230	 -1.3261
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 5.488845
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 5.2384e+02, final cost 3.1012e+02, first-order optimality 8.13e-02.
#
# Fit results:
#
# 1317.22	 0.000500	 13.713	 18.230	 -1.3261
#  	  	  	 0.017	 0.915	 0.627
#
# 1370.13	 0.000500	 13.713	 18.230	 -1.3261
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000500	 13.713	 18.230	 -1.3261
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 5.488845
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_5.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_5.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_5_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2070.000_13373/ocax01020/modified_component_groups/input_group_5_inspect.fits
#
# VPmeasure: 6/6 fits converged, 0/6 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.6648e+02, final cost 4.8843e+01, first-order optimality 2.23e-03.
#
# Fit results:
#
# 1239.93	 0.000490	 15.571	 17.170	 -15.892
#  	  	  	 0.033	 1.752	 1.171
#
# 1240.39	 0.000490	 15.571	 17.170	 -15.892
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.356756
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.6648e+02, final cost 4.8843e+01, first-order optimality 2.23e-03.
#
# Fit results:
#
# 1239.93	 0.000490	 15.571	 17.170	 -15.892
#  	  	  	 0.033	 1.752	 1.171
#
# 1240.39	 0.000490	 15.571	 17.170	 -15.892
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.356756
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 2.5401e+02, final cost 1.2362e+02, first-order optimality 3.44e-02.
#
# Fit results:
#
# 1317.22	 0.000470	 13.452	 15.000	 3.3296
#  	  	  	 0.023	 1.087	 0.724
#
# 1370.13	 0.000470	 13.452	 15.000	 3.3296
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000470	 13.452	 15.000	 3.3296
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.168702
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 2.5401e+02, final cost 1.2362e+02, first-order optimality 3.44e-02.
#
# Fit results:
#
# 1317.22	 0.000470	 13.452	 15.000	 3.3296
#  	  	  	 0.023	 1.087	 0.724
#
# 1370.13	 0.000470	 13.452	 15.000	 3.3296
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000470	 13.452	 15.000	 3.3296
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.168702
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 1.4724e+02, final cost 5.4161e+01, first-order optimality 5.96e-03.
#
# Fit results:
#
# 1239.93	 0.000460	 15.565	 16.680	 -6.1115
#  	  	  	 0.033	 1.717	 1.145
#
# 1240.39	 0.000460	 15.565	 16.680	 -6.1115
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.425296
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 1.4724e+02, final cost 5.4161e+01, first-order optimality 5.96e-03.
#
# Fit results:
#
# 1239.93	 0.000460	 15.565	 16.680	 -6.1115
#  	  	  	 0.033	 1.717	 1.145
#
# 1240.39	 0.000460	 15.565	 16.680	 -6.1115
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.425296
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 1.2757e+03, final cost 2.6470e+02, first-order optimality 6.03e-03.
#
# Fit results:
#
# 1250.58	 0.000020	 15.519	 8.0638	 1.8531
#  	  	  	 0.033	 0.229	 0.128
#
# 1253.8	 0.000020	 15.519	 8.0638	 1.8531
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 8.678553
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 1.2757e+03, final cost 2.6470e+02, first-order optimality 6.03e-03.
#
# Fit results:
#
# 1250.58	 0.000020	 15.519	 8.0638	 1.8531
#  	  	  	 0.033	 0.229	 0.128
#
# 1253.8	 0.000020	 15.519	 8.0638	 1.8531
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 8.678553
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.2319e+03, final cost 3.7522e+02, first-order optimality 9.08e-03.
#
# Fit results:
#
# 1250.58	 0.000490	 15.456	 21.230	 -4.9805
#  	  	  	 0.007	 0.29	 0.213
#
# 1253.8	 0.000490	 15.456	 21.230	 -4.9805
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 10.279872
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.2319e+03, final cost 3.7522e+02, first-order optimality 9.08e-03.
#
# Fit results:
#
# 1250.58	 0.000490	 15.456	 21.230	 -4.9805
#  	  	  	 0.007	 0.29	 0.213
#
# 1253.8	 0.000490	 15.456	 21.230	 -4.9805
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 10.279872
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_4.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_4_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_4_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 2.3299e+02, final cost 1.3133e+02, first-order optimality 2.81e-02.
#
# Fit results:
#
# 1317.22	 0.000490	 13.452	 15.000	 -0.0088311
#  	  	  	 0.023	 1.087	 0.724
#
# 1370.13	 0.000490	 13.452	 15.000	 -0.0088311
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 13.452	 15.000	 -0.0088311
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.188907
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 2.3299e+02, final cost 1.3133e+02, first-order optimality 2.81e-02.
#
# Fit results:
#
# 1317.22	 0.000490	 13.452	 15.000	 -0.0088311
#  	  	  	 0.023	 1.087	 0.724
#
# 1370.13	 0.000490	 13.452	 15.000	 -0.0088311
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 13.452	 15.000	 -0.0088311
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.188907
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_5.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_5.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_5_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2548.000_11623/ob2na1010/modified_component_groups/input_group_5_inspect.fits
#
# VPmeasure: 6/6 fits converged, 0/6 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 1.3768e+02, final cost 5.4995e+01, first-order optimality 3.24e-03.
#
# Fit results:
#
# 1239.93	 0.000460	 15.582	 15.000	 -3.5992
#  	  	  	 0.033	 1.587	 1.046
#
# 1240.39	 0.000460	 15.582	 15.000	 -3.5992
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.571273
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 1.3768e+02, final cost 5.4995e+01, first-order optimality 3.24e-03.
#
# Fit results:
#
# 1239.93	 0.000460	 15.582	 15.000	 -3.5992
#  	  	  	 0.033	 1.587	 1.046
#
# 1240.39	 0.000460	 15.582	 15.000	 -3.5992
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.571273
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 3.0336e+01, final cost 2.3601e+01, first-order optimality 8.70e-06.
#
# Fit results:
#
# 1152.82	 0.000460	 13.539	 22.360	 -2.3214
#  	  	  	 0.091	 5.71	 3.984
#
#
# Reduced chi-squared: 1.348616
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 3.0336e+01, final cost 2.3601e+01, first-order optimality 8.70e-06.
#
# Fit results:
#
# 1152.82	 0.000460	 13.539	 22.360	 -2.3214
#  	  	  	 0.091	 5.71	 3.984
#
#
# Reduced chi-squared: 1.348616
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.5472e+02, final cost 5.5239e+01, first-order optimality 2.16e-03.
#
# Fit results:
#
# 1239.93	 0.000460	 15.582	 15.000	 -8.4865
#  	  	  	 0.033	 1.587	 1.046
#
# 1240.39	 0.000460	 15.582	 15.000	 -8.4865
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.556037
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.5472e+02, final cost 5.5239e+01, first-order optimality 2.16e-03.
#
# Fit results:
#
# 1239.93	 0.000460	 15.582	 15.000	 -8.4865
#  	  	  	 0.033	 1.587	 1.046
#
# 1240.39	 0.000460	 15.582	 15.000	 -8.4865
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.556037
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 1.1371e+03, final cost 3.6303e+02, first-order optimality 3.40e-02.
#
# Fit results:
#
# 1250.58	 0.000020	 15.434	 8.5523	 0.87713
#  	  	  	 0.024	 0.219	 0.135
#
# 1253.8	 0.000020	 15.434	 8.5523	 0.87713
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 10.522643
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 1.1371e+03, final cost 3.6303e+02, first-order optimality 3.40e-02.
#
# Fit results:
#
# 1250.58	 0.000020	 15.434	 8.5523	 0.87713
#  	  	  	 0.024	 0.219	 0.135
#
# 1253.8	 0.000020	 15.434	 8.5523	 0.87713
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 10.522643
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.4333e+03, final cost 3.7456e+02, first-order optimality 4.82e-03.
#
# Fit results:
#
# 1250.58	 0.000490	 15.449	 20.650	 -6.8179
#  	  	  	 0.007	 0.291	 0.214
#
# 1253.8	 0.000490	 15.449	 20.650	 -6.8179
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 10.404583
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.4333e+03, final cost 3.7456e+02, first-order optimality 4.82e-03.
#
# Fit results:
#
# 1250.58	 0.000490	 15.449	 20.650	 -6.8179
#  	  	  	 0.007	 0.291	 0.214
#
# 1253.8	 0.000490	 15.449	 20.650	 -6.8179
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 10.404583
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_4.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_4_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_4_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 6.1076e+02, final cost 3.5266e+02, first-order optimality 9.28e-02.
#
# Fit results:
#
# 1317.22	 0.000490	 13.690	 19.470	 2.5525
#  	  	  	 0.016	 0.882	 0.611
#
# 1370.13	 0.000490	 13.690	 19.470	 2.5525
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 13.690	 19.470	 2.5525
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 6.241701
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 6.1076e+02, final cost 3.5266e+02, first-order optimality 9.28e-02.
#
# Fit results:
#
# 1317.22	 0.000490	 13.690	 19.470	 2.5525
#  	  	  	 0.016	 0.882	 0.611
#
# 1370.13	 0.000490	 13.690	 19.470	 2.5525
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 13.690	 19.470	 2.5525
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 6.241701
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_5.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_5.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_5_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2608.000_13373/ocax01010/modified_component_groups/input_group_5_inspect.fits
#
# VPmeasure: 6/6 fits converged, 0/6 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.7818e+02, final cost 6.5318e+01, first-order optimality 3.90e-03.
#
# Fit results:
#
# 1239.93	 0.000470	 15.594	 16.450	 -9.355
#  	  	  	 0.031	 1.473	 1.008
#
# 1240.39	 0.000470	 15.594	 16.450	 -9.355
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.107018
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.7818e+02, final cost 6.5318e+01, first-order optimality 3.90e-03.
#
# Fit results:
#
# 1239.93	 0.000470	 15.594	 16.450	 -9.355
#  	  	  	 0.031	 1.473	 1.008
#
# 1240.39	 0.000470	 15.594	 16.450	 -9.355
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.107018
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.7010e+02, final cost 1.5937e+02, first-order optimality 1.39e-02.
#
# Fit results:
#
# 1317.22	 0.000510	 13.548	 19.900	 -5.8106
#  	  	  	 0.021	 1.224	 0.83
#
# 1370.13	 0.000510	 13.548	 19.900	 -5.8106
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000510	 13.548	 19.900	 -5.8106
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.470824
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.7010e+02, final cost 1.5937e+02, first-order optimality 1.39e-02.
#
# Fit results:
#
# 1317.22	 0.000510	 13.548	 19.900	 -5.8106
#  	  	  	 0.021	 1.224	 0.83
#
# 1370.13	 0.000510	 13.548	 19.900	 -5.8106
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000510	 13.548	 19.900	 -5.8106
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.470824
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 6.8904e+01, final cost 5.0830e+01, first-order optimality 6.84e-03.
#
# Fit results:
#
# 1358.77	 0.000840	 12.664	 15.000	 -1.0282
#  	  	  	 0.05	 2.387	 1.573
#
#
# Reduced chi-squared: 2.675279
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 6.8904e+01, final cost 5.0830e+01, first-order optimality 6.84e-03.
#
# Fit results:
#
# 1358.77	 0.000840	 12.664	 15.000	 -1.0282
#  	  	  	 0.05	 2.387	 1.573
#
#
# Reduced chi-squared: 2.675279
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 1.1088e+03, final cost 3.5413e+02, first-order optimality 4.11e-02.
#
# Fit results:
#
# 1250.58	 0.000030	 15.491	 8.4049	 -1.2702
#  	  	  	 0.029	 0.224	 0.129
#
# 1253.8	 0.000030	 15.491	 8.4049	 -1.2702
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 9.702088
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 1.1088e+03, final cost 3.5413e+02, first-order optimality 4.11e-02.
#
# Fit results:
#
# 1250.58	 0.000030	 15.491	 8.4049	 -1.2702
#  	  	  	 0.029	 0.224	 0.129
#
# 1253.8	 0.000030	 15.491	 8.4049	 -1.2702
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 9.702088
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.3321e+03, final cost 4.4087e+02, first-order optimality 3.52e-03.
#
# Fit results:
#
# 1250.58	 0.000490	 15.441	 20.930	 -4.5078
#  	  	  	 0.007	 0.284	 0.207
#
# 1253.8	 0.000490	 15.441	 20.930	 -4.5078
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 11.451122
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 2.3321e+03, final cost 4.4087e+02, first-order optimality 3.52e-03.
#
# Fit results:
#
# 1250.58	 0.000490	 15.441	 20.930	 -4.5078
#  	  	  	 0.007	 0.284	 0.207
#
# 1253.8	 0.000490	 15.441	 20.930	 -4.5078
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 11.451122
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_2627.000_11623/ob2na1020/modified_component_groups/input_group_4.VP
# ...
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 20, initial cost 1.4577e+02, final cost 1.0507e+02, first-order optimality 2.83e-02.
#
# Fit results:
#
# 1239.93	 0.000470	 15.266	 11.076	 -9.1527
#  	  	  	 0.069	 2.545	 1.679
#
# 1240.39	 0.000470	 15.266	 11.076	 -9.1527
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 3.183887
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 20, initial cost 1.4577e+02, final cost 1.0507e+02, first-order optimality 2.83e-02.
#
# Fit results:
#
# 1239.93	 0.000470	 15.266	 11.076	 -9.1527
#  	  	  	 0.069	 2.545	 1.679
#
# 1240.39	 0.000470	 15.266	 11.076	 -9.1527
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 3.183887
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.3374e+02, final cost 1.1251e+02, first-order optimality 6.45e-03.
#
# Fit results:
#
# 1239.93	 0.000440	 15.264	 10.342	 -3.5038
#  	  	  	 0.069	 2.586	 1.641
#
# 1240.39	 0.000440	 15.264	 10.342	 -3.5038
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.922347
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.3374e+02, final cost 1.1251e+02, first-order optimality 6.45e-03.
#
# Fit results:
#
# 1239.93	 0.000440	 15.264	 10.342	 -3.5038
#  	  	  	 0.069	 2.586	 1.641
#
# 1240.39	 0.000440	 15.264	 10.342	 -3.5038
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.922347
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 1.9429e+03, final cost 4.4979e+02, first-order optimality 3.88e-02.
#
# Fit results:
#
# 1250.58	 0.000030	 15.402	 8.6784	 1.2216
#  	  	  	 0.016	 0.158	 0.102
#
# 1253.8	 0.000030	 15.402	 8.6784	 1.2216
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 14.747169
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 1.9429e+03, final cost 4.4979e+02, first-order optimality 3.88e-02.
#
# Fit results:
#
# 1250.58	 0.000030	 15.402	 8.6784	 1.2216
#  	  	  	 0.016	 0.158	 0.102
#
# 1253.8	 0.000030	 15.402	 8.6784	 1.2216
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 14.747169
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 4.3120e+03, final cost 9.9768e+02, first-order optimality 7.79e-02.
#
# Fit results:
#
# 1250.58	 0.000490	 15.442	 20.660	 -2.2006
#  	  	  	 0.005	 0.201	 0.144
#
# 1253.8	 0.000490	 15.442	 20.660	 -2.2006
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 22.170571
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 4.3120e+03, final cost 9.9768e+02, first-order optimality 7.79e-02.
#
# Fit results:
#
# 1250.58	 0.000490	 15.442	 20.660	 -2.2006
#  	  	  	 0.005	 0.201	 0.144
#
# 1253.8	 0.000490	 15.442	 20.660	 -2.2006
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 22.170571
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_4.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_4_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_4_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 4.2824e+03, final cost 3.0338e+03, first-order optimality 5.22e-01.
#
# Fit results:
#
# 1317.22	 0.000500	 13.981	 23.150	 0.093465
#  	  	  	 0.006	 0.397	 0.285
#
# 1370.13	 0.000500	 13.981	 23.150	 0.093465
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000500	 13.981	 23.150	 0.093465
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 45.620561
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 4.2824e+03, final cost 3.0338e+03, first-order optimality 5.22e-01.
#
# Fit results:
#
# 1317.22	 0.000500	 13.981	 23.150	 0.093465
#  	  	  	 0.006	 0.397	 0.285
#
# 1370.13	 0.000500	 13.981	 23.150	 0.093465
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000500	 13.981	 23.150	 0.093465
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 45.620561
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_5.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_5.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_5_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E140M_1425_0.2x0.2_3236.000_7480/o55q04070/modified_component_groups/input_group_5_inspect.fits
#
# VPmeasure: 6/6 fits converged, 0/6 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 2.8070e+02, final cost 1.4925e+02, first-order optimality 2.52e-02.
#
# Fit results:
#
# 2249.88	 0.000500	 14.900	 19.340	 -2.1488
#  	  	  	 0.017	 0.999	 0.676
#
# 2260.78	 0.000500	 14.900	 19.340	 -2.1488
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 3.244564
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 2.8070e+02, final cost 1.4925e+02, first-order optimality 2.52e-02.
#
# Fit results:
#
# 2249.88	 0.000500	 14.900	 19.340	 -2.1488
#  	  	  	 0.017	 0.999	 0.676
#
# 2260.78	 0.000500	 14.900	 19.340	 -2.1488
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 3.244564
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_1978_0.2x0.2_1609.000_9094/o6cd01020/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_1978_0.2x0.2_1609.000_9094/o6cd01020/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_1978_0.2x0.2_1609.000_9094/o6cd01020/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_1978_0.2x0.2_1609.000_9094/o6cd01020/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 2.2722e+02, final cost 6.3259e+01, first-order optimality 7.44e-03.
#
# Fit results:
#
# 1808.01	 0.000470	 15.686	 21.940	 0.47919
#  	  	  	 0.015	 0.882	 0.613
#
#
# Reduced chi-squared: 2.635802
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 2.2722e+02, final cost 6.3259e+01, first-order optimality 7.44e-03.
#
# Fit results:
#
# 1808.01	 0.000470	 15.686	 21.940	 0.47919
#  	  	  	 0.015	 0.882	 0.613
#
#
# Reduced chi-squared: 2.635802
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_1978_0.2x0.2_1609.000_9094/o6cd01020/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_1978_0.2x0.2_1609.000_9094/o6cd01020/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_1978_0.2x0.2_1609.000_9094/o6cd01020/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_1978_0.2x0.2_1609.000_9094/o6cd01020/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.6039e+02, final cost 1.0092e+02, first-order optimality 5.83e-03.
#
# Fit results:
#
# 2056.26	 0.000510	 12.994	 15.000	 -5.7621
#  	  	  	 0.04	 2.091	 1.329
#
# 2066.16	 0.000510	 12.994	 15.000	 -5.7621
#  	  	  	 0.0	 0.0	 0.0
#
# 2062.66	 0.000490	 12.674	 15.000	 -9.8589
#  	  	  	 0.044	 2.292	 1.447
#
#
# Reduced chi-squared: 1.868940
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.6039e+02, final cost 1.0092e+02, first-order optimality 5.83e-03.
#
# Fit results:
#
# 2056.26	 0.000510	 12.994	 15.000	 -5.7621
#  	  	  	 0.04	 2.091	 1.329
#
# 2066.16	 0.000510	 12.994	 15.000	 -5.7621
#  	  	  	 0.0	 0.0	 0.0
#
# 2062.66	 0.000490	 12.674	 15.000	 -9.8589
#  	  	  	 0.044	 2.292	 1.447
#
#
# Reduced chi-squared: 1.868940
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_1978_0.2x0.2_1609.000_9094/o6cd01020/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_1978_0.2x0.2_1609.000_9094/o6cd01020/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_1978_0.2x0.2_1609.000_9094/o6cd01020/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_1978_0.2x0.2_1609.000_9094/o6cd01020/modified_component_groups/input_group_2_inspect.fits
#
# VPmeasure: 3/3 fits converged, 0/3 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 6.0678e+02, final cost 3.9497e+02, first-order optimality 5.13e-02.
#
# Fit results:
#
# 2576.88	 0.000480	 12.697	 17.560	 -4.0956
#  	  	  	 0.014	 0.81	 0.536
#
# 2594.5	 0.000480	 12.697	 17.560	 -4.0956
#  	  	  	 0.0	 0.0	 0.0
#
# 2606.46	 0.000480	 12.697	 17.560	 -4.0956
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 7.247152
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 6.0678e+02, final cost 3.9497e+02, first-order optimality 5.13e-02.
#
# Fit results:
#
# 2576.88	 0.000480	 12.697	 17.560	 -4.0956
#  	  	  	 0.014	 0.81	 0.536
#
# 2594.5	 0.000480	 12.697	 17.560	 -4.0956
#  	  	  	 0.0	 0.0	 0.0
#
# 2606.46	 0.000480	 12.697	 17.560	 -4.0956
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 7.247152
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_2707_0.2x0.2_1300.000_9094/o6cd01030/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_2707_0.2x0.2_1300.000_9094/o6cd01030/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_2707_0.2x0.2_1300.000_9094/o6cd01030/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SMC N66A/HD 5980/E230M_2707_0.2x0.2_1300.000_9094/o6cd01030/modified_component_groups/input_group_0_inspect.fits
#
# VPmeasure: 1/1 fits converged, 0/1 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.

# %%
records = []

for i in range(len(spectra_directories)):

    directory = spectra_directories[i]
    path = target_directory / directory
    
    for subdir in os.listdir(path):
        
        subdir_path = path / subdir
        if not subdir_path.is_dir():
            continue
        fn = os.path.join(subdir_path, "compiledVPoutputs.dat")
        if not os.path.isfile(fn):
            continue

        df_outputs = pd.read_csv(fn, sep = "|")
        df_outputs = df_outputs[(np.abs(df_outputs["zsys"]) > 0.0001) & (df_outputs["sigcol"] != 0.0)]
        records.append(df_outputs[["trans", "col", "sigcol"]])

all_measurements = pd.concat(records, ignore_index = True)

def random_effects_mean(vals, sigmas):
    vals = np.asarray(vals, dtype = float)
    sigmas = np.asarray(sigmas, dtype = float)
    var = sigmas ** 2

    w  = 1.0 / var
    mu = (w * vals).sum() / w.sum()

    Q  = (w * (vals - mu) ** 2).sum()
    df = len(vals) - 1
    c  = w.sum() - (w ** 2).sum() / w.sum()
    T2 = max(0.0, (Q - df) / c) if c > 0 else 0.0

    w_re = 1.0 / (var + T2)
    mean = (w_re * vals).sum() / w_re.sum()
    std  = np.sqrt(1.0 / w_re.sum())
    return mean, std

combined = (
    all_measurements
    .groupby("trans", sort = True)
    .apply(lambda g: random_effects_mean(g["col"], g["sigcol"]))
    .apply(pd.Series)
    .reset_index()
    .rename(columns = {0: "col_combined", 1: "sigcol_combined"})
)

combined = combined.sort_values("trans").reset_index(drop = True)

for _, row in combined.iterrows():
    print(f"{row.trans}  {row.col_combined:.3f} ± {row.sigcol_combined:.3f}")

output_file = os.path.join(target_directory, "abundances.txt")

with open(output_file, "w") as f:
    for _, row in combined.iterrows():
        f.write(f"{row.trans} {row.col_combined:.3f} {row.sigcol_combined:.3f}\n")
# Out:
# CrII  12.994 ± 0.040
# CuII  12.664 ± 0.050
# FeII  14.900 ± 0.017
# MgII  15.629 ± 0.032
# MnII  12.697 ± 0.014
# NiII  13.682 ± 0.049
# P II  13.505 ± 0.026
# S II  15.449 ± 0.008
# SiII  15.686 ± 0.015
# ZnII  12.674 ± 0.044
# /var/folders/7n/v6gcxcpj68q6nnv2znnc85xc0000gn/T/ipykernel_46980/817733302.py:44: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: random_effects_mean(g["col"], g["sigcol"]))

# %%
records = []

for i in range(len(spectra_directories)):

    directory = spectra_directories[i]
    path = target_directory / directory
    
    for subdir in os.listdir(path):
        
        subdir_path = path / subdir
        if not subdir_path.is_dir():
            continue
        fn = os.path.join(subdir_path, "compiledVPoutputs.dat")
        if not os.path.isfile(fn):
            continue

        df_SII = pd.read_csv(fn, sep = "|")
        df_SII = df_SII[df_SII["trans"].str.strip() == "S II"]
        df_SII["z_tot"] = df_SII["zsys"] + df_SII["vel"] / 299792.458
        records.append(df_SII[["z_tot", "sigvel"]])

df_SII = pd.concat(records, ignore_index = True)
bin_mw = df_SII[np.abs(df_SII["z_tot"]) <= 0.0001]
bin_sys = df_SII[np.abs(df_SII["z_tot"] - guess_redshift) <= 0.0001]
bin_mw = bin_mw[bin_mw["sigvel"] != 0]
bin_sys = bin_sys[bin_sys["sigvel"] != 0]

z_mw = random_effects_mean(bin_mw["z_tot"].values, bin_mw["sigvel"].values)[0]
z_sys = random_effects_mean(bin_sys["z_tot"].values, bin_sys["sigvel"].values)[0]
        
output_path = os.path.join(target_directory, "heliocentric_velocities.txt")
with open(output_path, "w") as f:
    f.write(f"{z_mw:.8f}\n")
    f.write(f"{z_sys:.8f}\n")       

print(f"{z_mw:.8f}")
print(f"{z_sys:.8f}")
# Out:
# 0.00003081
# 0.00047996

# %%
# END
