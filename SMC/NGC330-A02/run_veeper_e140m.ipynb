# %%
import os
import re
import glob
import numpy as np
import pandas as pd

from importlib import reload
from joebvp import cfg, utils, VPmeasure

# %%
def replace_string(dataset_name):
    segment = """lt_xspec [dataset_name]_x1d.fits 
lt_continuumfit --redshift 0.00053 [dataset_name]_x1d.fits [dataset_name]_continuumfit.fits
pyigm_igmguesses [dataset_name]_continuumfit.fits -o [dataset_name]_x1dfits_model.json
pyigm_fitdla --out_file [dataset_name]_xfitdla.json [dataset_name]_continuumfit.fits 0"""
    modified_segment = segment.replace("[dataset_name]", dataset_name)
    print(modified_segment)
    
replace_string("o6df24030")
# Out:
# lt_xspec o6df24030_x1d.fits
# lt_continuumfit --redshift 0.00053 o6df24030_x1d.fits o6df24030_continuumfit.fits
# pyigm_igmguesses o6df24030_continuumfit.fits -o o6df24030_x1dfits_model.json
# pyigm_fitdla --out_file o6df24030_xfitdla.json o6df24030_continuumfit.fits 0

# %%
reload(cfg)

d = pd.DataFrame({
    'instr': ['COS', 'COS', 'COS', 'COS', 'STIS', 'STIS', 'Gaussian'],
    'gratings': ['G130M', 'G160M', 'G185M', 'G225M', 'E230M', 'E140M', 'N/A'],
    'slits': ['NA', 'NA', 'NA', 'NA', '0.2x0.2', '0.2x0.2', 'NA'],
    'lsfranges': [[1100, 1460], [1400, 1800], [1800, 2100], [2100, 2278], [1607, 3129], [1144, 1729], [899, 1191]],
    'lps': ['1', '1', '1', '1', '1', '1', 'NA'],
    'cen_wave': ['1291', '1611', '1953', '2250', '1978', '1425', 'NA'],
    'pixel_scales': [None, None, None, None, None, None, 0.013], 
    'fwhms': [None, None, None, None, None, None, 0.02]
})

num = 5

cfg.lsfs = []
for col in ['instr', 'gratings', 'slits', 'cen_wave', 'pixel_scales', 'fwhms']:
    setattr(cfg, col, [d.at[num, col]])

cfg.lsfranges = np.array([d.at[num, 'lsfranges']])

# %%
base_directory = "/Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M"
directories = sorted([d for d in os.listdir(base_directory) if d.startswith("E140M")])

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_model = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))[0]
    continuumfit = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))[0]

    utils.pyigm_to_veeper(igm_model, continuumfit)

    os.chdir(base_directory)
# Out:
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    component_groups_dir = os.path.join(current_directory, "component_groups")
    output_dir = os.path.join(current_directory, "modified_component_groups")

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    mc_lines_file = "/Users/billyli/Documents/float-for-morrow/mc_lines_e140m.txt"
    mc_lines_df = pd.read_csv(mc_lines_file, sep = r"\s+", header = None, names = ["line", "wavelength"])
    mc_lines_df["wavelength"] = mc_lines_df["wavelength"].astype(float)

    def is_valid_line(row, line_df):
        trans = row["trans"].strip()
        restwave = row["restwave"]
        matching_lines = line_df[line_df["line"] == trans]
        for wave in matching_lines["wavelength"]:
            if 0.997 * wave <= restwave <= 1.003 * wave:
                return True
        return False

    input_files = glob.glob(os.path.join(component_groups_dir, "*.txt"))

    for file in input_files:
        df = pd.read_csv(file, sep = "|")
        df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    
        df["restwave"] = pd.to_numeric(df["restwave"], errors = "coerce")
        df["bval"] = pd.to_numeric(df["bval"], errors = "coerce")
    
        valid_mask = df.apply(lambda row: is_valid_line(row, mc_lines_df), axis = 1)
        df_filtered = df[valid_mask].copy()
    
        # df_filtered["col"] = df_filtered["col"] - 0.2
        df_filtered["bval"] = df_filtered["bval"]
    
        output_file = os.path.join(output_dir, os.path.basename(file))
        df_filtered.to_csv(output_file, sep = "|", index = False)
        # print(f"Processed file: {os.path.basename(file)} -> {output_file}")

# %%
# Before fitting, should manually adjust the input group files

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_models = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))
    continuumfits = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))

    component_groups_dir = os.path.join(current_directory, "modified_component_groups")
    
    input_group_files = sorted([f for f in glob.glob(os.path.join(component_groups_dir, "input_group_*.txt")) if re.match(r".*input_group_\d+\.txt$", f)])

    VPmeasure.batch_fit(continuumfits[0], input_group_files, filepath = './modified_component_groups/')

    os.chdir(base_directory)
# Out:
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 1.6478e+02, final cost 1.5778e+02, first-order optimality 2.61e-02.
#
# Fit results:
#
# 1608.45	 0.000460	 15.513	 18.592	 -3.964
#  	  	  	 0.091	 0.978	 1.134
#
# 1611.2	 0.000460	 15.513	 18.592	 -3.964
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 3.253152
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 1.6478e+02, final cost 1.5778e+02, first-order optimality 2.61e-02.
#
# Fit results:
#
# 1608.45	 0.000460	 15.513	 18.592	 -3.964
#  	  	  	 0.091	 0.978	 1.134
#
# 1611.2	 0.000460	 15.513	 18.592	 -3.964
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 3.253152
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 3.3155e+01, final cost 3.2774e+01, first-order optimality 5.75e-03.
#
# Fit results:
#
# 1239.93	 0.000460	 16.219	 21.188	 1.3822
#  	  	  	 0.059	 3.525	 2.413
#
# 1240.39	 0.000460	 16.219	 21.188	 1.3822
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 0.963941
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 3.3155e+01, final cost 3.2774e+01, first-order optimality 5.75e-03.
#
# Fit results:
#
# 1239.93	 0.000460	 16.219	 21.188	 1.3822
#  	  	  	 0.059	 3.525	 2.413
#
# 1240.39	 0.000460	 16.219	 21.188	 1.3822
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 0.963941
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 9.0133e+01, final cost 6.9171e+01, first-order optimality 1.21e-02.
#
# Fit results:
#
# 1250.58	 0.000500	 15.933	 27.810	 -3.7047
#  	  	  	 0.052	 1.471	 1.026
#
# 1253.8	 0.000500	 15.933	 27.810	 -3.7047
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.411652
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 9.0133e+01, final cost 6.9171e+01, first-order optimality 1.21e-02.
#
# Fit results:
#
# 1250.58	 0.000500	 15.933	 27.810	 -3.7047
#  	  	  	 0.052	 1.471	 1.026
#
# 1253.8	 0.000500	 15.933	 27.810	 -3.7047
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.411652
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 2.1146e+01, final cost 1.7932e+01, first-order optimality 3.04e-04.
#
# Fit results:
#
# 1355.6	 0.000430	 18.430	 16.254	 -6.5754
#  	  	  	 0.098	 4.922	 3.311
#
#
# Reduced chi-squared: 1.434526
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 2.1146e+01, final cost 1.7932e+01, first-order optimality 3.04e-04.
#
# Fit results:
#
# 1355.6	 0.000430	 18.430	 16.254	 -6.5754
#  	  	  	 0.098	 4.922	 3.311
#
#
# Reduced chi-squared: 1.434526
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.1867e+02, final cost 8.6628e+01, first-order optimality 7.04e-03.
#
# Fit results:
#
# 1317.22	 0.000480	 14.217	 28.817	 -7.8145
#  	  	  	 0.029	 2.236	 1.591
#
# 1370.13	 0.000480	 14.217	 28.817	 -7.8145
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000480	 14.217	 28.817	 -7.8145
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.575056
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.1867e+02, final cost 8.6628e+01, first-order optimality 7.04e-03.
#
# Fit results:
#
# 1317.22	 0.000480	 14.217	 28.817	 -7.8145
#  	  	  	 0.029	 2.236	 1.591
#
# 1370.13	 0.000480	 14.217	 28.817	 -7.8145
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000480	 14.217	 28.817	 -7.8145
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.575056
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_4.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_4_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M10/modified_component_groups/input_group_4_inspect.fits
#
# VPmeasure: 5/5 fits converged, 0/5 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 1.8056e+02, final cost 1.2285e+02, first-order optimality 4.54e-03.
#
# Fit results:
#
# 1608.45	 0.000470	 15.730	 18.299	 -5.4478
#  	  	  	 0.074	 0.876	 1.259
#
# 1611.2	 0.000470	 15.730	 18.299	 -5.4478
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.670744
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 1.8056e+02, final cost 1.2285e+02, first-order optimality 4.54e-03.
#
# Fit results:
#
# 1608.45	 0.000470	 15.730	 18.299	 -5.4478
#  	  	  	 0.074	 0.876	 1.259
#
# 1611.2	 0.000470	 15.730	 18.299	 -5.4478
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.670744
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 4.1711e+01, final cost 3.5862e+01, first-order optimality 7.10e-03.
#
# Fit results:
#
# 1239.93	 0.000460	 16.348	 12.580	 -3.9891
#  	  	  	 0.068	 2.726	 1.623
#
# 1240.39	 0.000460	 16.348	 12.580	 -3.9891
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.195405
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 4.1711e+01, final cost 3.5862e+01, first-order optimality 7.10e-03.
#
# Fit results:
#
# 1239.93	 0.000460	 16.348	 12.580	 -3.9891
#  	  	  	 0.068	 2.726	 1.623
#
# 1240.39	 0.000460	 16.348	 12.580	 -3.9891
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.195405
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.4693e+02, final cost 7.4182e+01, first-order optimality 1.53e-02.
#
# Fit results:
#
# 1250.58	 0.000520	 16.871	 16.392	 -9.6755
#  	  	  	 0.842	 3.885	 0.914
#
# 1253.8	 0.000520	 16.871	 16.392	 -9.6755
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.412985
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.4693e+02, final cost 7.4182e+01, first-order optimality 1.53e-02.
#
# Fit results:
#
# 1250.58	 0.000520	 16.871	 16.392	 -9.6755
#  	  	  	 0.842	 3.885	 0.914
#
# 1253.8	 0.000520	 16.871	 16.392	 -9.6755
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.412985
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 1.5772e+01, final cost 1.2767e+01, first-order optimality 2.99e-04.
#
# Fit results:
#
# 1355.6	 0.000430	 18.371	 8.5212	 -4.538
#  	  	  	 0.097	 5.258	 2.697
#
#
# Reduced chi-squared: 0.945672
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 1.5772e+01, final cost 1.2767e+01, first-order optimality 2.99e-04.
#
# Fit results:
#
# 1355.6	 0.000430	 18.371	 8.5212	 -4.538
#  	  	  	 0.097	 5.258	 2.697
#
#
# Reduced chi-squared: 0.945672
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 7.2583e+01, final cost 6.8146e+01, first-order optimality 8.47e-03.
#
# Fit results:
#
# 1317.22	 0.000440	 14.304	 13.055	 -1.0217
#  	  	  	 0.037	 1.307	 0.81
#
# 1370.13	 0.000440	 14.304	 13.055	 -1.0217
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000440	 14.304	 13.055	 -1.0217
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.273766
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 7.2583e+01, final cost 6.8146e+01, first-order optimality 8.47e-03.
#
# Fit results:
#
# 1317.22	 0.000440	 14.304	 13.055	 -1.0217
#  	  	  	 0.037	 1.307	 0.81
#
# 1370.13	 0.000440	 14.304	 13.055	 -1.0217
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000440	 14.304	 13.055	 -1.0217
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.273766
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_4.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_4_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_4_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.5358e+01, final cost 1.1603e+01, first-order optimality 4.15e-05.
#
# Fit results:
#
# 1358.77	 0.000420	 12.809	 4.0000	 -1.2719
#  	  	  	 0.342	 10.762	 3.495
#
#
# Reduced chi-squared: 0.892552
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.5358e+01, final cost 1.1603e+01, first-order optimality 4.15e-05.
#
# Fit results:
#
# 1358.77	 0.000420	 12.809	 4.0000	 -1.2719
#  	  	  	 0.342	 10.762	 3.495
#
#
# Reduced chi-squared: 0.892552
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_5.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_5.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_5_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M20/modified_component_groups/input_group_5_inspect.fits
#
# VPmeasure: 6/6 fits converged, 0/6 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 1.7597e+02, final cost 1.5716e+02, first-order optimality 1.41e-02.
#
# Fit results:
#
# 1608.45	 0.000460	 15.670	 18.610	 -3.4105
#  	  	  	 0.087	 1.04	 1.49
#
# 1611.2	 0.000460	 15.670	 18.610	 -3.4105
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 3.308718
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 1.7597e+02, final cost 1.5716e+02, first-order optimality 1.41e-02.
#
# Fit results:
#
# 1608.45	 0.000460	 15.670	 18.610	 -3.4105
#  	  	  	 0.087	 1.04	 1.49
#
# 1611.2	 0.000460	 15.670	 18.610	 -3.4105
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 3.308718
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 6.3398e+01, final cost 4.6964e+01, first-order optimality 6.47e-03.
#
# Fit results:
#
# 1239.93	 0.000420	 16.441	 12.576	 6.0493
#  	  	  	 0.098	 3.062	 2.018
#
# 1240.39	 0.000420	 16.441	 12.576	 6.0493
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.467633
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 6.3398e+01, final cost 4.6964e+01, first-order optimality 6.47e-03.
#
# Fit results:
#
# 1239.93	 0.000420	 16.441	 12.576	 6.0493
#  	  	  	 0.098	 3.062	 2.018
#
# 1240.39	 0.000420	 16.441	 12.576	 6.0493
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.467633
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 2.2827e+02, final cost 8.3022e+01, first-order optimality 1.74e-02.
#
# Fit results:
#
# 1250.58	 0.000540	 16.217	 23.285	 -15.418
#  	  	  	 0.185	 2.517	 1.127
#
# 1253.8	 0.000540	 16.217	 23.285	 -15.418
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.551807
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 2.2827e+02, final cost 8.3022e+01, first-order optimality 1.74e-02.
#
# Fit results:
#
# 1250.58	 0.000540	 16.217	 23.285	 -15.418
#  	  	  	 0.185	 2.517	 1.127
#
# 1253.8	 0.000540	 16.217	 23.285	 -15.418
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.551807
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.9415e+01, final cost 1.7682e+01, first-order optimality 2.68e-03.
#
# Fit results:
#
# 1355.6	 0.000460	 18.533	 27.648	 -4.240
#  	  	  	 0.102	 10.071	 6.34
#
#
# Reduced chi-squared: 1.040097
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.9415e+01, final cost 1.7682e+01, first-order optimality 2.68e-03.
#
# Fit results:
#
# 1355.6	 0.000460	 18.533	 27.648	 -4.240
#  	  	  	 0.102	 10.071	 6.34
#
#
# Reduced chi-squared: 1.040097
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 24, initial cost 1.1583e+02, final cost 1.0160e+02, first-order optimality 1.57e-02.
#
# Fit results:
#
# 1317.22	 0.000490	 14.227	 16.813	 -9.7092
#  	  	  	 0.034	 1.963	 1.265
#
# 1370.13	 0.000490	 14.227	 16.813	 -9.7092
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 14.227	 16.813	 -9.7092
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.707599
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 24, initial cost 1.1583e+02, final cost 1.0160e+02, first-order optimality 1.57e-02.
#
# Fit results:
#
# 1317.22	 0.000490	 14.227	 16.813	 -9.7092
#  	  	  	 0.034	 1.963	 1.265
#
# 1370.13	 0.000490	 14.227	 16.813	 -9.7092
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 14.227	 16.813	 -9.7092
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.707599
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_4.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_4_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_4_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 2.0236e+01, final cost 1.6643e+01, first-order optimality 4.44e-04.
#
# Fit results:
#
# 1358.77	 0.000540	 12.848	 4.0000	 -5.8856
#  	  	  	 0.392	 11.213	 3.77
#
#
# Reduced chi-squared: 1.447203
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 2.0236e+01, final cost 1.6643e+01, first-order optimality 4.44e-04.
#
# Fit results:
#
# 1358.77	 0.000540	 12.848	 4.0000	 -5.8856
#  	  	  	 0.392	 11.213	 3.77
#
#
# Reduced chi-squared: 1.447203
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_5.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_5.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_5_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M30/modified_component_groups/input_group_5_inspect.fits
#
# VPmeasure: 6/6 fits converged, 0/6 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 20, initial cost 2.6174e+02, final cost 1.8228e+02, first-order optimality 8.35e-03.
#
# Fit results:
#
# 1608.45	 0.000460	 15.981	 23.810	 -20.696
#  	  	  	 0.058	 0.723	 0.992
#
# 1611.2	 0.000460	 15.981	 23.810	 -20.696
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 3.962536
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 20, initial cost 2.6174e+02, final cost 1.8228e+02, first-order optimality 8.35e-03.
#
# Fit results:
#
# 1608.45	 0.000460	 15.981	 23.810	 -20.696
#  	  	  	 0.058	 0.723	 0.992
#
# 1611.2	 0.000460	 15.981	 23.810	 -20.696
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 3.962536
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 3.2250e+01, final cost 2.8388e+01, first-order optimality 3.94e-04.
#
# Fit results:
#
# 1239.93	 0.000450	 16.165	 9.9357	 3.3573
#  	  	  	 0.093	 3.544	 1.947
#
# 1240.39	 0.000450	 16.165	 9.9357	 3.3573
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.013854
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 3.2250e+01, final cost 2.8388e+01, first-order optimality 3.94e-04.
#
# Fit results:
#
# 1239.93	 0.000450	 16.165	 9.9357	 3.3573
#  	  	  	 0.093	 3.544	 1.947
#
# 1240.39	 0.000450	 16.165	 9.9357	 3.3573
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.013854
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 1.1737e+02, final cost 8.6967e+01, first-order optimality 1.42e-02.
#
# Fit results:
#
# 1250.58	 0.000500	 16.728	 18.250	 -5.1871
#  	  	  	 0.519	 3.101	 0.871
#
# 1253.8	 0.000500	 16.728	 18.250	 -5.1871
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.811806
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 1.1737e+02, final cost 8.6967e+01, first-order optimality 1.42e-02.
#
# Fit results:
#
# 1250.58	 0.000500	 16.728	 18.250	 -5.1871
#  	  	  	 0.519	 3.101	 0.871
#
# 1253.8	 0.000500	 16.728	 18.250	 -5.1871
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.811806
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 1.4137e+01, final cost 1.1838e+01, first-order optimality 1.17e-04.
#
# Fit results:
#
# 1355.6	 0.000440	 18.335	 14.793	 -4.8702
#  	  	  	 0.108	 7.066	 4.309
#
#
# Reduced chi-squared: 0.816428
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 1.4137e+01, final cost 1.1838e+01, first-order optimality 1.17e-04.
#
# Fit results:
#
# 1355.6	 0.000440	 18.335	 14.793	 -4.8702
#  	  	  	 0.108	 7.066	 4.309
#
#
# Reduced chi-squared: 0.816428
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_3_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 1.1146e+02, final cost 1.1060e+02, first-order optimality 2.90e-02.
#
# Fit results:
#
# 1317.22	 0.000460	 14.231	 21.558	 -1.4173
#  	  	  	 0.025	 1.917	 1.224
#
# 1370.13	 0.000460	 14.231	 21.558	 -1.4173
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000460	 14.231	 21.558	 -1.4173
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.957535
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 1.1146e+02, final cost 1.1060e+02, first-order optimality 2.90e-02.
#
# Fit results:
#
# 1317.22	 0.000460	 14.231	 21.558	 -1.4173
#  	  	  	 0.025	 1.917	 1.224
#
# 1370.13	 0.000460	 14.231	 21.558	 -1.4173
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000460	 14.231	 21.558	 -1.4173
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.957535
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_4.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_4.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_4_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_4_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 1.1099e+01, final cost 1.0090e+01, first-order optimality 8.38e-05.
#
# Fit results:
#
# 1358.77	 0.000660	 12.867	 11.726	 0.29044
#  	  	  	 0.139	 8.487	 4.753
#
#
# Reduced chi-squared: 0.720732
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 1.1099e+01, final cost 1.0090e+01, first-order optimality 8.38e-05.
#
# Fit results:
#
# 1358.77	 0.000660	 12.867	 11.726	 0.29044
#  	  	  	 0.139	 8.487	 4.753
#
#
# Reduced chi-squared: 0.720732
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_5.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_5.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_5_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC330-A02/E140M/E140M40/modified_component_groups/input_group_5_inspect.fits
#
# VPmeasure: 6/6 fits converged, 0/6 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    df = pd.read_csv('compiledVPoutputs.dat', sep = '|')
    filtered_df = df[df['zsys'] > 0.0002]
    filtered_df = filtered_df[filtered_df['sigcol'] != 0.000]
    result = filtered_df[['col', 'sigcol', 'trans']]

    unique_result = result#.drop_duplicates()
    print(unique_result)
    os.chdir(base_directory)
# Out:
#       col  sigcol trans
# 0  15.933   0.052  S II
# 2  18.430   0.098   O I
# 3  14.217   0.029  NiII
# 6  15.513   0.091  FeII
# 8  16.219   0.059  MgII
#        col  sigcol trans
# 0   16.871   0.842  S II
# 2   18.371   0.097   O I
# 3   14.304   0.037  NiII
# 6   15.730   0.074  FeII
# 8   16.348   0.068  MgII
# 10  12.809   0.342  CuII
#        col  sigcol trans
# 0   16.217   0.185  S II
# 2   18.533   0.102   O I
# 3   14.227   0.034  NiII
# 6   15.670   0.087  FeII
# 8   16.441   0.098  MgII
# 10  12.848   0.392  CuII
#        col  sigcol trans
# 0   16.728   0.519  S II
# 2   18.335   0.108   O I
# 3   14.231   0.025  NiII
# 6   15.981   0.058  FeII
# 8   16.165   0.093  MgII
# 10  12.867   0.139  CuII

# %%
directories = [d for d in os.listdir(base_directory)
               if os.path.isdir(os.path.join(base_directory, d))]

records = []

for specdir in directories:
    fn = os.path.join(base_directory, specdir, "compiledVPoutputs.dat")
    if not os.path.isfile(fn):
        continue

    df = pd.read_csv(fn, sep = "|")
    df = df[(df["zsys"] > 0.0002) & (df["sigcol"] != 0.0)]
    records.append(df[["trans", "col", "sigcol"]])

all_measurements = pd.concat(records, ignore_index = True)

def random_effects_mean(vals, sigmas):
    vals = np.asarray(vals, dtype = float)
    sigmas = np.asarray(sigmas, dtype = float)
    var = sigmas ** 2

    w  = 1.0 / var
    mu = (w * vals).sum() / w.sum()

    Q  = (w * (vals - mu) ** 2).sum()
    df = len(vals) - 1
    c  = w.sum() - (w ** 2).sum() / w.sum()
    T2 = max(0.0, (Q - df) / c) if c > 0 else 0.0

    w_re = 1.0 / (var + T2)
    mean = (w_re * vals).sum() / w_re.sum()
    std  = np.sqrt(1.0 / w_re.sum())
    return mean, std

combined = (
    all_measurements
    .groupby("trans", sort = True)
    .apply(lambda g: random_effects_mean(g["col"], g["sigcol"]))
    .apply(pd.Series)
    .reset_index()
    .rename(columns = {0: "col_combined", 1: "sigcol_combined"})
)

combined = combined.sort_values("trans").reset_index(drop = True)

for _, row in combined.iterrows():
    print(f"{row.trans}  {row.col_combined:.3f} ± {row.sigcol_combined:.3f}")
# Out:
# CuII  12.858 ± 0.122
# FeII  15.731 ± 0.104
# MgII  16.288 ± 0.056
# NiII  14.240 ± 0.017
# O I  18.418 ± 0.050
# S II  16.118 ± 0.155
# /var/folders/7n/v6gcxcpj68q6nnv2znnc85xc0000gn/T/ipykernel_1021/2562963298.py:38: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: random_effects_mean(g["col"], g["sigcol"]))

# %%
# END
