# %%
import os
import re
import glob
import numpy as np
import pandas as pd

from importlib import reload
from joebvp import cfg, utils, VPmeasure

# %%
def replace_string(dataset_name):
    segment = """lt_xspec [dataset_name]_x1dsum.fits 
lt_continuumfit --redshift 0.00053 [dataset_name]_x1dsum.fits [dataset_name]_continuumfit.fits
pyigm_igmguesses [dataset_name]_continuumfit.fits -o [dataset_name]_x1dfits_model.json
pyigm_fitdla --out_file [dataset_name]_xfitdla.json [dataset_name]_continuumfit.fits 0"""
    modified_segment = segment.replace("[dataset_name]", dataset_name)
    print(modified_segment)
    
replace_string("lek63c010")
# Out:
# lt_xspec lek63c010_x1dsum.fits
# lt_continuumfit --redshift 0.00053 lek63c010_x1dsum.fits lek63c010_continuumfit.fits
# pyigm_igmguesses lek63c010_continuumfit.fits -o lek63c010_x1dfits_model.json
# pyigm_fitdla --out_file lek63c010_xfitdla.json lek63c010_continuumfit.fits 0

# %%
reload(cfg)

d = pd.DataFrame({
    'instr': ['COS', 'COS', 'COS', 'COS', 'STIS', 'STIS', 'Gaussian'],
    'gratings': ['G130M', 'G160M', 'G185M', 'G225M', 'E230M', 'E140M', 'N/A'],
    'slits': ['NA', 'NA', 'NA', 'NA', '0.2x0.2', '0.2x0.2', 'NA'],
    'lsfranges': [[1120, 1440], [1460, 1800], [1800, 2100], [2100, 2278], [1607, 3129], [1144, 1729], [899, 1191]],
    'lps': ['1', '1', '1', '1', '1', '1', 'NA'],
    'cen_wave': ['1291', '1600', '1953', '2250', '1978', '1425', 'NA'],
    'pixel_scales': [None, None, None, None, None, None, 0.013], 
    'fwhms': [None, None, None, None, None, None, 0.02]
})

num = 0

cfg.lsfs = []
for col in ['instr', 'gratings', 'slits', 'lps', 'cen_wave', 'pixel_scales', 'fwhms']:
    setattr(cfg, col, [d.at[num, col]])

cfg.lsfranges = np.array([d.at[num, 'lsfranges']])

# %%
base_directory = "/Users/billyli/Documents/float-for-morrow/SMC/NGC346-ELS-13/G130M"
directories = sorted([d for d in os.listdir(base_directory) if d.startswith("G130M")])

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_models = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))
    continuumfits = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))

    utils.pyigm_to_veeper(igm_models[0], continuumfits[0])

    os.chdir(base_directory)
# Out:
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    component_groups_dir = os.path.join(current_directory, "component_groups")
    output_dir = os.path.join(current_directory, "modified_component_groups")

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    mc_lines_file = "/Users/billyli/Documents/float-for-morrow/mc_lines_g130m.txt"
    mc_lines_df = pd.read_csv(mc_lines_file, sep = r"\s+", header = None, names = ["line", "wavelength"])
    mc_lines_df["wavelength"] = mc_lines_df["wavelength"].astype(float)

    def is_valid_line(row, line_df):
        trans = row["trans"].strip()
        restwave = row["restwave"]
        matching_lines = line_df[line_df["line"] == trans]
        for wave in matching_lines["wavelength"]:
            if 0.995 * wave <= restwave <= 1.005 * wave:
                return True
        return False

    input_files = glob.glob(os.path.join(component_groups_dir, "*.txt"))

    for file in input_files:
        df = pd.read_csv(file, sep = "|")
        df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    
        df["restwave"] = pd.to_numeric(df["restwave"], errors = "coerce")
        df["bval"] = pd.to_numeric(df["bval"], errors = "coerce")
    
        valid_mask = df.apply(lambda row: is_valid_line(row, mc_lines_df), axis = 1)
        df_filtered = df[valid_mask].copy()

        # df_filtered["col"] = df_filtered["col"] - 0.2
        df_filtered["bval"] = df_filtered["bval"] / 2
    
        output_file = os.path.join(output_dir, os.path.basename(file))
        df_filtered.to_csv(output_file, sep = "|", index = False)
        # print(f"Processed file: {os.path.basename(file)} -> {output_file}")

# %%
# Before fitting, should manually adjust the input group files

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_models = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))
    continuumfits = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))

    component_groups_dir = os.path.join(current_directory, "modified_component_groups")
    
    input_group_files = sorted([f for f in glob.glob(os.path.join(component_groups_dir, "input_group_*.txt")) if re.match(r".*input_group_\d+\.txt$", f)])

    VPmeasure.batch_fit(continuumfits[0], input_group_files, filepath = './modified_component_groups/')

    os.chdir(base_directory)
# Out:
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 3.4881e+01, final cost 1.6933e+01, first-order optimality 2.01e-04.
#
# Fit results:
#
# 1152.82	 0.000470	 13.420	 22.600	 -3.3466
#  	  	  	 0.029	 2.694	 1.645
#
#
# Reduced chi-squared: 0.705528
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 3.4881e+01, final cost 1.6933e+01, first-order optimality 2.01e-04.
#
# Fit results:
#
# 1152.82	 0.000470	 13.420	 22.600	 -3.3466
#  	  	  	 0.029	 2.694	 1.645
#
#
# Reduced chi-squared: 0.705528
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC346-ELS-13/G130M/G130M10/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC346-ELS-13/G130M/G130M10/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC346-ELS-13/G130M/G130M10/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC346-ELS-13/G130M/G130M10/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 6.4055e+01, final cost 6.0783e+01, first-order optimality 3.58e-04.
#
# Fit results:
#
# 1239.93	 0.000450	 15.516	 17.012	 -1.7058
#  	  	  	 0.048	 3.698	 2.297
#
# 1240.39	 0.000450	 15.516	 17.012	 -1.7058
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.397315
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 6.4055e+01, final cost 6.0783e+01, first-order optimality 3.58e-04.
#
# Fit results:
#
# 1239.93	 0.000450	 15.516	 17.012	 -1.7058
#  	  	  	 0.048	 3.698	 2.297
#
# 1240.39	 0.000450	 15.516	 17.012	 -1.7058
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.397315
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC346-ELS-13/G130M/G130M10/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC346-ELS-13/G130M/G130M10/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC346-ELS-13/G130M/G130M10/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC346-ELS-13/G130M/G130M10/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 6.7048e+02, final cost 1.7265e+02, first-order optimality 4.05e-02.
#
# Fit results:
#
# 1250.58	 0.000440	 15.389	 28.670	 6.8758
#  	  	  	 0.007	 0.619	 0.427
#
# 1253.8	 0.000440	 15.389	 28.670	 6.8758
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.448942
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 6.7048e+02, final cost 1.7265e+02, first-order optimality 4.05e-02.
#
# Fit results:
#
# 1250.58	 0.000440	 15.389	 28.670	 6.8758
#  	  	  	 0.007	 0.619	 0.427
#
# 1253.8	 0.000440	 15.389	 28.670	 6.8758
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.448942
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC346-ELS-13/G130M/G130M10/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC346-ELS-13/G130M/G130M10/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC346-ELS-13/G130M/G130M10/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC346-ELS-13/G130M/G130M10/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 1.0091e+02, final cost 7.7996e+01, first-order optimality 4.81e-03.
#
# Fit results:
#
# 1317.22	 0.000490	 13.692	 29.220	 -5.2425
#  	  	  	 0.03	 3.059	 1.996
#
# 1370.13	 0.000490	 13.692	 29.220	 -5.2425
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.164117
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 1.0091e+02, final cost 7.7996e+01, first-order optimality 4.81e-03.
#
# Fit results:
#
# 1317.22	 0.000490	 13.692	 29.220	 -5.2425
#  	  	  	 0.03	 3.059	 1.996
#
# 1370.13	 0.000490	 13.692	 29.220	 -5.2425
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.164117
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/NGC346-ELS-13/G130M/G130M10/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/NGC346-ELS-13/G130M/G130M10/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC346-ELS-13/G130M/G130M10/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/NGC346-ELS-13/G130M/G130M10/modified_component_groups/input_group_3_inspect.fits
#
# VPmeasure: 4/4 fits converged, 0/4 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    df = pd.read_csv('compiledVPoutputs.dat', sep = '|')
    filtered_df = df[df['zsys'] > 0.0002]
    filtered_df = filtered_df[filtered_df['sigcol'] != 0.000]
    result = filtered_df[['col', 'sigcol', 'trans']]

    unique_result = result.drop_duplicates()
    print(unique_result)
    os.chdir(base_directory)
# Out:
#       col  sigcol trans
# 0  15.389   0.007  S II
# 2  13.692   0.030  NiII
# 4  13.420   0.029  P II
# 5  15.516   0.048  MgII

# %%
directories = [d for d in os.listdir(base_directory)
               if os.path.isdir(os.path.join(base_directory, d))]

records = []

for specdir in directories:
    fn = os.path.join(base_directory, specdir, "compiledVPoutputs.dat")
    if not os.path.isfile(fn):
        continue

    df = pd.read_csv(fn, sep = "|")
    df = df[(df["zsys"] > 0.0002) & (df["sigcol"] != 0.0)]
    records.append(df[["trans", "col", "sigcol"]])

all_measurements = pd.concat(records, ignore_index = True)

def random_effects_mean(vals, sigmas):
    vals = np.asarray(vals, dtype = float)
    sigmas = np.asarray(sigmas, dtype = float)
    var = sigmas ** 2

    w  = 1.0 / var
    mu = (w * vals).sum() / w.sum()

    Q  = (w * (vals - mu) ** 2).sum()
    df = len(vals) - 1
    c  = w.sum() - (w ** 2).sum() / w.sum()
    T2 = max(0.0, (Q - df) / c) if c > 0 else 0.0

    w_re = 1.0 / (var + T2)
    mean = (w_re * vals).sum() / w_re.sum()
    std  = np.sqrt(1.0 / w_re.sum())
    return mean, std

combined = (
    all_measurements
    .groupby("trans", sort = True)
    .apply(lambda g: random_effects_mean(g["col"], g["sigcol"]))
    .apply(pd.Series)
    .reset_index()
    .rename(columns = {0: "col_combined", 1: "sigcol_combined"})
)

combined = combined.sort_values("trans").reset_index(drop = True)

for _, row in combined.iterrows():
    print(f"{row.trans}  {row.col_combined:.3f} ± {row.sigcol_combined:.3f}")
# Out:
# MgII  15.516 ± 0.048
# NiII  13.692 ± 0.030
# P II  13.420 ± 0.029
# S II  15.389 ± 0.007
# /var/folders/7n/v6gcxcpj68q6nnv2znnc85xc0000gn/T/ipykernel_1404/2562963298.py:38: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: random_effects_mean(g["col"], g["sigcol"]))

# %%
# END
