# %%
import os
import numpy as np
import pandas as pd
import astropy.units as u
import matplotlib.pyplot as plt

from pathlib import Path
from astropy.io import fits
from astropy.wcs import WCS
from astroquery.simbad import Simbad
from reproject import reproject_interp
from matplotlib.patches import Rectangle
from astroquery.hips2fits import hips2fits
import matplotlib.patheffects as PathEffects
from astropy.wcs.utils import proj_plane_pixel_scales
from astropy.coordinates import SkyCoord, Angle, SkyOffsetFrame

font = {'family' : 'gill sans',
         'size'   : 12,
         'serif':  'cmr10'
         }

plt.rc('font', **font)
plt.rc('axes', unicode_minus = False)

# %%
galaxy_directory = Path().resolve()
galaxy = galaxy_directory.parts[galaxy_directory.parts.index("float-for-morrow") + 1]

# %%
records_O = []
records_S = []
records_Fe = []

for region_name in os.listdir(galaxy_directory):
    region_path = galaxy_directory / region_name
    if region_path.name.startswith(".") or not region_path.is_dir():
        continue

    for target_name in os.listdir(region_path):
        target_path = region_path / target_name
        if target_path.name.startswith(".") or target_path.name.startswith("unused") or not target_path.is_dir():
            continue
        target = Simbad.query_object(target_name)
        ra_str  = target["ra"][0]
        dec_str = target["dec"][0]
        coord = SkyCoord(ra_str, dec_str, unit = (u.deg, u.deg), frame = "icrs")
    
        O_path = target_path / "O.txt"
        
        if O_path.is_file():
            
            with open(O_path, "r") as file:
                
                lines = file.readlines()
                OI_H = float(lines[0].strip())
                sigma_OI_H = float(lines[1].strip())
    
            records_O.append({
                    "Target": target_name,
                    "RA": coord.ra.deg,
                    "DEC": coord.dec.deg,
                    "OI_H": OI_H,
                    "sigma_OI_H": sigma_OI_H,
                })
            
        S_path = target_path / "S.txt"
        
        if S_path.is_file():
            
            with open(S_path, "r") as file:
                
                lines = file.readlines()
                SII_H = float(lines[0].strip())
                sigma_SII_H = float(lines[1].strip())
    
            records_S.append({
                    "Target": target_name,
                    "RA": coord.ra.deg,
                    "DEC": coord.dec.deg,
                    "SII_H": SII_H,
                    "sigma_SII_H": sigma_SII_H,
                })
            
        Fe_path = target_path / "Fe.txt"
        
        if Fe_path.is_file():
            
            with open(Fe_path, "r") as file:
                
                lines = file.readlines()
                FeII_H = float(lines[0].strip())
                sigma_FeII_H = float(lines[1].strip())
    
            records_Fe.append({
                    "Region": region_name, 
                    "Target": target_name,
                    "RA": coord.ra.deg,
                    "DEC": coord.dec.deg,
                    "FeII_H": FeII_H,
                    "sigma_FeII_H": sigma_FeII_H,
                })

# %%
df_O = pd.DataFrame.from_records(records_O)
df_S = pd.DataFrame.from_records(records_S)
df_Fe = pd.DataFrame.from_records(records_Fe)

# %%
df_Fe
# Out:
#       Region               Target         RA        DEC    FeII_H  \
# 0   SMC N88A            2dFS 3694  21.143522 -73.152468  6.045715
# 1    SMC N90               SK 183  22.352284 -73.554541  5.929617
# 2   SMC N66A   Cl* NGC 346 ELS 51  14.786236 -72.170593  5.905223
# 3   SMC N66A   Cl* NGC 346 ELS 50  14.730089 -72.151859  5.855228
# 4   SMC N66A  Cl* NGC 346 MPG 782  14.876602 -72.152674  6.417801
# 5   SMC N66A      Cl* NGC 346 W 3  14.753163 -72.174492  6.184877
# 6   SMC N66A      Cl* NGC 346 W 4  14.750219 -72.177212  6.036586
# 7   SMC N66A   Cl* NGC 346 ELS 22  14.827573 -72.186080  5.896830
# 8   SMC N66A    Cl* NGC 346 SSN 7  14.768732 -72.173540  6.060756
# 9   SMC N66A    Cl* NGC 346 ELS 7  14.739151 -72.176017  6.075540
# 10  SMC N66A   Cl* NGC 346 SSN 25  14.801250 -72.185528  5.669848
# 11  SMC N66A   Cl* NGC 346 NMC 28  14.757578 -72.175338  5.825405
# 12  SMC N66A   Cl* NGC 346 NMC 17  14.778124 -72.178128  5.837428
# ...

# %%
def make_north_up_header(hdu):
    wcs_in = WCS(hdu.header)
    ny, nx = hdu.data.shape
    center_pix = ((nx - 1) / 2.0, (ny - 1) / 2.0)
    center_world = wcs_in.pixel_to_world(*center_pix)

    scales = proj_plane_pixel_scales(wcs_in)

    wcs_target = WCS(naxis = 2)
    wcs_target.wcs.crval = [center_world.ra.deg, center_world.dec.deg]
    wcs_target.wcs.crpix = [ (nx + 1) / 2.0, (ny + 1) / 2.0 ]
    wcs_target.wcs.cdelt = [-scales[0], scales[1]]
    wcs_target.wcs.ctype = ["RA---TAN", "DEC--TAN"]

    header = wcs_target.to_header()
    header["NAXIS1"] = nx
    header["NAXIS2"] = ny
    return header

# %%
region_count = 0
region_hdus = []
Simbad.add_votable_fields("dimensions")
for region_name in os.listdir(galaxy_directory):
    region_path = galaxy_directory / region_name
    if region_path.name.startswith(".") or not region_path.is_dir():
        continue
    print(region_name)
    region_query = Simbad.query_object(region_name)
    ra_region = region_query["ra"][0]
    dec_region = region_query["dec"][0]
    majaxis_region = 5
    minaxis_region = 5
    position = SkyCoord(ra_region, dec_region, unit = (u.deg, u.deg), frame = "icrs")
    hdu_list = hips2fits.query(hips = "CDS/P/DSS2/red", width = 3000, height = 3000, projection = "TAN", ra = position.ra, dec = position.dec, fov = Angle(np.max(np.array([majaxis_region, minaxis_region])) * u.arcmin), format = "fits")

    # Halpha: CDS/P/SHASSA/H
    
    region_count += 1
    region_hdus.append(hdu_list)
# Out:
# SMC N88A
# SMC N90
# SMC N66A
# SMC N81

# %%
selection = 0

i = 0
for region_name in os.listdir(galaxy_directory):
    region_path = galaxy_directory / region_name
    if region_path.name.startswith(".") or not region_path.is_dir():
        continue
    if i == selection:
        df_Fe_cur = df_Fe[df_Fe["Region"] == region_name].copy()
        region_query = Simbad.query_object(region_name)
        ra_region = region_query["ra"][0]
        dec_region = region_query["dec"][0]
        position = SkyCoord(ra_region, dec_region, unit = (u.deg, u.deg), frame = "icrs")

        if galaxy == "LMC": 
            d = 49.97 * u.kpc
        elif galaxy == "SMC":
            d = 62.1 * u.kpc
        origin = position
        off_frame = SkyOffsetFrame(origin = origin)

        sky  = SkyCoord(df_Fe_cur["RA"].values * u.deg, df_Fe_cur["DEC"].values * u.deg)
        off  = sky.transform_to(off_frame)

        scale = (d.to(u.pc) * (np.pi / 180)).value

        df_Fe_cur["x_pc"] = off.lon.deg * scale
        df_Fe_cur["y_pc"] = off.lat.deg * scale
        
        hdu_list = region_hdus[selection]
        
        hdu = hdu_list[0]
        wcs = WCS(hdu.header)  

        ny, nx = hdu.data.shape
        corners_px = np.array([[0, 0], [nx, 0], [0, ny], [nx, ny]])
        corners_sky = wcs.pixel_to_world(corners_px[:, 0], corners_px[:, 1])
        corners_off = corners_sky.transform_to(off_frame)
        
        x_corners = corners_off.lon.deg * scale
        y_corners = corners_off.lat.deg * scale
        extent_pc = [x_corners.min(), x_corners.max(), y_corners.min(), y_corners.max()]
        
        fig, ax = plt.subplots(figsize = (6, 6), dpi = 300)
        
        ax.imshow(np.log(hdu.data), origin = "lower", cmap = "grey_r", vmin = np.nanpercentile(np.log(hdu.data), 90), vmax = np.nanpercentile(np.log(hdu.data), 99.9), extent = extent_pc)
        
        block_size = 2

        for _, row in df_Fe_cur.iterrows():
            rect = Rectangle((row.x_pc - block_size / 2, row.y_pc - block_size / 2), block_size, block_size, linewidth = 2, edgecolor = 'white', facecolor = 'none')
            ax.add_patch(rect)
            rect.set_path_effects([PathEffects.withStroke(linewidth = 3, foreground = "black")])
            txt = ax.text(row.x_pc + 0.06, row.y_pc - 0.2, f"{row["FeII_H"]:.1f}", fontsize = 12, color = "white", ha = "center", va = "center", weight = "bold")
            txt.set_path_effects([PathEffects.withStroke(linewidth = 2, foreground = "black")])
            
        center_x_correction = 0
        center_y_correction = 0
        
        block_width_deg = 5.3 / 3600
        block_height_deg = 3 / 3600
        
        block_width_pc = block_width_deg * scale
        block_height_pc = block_height_deg * scale

        big_rect = Rectangle((center_x_correction - block_width_pc / 2, center_y_correction - block_height_pc / 2), block_width_pc, block_height_pc, linewidth = 1, edgecolor = "black", facecolor = "none", angle = 0)
        ax.add_patch(big_rect)
        big_rect.set_path_effects([PathEffects.withStroke(linewidth = 3, foreground = "white")])

        text = ax.text(center_x_correction, center_y_correction, r"$5.59\pm0.03$", fontsize = 30, color = "black", ha = "left", va = "bottom", weight = "bold")
        text.set_path_effects([PathEffects.withStroke(linewidth = 4, foreground = "white")])

        ax.set_aspect("equal")
        ax.set_title("SMC N88A")
        ax.set_xticks([])
        ax.set_yticks([])

        scalebar_length = 10
        scalebar_x = extent_pc[0] + 30
        scalebar_y = extent_pc[3] - 30
        
        ax.plot([scalebar_x, scalebar_x + scalebar_length], [scalebar_y, scalebar_y], color = "black", lw = 3)
        ax.text(scalebar_x + scalebar_length / 2, scalebar_y + 0.5, f"{scalebar_length} pc", color = "black", fontsize = 12, ha = "center", va = "bottom", weight = "bold")
            
        plt.tight_layout()
        plt.show()
        
    i += 1

# %%
selection = 1

i = 0
for region_name in os.listdir(galaxy_directory):
    region_path = galaxy_directory / region_name
    if region_path.name.startswith(".") or not region_path.is_dir():
        continue
    if i == selection:
        df_Fe_cur = df_Fe[df_Fe["Region"] == region_name].copy()
        region_query = Simbad.query_object(region_name)
        ra_region = region_query["ra"][0]
        dec_region = region_query["dec"][0]
        position = SkyCoord(ra_region, dec_region, unit = (u.deg, u.deg), frame = "icrs")

        if galaxy == "LMC": 
            d = 49.97 * u.kpc
        elif galaxy == "SMC":
            d = 62.1 * u.kpc
        origin = position
        off_frame = SkyOffsetFrame(origin = origin)

        sky  = SkyCoord(df_Fe_cur["RA"].values * u.deg, df_Fe_cur["DEC"].values * u.deg)
        off  = sky.transform_to(off_frame)

        scale = (d.to(u.pc) * (np.pi / 180)).value

        df_Fe_cur["x_pc"] = off.lon.deg * scale
        df_Fe_cur["y_pc"] = off.lat.deg * scale
        
        hdu_list = region_hdus[selection]
        
        hdu = hdu_list[0]
        wcs = WCS(hdu.header)  

        ny, nx = hdu.data.shape
        corners_px = np.array([[0, 0], [nx, 0], [0, ny], [nx, ny]])
        corners_sky = wcs.pixel_to_world(corners_px[:, 0], corners_px[:, 1])
        corners_off = corners_sky.transform_to(off_frame)
        
        x_corners = corners_off.lon.deg * scale
        y_corners = corners_off.lat.deg * scale
        extent_pc = [x_corners.min(), x_corners.max(), y_corners.min(), y_corners.max()]
        
        fig, ax = plt.subplots(figsize = (6, 6), dpi = 300)
        
        ax.imshow(np.log(hdu.data), origin = "lower", cmap = "grey_r", vmin = np.nanpercentile(np.log(hdu.data), 1), vmax = np.nanpercentile(np.log(hdu.data), 99), extent = extent_pc)
        
        block_size = 4

        for _, row in df_Fe_cur.iterrows():
            rect = Rectangle((row.x_pc - block_size / 2, row.y_pc - block_size / 2), block_size, block_size, linewidth = 2, edgecolor = 'white', facecolor = 'none')
            ax.add_patch(rect)
            rect.set_path_effects([PathEffects.withStroke(linewidth = 3, foreground = "black")])
            txt = ax.text(row.x_pc - 0.03, row.y_pc - 0.25, f"{row["FeII_H"]:.1f}", fontsize = 12, color = "white", ha = "center", va = "center", weight = "bold")
            txt.set_path_effects([PathEffects.withStroke(linewidth = 2, foreground = "black")])
            
        center_x_correction = -1
        center_y_correction = 1.5
        
        block_width_deg = 3 / 3600
        block_height_deg = 9.5 / 3600
        
        block_width_pc = block_width_deg * scale
        block_height_pc = block_height_deg * scale

        big_rect = Rectangle((center_x_correction - block_width_pc / 2, center_y_correction - block_height_pc / 2), block_width_pc, block_height_pc, linewidth = 1, edgecolor = "black", facecolor = "none", angle = -70)
        ax.add_patch(big_rect)
        big_rect.set_path_effects([PathEffects.withStroke(linewidth = 3, foreground = "white")])

        text = ax.text(center_x_correction, center_y_correction, r"$\leq 4.72$", fontsize = 30, color = "black", ha = "left", va = "bottom", weight = "bold")
        text.set_path_effects([PathEffects.withStroke(linewidth = 4, foreground = "white")])
        
        ax.set_aspect("equal")
        ax.set_title("SMC N90")
        ax.set_xticks([])
        ax.set_yticks([])

        scalebar_length = 10
        scalebar_x = extent_pc[0] + 10
        scalebar_y = extent_pc[3] - 10
        
        ax.plot([scalebar_x, scalebar_x + scalebar_length], [scalebar_y, scalebar_y], color = "black", lw = 3)
        ax.text(scalebar_x + scalebar_length / 2, scalebar_y + 0.5, f"{scalebar_length} pc", color = "black", fontsize = 12, ha = "center", va = "bottom", weight = "bold")
            
        plt.tight_layout()
        plt.show()
        
    i += 1

# %%
selection = 2

i = 0
for region_name in os.listdir(galaxy_directory):
    region_path = galaxy_directory / region_name
    if region_path.name.startswith(".") or not region_path.is_dir():
        continue
    if i == selection:
        
        df_Fe_cur = df_Fe[df_Fe["Region"] == region_name].copy()
        region_query = Simbad.query_object(region_name)
        ra_region = region_query["ra"][0]
        dec_region = region_query["dec"][0]

        if galaxy == "LMC": 
            d = 49.97 * u.kpc
        elif galaxy == "SMC":
            d = 62.1 * u.kpc
            
        origin = SkyCoord(ra_region, dec_region, unit = (u.deg, u.deg), frame = "icrs")
        off_frame = SkyOffsetFrame(origin = origin)

        sky = SkyCoord(df_Fe_cur["RA"].values * u.deg, df_Fe_cur["DEC"].values * u.deg)
        off = sky.transform_to(off_frame)

        scale = (d.to(u.pc) * (np.pi / 180)).value

        df_Fe_cur["x_pc"] = off.lon.deg * scale
        df_Fe_cur["y_pc"] = off.lat.deg * scale

        hdu_list = fits.open("/Users/billyli/Documents/backups/j92fa3010_drz.fits")
        
        hdu = hdu_list[1]
        wcs = WCS(hdu.header)  

        ny, nx = hdu.data.shape
        corners_px = np.array([[0, 0], [nx, 0], [0, ny], [nx, ny]])
        corners_sky = wcs.pixel_to_world(corners_px[:, 0], corners_px[:, 1])
        corners_off = corners_sky.transform_to(off_frame)
        
        x_corners = corners_off.lon.deg * scale
        y_corners = corners_off.lat.deg * scale
        extent_pc = [x_corners.min(), x_corners.max(), y_corners.min(), y_corners.max()]
        
        fig, ax = plt.subplots(figsize = (6, 6), dpi = 200)
        
        ax.imshow(hdu.data, origin = "lower", cmap = "Greys", vmax = np.nanpercentile(hdu.data, 99.9), extent = extent_pc)
        
        block_size = 4

        for _, row in df_Fe_cur.iterrows():
            rect = Rectangle((row.x_pc - block_size / 2, row.y_pc - block_size / 2), block_size, block_size, linewidth = 2, edgecolor = 'white', facecolor = 'none')
            ax.add_patch(rect)
            rect.set_path_effects([PathEffects.withStroke(linewidth = 3, foreground = "black")])
            txt = ax.text(row.x_pc - 0.03, row.y_pc - 0.25, f"{row["FeII_H"]:.1f}", fontsize = 12, color = "white", ha = "center", va = "center", weight = "bold")
            txt.set_path_effects([PathEffects.withStroke(linewidth = 2, foreground = "black")])

        slit_position = SkyCoord('00h59m14.3s', '-72d11m02.8s', frame = 'icrs')
        slit_position_new_frame = slit_position.transform_to(off_frame)
        center_x_correction = slit_position_new_frame.lon.deg * scale + 4.5
        center_y_correction = slit_position_new_frame.lat.deg * scale + 2.7
        
        block_width_deg = 3 / 3600
        block_height_deg = 9.5 / 3600
        
        block_width_pc = block_width_deg * scale
        block_height_pc = block_height_deg * scale

        big_rect = Rectangle((center_x_correction - block_width_pc / 2, center_y_correction - block_height_pc / 2), block_width_pc, block_height_pc, linewidth = 1, edgecolor = "black", facecolor = "none", angle = 90)
        ax.add_patch(big_rect)
        big_rect.set_path_effects([PathEffects.withStroke(linewidth = 2, foreground = "white")])

        text = ax.text(center_x_correction, center_y_correction + 1, r"$[5.17\pm0.03, 5.26\pm0.02]$", fontsize = 12, color = "black", ha = "center", va = "center", weight = "bold")
        text.set_path_effects([PathEffects.withStroke(linewidth = 4, foreground = "white")])
        
        ax.set_aspect("equal")
        ax.set_title(r"SMC N66A")
        ax.set_xticks([])
        ax.set_yticks([])

        scalebar_length = 20
        scalebar_x = extent_pc[0] + 5
        scalebar_y = extent_pc[2] + 5
        
        ax.plot([scalebar_x, scalebar_x + scalebar_length], [scalebar_y, scalebar_y], color = "black", lw = 3)
        ax.text(scalebar_x + scalebar_length / 2, scalebar_y + 1, f"{scalebar_length} pc", color = "black", fontsize = 10, ha = "center", va = "bottom", weight = "bold")
        
        plt.tight_layout()
        plt.show()
        
    i += 1

# %%
from matplotlib.patches import FancyArrow

# %%
selection = 2

i = 0
for region_name in os.listdir(galaxy_directory):
    region_path = galaxy_directory / region_name
    if region_path.name.startswith(".") or not region_path.is_dir():
        continue
    if i == selection:
        
        df_Fe_cur = df_Fe[df_Fe["Region"] == region_name].copy()
        region_query = Simbad.query_object(region_name)
        ra_region = region_query["ra"][0]
        dec_region = region_query["dec"][0]

        region_position = SkyCoord(ra = ra_region * u.deg, dec = dec_region * u.deg, frame = "icrs")

        fits_files = list(region_path.glob("*_drz.fits"))
        if fits_files:
            hdu_list = fits.open(fits_files[0])

        hdu = hdu_list[1]
        wcs = WCS(hdu.header)

        north_up_header = make_north_up_header(hdu)
        array, footprint = reproject_interp(hdu, north_up_header, shape_out = hdu.data.shape)
        
        fig = plt.figure(figsize = (6, 6), dpi = 200)
        ax = fig.add_subplot(projection = WCS(north_up_header))

        ax.imshow(array, origin = "lower", cmap = "Greys", vmax = np.nanpercentile(hdu.data, 99.9))

        if galaxy == "LMC": 
            d = 49.97 * 1000
        elif galaxy == "SMC":
            d = 62.1 * 1000

        block_size = 4
        block_size_degrees = (block_size / d) * (180.0 / np.pi)

        for _, row in df_Fe_cur.iterrows():
            
            coord = SkyCoord(ra = row["RA"] * u.deg, dec = row["DEC"] * u.deg, frame = "icrs")

            rect = Rectangle((coord.ra.deg - block_size_degrees / 2.0 / np.cos(np.deg2rad(coord.dec.deg)), coord.dec.deg - block_size_degrees / 2.0), block_size_degrees / np.cos(np.deg2rad(coord.dec.deg)), block_size_degrees, linewidth = 2, edgecolor = "white", facecolor = "none", transform = ax.get_transform("world"), clip_on = False)
            rect.set_path_effects([PathEffects.withStroke(linewidth = 3, foreground = "black")])
            ax.add_patch(rect)
            txt = ax.text(coord.ra.deg + 0.0001, coord.dec.deg - 0.0002, f"{row["FeII_H"]:.1f}", fontsize = 12, color = "white", ha = "center", va = "center", weight = "bold", transform = ax.get_transform("world")) # adjusted for centering
            txt.set_path_effects([PathEffects.withStroke(linewidth = 2, foreground = "black")])

        slit_position = SkyCoord('00h59m14.3s', '-72d11m02.8s', frame = 'icrs')
        
        block_width = 3 / 3600
        block_height = 9.5 / 3600

        slit_position_x_correction = 0
        slit_position_y_correction = 0

        big_rect = Rectangle((slit_position.ra.deg - block_width / 2.0 / np.cos(np.deg2rad(coord.dec.deg)) + slit_position_x_correction, slit_position.dec.deg - block_height / 2.0 + slit_position_y_correction), block_width / np.cos(np.deg2rad(coord.dec.deg)), block_height, linewidth = 1, edgecolor = "black", facecolor = "none", angle = 0, transform = ax.get_transform("world"), clip_on = False)
        big_rect.set_path_effects([PathEffects.withStroke(linewidth = 2, foreground = "white")])
        ax.add_patch(big_rect)

        text = ax.text(slit_position.ra.deg + slit_position_x_correction, slit_position.dec.deg + slit_position_y_correction + 0.003, r"$[5.17\pm0.03, 5.26\pm0.02]$", fontsize = 12, color = "black", ha = "center", va = "center", weight = "bold", transform = ax.get_transform("world"))
        text.set_path_effects([PathEffects.withStroke(linewidth = 4, foreground = "white")])
        
        ax.set_aspect("equal")
        ax.set_title(r"SMC N66A")

        scalebar_length = 20
        scalebar_length_degrees = (scalebar_length / d) * (180.0 / np.pi)
        scalebar_x, scalebar_y = ax.wcs.pixel_to_world_values(hdu.data.shape[1] - 1000, 500)
        
        ax.plot([scalebar_x - scalebar_length_degrees / 2.0 / np.cos(np.deg2rad(region_position.dec.deg)), scalebar_x + scalebar_length_degrees / 2.0 / np.cos(np.deg2rad(region_position.dec.deg))], [scalebar_y, scalebar_y], color = "black", lw = 3, transform = ax.get_transform("world"))
        ax.text(scalebar_x, scalebar_y + 0.001, f"{scalebar_length} pc", color = "black", fontsize = 10, ha = "center", va = "bottom", weight = "bold", transform = ax.get_transform("world"))

        arrow_x, arrow_y = ax.wcs.pixel_to_world_values(500, 500)

        arrow_north = FancyArrow(arrow_x, arrow_y, 0, 0.3 / 60, transform = ax.get_transform("world"), width = 0.0001 / np.cos(np.deg2rad(region_position.dec.deg)), head_width = 0.0005 / np.cos(np.deg2rad(region_position.dec.deg)), head_length = 0.0005, length_includes_head = True, color = "black", clip_on = False)
        arrow_east = FancyArrow(arrow_x, arrow_y, 0.3 / 60 / np.cos(np.deg2rad(region_position.dec.deg)), 0, transform = ax.get_transform("world"), width = 0.0001, head_width = 0.0005, head_length = 0.0005 / np.cos(np.deg2rad(region_position.dec.deg)), length_includes_head = True, color = "black", clip_on = False)
        
        ax.add_patch(arrow_north)
        ax.add_patch(arrow_east)

        ax.text(arrow_x, arrow_y + 0.3 / 60 + 0.001, "N", color = "black", fontsize = 10, ha = "center", va = "center", weight = "bold", transform = ax.get_transform("world"))
        ax.text(arrow_x + 0.3 / 60 / np.cos(np.deg2rad(region_position.dec.deg)) + 0.001 / np.cos(np.deg2rad(region_position.dec.deg)), arrow_y, "E", color = "black", fontsize = 10, ha = "center", va = "center", weight = "bold", transform = ax.get_transform("world"))
        
        for coord in ax.coords:
            coord.set_ticks_visible(False)
            coord.set_ticklabel_visible(False)
            coord.set_axislabel("")
            
        plt.tight_layout()
        plt.show()
        
    i += 1

# %%
selection = 3

i = 0
for region_name in os.listdir(galaxy_directory):
    region_path = galaxy_directory / region_name
    if region_path.name.startswith(".") or not region_path.is_dir():
        continue
    if i == selection:
        df_Fe_cur = df_Fe[df_Fe["Region"] == region_name].copy()
        region_query = Simbad.query_object(region_name)
        ra_region = region_query["ra"][0]
        dec_region = region_query["dec"][0]
        position = SkyCoord(ra_region, dec_region, unit = (u.deg, u.deg), frame = "icrs")

        if galaxy == "LMC": 
            d = 49.97 * u.kpc
        elif galaxy == "SMC":
            d = 62.1 * u.kpc
        origin = position
        off_frame = SkyOffsetFrame(origin = origin)

        sky  = SkyCoord(df_Fe_cur["RA"].values * u.deg, df_Fe_cur["DEC"].values * u.deg)
        off  = sky.transform_to(off_frame)

        scale = (d.to(u.pc) * (np.pi / 180)).value

        df_Fe_cur["x_pc"] = off.lon.deg * scale
        df_Fe_cur["y_pc"] = off.lat.deg * scale
        
        hdu_list = region_hdus[selection]
        
        hdu = hdu_list[0]
        wcs = WCS(hdu.header)  

        ny, nx = hdu.data.shape
        corners_px = np.array([[0, 0], [nx, 0], [0, ny], [nx, ny]])
        corners_sky = wcs.pixel_to_world(corners_px[:, 0], corners_px[:, 1])
        corners_off = corners_sky.transform_to(off_frame)
        
        x_corners = corners_off.lon.deg * scale
        y_corners = corners_off.lat.deg * scale
        extent_pc = [x_corners.min(), x_corners.max(), y_corners.min(), y_corners.max()]
        
        fig, ax = plt.subplots(figsize = (6, 6))
        
        ax.imshow(hdu.data, origin = "lower", cmap = "grey_r", vmin = np.nanpercentile(hdu.data, 5), vmax = np.nanpercentile(hdu.data, 99), extent = extent_pc)
        
        sca = ax.scatter(df_Fe_cur["x_pc"], df_Fe_cur["y_pc"], s = 400, facecolors = "none", edgecolors = "white", linewidth = 1.5)
        sca.set_path_effects([PathEffects.withStroke(linewidth = 2, foreground = "black")])
        
        for _, row in df_Fe_cur.iterrows():
            txt = ax.text(row.x_pc - 0.05, row.y_pc - 0.2, f"{row["FeII_H"]:.1f}", fontsize = 12, color = "white", ha = "center", va = "center", weight = "bold")
            txt.set_path_effects([PathEffects.withStroke(linewidth = 2, foreground = "black")])
            
        ax.text(0, 0, 5.5, fontsize = 18, color = "red", ha = "center", va = "center", weight = "bold")
        
        ax.set_aspect("equal")
        ax.set_title("SMC N81")
        ax.set_xticks([])
        ax.set_yticks([])

        scalebar_length = 20
        scalebar_x = extent_pc[0] + 5
        scalebar_y = extent_pc[3] - 5
        
        ax.plot([scalebar_x, scalebar_x + scalebar_length], [scalebar_y, scalebar_y], color = "black", lw = 3)
        ax.text(scalebar_x + scalebar_length / 2, scalebar_y + 1, f"{scalebar_length} pc", color = "black", fontsize = 12, ha = "center", va = "bottom", weight = "bold")

        plt.tight_layout()
        plt.show()
        
    i += 1

# %%
# END
