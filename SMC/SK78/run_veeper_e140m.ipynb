# %%
import os
import re
import glob
import numpy as np
import pandas as pd

from importlib import reload
from joebvp import cfg, utils, VPmeasure

# %%
def replace_string(dataset_name):
    segment = """lt_xspec [dataset_name]_x1d.fits 
lt_continuumfit --redshift 0.00053 [dataset_name]_x1d.fits [dataset_name]_continuumfit.fits
pyigm_igmguesses [dataset_name]_continuumfit.fits -o [dataset_name]_x1dfits_model.json
pyigm_fitdla --out_file [dataset_name]_xfitdla.json [dataset_name]_continuumfit.fits 0"""
    modified_segment = segment.replace("[dataset_name]", dataset_name)
    print(modified_segment)
    
replace_string("ob2na1010")
# Out:
# lt_xspec ob2na1010_x1d.fits
# lt_continuumfit --redshift 0.00053 ob2na1010_x1d.fits ob2na1010_continuumfit.fits
# pyigm_igmguesses ob2na1010_continuumfit.fits -o ob2na1010_x1dfits_model.json
# pyigm_fitdla --out_file ob2na1010_xfitdla.json ob2na1010_continuumfit.fits 0

# %%
reload(cfg)

d = pd.DataFrame({
    'instr': ['COS', 'COS', 'COS', 'COS', 'STIS', 'STIS', 'Gaussian'],
    'gratings': ['G130M', 'G160M', 'G185M', 'G225M', 'E230M', 'E140M', 'N/A'],
    'slits': ['NA', 'NA', 'NA', 'NA', '0.2x0.2', '0.2x0.2', 'NA'],
    'lsfranges': [[1100, 1460], [1400, 1800], [1800, 2100], [2100, 2278], [1607, 3129], [1144, 1729], [899, 1191]],
    'lps': ['1', '1', '1', '1', '1', '1', 'NA'],
    'cen_wave': ['1291', '1611', '1953', '2250', '1978', '1425', 'NA'],
    'pixel_scales': [None, None, None, None, None, None, 0.013], 
    'fwhms': [None, None, None, None, None, None, 0.02]
})

num = 5

cfg.lsfs = []
for col in ['instr', 'gratings', 'slits', 'cen_wave', 'pixel_scales', 'fwhms']:
    setattr(cfg, col, [d.at[num, col]])

cfg.lsfranges = np.array([d.at[num, 'lsfranges']])

# %%
base_directory = "/Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M"
directories = sorted([d for d in os.listdir(base_directory) if d.startswith("E140M")])

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_model = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))[0]
    continuumfit = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))[0]

    utils.pyigm_to_veeper(igm_model, continuumfit)

    os.chdir(base_directory)
# Out:
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    component_groups_dir = os.path.join(current_directory, "component_groups")
    output_dir = os.path.join(current_directory, "modified_component_groups")

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    mc_lines_file = "/Users/billyli/Documents/float-for-morrow/mc_lines_e140m.txt"
    mc_lines_df = pd.read_csv(mc_lines_file, sep = r"\s+", header = None, names = ["line", "wavelength"])
    mc_lines_df["wavelength"] = mc_lines_df["wavelength"].astype(float)

    def is_valid_line(row, line_df):
        trans = row["trans"].strip()
        restwave = row["restwave"]
        matching_lines = line_df[line_df["line"] == trans]
        for wave in matching_lines["wavelength"]:
            if 0.997 * wave <= restwave <= 1.003 * wave:
                return True
        return False

    input_files = glob.glob(os.path.join(component_groups_dir, "*.txt"))

    for file in input_files:
        df = pd.read_csv(file, sep = "|")
        df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    
        df["restwave"] = pd.to_numeric(df["restwave"], errors = "coerce")
        df["bval"] = pd.to_numeric(df["bval"], errors = "coerce")
    
        valid_mask = df.apply(lambda row: is_valid_line(row, mc_lines_df), axis = 1)
        df_filtered = df[valid_mask].copy()
    
        # df_filtered["col"] = df_filtered["col"] - 0.2
        df_filtered["bval"] = df_filtered["bval"] / 2
    
        output_file = os.path.join(output_dir, os.path.basename(file))
        df_filtered.to_csv(output_file, sep = "|", index = False)
        # print(f"Processed file: {os.path.basename(file)} -> {output_file}")

# %%
# Before fitting, should manually adjust the input group files

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_models = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))
    continuumfits = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))

    component_groups_dir = os.path.join(current_directory, "modified_component_groups")
    
    input_group_files = sorted([f for f in glob.glob(os.path.join(component_groups_dir, "input_group_*.txt")) if re.match(r".*input_group_\d+\.txt$", f)])

    VPmeasure.batch_fit(continuumfits[0], input_group_files, filepath = './modified_component_groups/')

    os.chdir(base_directory)
# Out:
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 23, initial cost 6.4120e+03, final cost 1.8499e+03, first-order optimality 1.79e-01.
#
# Fit results:
#
# 1608.45	 0.000510	 15.588	 20.620	 -23.544
#  	  	  	 0.018	 0.177	 0.174
#
# 1611.2	 0.000510	 15.588	 20.620	 -23.544
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 42.527079
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 23, initial cost 6.4120e+03, final cost 1.8499e+03, first-order optimality 1.79e-01.
#
# Fit results:
#
# 1608.45	 0.000510	 15.588	 20.620	 -23.544
#  	  	  	 0.018	 0.177	 0.174
#
# 1611.2	 0.000510	 15.588	 20.620	 -23.544
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 42.527079
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M10/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M10/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M10/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M10/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 1.3653e+02, final cost 5.9943e+01, first-order optimality 2.87e-03.
#
# Fit results:
#
# 1239.93	 0.000470	 15.590	 18.480	 -3.2371
#  	  	  	 0.031	 1.753	 1.178
#
# 1240.39	 0.000470	 15.590	 18.480	 -3.2371
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.737491
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 1.3653e+02, final cost 5.9943e+01, first-order optimality 2.87e-03.
#
# Fit results:
#
# 1239.93	 0.000470	 15.590	 18.480	 -3.2371
#  	  	  	 0.031	 1.753	 1.178
#
# 1240.39	 0.000470	 15.590	 18.480	 -3.2371
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.737491
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M10/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M10/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M10/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M10/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 4.8457e+03, final cost 1.1189e+03, first-order optimality 1.37e-01.
#
# Fit results:
#
# 1250.58	 0.000480	 15.479	 20.790	 0.39828
#  	  	  	 0.005	 0.192	 0.142
#
# 1253.8	 0.000480	 15.479	 20.790	 0.39828
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 29.061578
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 4.8457e+03, final cost 1.1189e+03, first-order optimality 1.37e-01.
#
# Fit results:
#
# 1250.58	 0.000480	 15.479	 20.790	 0.39828
#  	  	  	 0.005	 0.192	 0.142
#
# 1253.8	 0.000480	 15.479	 20.790	 0.39828
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 29.061578
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M10/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M10/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M10/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M10/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 3.4034e+02, final cost 1.8928e+02, first-order optimality 2.82e-02.
#
# Fit results:
#
# 1317.22	 0.000530	 13.406	 15.000	 -10.937
#  	  	  	 0.022	 1.048	 0.698
#
# 1370.13	 0.000530	 13.406	 15.000	 -10.937
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000530	 13.406	 15.000	 -10.937
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 3.350002
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 3.4034e+02, final cost 1.8928e+02, first-order optimality 2.82e-02.
#
# Fit results:
#
# 1317.22	 0.000530	 13.406	 15.000	 -10.937
#  	  	  	 0.022	 1.048	 0.698
#
# 1370.13	 0.000530	 13.406	 15.000	 -10.937
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000530	 13.406	 15.000	 -10.937
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 3.350002
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M10/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M10/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M10/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M10/modified_component_groups/input_group_3_inspect.fits
#
# VPmeasure: 4/4 fits converged, 0/4 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 20, initial cost 3.7551e+03, final cost 1.1707e+03, first-order optimality 7.20e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.670	 19.400	 -18.886
#  	  	  	 0.024	 0.228	 0.269
#
# 1611.2	 0.000500	 15.670	 19.400	 -18.886
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 27.546490
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 20, initial cost 3.7551e+03, final cost 1.1707e+03, first-order optimality 7.20e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.670	 19.400	 -18.886
#  	  	  	 0.024	 0.228	 0.269
#
# 1611.2	 0.000500	 15.670	 19.400	 -18.886
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 27.546490
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M20/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M20/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M20/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M20/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.4644e+02, final cost 9.2074e+01, first-order optimality 1.87e-03.
#
# Fit results:
#
# 1239.93	 0.000450	 15.869	 17.252	 -1.4337
#  	  	  	 0.022	 1.676	 1.037
#
# 1240.39	 0.000450	 15.869	 17.252	 -1.4337
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.748467
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 1.4644e+02, final cost 9.2074e+01, first-order optimality 1.87e-03.
#
# Fit results:
#
# 1239.93	 0.000450	 15.869	 17.252	 -1.4337
#  	  	  	 0.022	 1.676	 1.037
#
# 1240.39	 0.000450	 15.869	 17.252	 -1.4337
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 2.748467
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M20/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M20/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M20/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M20/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 2.3690e+03, final cost 4.6128e+02, first-order optimality 5.98e-02.
#
# Fit results:
#
# 1250.58	 0.000480	 15.569	 20.612	 -0.17508
#  	  	  	 0.01	 0.351	 0.228
#
# 1253.8	 0.000480	 15.569	 20.612	 -0.17508
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 11.389528
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 2.3690e+03, final cost 4.6128e+02, first-order optimality 5.98e-02.
#
# Fit results:
#
# 1250.58	 0.000480	 15.569	 20.612	 -0.17508
#  	  	  	 0.01	 0.351	 0.228
#
# 1253.8	 0.000480	 15.569	 20.612	 -0.17508
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 11.389528
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M20/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M20/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M20/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M20/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 1.6089e+02, final cost 1.0201e+02, first-order optimality 3.89e-03.
#
# Fit results:
#
# 1317.22	 0.000510	 13.543	 18.660	 -6.6607
#  	  	  	 0.022	 1.663	 1.039
#
# 1370.13	 0.000510	 13.543	 18.660	 -6.6607
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000510	 13.543	 18.660	 -6.6607
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.805508
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 1.6089e+02, final cost 1.0201e+02, first-order optimality 3.89e-03.
#
# Fit results:
#
# 1317.22	 0.000510	 13.543	 18.660	 -6.6607
#  	  	  	 0.022	 1.663	 1.039
#
# 1370.13	 0.000510	 13.543	 18.660	 -6.6607
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000510	 13.543	 18.660	 -6.6607
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.805508
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M20/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M20/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M20/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M20/modified_component_groups/input_group_3_inspect.fits
#
# VPmeasure: 4/4 fits converged, 0/4 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 2.2778e+03, final cost 7.0956e+02, first-order optimality 4.09e-02.
#
# Fit results:
#
# 1608.45	 0.000490	 15.597	 19.920	 -17.494
#  	  	  	 0.03	 0.31	 0.346
#
# 1611.2	 0.000490	 15.597	 19.920	 -17.494
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 17.097788
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 2.2778e+03, final cost 7.0956e+02, first-order optimality 4.09e-02.
#
# Fit results:
#
# 1608.45	 0.000490	 15.597	 19.920	 -17.494
#  	  	  	 0.03	 0.31	 0.346
#
# 1611.2	 0.000490	 15.597	 19.920	 -17.494
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 17.097788
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M30/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M30/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M30/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M30/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 8.1015e+01, final cost 5.2331e+01, first-order optimality 2.26e-03.
#
# Fit results:
#
# 1239.93	 0.000450	 15.657	 15.000	 0.12527
#  	  	  	 0.032	 2.339	 1.342
#
# 1240.39	 0.000450	 15.657	 15.000	 0.12527
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.773920
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 8.1015e+01, final cost 5.2331e+01, first-order optimality 2.26e-03.
#
# Fit results:
#
# 1239.93	 0.000450	 15.657	 15.000	 0.12527
#  	  	  	 0.032	 2.339	 1.342
#
# 1240.39	 0.000450	 15.657	 15.000	 0.12527
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.773920
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M30/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M30/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M30/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M30/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 2.7501e+03, final cost 4.1827e+02, first-order optimality 2.07e-04.
#
# Fit results:
#
# 1250.58	 0.000490	 15.600	 19.990	 -4.9611
#  	  	  	 0.012	 0.361	 0.236
#
# 1253.8	 0.000490	 15.600	 19.990	 -4.9611
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 10.864248
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 2.7501e+03, final cost 4.1827e+02, first-order optimality 2.07e-04.
#
# Fit results:
#
# 1250.58	 0.000490	 15.600	 19.990	 -4.9611
#  	  	  	 0.012	 0.361	 0.236
#
# 1253.8	 0.000490	 15.600	 19.990	 -4.9611
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 10.864248
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M30/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M30/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M30/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M30/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 1.5918e+02, final cost 8.9779e+01, first-order optimality 1.20e-02.
#
# Fit results:
#
# 1317.22	 0.000510	 13.458	 15.000	 -2.6436
#  	  	  	 0.028	 1.872	 1.12
#
# 1370.13	 0.000510	 13.458	 15.000	 -2.6436
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000510	 13.458	 15.000	 -2.6436
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.832226
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 1.5918e+02, final cost 8.9779e+01, first-order optimality 1.20e-02.
#
# Fit results:
#
# 1317.22	 0.000510	 13.458	 15.000	 -2.6436
#  	  	  	 0.028	 1.872	 1.12
#
# 1370.13	 0.000510	 13.458	 15.000	 -2.6436
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000510	 13.458	 15.000	 -2.6436
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.832226
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M30/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M30/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M30/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M30/modified_component_groups/input_group_3_inspect.fits
#
# VPmeasure: 4/4 fits converged, 0/4 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 3.3731e+03, final cost 8.7423e+02, first-order optimality 3.17e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.635	 20.570	 -20.194
#  	  	  	 0.026	 0.261	 0.29
#
# 1611.2	 0.000500	 15.635	 20.570	 -20.194
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 19.645555
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 3.3731e+03, final cost 8.7423e+02, first-order optimality 3.17e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.635	 20.570	 -20.194
#  	  	  	 0.026	 0.261	 0.29
#
# 1611.2	 0.000500	 15.635	 20.570	 -20.194
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 19.645555
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M40/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M40/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M40/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M40/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 7.8678e+01, final cost 5.4448e+01, first-order optimality 7.32e-04.
#
# Fit results:
#
# 1239.93	 0.000470	 15.588	 17.150	 -5.3486
#  	  	  	 0.035	 2.722	 1.646
#
# 1240.39	 0.000470	 15.588	 17.150	 -5.3486
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.601421
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 7.8678e+01, final cost 5.4448e+01, first-order optimality 7.32e-04.
#
# Fit results:
#
# 1239.93	 0.000470	 15.588	 17.150	 -5.3486
#  	  	  	 0.035	 2.722	 1.646
#
# 1240.39	 0.000470	 15.588	 17.150	 -5.3486
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.601421
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M40/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M40/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M40/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M40/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 2.8874e+03, final cost 4.5311e+02, first-order optimality 2.53e-02.
#
# Fit results:
#
# 1250.58	 0.000490	 15.604	 20.291	 -3.9747
#  	  	  	 0.01	 0.317	 0.205
#
# 1253.8	 0.000490	 15.604	 20.291	 -3.9747
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 12.586449
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 2.8874e+03, final cost 4.5311e+02, first-order optimality 2.53e-02.
#
# Fit results:
#
# 1250.58	 0.000490	 15.604	 20.291	 -3.9747
#  	  	  	 0.01	 0.317	 0.205
#
# 1253.8	 0.000490	 15.604	 20.291	 -3.9747
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 12.586449
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M40/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M40/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M40/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M40/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 1.6032e+02, final cost 9.6028e+01, first-order optimality 8.00e-03.
#
# Fit results:
#
# 1317.22	 0.000500	 13.550	 16.590	 -5.7417
#  	  	  	 0.02	 1.4	 0.86
#
# 1370.13	 0.000500	 13.550	 16.590	 -5.7417
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000500	 13.550	 16.590	 -5.7417
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.846690
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 1.6032e+02, final cost 9.6028e+01, first-order optimality 8.00e-03.
#
# Fit results:
#
# 1317.22	 0.000500	 13.550	 16.590	 -5.7417
#  	  	  	 0.02	 1.4	 0.86
#
# 1370.13	 0.000500	 13.550	 16.590	 -5.7417
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000500	 13.550	 16.590	 -5.7417
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.846690
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M40/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M40/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M40/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M40/modified_component_groups/input_group_3_inspect.fits
#
# VPmeasure: 4/4 fits converged, 0/4 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.3628e+03, final cost 7.9265e+02, first-order optimality 4.83e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.663	 20.390	 -20.251
#  	  	  	 0.026	 0.264	 0.302
#
# 1611.2	 0.000500	 15.663	 20.390	 -20.251
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 19.099995
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 3.3628e+03, final cost 7.9265e+02, first-order optimality 4.83e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.663	 20.390	 -20.251
#  	  	  	 0.026	 0.264	 0.302
#
# 1611.2	 0.000500	 15.663	 20.390	 -20.251
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 19.099995
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M50/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M50/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M50/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M50/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 1.1120e+02, final cost 4.9618e+01, first-order optimality 5.24e-05.
#
# Fit results:
#
# 1239.93	 0.000480	 15.636	 15.000	 -12.435
#  	  	  	 0.032	 2.351	 1.39
#
# 1240.39	 0.000480	 15.636	 15.000	 -12.435
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.417647
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 1.1120e+02, final cost 4.9618e+01, first-order optimality 5.24e-05.
#
# Fit results:
#
# 1239.93	 0.000480	 15.636	 15.000	 -12.435
#  	  	  	 0.032	 2.351	 1.39
#
# 1240.39	 0.000480	 15.636	 15.000	 -12.435
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.417647
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M50/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M50/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M50/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M50/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 2.1166e+03, final cost 3.7677e+02, first-order optimality 1.97e-03.
#
# Fit results:
#
# 1250.58	 0.000490	 15.601	 21.330	 -2.1165
#  	  	  	 0.01	 0.361	 0.238
#
# 1253.8	 0.000490	 15.601	 21.330	 -2.1165
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 10.047270
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 2.1166e+03, final cost 3.7677e+02, first-order optimality 1.97e-03.
#
# Fit results:
#
# 1250.58	 0.000490	 15.601	 21.330	 -2.1165
#  	  	  	 0.01	 0.361	 0.238
#
# 1253.8	 0.000490	 15.601	 21.330	 -2.1165
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 10.047270
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M50/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M50/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M50/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M50/modified_component_groups/input_group_2_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 1.3051e+02, final cost 8.1290e+01, first-order optimality 1.18e-02.
#
# Fit results:
#
# 1317.22	 0.000500	 13.531	 15.000	 -1.8271
#  	  	  	 0.022	 1.475	 0.894
#
# 1370.13	 0.000500	 13.531	 15.000	 -1.8271
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000500	 13.531	 15.000	 -1.8271
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.426147
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 1.3051e+02, final cost 8.1290e+01, first-order optimality 1.18e-02.
#
# Fit results:
#
# 1317.22	 0.000500	 13.531	 15.000	 -1.8271
#  	  	  	 0.022	 1.475	 0.894
#
# 1370.13	 0.000500	 13.531	 15.000	 -1.8271
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000500	 13.531	 15.000	 -1.8271
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 1.426147
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M50/modified_component_groups/input_group_3.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M50/modified_component_groups/input_group_3.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M50/modified_component_groups/input_group_3_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/E140M50/modified_component_groups/input_group_3_inspect.fits
#
# VPmeasure: 4/4 fits converged, 0/4 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    df = pd.read_csv('compiledVPoutputs.dat', sep = '|')
    filtered_df = df[df['zsys'] > 0.0002]
    filtered_df = filtered_df[filtered_df['sigcol'] != 0.000]
    result = filtered_df[['col', 'sigcol', 'trans']]

    unique_result = result#.drop_duplicates()
    print(unique_result)
    os.chdir(base_directory)
# Out:
#       col  sigcol trans
# 0  15.479   0.005  S II
# 2  13.406   0.022  NiII
# 5  15.588   0.018  FeII
# 7  15.590   0.031  MgII
#       col  sigcol trans
# 0  15.569   0.010  S II
# 2  13.543   0.022  NiII
# 5  15.670   0.024  FeII
# 7  15.869   0.022  MgII
#       col  sigcol trans
# 0  15.600   0.012  S II
# 2  13.458   0.028  NiII
# 5  15.597   0.030  FeII
# 7  15.657   0.032  MgII
#       col  sigcol trans
# 0  15.604   0.010  S II
# 2  13.550   0.020  NiII
# 5  15.635   0.026  FeII
# 7  15.588   0.035  MgII
#       col  sigcol trans
# 0  15.601   0.010  S II
# 2  13.531   0.022  NiII
# 5  15.663   0.026  FeII
# 7  15.636   0.032  MgII

# %%
directories = [d for d in os.listdir(base_directory)
               if os.path.isdir(os.path.join(base_directory, d))]

records = []

for specdir in directories:
    fn = os.path.join(base_directory, specdir, "compiledVPoutputs.dat")
    if not os.path.isfile(fn):
        continue

    df = pd.read_csv(fn, sep = "|")
    df = df[(df["zsys"] > 0.0002) & (df["sigcol"] != 0.0)]
    records.append(df[["trans", "col", "sigcol"]])

all_measurements = pd.concat(records, ignore_index = True)

def random_effects_mean(vals, sigmas):
    vals = np.asarray(vals, dtype = float)
    sigmas = np.asarray(sigmas, dtype = float)
    var = sigmas ** 2

    w  = 1.0 / var
    mu = (w * vals).sum() / w.sum()

    Q  = (w * (vals - mu) ** 2).sum()
    df = len(vals) - 1
    c  = w.sum() - (w ** 2).sum() / w.sum()
    T2 = max(0.0, (Q - df) / c) if c > 0 else 0.0

    w_re = 1.0 / (var + T2)
    mean = (w_re * vals).sum() / w_re.sum()
    std  = np.sqrt(1.0 / w_re.sum())
    return mean, std

combined = (
    all_measurements
    .groupby("trans", sort = True)
    .apply(lambda g: random_effects_mean(g["col"], g["sigcol"]))
    .apply(pd.Series)
    .reset_index()
    .rename(columns = {0: "col_combined", 1: "sigcol_combined"})
)

combined = combined.sort_values("trans").reset_index(drop = True)

for _, row in combined.iterrows():
    print(f"{row.trans}  {row.col_combined:.3f} ± {row.sigcol_combined:.3f}")
# Out:
# FeII  15.630 ± 0.018
# MgII  15.669 ± 0.062
# NiII  13.498 ± 0.029
# S II  15.570 ± 0.032
# /var/folders/7n/v6gcxcpj68q6nnv2znnc85xc0000gn/T/ipykernel_3909/2562963298.py:38: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: random_effects_mean(g["col"], g["sigcol"]))

# %%
# END
