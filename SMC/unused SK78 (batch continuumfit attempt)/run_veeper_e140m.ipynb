# %%
import os
import re
import glob
import numpy as np
import pandas as pd

from importlib import reload
from joebvp import cfg, utils, VPmeasure
# Out:
# read_sets: Using set file --
#   /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/lists/sets/llist_v1.3.ascii
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/morton03_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/verner96_tab1.fits.gz
# joebvp.makevoigt: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# joebvp.VPmeasure: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/morton03_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/linetools/data/lines/verner96_tab1.fits.gz
# joebvp.makevoigt: No local joebvp_cfg.py found, using default cfg.py file from joebvp.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/joebvp
# joebvp.utils: No local joebvp_cfg.py found, using default cfg.py file from joebvp.

# %%
def replace_string(dataset_name):
    segment = """lt_xspec [dataset_name]_x1d.fits 
lt_continuumfit --redshift 0.00053 [dataset_name]_x1d.fits [dataset_name]_continuumfit.fits
pyigm_igmguesses [dataset_name]_continuumfit.fits -o [dataset_name]_x1dfits_model.json
pyigm_fitdla --out_file [dataset_name]_xfitdla.json [dataset_name]_continuumfit.fits 0"""
    modified_segment = segment.replace("[dataset_name]", dataset_name)
    print(modified_segment)
    
replace_string("od3g01010")
# Out:
# lt_xspec od3g01010_x1d.fits
# lt_continuumfit --redshift 0.00053 od3g01010_x1d.fits od3g01010_continuumfit.fits
# pyigm_igmguesses od3g01010_continuumfit.fits -o od3g01010_x1dfits_model.json
# pyigm_fitdla --out_file od3g01010_xfitdla.json od3g01010_continuumfit.fits 0

# %%
reload(cfg)

d = pd.DataFrame({
    'instr': ['COS', 'COS', 'COS', 'COS', 'STIS', 'STIS', 'Gaussian'],
    'gratings': ['G130M', 'G160M', 'G185M', 'G225M', 'E230M', 'E140M', 'N/A'],
    'slits': ['NA', 'NA', 'NA', 'NA', '0.2x0.2', '0.2x0.2', 'NA'],
    'lsfranges': [[1100, 1460], [1400, 1800], [1800, 2100], [2100, 2278], [1607, 3129], [1144, 1729], [899, 1191]],
    'lps': ['1', '1', '1', '1', '1', '1', 'NA'],
    'cen_wave': ['1291', '1611', '1953', '2250', '1978', '1425', 'NA'],
    'pixel_scales': [None, None, None, None, None, None, 0.013], 
    'fwhms': [None, None, None, None, None, None, 0.02]
})

num = 5

cfg.lsfs = []
for col in ['instr', 'gratings', 'slits', 'cen_wave', 'pixel_scales', 'fwhms']:
    setattr(cfg, col, [d.at[num, col]])

cfg.lsfranges = np.array([d.at[num, 'lsfranges']])

# %%
base_directory = "/Users/billyli/Documents/float-for-morrow/SMC/SK78"
directories = sorted([d for d in os.listdir(base_directory) if d.startswith("E140M")])

# %%
def replace_string_continuumfit(file_name):
    dataset_name = file_name.replace("_x1d.fits", "")
    segment = """lt_continuumfit --redshift 0.00053 [dataset_name]_x1d.fits [dataset_name]_continuumfit.fits"""
    modified_segment = segment.replace("[dataset_name]", dataset_name)
    print(modified_segment)

for spectra_directory in directories:

    os.chdir(spectra_directory)

    spectra = glob.glob("*_x1d.fits")
    for i in range(len(spectra)):
        replace_string_continuumfit(spectra[i])

    os.chdir(base_directory)
# Out:
# lt_continuumfit --redshift 0.00053 od3g01010_x1d.fits od3g01010_continuumfit.fits
# lt_continuumfit --redshift 0.00053 o55q05070_x1d.fits o55q05070_continuumfit.fits
# lt_continuumfit --redshift 0.00053 o55q06070_x1d.fits o55q06070_continuumfit.fits
# lt_continuumfit --redshift 0.00053 ob2na1010_x1d.fits ob2na1010_continuumfit.fits
# lt_continuumfit --redshift 0.00053 ocax01020_x1d.fits ocax01020_continuumfit.fits
# lt_continuumfit --redshift 0.00053 o55q03070_x1d.fits o55q03070_continuumfit.fits
# lt_continuumfit --redshift 0.00053 ob2na1020_x1d.fits ob2na1020_continuumfit.fits
# lt_continuumfit --redshift 0.00053 o55q04070_x1d.fits o55q04070_continuumfit.fits
# lt_continuumfit --redshift 0.00053 o6cd01010_x1d.fits o6cd01010_continuumfit.fits
# lt_continuumfit --redshift 0.00053 o55q01070_x1d.fits o55q01070_continuumfit.fits
# lt_continuumfit --redshift 0.00053 ocax01010_x1d.fits ocax01010_continuumfit.fits
# lt_continuumfit --redshift 0.00053 o55q02070_x1d.fits o55q02070_continuumfit.fits
# lt_continuumfit --redshift 0.00053 od3g01020_x1d.fits od3g01020_continuumfit.fits

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    igm_models = glob.glob(os.path.join(current_directory, "*_x1dfits_model.json"))
    continuumfits = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))

    for i in range(len(igm_models)):

        utils.pyigm_to_veeper(igm_models[i], continuumfits[i])

    os.chdir(base_directory)
# Out:
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    component_groups_dir = os.path.join(current_directory, "component_groups")
    output_dir = os.path.join(current_directory, "modified_component_groups")

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    mc_lines_file = "/Users/billyli/Documents/float-for-morrow/mc_lines_e140m.txt"
    mc_lines_df = pd.read_csv(mc_lines_file, sep = r"\s+", header = None, names = ["line", "wavelength"])
    mc_lines_df["wavelength"] = mc_lines_df["wavelength"].astype(float)

    def is_valid_line(row, line_df):
        trans = row["trans"].strip()
        restwave = row["restwave"]
        matching_lines = line_df[line_df["line"] == trans]
        for wave in matching_lines["wavelength"]:
            if 0.997 * wave <= restwave <= 1.003 * wave:
                return True
        return False

    input_files = glob.glob(os.path.join(component_groups_dir, "*.txt"))

    for file in input_files:
        df = pd.read_csv(file, sep = "|")
        df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    
        df["restwave"] = pd.to_numeric(df["restwave"], errors = "coerce")
        df["bval"] = pd.to_numeric(df["bval"], errors = "coerce")
    
        valid_mask = df.apply(lambda row: is_valid_line(row, mc_lines_df), axis = 1)
        df_filtered = df[valid_mask].copy()
    
        # df_filtered["col"] = df_filtered["col"] - 0.2
        df_filtered["bval"] = df_filtered["bval"]
    
        output_file = os.path.join(output_dir, os.path.basename(file))
        df_filtered.to_csv(output_file, sep = "|", index = False)
        # print(f"Processed file: {os.path.basename(file)} -> {output_file}")

# %%
# Before fitting, should manually adjust the input group files

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    continuumfits = glob.glob(os.path.join(current_directory, "*_continuumfit.fits"))

    component_groups_dir = os.path.join(current_directory, "modified_component_groups")
    
    input_group_files = sorted([f for f in glob.glob(os.path.join(component_groups_dir, "input_group_*.txt")) if re.match(r".*input_group_\d+\.txt$", f)])

    for i in range(len(continuumfits)):
        VPmeasure.batch_fit(continuumfits[i], input_group_files, filepath = './modified_component_groups/')

    os.chdir(base_directory)
# Out:
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 3.6157e+03, final cost 8.3751e+02, first-order optimality 2.81e-01.
#
# Fit results:
#
# 1608.45	 0.000500	 15.207	 30.670	 -21.598
#  	  	  	 0.02	 0.56	 0.302
#
# 1611.2	 0.000500	 15.207	 30.670	 -21.598
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 20.679216
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 3.6157e+03, final cost 8.3751e+02, first-order optimality 2.81e-01.
#
# Fit results:
#
# 1608.45	 0.000500	 15.207	 30.670	 -21.598
#  	  	  	 0.02	 0.56	 0.302
#
# 1611.2	 0.000500	 15.207	 30.670	 -21.598
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 20.679216
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# joebvp.joebvpfit: No local joebvp_cfg.py found, using default cfg.py file form joebvp.
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 9.4360e+02, final cost 8.3883e+02, first-order optimality 1.17e-01.
#
# Fit results:
#
# 1250.58	 0.000480	 15.459	 26.233	 -1.570
#  	  	  	 0.005	 0.265	 0.202
#
# 1253.8	 0.000480	 15.459	 26.233	 -1.570
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 20.711732
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 9.4360e+02, final cost 8.3883e+02, first-order optimality 1.17e-01.
#
# Fit results:
#
# 1250.58	 0.000480	 15.459	 26.233	 -1.570
#  	  	  	 0.005	 0.265	 0.202
#
# 1253.8	 0.000480	 15.459	 26.233	 -1.570
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 20.711732
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 22, initial cost 6.7950e+03, final cost 3.8066e+03, first-order optimality 1.02e+00.
#
# Fit results:
#
# 1317.22	 0.000490	 14.004	 20.000	 -0.45743
#  	  	  	 0.006	 0.307	 0.218
#
# 1370.13	 0.000490	 14.004	 20.000	 -0.45743
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 14.004	 20.000	 -0.45743
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 74.639166
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 22, initial cost 6.7950e+03, final cost 3.8066e+03, first-order optimality 1.02e+00.
#
# Fit results:
#
# 1317.22	 0.000490	 14.004	 20.000	 -0.45743
#  	  	  	 0.006	 0.307	 0.218
#
# 1370.13	 0.000490	 14.004	 20.000	 -0.45743
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 14.004	 20.000	 -0.45743
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 74.639166
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_inspect.fits
#
# VPmeasure: 3/3 fits converged, 0/3 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.0779e+03, final cost 3.1190e+02, first-order optimality 7.30e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.200	 30.670	 -19.051
#  	  	  	 0.04	 1.147	 0.6
#
# 1611.2	 0.000500	 15.200	 30.670	 -19.051
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 7.701192
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.0779e+03, final cost 3.1190e+02, first-order optimality 7.30e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.200	 30.670	 -19.051
#  	  	  	 0.04	 1.147	 0.6
#
# 1611.2	 0.000500	 15.200	 30.670	 -19.051
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 7.701192
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 4.4022e+02, final cost 3.7846e+02, first-order optimality 2.86e-02.
#
# Fit results:
#
# 1250.58	 0.000480	 15.589	 20.896	 0.36921
#  	  	  	 0.012	 0.412	 0.27
#
# 1253.8	 0.000480	 15.589	 20.896	 0.36921
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 9.344733
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 4.4022e+02, final cost 3.7846e+02, first-order optimality 2.86e-02.
#
# Fit results:
#
# 1250.58	 0.000480	 15.589	 20.896	 0.36921
#  	  	  	 0.012	 0.412	 0.27
#
# 1253.8	 0.000480	 15.589	 20.896	 0.36921
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 9.344733
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.4893e+03, final cost 7.6591e+02, first-order optimality 1.98e-01.
#
# Fit results:
#
# 1317.22	 0.000490	 13.939	 20.000	 1.3057
#  	  	  	 0.01	 0.763	 0.488
#
# 1370.13	 0.000490	 13.939	 20.000	 1.3057
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 13.939	 20.000	 1.3057
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 15.472876
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.4893e+03, final cost 7.6591e+02, first-order optimality 1.98e-01.
#
# Fit results:
#
# 1317.22	 0.000490	 13.939	 20.000	 1.3057
#  	  	  	 0.01	 0.763	 0.488
#
# 1370.13	 0.000490	 13.939	 20.000	 1.3057
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 13.939	 20.000	 1.3057
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 15.472876
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_inspect.fits
#
# VPmeasure: 3/3 fits converged, 0/3 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 1.6827e+03, final cost 3.9063e+02, first-order optimality 7.26e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.242	 30.670	 -20.81
#  	  	  	 0.035	 0.967	 0.545
#
# 1611.2	 0.000500	 15.242	 30.670	 -20.81
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 9.645136
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 1.6827e+03, final cost 3.9063e+02, first-order optimality 7.26e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.242	 30.670	 -20.81
#  	  	  	 0.035	 0.967	 0.545
#
# 1611.2	 0.000500	 15.242	 30.670	 -20.81
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 9.645136
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 6.7672e+02, final cost 4.5489e+02, first-order optimality 4.22e-02.
#
# Fit results:
#
# 1250.58	 0.000480	 15.614	 22.949	 -1.1191
#  	  	  	 0.009	 0.357	 0.241
#
# 1253.8	 0.000480	 15.614	 22.949	 -1.1191
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 11.231801
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 6.7672e+02, final cost 4.5489e+02, first-order optimality 4.22e-02.
#
# Fit results:
#
# 1250.58	 0.000480	 15.614	 22.949	 -1.1191
#  	  	  	 0.009	 0.357	 0.241
#
# 1253.8	 0.000480	 15.614	 22.949	 -1.1191
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 11.231801
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.6268e+03, final cost 8.8167e+02, first-order optimality 1.35e-01.
#
# Fit results:
#
# 1317.22	 0.000490	 13.915	 20.000	 -0.56416
#  	  	  	 0.01	 0.733	 0.469
#
# 1370.13	 0.000490	 13.915	 20.000	 -0.56416
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 13.915	 20.000	 -0.56416
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 17.287739
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.6268e+03, final cost 8.8167e+02, first-order optimality 1.35e-01.
#
# Fit results:
#
# 1317.22	 0.000490	 13.915	 20.000	 -0.56416
#  	  	  	 0.01	 0.733	 0.469
#
# 1370.13	 0.000490	 13.915	 20.000	 -0.56416
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 13.915	 20.000	 -0.56416
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 17.287739
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_inspect.fits
#
# VPmeasure: 3/3 fits converged, 0/3 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 1.7732e+03, final cost 4.1555e+02, first-order optimality 3.49e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.274	 30.670	 -21.537
#  	  	  	 0.035	 0.954	 0.588
#
# 1611.2	 0.000500	 15.274	 30.670	 -21.537
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 10.260508
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 1.7732e+03, final cost 4.1555e+02, first-order optimality 3.49e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.274	 30.670	 -21.537
#  	  	  	 0.035	 0.954	 0.588
#
# 1611.2	 0.000500	 15.274	 30.670	 -21.537
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 10.260508
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 6.7853e+02, final cost 5.1629e+02, first-order optimality 6.00e-02.
#
# Fit results:
#
# 1250.58	 0.000480	 15.586	 23.388	 -0.9296
#  	  	  	 0.008	 0.36	 0.243
#
# 1253.8	 0.000480	 15.586	 23.388	 -0.9296
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 12.747892
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 6.7853e+02, final cost 5.1629e+02, first-order optimality 6.00e-02.
#
# Fit results:
#
# 1250.58	 0.000480	 15.586	 23.388	 -0.9296
#  	  	  	 0.008	 0.36	 0.243
#
# 1253.8	 0.000480	 15.586	 23.388	 -0.9296
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 12.747892
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 1.7208e+03, final cost 9.3504e+02, first-order optimality 1.88e-01.
#
# Fit results:
#
# 1317.22	 0.000490	 13.924	 20.000	 1.3044
#  	  	  	 0.01	 0.721	 0.459
#
# 1370.13	 0.000490	 13.924	 20.000	 1.3044
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 13.924	 20.000	 1.3044
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 18.515644
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 1.7208e+03, final cost 9.3504e+02, first-order optimality 1.88e-01.
#
# Fit results:
#
# 1317.22	 0.000490	 13.924	 20.000	 1.3044
#  	  	  	 0.01	 0.721	 0.459
#
# 1370.13	 0.000490	 13.924	 20.000	 1.3044
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 13.924	 20.000	 1.3044
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 18.515644
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_inspect.fits
#
# VPmeasure: 3/3 fits converged, 0/3 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 3.5517e+03, final cost 8.1480e+02, first-order optimality 1.57e-01.
#
# Fit results:
#
# 1608.45	 0.000500	 15.272	 30.670	 -20.809
#  	  	  	 0.023	 0.632	 0.391
#
# 1611.2	 0.000500	 15.272	 30.670	 -20.809
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 20.118626
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 3.5517e+03, final cost 8.1480e+02, first-order optimality 1.57e-01.
#
# Fit results:
#
# 1608.45	 0.000500	 15.272	 30.670	 -20.809
#  	  	  	 0.023	 0.632	 0.391
#
# 1611.2	 0.000500	 15.272	 30.670	 -20.809
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 20.118626
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 1.1720e+03, final cost 1.0232e+03, first-order optimality 1.03e-01.
#
# Fit results:
#
# 1250.58	 0.000480	 15.579	 21.249	 -0.67066
#  	  	  	 0.007	 0.261	 0.173
#
# 1253.8	 0.000480	 15.579	 21.249	 -0.67066
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 25.263173
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 1.1720e+03, final cost 1.0232e+03, first-order optimality 1.03e-01.
#
# Fit results:
#
# 1250.58	 0.000480	 15.579	 21.249	 -0.67066
#  	  	  	 0.007	 0.261	 0.173
#
# 1253.8	 0.000480	 15.579	 21.249	 -0.67066
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 25.263173
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 23, initial cost 3.2938e+04, final cost 1.4305e+04, first-order optimality 3.66e+00.
#
# Fit results:
#
# 1317.22	 0.000490	 14.478	 20.000	 1.3569
#  	  	  	 0.004	 0.186	 0.122
#
# 1370.13	 0.000490	 14.478	 20.000	 1.3569
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 14.478	 20.000	 1.3569
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 286.092912
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 23, initial cost 3.2938e+04, final cost 1.4305e+04, first-order optimality 3.66e+00.
#
# Fit results:
#
# 1317.22	 0.000490	 14.478	 20.000	 1.3569
#  	  	  	 0.004	 0.186	 0.122
#
# 1370.13	 0.000490	 14.478	 20.000	 1.3569
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 14.478	 20.000	 1.3569
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 286.092912
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_inspect.fits
#
# VPmeasure: 3/3 fits converged, 0/3 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.7624e+03, final cost 4.4769e+02, first-order optimality 7.96e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.243	 30.670	 -20.708
#  	  	  	 0.033	 0.915	 0.521
#
# 1611.2	 0.000500	 15.243	 30.670	 -20.708
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 11.053953
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.7624e+03, final cost 4.4769e+02, first-order optimality 7.96e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.243	 30.670	 -20.708
#  	  	  	 0.033	 0.915	 0.521
#
# 1611.2	 0.000500	 15.243	 30.670	 -20.708
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 11.053953
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 7.1605e+02, final cost 5.6411e+02, first-order optimality 4.54e-02.
#
# Fit results:
#
# 1250.58	 0.000480	 15.625	 20.081	 -0.24952
#  	  	  	 0.01	 0.314	 0.205
#
# 1253.8	 0.000480	 15.625	 20.081	 -0.24952
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 13.928676
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 7.1605e+02, final cost 5.6411e+02, first-order optimality 4.54e-02.
#
# Fit results:
#
# 1250.58	 0.000480	 15.625	 20.081	 -0.24952
#  	  	  	 0.01	 0.314	 0.205
#
# 1253.8	 0.000480	 15.625	 20.081	 -0.24952
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 13.928676
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 1.8707e+03, final cost 9.7969e+02, first-order optimality 1.58e-01.
#
# Fit results:
#
# 1317.22	 0.000490	 13.915	 20.000	 -2.1867
#  	  	  	 0.009	 0.67	 0.427
#
# 1370.13	 0.000490	 13.915	 20.000	 -2.1867
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 13.915	 20.000	 -2.1867
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 19.399727
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 1.8707e+03, final cost 9.7969e+02, first-order optimality 1.58e-01.
#
# Fit results:
#
# 1317.22	 0.000490	 13.915	 20.000	 -2.1867
#  	  	  	 0.009	 0.67	 0.427
#
# 1370.13	 0.000490	 13.915	 20.000	 -2.1867
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 13.915	 20.000	 -2.1867
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 19.399727
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_inspect.fits
#
# VPmeasure: 3/3 fits converged, 0/3 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 3.2598e+03, final cost 7.6986e+02, first-order optimality 2.41e-01.
#
# Fit results:
#
# 1608.45	 0.000500	 15.298	 30.670	 -20.362
#  	  	  	 0.023	 0.629	 0.428
#
# 1611.2	 0.000500	 15.298	 30.670	 -20.362
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 19.008954
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 3.2598e+03, final cost 7.6986e+02, first-order optimality 2.41e-01.
#
# Fit results:
#
# 1608.45	 0.000500	 15.298	 30.670	 -20.362
#  	  	  	 0.023	 0.629	 0.428
#
# 1611.2	 0.000500	 15.298	 30.670	 -20.362
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 19.008954
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 9.8515e+02, final cost 8.0784e+02, first-order optimality 1.08e-01.
#
# Fit results:
#
# 1250.58	 0.000480	 15.605	 20.542	 0.073246
#  	  	  	 0.008	 0.259	 0.173
#
# 1253.8	 0.000480	 15.605	 20.542	 0.073246
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 19.946738
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 9.8515e+02, final cost 8.0784e+02, first-order optimality 1.08e-01.
#
# Fit results:
#
# 1250.58	 0.000480	 15.605	 20.542	 0.073246
#  	  	  	 0.008	 0.259	 0.173
#
# 1253.8	 0.000480	 15.605	 20.542	 0.073246
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 19.946738
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 33, initial cost 5.4788e+04, final cost 1.9765e+04, first-order optimality 4.81e+00.
#
# Fit results:
#
# 1317.22	 0.000490	 14.717	 20.000	 -5.4848
#  	  	  	 0.005	 0.149	 0.093
#
# 1370.13	 0.000490	 14.717	 20.000	 -5.4848
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 14.717	 20.000	 -5.4848
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 391.392970
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 33, initial cost 5.4788e+04, final cost 1.9765e+04, first-order optimality 4.81e+00.
#
# Fit results:
#
# 1317.22	 0.000490	 14.717	 20.000	 -5.4848
#  	  	  	 0.005	 0.149	 0.093
#
# 1370.13	 0.000490	 14.717	 20.000	 -5.4848
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 14.717	 20.000	 -5.4848
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 391.392970
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_inspect.fits
#
# VPmeasure: 3/3 fits converged, 0/3 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 1.0610e+03, final cost 2.9910e+02, first-order optimality 6.43e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.271	 30.670	 -20.508
#  	  	  	 0.043	 1.186	 0.752
#
# 1611.2	 0.000500	 15.271	 30.670	 -20.508
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 7.385264
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 1.0610e+03, final cost 2.9910e+02, first-order optimality 6.43e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.271	 30.670	 -20.508
#  	  	  	 0.043	 1.186	 0.752
#
# 1611.2	 0.000500	 15.271	 30.670	 -20.508
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 7.385264
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 4.8831e+02, final cost 4.1512e+02, first-order optimality 6.65e-02.
#
# Fit results:
#
# 1250.58	 0.000480	 15.611	 20.160	 0.67671
#  	  	  	 0.013	 0.412	 0.265
#
# 1253.8	 0.000480	 15.611	 20.160	 0.67671
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 10.249954
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 4.8831e+02, final cost 4.1512e+02, first-order optimality 6.65e-02.
#
# Fit results:
#
# 1250.58	 0.000480	 15.611	 20.160	 0.67671
#  	  	  	 0.013	 0.412	 0.265
#
# 1253.8	 0.000480	 15.611	 20.160	 0.67671
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 10.249954
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 1.4989e+03, final cost 7.0900e+02, first-order optimality 1.85e-01.
#
# Fit results:
#
# 1317.22	 0.000490	 13.998	 20.000	 -0.75046
#  	  	  	 0.01	 0.757	 0.49
#
# 1370.13	 0.000490	 13.998	 20.000	 -0.75046
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 13.998	 20.000	 -0.75046
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 14.039657
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 1.4989e+03, final cost 7.0900e+02, first-order optimality 1.85e-01.
#
# Fit results:
#
# 1317.22	 0.000490	 13.998	 20.000	 -0.75046
#  	  	  	 0.01	 0.757	 0.49
#
# 1370.13	 0.000490	 13.998	 20.000	 -0.75046
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 13.998	 20.000	 -0.75046
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 14.039657
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_inspect.fits
#
# VPmeasure: 3/3 fits converged, 0/3 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 2.8818e+03, final cost 6.1934e+02, first-order optimality 4.09e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.317	 30.670	 -20.169
#  	  	  	 0.027	 0.678	 0.437
#
# 1611.2	 0.000500	 15.317	 30.670	 -20.169
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 15.292257
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 2.8818e+03, final cost 6.1934e+02, first-order optimality 4.09e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.317	 30.670	 -20.169
#  	  	  	 0.027	 0.678	 0.437
#
# 1611.2	 0.000500	 15.317	 30.670	 -20.169
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 15.292257
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 8.2702e+02, final cost 7.2274e+02, first-order optimality 1.18e-01.
#
# Fit results:
#
# 1250.58	 0.000480	 15.606	 19.476	 0.27081
#  	  	  	 0.01	 0.297	 0.19
#
# 1253.8	 0.000480	 15.606	 19.476	 0.27081
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 17.845325
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 8.2702e+02, final cost 7.2274e+02, first-order optimality 1.18e-01.
#
# Fit results:
#
# 1250.58	 0.000480	 15.606	 19.476	 0.27081
#  	  	  	 0.01	 0.297	 0.19
#
# 1253.8	 0.000480	 15.606	 19.476	 0.27081
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 17.845325
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 21, initial cost 4.3216e+03, final cost 1.7579e+03, first-order optimality 4.63e-01.
#
# Fit results:
#
# 1317.22	 0.000490	 14.094	 20.000	 -1.3696
#  	  	  	 0.006	 0.441	 0.287
#
# 1370.13	 0.000490	 14.094	 20.000	 -1.3696
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 14.094	 20.000	 -1.3696
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 34.810530
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 21, initial cost 4.3216e+03, final cost 1.7579e+03, first-order optimality 4.63e-01.
#
# Fit results:
#
# 1317.22	 0.000490	 14.094	 20.000	 -1.3696
#  	  	  	 0.006	 0.441	 0.287
#
# 1370.13	 0.000490	 14.094	 20.000	 -1.3696
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 14.094	 20.000	 -1.3696
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 34.810530
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_inspect.fits
#
# VPmeasure: 3/3 fits converged, 0/3 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 1.4833e+03, final cost 3.7238e+02, first-order optimality 1.02e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.267	 30.670	 -22.37
#  	  	  	 0.036	 1.031	 0.679
#
# 1611.2	 0.000500	 15.267	 30.670	 -22.37
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 9.194480
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 1.4833e+03, final cost 3.7238e+02, first-order optimality 1.02e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.267	 30.670	 -22.37
#  	  	  	 0.036	 1.031	 0.679
#
# 1611.2	 0.000500	 15.267	 30.670	 -22.37
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 9.194480
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 5.9036e+02, final cost 4.5812e+02, first-order optimality 1.20e-01.
#
# Fit results:
#
# 1250.58	 0.000480	 15.609	 20.470	 -1.9016
#  	  	  	 0.011	 0.359	 0.24
#
# 1253.8	 0.000480	 15.609	 20.470	 -1.9016
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 11.311482
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 5.9036e+02, final cost 4.5812e+02, first-order optimality 1.20e-01.
#
# Fit results:
#
# 1250.58	 0.000480	 15.609	 20.470	 -1.9016
#  	  	  	 0.011	 0.359	 0.24
#
# 1253.8	 0.000480	 15.609	 20.470	 -1.9016
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 11.311482
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 1.7858e+03, final cost 8.8061e+02, first-order optimality 2.20e-01.
#
# Fit results:
#
# 1317.22	 0.000490	 13.966	 20.000	 0.16404
#  	  	  	 0.009	 0.689	 0.444
#
# 1370.13	 0.000490	 13.966	 20.000	 0.16404
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 13.966	 20.000	 0.16404
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 17.612141
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 1.7858e+03, final cost 8.8061e+02, first-order optimality 2.20e-01.
#
# Fit results:
#
# 1317.22	 0.000490	 13.966	 20.000	 0.16404
#  	  	  	 0.009	 0.689	 0.444
#
# 1370.13	 0.000490	 13.966	 20.000	 0.16404
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 13.966	 20.000	 0.16404
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 17.612141
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_inspect.fits
#
# VPmeasure: 3/3 fits converged, 0/3 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 2.5231e+03, final cost 6.8479e+02, first-order optimality 3.25e-01.
#
# Fit results:
#
# 1608.45	 0.000500	 15.246	 30.670	 -20.164
#  	  	  	 0.026	 0.689	 0.395
#
# 1611.2	 0.000500	 15.246	 30.670	 -20.164
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 16.908433
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 2.5231e+03, final cost 6.8479e+02, first-order optimality 3.25e-01.
#
# Fit results:
#
# 1608.45	 0.000500	 15.246	 30.670	 -20.164
#  	  	  	 0.026	 0.689	 0.395
#
# 1611.2	 0.000500	 15.246	 30.670	 -20.164
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 16.908433
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 2.8193e+03, final cost 1.8097e+03, first-order optimality 3.53e-01.
#
# Fit results:
#
# 1250.58	 0.000480	 15.663	 26.038	 -0.55754
#  	  	  	 0.006	 0.271	 0.187
#
# 1253.8	 0.000480	 15.663	 26.038	 -0.55754
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 44.684946
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 2.8193e+03, final cost 1.8097e+03, first-order optimality 3.53e-01.
#
# Fit results:
#
# 1250.58	 0.000480	 15.663	 26.038	 -0.55754
#  	  	  	 0.006	 0.271	 0.187
#
# 1253.8	 0.000480	 15.663	 26.038	 -0.55754
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 44.684946
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 32, initial cost 4.0363e+04, final cost 1.6967e+04, first-order optimality 4.15e+00.
#
# Fit results:
#
# 1317.22	 0.000490	 14.617	 20.000	 -1.9899
#  	  	  	 0.005	 0.176	 0.113
#
# 1370.13	 0.000490	 14.617	 20.000	 -1.9899
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 14.617	 20.000	 -1.9899
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 332.688910
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 32, initial cost 4.0363e+04, final cost 1.6967e+04, first-order optimality 4.15e+00.
#
# Fit results:
#
# 1317.22	 0.000490	 14.617	 20.000	 -1.9899
#  	  	  	 0.005	 0.176	 0.113
#
# 1370.13	 0.000490	 14.617	 20.000	 -1.9899
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 14.617	 20.000	 -1.9899
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 332.688910
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_inspect.fits
#
# VPmeasure: 3/3 fits converged, 0/3 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 2.9919e+03, final cost 7.7402e+02, first-order optimality 2.60e-01.
#
# Fit results:
#
# 1608.45	 0.000500	 15.261	 30.670	 -19.775
#  	  	  	 0.024	 0.645	 0.366
#
# 1611.2	 0.000500	 15.261	 30.670	 -19.775
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 19.111692
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 2.9919e+03, final cost 7.7402e+02, first-order optimality 2.60e-01.
#
# Fit results:
#
# 1608.45	 0.000500	 15.261	 30.670	 -19.775
#  	  	  	 0.024	 0.645	 0.366
#
# 1611.2	 0.000500	 15.261	 30.670	 -19.775
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 19.111692
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 1.2101e+03, final cost 9.9493e+02, first-order optimality 2.06e-01.
#
# Fit results:
#
# 1250.58	 0.000480	 15.614	 20.896	 -0.0085159
#  	  	  	 0.008	 0.27	 0.18
#
# 1253.8	 0.000480	 15.614	 20.896	 -0.0085159
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 24.566089
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 1.2101e+03, final cost 9.9493e+02, first-order optimality 2.06e-01.
#
# Fit results:
#
# 1250.58	 0.000480	 15.614	 20.896	 -0.0085159
#  	  	  	 0.008	 0.27	 0.18
#
# 1253.8	 0.000480	 15.614	 20.896	 -0.0085159
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 24.566089
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 20, initial cost 7.1770e+03, final cost 3.3746e+03, first-order optimality 6.96e-01.
#
# Fit results:
#
# 1317.22	 0.000490	 14.110	 20.000	 -1.2901
#  	  	  	 0.005	 0.366	 0.237
#
# 1370.13	 0.000490	 14.110	 20.000	 -1.2901
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 14.110	 20.000	 -1.2901
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 66.823732
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 20, initial cost 7.1770e+03, final cost 3.3746e+03, first-order optimality 6.96e-01.
#
# Fit results:
#
# 1317.22	 0.000490	 14.110	 20.000	 -1.2901
#  	  	  	 0.005	 0.366	 0.237
#
# 1370.13	 0.000490	 14.110	 20.000	 -1.2901
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 14.110	 20.000	 -1.2901
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 66.823732
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_inspect.fits
#
# VPmeasure: 3/3 fits converged, 0/3 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.
# Bad METADATA;  proceeding without
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.9120e+03, final cost 5.3043e+02, first-order optimality 8.95e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.281	 30.670	 -20.959
#  	  	  	 0.031	 0.871	 0.567
#
# 1611.2	 0.000500	 15.281	 30.670	 -20.959
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 13.097021
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.9120e+03, final cost 5.3043e+02, first-order optimality 8.95e-02.
#
# Fit results:
#
# 1608.45	 0.000500	 15.281	 30.670	 -20.959
#  	  	  	 0.031	 0.871	 0.567
#
# 1611.2	 0.000500	 15.281	 30.670	 -20.959
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 13.097021
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_0_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 7.7903e+02, final cost 6.6173e+02, first-order optimality 6.95e-02.
#
# Fit results:
#
# 1250.58	 0.000480	 15.608	 20.448	 -0.78377
#  	  	  	 0.01	 0.336	 0.221
#
# 1253.8	 0.000480	 15.608	 20.448	 -0.78377
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 16.338951
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 7.7903e+02, final cost 6.6173e+02, first-order optimality 6.95e-02.
#
# Fit results:
#
# 1250.58	 0.000480	 15.608	 20.448	 -0.78377
#  	  	  	 0.01	 0.336	 0.221
#
# 1253.8	 0.000480	 15.608	 20.448	 -0.78377
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 16.338951
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_1_inspect.fits
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 3.5725e+03, final cost 1.7353e+03, first-order optimality 4.20e-01.
#
# Fit results:
#
# 1317.22	 0.000490	 14.049	 20.000	 -1.6497
#  	  	  	 0.007	 0.51	 0.332
#
# 1370.13	 0.000490	 14.049	 20.000	 -1.6497
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 14.049	 20.000	 -1.6497
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 34.362611
# Iteration 1 -
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 3.5725e+03, final cost 1.7353e+03, first-order optimality 4.20e-01.
#
# Fit results:
#
# 1317.22	 0.000490	 14.049	 20.000	 -1.6497
#  	  	  	 0.007	 0.51	 0.332
#
# 1370.13	 0.000490	 14.049	 20.000	 -1.6497
#  	  	  	 0.0	 0.0	 0.0
#
# 1454.84	 0.000490	 14.049	 20.000	 -1.6497
#  	  	  	 0.0	 0.0	 0.0
#
#
# Reduced chi-squared: 34.362611
# Iteration 2 -
# Fit converged after 2 iterations.
# VPmeasure: Fit converged: /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.txt
# Line parameters written to:
# /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2.VP
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_VPmodel.fits
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to /Users/billyli/Documents/float-for-morrow/SMC/SK78/E140M/modified_component_groups/input_group_2_inspect.fits
#
# VPmeasure: 3/3 fits converged, 0/3 failed (see log for details).
#
# VPmeasure: concatenating individual outputs and creating figures for inspection.
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# Bad METADATA;  proceeding without
# Wrote spectrum to FitInspection.fits
# VPmeasure: Done.

# %%
for spectra_directory in directories:

    current_directory = os.path.join(base_directory, spectra_directory)

    os.chdir(current_directory)

    df = pd.read_csv('compiledVPoutputs.dat', sep = '|')
    filtered_df = df[df['zsys'] > 0.0002]
    filtered_df = filtered_df[filtered_df['sigcol'] != 0.000]
    result = filtered_df[['col', 'sigcol', 'trans']]

    unique_result = result#.drop_duplicates()
    print(unique_result)
    os.chdir(base_directory)
# Out:
#       col  sigcol trans
# 0  14.049   0.007  NiII
# 3  15.281   0.031  FeII
# 5  15.608   0.010  S II

# %%
directories = [d for d in os.listdir(base_directory)
               if os.path.isdir(os.path.join(base_directory, d))]

records = []

for specdir in directories:
    fn = os.path.join(base_directory, specdir, "compiledVPoutputs.dat")
    if not os.path.isfile(fn):
        continue

    df = pd.read_csv(fn, sep = "|")
    df = df[(df["zsys"] > 0.0002) & (df["sigcol"] != 0.0)]
    records.append(df[["trans", "col", "sigcol"]])

all_measurements = pd.concat(records, ignore_index = True)

def random_effects_mean(vals, sigmas):
    vals = np.asarray(vals, dtype = float)
    sigmas = np.asarray(sigmas, dtype = float)
    var = sigmas ** 2

    w  = 1.0 / var
    mu = (w * vals).sum() / w.sum()

    Q  = (w * (vals - mu) ** 2).sum()
    df = len(vals) - 1
    c  = w.sum() - (w ** 2).sum() / w.sum()
    T2 = max(0.0, (Q - df) / c) if c > 0 else 0.0

    w_re = 1.0 / (var + T2)
    mean = (w_re * vals).sum() / w_re.sum()
    std  = np.sqrt(1.0 / w_re.sum())
    return mean, std

combined = (
    all_measurements
    .groupby("trans", sort = True)
    .apply(lambda g: random_effects_mean(g["col"], g["sigcol"]))
    .apply(pd.Series)
    .reset_index()
    .rename(columns = {0: "col_combined", 1: "sigcol_combined"})
)

combined = combined.sort_values("trans").reset_index(drop = True)

for _, row in combined.iterrows():
    print(f"{row.trans}  {row.col_combined:.3f} ± {row.sigcol_combined:.3f}")
# Out:
# FeII  15.281 ± 0.031
# NiII  14.049 ± 0.007
# S II  15.608 ± 0.010
# /var/folders/7n/v6gcxcpj68q6nnv2znnc85xc0000gn/T/ipykernel_3778/2562963298.py:38: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: random_effects_mean(g["col"], g["sigcol"]))

# %%
# END
