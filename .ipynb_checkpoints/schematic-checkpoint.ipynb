# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({"text.usetex" : False, "font.family" : "sans-serif", "font.size" : 11, "axes.linewidth" : 1.5, "xtick.major.width" : 1.5, "ytick.major.width" : 1.5})

fig, ax = plt.subplots(figsize = (6, 4), dpi = 300)

t1 = np.linspace(0, 20, 200)

f_min = 90
f_max = 97
tau_growth = 5

raw_end_value = f_max - (f_max - f_min) * np.exp(-20 / tau_growth)

deficit = f_max - raw_end_value
f1 = (f_max - (f_max - f_min) * np.exp(-t1 / tau_growth)) + (deficit * (t1 / 20))

t2 = np.linspace(20, 30, 100)
f2 = np.full_like(t2, f1[-1])

ax.plot(t1, f1, color = "#1f77b4", linewidth = 2.5)
ax.plot(t2, f2, color = "0", linewidth = 2.5)

ax.axvspan(0, 20, color = "#f0f4f8", alpha = 0.7)
ax.axvspan(20, 30, color = "#fff0f0", alpha = 0.7)

ax.axvline(x = 20, color = "gray", linestyle = "--", linewidth = 1.2)
ax.axhline(y = f_max, color = "gray", linestyle = ":", linewidth = 1)

f_min = 90
f_max = 100
tau_growth = 5

raw_end_value = f_max - (f_max - f_min) * np.exp(-20 / tau_growth)

deficit = f_max - raw_end_value
f1 = (f_max - (f_max - f_min) * np.exp(-t1 / tau_growth)) + (deficit * (t1 / 20))

t2 = np.linspace(20, 30, 100)

raw_end_value = f_max - (3 - 3 * np.exp(-10 / 8))
deficit = 97 - raw_end_value
f2 = (f_max - (3 - 3 * np.exp(-(t2 - 20) / 8))) + (deficit * ((t2 - 20) / 10))

ax.plot(t1, f1, color = "green", linewidth = 2.5)
ax.plot(t2, f2, color = "#d62728", linewidth = 2.5)

ax.axhline(y = f_max, color = "gray", linestyle = ":", linewidth = 1)

ax.text(10, 87.5, r"$\tau_{\rm MC}$", fontsize = 12, ha = "center", weight = "bold")
ax.text(25, 87.5, r"$\tau_{\rm H\,II}$", fontsize = 12, ha = "center", weight = "bold")

ax.text(10, 93, "grain growth", fontsize = 12, ha = "center")
ax.text(25, 93, "mixing/\n destruction", fontsize = 12, ha = "center")

ax.set_xlabel("Time (t)", fontsize = 13, labelpad = 10)
ax.set_ylabel(r"$f_{\rm Fe, dust}$", fontsize = 13, labelpad = 10)

ax.set_xlim(0, 31)
ax.set_ylim(87, 101)

ax.set_xticks([0, 20, 30])
ax.set_xticklabels(["Diffuse ISM", "End of Molecular Cloud", "H II Region"])

ax.set_yticks([90, 97, 100])
ax.set_yticklabels([r"$\sim 90\%$", r"$\sim 99\%$", r"$\sim 100\%$"])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.savefig("schematic.png", bbox_inches = "tight")
plt.show()
