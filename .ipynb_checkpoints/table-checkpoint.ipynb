# %%
import os
import numpy as np
import pandas as pd
import astropy.units as u
import matplotlib.pyplot as plt

from pathlib import Path
from astropy.io import fits
from astropy.wcs import WCS
from astroquery.simbad import Simbad
from matplotlib.patches import Rectangle
from astroquery.hips2fits import hips2fits
from astropy.coordinates import SkyCoord, Angle

font = {'family' : 'gill sans',
         'size'   : 12,
         'serif':  'cmr10'
         }

plt.rc('font', **font)
plt.rc('axes', unicode_minus = False)

# %%
main_directory = Path().resolve()

# %%
def parse_directory(dirname, galaxy_name, region_name, target_name, angular_separation): # different with some other functions I wrote

    parts = dirname.split("_")

    Grating = parts[0]
    Cenwave = int(parts[1])
    T_exp = str(parts[3])
    PID = int(parts[4])

    if Grating.startswith("G"):
        
        Instrument = "COS"
        LP = parts[2]

        return {
            # "Galaxy": galaxy_name, 
            "Region": region_name, 
            "Target": target_name, 
            "Angular Separation": round(angular_separation, 2), 
            "Instrument/Grating/Cenwave": Instrument + "/" + Grating + "/" + str(Cenwave), 
            "LP/Aperture": LP,  
            "T_exp": str(T_exp), 
            "PID": str(PID), 
        }
        
    else:
        
        Instrument = "STIS"
        Aperture = parts[2]
        return {
            # "Galaxy": galaxy_name, 
            "Region": region_name, 
            "Target": target_name, 
            "Angular Separation": round(angular_separation, 2), 
            "Instrument/Grating/Cenwave": Instrument + "/" + Grating + "/" + str(Cenwave), 
            "LP/Aperture": Aperture, 
            "T_exp": str(T_exp), 
            "PID": str(PID), 
        }

# %%
records = []

for galaxy_name in os.listdir(main_directory):
    galaxy_path = main_directory / galaxy_name
    if galaxy_path.name.startswith(".") or not galaxy_path.is_dir():
        continue
        
    for region_name in os.listdir(galaxy_path):
        region_path = galaxy_path / region_name
        if region_path.name.startswith(".") or not region_path.is_dir():
            continue

        region = Simbad.query_object(region_name)
        ra_region = region["ra"][0]
        dec_region = region["dec"][0]
        coord_region = SkyCoord(ra_region, dec_region, unit = (u.deg, u.deg), frame = "icrs")
    
        for target_name in os.listdir(region_path):
            target_path = region_path / target_name
            if target_path.name.startswith("unused") or target_path.name.startswith(".") or not target_path.is_dir():
                continue

            target = Simbad.query_object(target_name)
            ra_target = target["ra"][0]
            dec_target = target["dec"][0]
            coord_target = SkyCoord(ra_target, dec_target, unit = (u.deg, u.deg), frame = "icrs")

            angular_separation = coord_region.separation(coord_target).arcmin

            spectra_directories = sorted([d for d in os.listdir(target_path) if d.startswith("G") or d.startswith("E")])

            for d in spectra_directories:
                info = parse_directory(d, galaxy_name, region_name, target_name, angular_separation)
                records.append(info)

df = pd.DataFrame.from_records(records)

# %%
df
# Out:
#         Region               Target  Angular Separation  \
# 0     SMC N88A            2dFS 3694                1.93
# 1     SMC N88A            2dFS 3694                1.93
# 2      SMC N90               SK 183                0.41
# 3      SMC N90               SK 183                0.41
# 4      SMC N90               SK 183                0.41
# ..         ...                  ...                 ...
# 77  30 Doradus            BAT99 114                0.20
# 78  30 Doradus            BAT99 113                0.28
# 79  30 Doradus            BAT99 113                0.28
# 80  30 Doradus  Cl* NGC 2070 MEL 55                1.86
# 81  30 Doradus  Cl* NGC 2070 MEL 55                1.86
#
#    Instrument/Grating/Cenwave LP/Aperture     T_exp    PID
# 0              COS/G130M/1291         LP4  1534.400  16101
# 1              COS/G160M/1611         LP4  2336.032  16101
# 2             STIS/E140M/1425     0.2x0.2  2707.000  15837
# 3              COS/G130M/1096         LP2  1736.064  16808
# 4              COS/G130M/1096         LP2  1736.096  17295
# ..                        ...         ...       ...    ...
# 77             COS/G160M/1611         LP6  2024.096  16812
# 78             COS/G130M/1291         LP5  2062.400  16812
# 79             COS/G160M/1611         LP6  2004.032  16812
# 80             COS/G130M/1291         LP5  4774.368  16815
# 81             COS/G160M/1611         LP6  4410.784  16815
#
# [82 rows x 7 columns]

# %%
df.to_csv("table.csv", index = False)

# %%
latex = df.to_latex(index = False, header = False, escape = True, na_rep = "/", float_format = "%.2f")
lines = latex.splitlines()
lines = "\n".join(lines)
print(lines)
# Out:
# \begin{tabular}{llrllll}
# \toprule
# \midrule
# SMC N88A & 2dFS 3694 & 1.93 & COS/G130M/1291 & LP4 & 1534.400 & 16101 \\
# SMC N88A & 2dFS 3694 & 1.93 & COS/G160M/1611 & LP4 & 2336.032 & 16101 \\
# SMC N90 & SK 183 & 0.41 & STIS/E140M/1425 & 0.2x0.2 & 2707.000 & 15837 \\
# SMC N90 & SK 183 & 0.41 & COS/G130M/1096 & LP2 & 1736.064 & 16808 \\
# SMC N90 & SK 183 & 0.41 & COS/G130M/1096 & LP2 & 1736.096 & 17295 \\
# SMC N66A & Cl* NGC 346 ELS 51 & 0.53 & COS/G130M/1096 & LP2 & 9959.808 & 16103 \\
# SMC N66A & Cl* NGC 346 ELS 51 & 0.53 & COS/G130M/1291 & LP1 & 360.032 & 11625 \\
# SMC N66A & Cl* NGC 346 ELS 51 & 0.53 & COS/G130M/1327 & LP1 & 360.032 & 11625 \\
# SMC N66A & Cl* NGC 346 ELS 51 & 0.53 & COS/G160M/1577 & LP1 & 648.224 & 11625 \\
# SMC N66A & Cl* NGC 346 ELS 51 & 0.53 & COS/G160M/1623 & LP1 & 648.224 & 11625 \\
# SMC N66A & Cl* NGC 346 ELS 50 & 1.69 & COS/G130M/1096 & LP2 & 9965.762 & 16103 \\
# SMC N66A & Cl* NGC 346 ELS 50 & 1.69 & COS/G130M/1291 & LP1 & 335.008 & 11625 \\
# SMC N66A & Cl* NGC 346 ELS 50 & 1.69 & COS/G130M/1327 & LP1 & 334.016 & 11625 \\
# SMC N66A & Cl* NGC 346 ELS 50 & 1.69 & COS/G160M/1623 & LP1 & 600.192 & 11625 \\
# SMC N66A & Cl* NGC 346 MPG 782 & 2.49 & COS/G130M/1096 & LP2 & 10611.616 & 16371 \\
# SMC N66A & Cl* NGC 346 MPG 782 & 2.49 & COS/G130M/1291 & LP5 & 959.456 & 16371 \\
# SMC N66A & Cl* NGC 346 W 3 & 0.33 & STIS/E140M/1425 & 0.2x0.2 & 2215.200 & 16098 \\
# SMC N66A & Cl* NGC 346 W 3 & 0.33 & STIS/E140M/1425 & 0.2x0.2 & 2567.200 & 16098 \\
# SMC N66A & Cl* NGC 346 W 3 & 0.33 & STIS/E140M/1425 & 0.2x0.2 & 2700.000 & 7437 \\
# SMC N66A & Cl* NGC 346 W 4 & 0.33 & STIS/E140M/1425 & 0.2x0.2 & 2707.000 & 15837 \\
# SMC N66A & Cl* NGC 346 ELS 22 & 1.20 & COS/G130M/1291 & LP1 & 360.000 & 11625 \\
# SMC N66A & Cl* NGC 346 ELS 22 & 1.20 & COS/G130M/1327 & LP1 & 360.032 & 11625 \\
# SMC N66A & Cl* NGC 346 ELS 22 & 1.20 & COS/G160M/1577 & LP1 & 560.032 & 11625 \\
# SMC N66A & Cl* NGC 346 ELS 22 & 1.20 & COS/G160M/1623 & LP1 & 560.032 & 11625 \\
# SMC N66A & Cl* NGC 346 SSN 7 & 0.24 & STIS/E140M/1425 & 0.2x0.2 & 2210.200 & 16805 \\
# SMC N66A & Cl* NGC 346 ELS 7 & 0.54 & STIS/E140M/1425 & 0.2x0.2 & 5400.000 & 7437 \\
# SMC N66A & Cl* NGC 346 SSN 25 & 0.77 & STIS/E140M/1425 & 0.2x0.2 & 2707.000 & 15837 \\
# SMC N66A & Cl* NGC 346 NMC 28 & 0.24 & STIS/E140M/1425 & 0.2x0.2 & 6000.00 & 7437 \\
# SMC N66A & Cl* NGC 346 NMC 28 & 0.24 & COS/G130M/1096 & LP2 & 4394.784 & 16013 \\
# SMC N66A & Cl* NGC 346 NMC 17 & 0.18 & STIS/E140M/1425 & 0.2x0.2 & 9360.000 & 7437 \\
# SMC N66A & HD 5980 & 1.86 & STIS/E140M/1425 & 0.2x0.2 & 2028.000 & 14476 \\
# SMC N66A & HD 5980 & 1.86 & STIS/E140M/1425 & 0.2x0.2 & 2070.000 & 13373 \\
# SMC N66A & HD 5980 & 1.86 & STIS/E140M/1425 & 0.2x0.2 & 2548.000 & 11623 \\
# SMC N66A & HD 5980 & 1.86 & STIS/E140M/1425 & 0.2x0.2 & 2608.000 & 13373 \\
# SMC N66A & HD 5980 & 1.86 & STIS/E140M/1425 & 0.2x0.2 & 2627.000 & 11623 \\
# SMC N66A & HD 5980 & 1.86 & STIS/E140M/1425 & 0.2x0.2 & 2776.000 & 9094 \\
# SMC N66A & HD 5980 & 1.86 & STIS/E140M/1425 & 0.2x0.2 & 2837.000 & 14476 \\
# SMC N66A & HD 5980 & 1.86 & STIS/E140M/1425 & 0.2x0.2 & 3236.000 & 7480 \\
# SMC N66A & HD 5980 & 1.86 & STIS/E230M/1978 & 0.2x0.2 & 1609.000 & 9094 \\
# SMC N66A & HD 5980 & 1.86 & STIS/E230M/2707 & 0.2x0.2 & 1300.000 & 9094 \\
# SMC N66A & SK 80 & 2.11 & STIS/E140M/1425 & 0.2x0.2 & 1200.000 & 9434 \\
# SMC N81 & AzV 446 & 2.33 & COS/G130M/1291 & LP1 & 323.008 & 11625 \\
# SMC N81 & AzV 446 & 2.33 & COS/G130M/1327 & LP1 & 323.040 & 11625 \\
# SMC N81 & AzV 446 & 2.33 & COS/G160M/1577 & LP1 & 630.208 & 11625 \\
# SMC N81 & AzV 446 & 2.33 & COS/G160M/1623 & LP1 & 620.192 & 11625 \\
# LMC N11B & PGMW 3120 & 0.59 & STIS/E140M/1425 & 0.2x0.06 & 2291.000 & 8320 \\
# LMC N11B & PGMW 3120 & 0.59 & STIS/E140M/1425 & 0.2x0.06 & 3152.000 & 8320 \\
# LMC N11B & PGMW 3120 & 0.59 & STIS/E230M/1978 & 0.2x0.2 & 1570.000 & 14675 \\
# LMC N11B & PGMW 3120 & 0.59 & STIS/E230M/1978 & 0.2x0.2 & 2240.000 & 14675 \\
# LMC N11B & BRRG 75 & 1.03 & STIS/E140M/1425 & 0.2x0.2 & 2192.200 & 16820 \\
# LMC N11B & BRRG 75 & 1.03 & STIS/E140M/1425 & 0.2x0.2 & 2548.200 & 16820 \\
# LMC N11B & BI 42 & 0.94 & STIS/E140M/1425 & 0.2x0.2 & 2240.000 & 14675 \\
# LMC N11B & BI 42 & 0.94 & STIS/E140M/1425 & 0.2x0.2 & 2750.000 & 14675 \\
# LMC N11B & BI 42 & 0.94 & STIS/E140M/1425 & 0.2x0.2 & 2778.000 & 14675 \\
# LMC N11B & BI 42 & 0.94 & STIS/E230M/1978 & 0.2x0.2 & 2240.000 & 14675 \\
# LMC N11B & BI 42 & 0.94 & STIS/E230M/1978 & 0.2x0.2 & 2730.000 & 14675 \\
# LMC N11B & PGMW 3204 & 0.77 & STIS/E140M/1425 & 0.2x0.2 & 2176.200 & 16815 \\
# LMC N11B & PGMW 3204 & 0.77 & STIS/E140M/1425 & 0.2x0.2 & 2548.198 & 16815 \\
# LMC N11B & PGMW 3204 & 0.77 & STIS/E140M/1425 & 0.2x0.2 & 2548.199 & 16815 \\
# LMC N11B & PGMW 3053 & 1.08 & COS/G130M/1291 & LP4 & 475.232 & 16095 \\
# LMC N11B & PGMW 3168 & 0.33 & COS/G130M/1291 & LP5 & 1970.400 & 16818 \\
# LMC N11B & PGMW 3168 & 0.33 & COS/G160M/1611 & LP6 & 1964.032 & 16818 \\
# LMC N11B & [L72] LH 10-3061 & 1.26 & COS/G130M/1291 & LP5 & 2066.368 & 16811 \\
# LMC N11B & [L72] LH 10-3061 & 1.26 & COS/G160M/1611 & LP6 & 1996.096 & 16811 \\
# LMC N11B & PGMW 3058 & 1.06 & COS/G130M/1291 & LP4 & 2066.368 & 16319 \\
# LMC N11B & PGMW 3058 & 1.06 & COS/G160M/1611 & LP4 & 1996.096 & 16319 \\
# LMC N11B & PGMW 3100 & 0.99 & COS/G130M/1291 & LP4 & 1990.400 & 16094 \\
# LMC N11B & PGMW 3100 & 0.99 & COS/G160M/1611 & LP4 & 1968.096 & 16094 \\
# 30 Doradus & Cl* NGC 2070 MH 57 & 0.20 & COS/G130M/1291 & LP4 & 2040.384 & 16093 \\
# 30 Doradus & Cl* NGC 2070 MH 57 & 0.20 & COS/G160M/1611 & LP4 & 2080.064 & 16093 \\
# 30 Doradus & Brey 77 & 0.14 & STIS/E140M/1425 & 0.2x0.2 & 2192.200 & 16090 \\
# 30 Doradus & Brey 77 & 0.14 & STIS/E140M/1425 & 0.2x0.2 & 2638.199 & 16090 \\
# 30 Doradus & Brey 77 & 0.14 & STIS/E140M/1425 & 0.2x0.2 & 2638.200 & 16090 \\
# 30 Doradus & RMC 140 & 0.83 & STIS/E140M/1425 & 0.2x0.2 & 2670.000 & 16272 \\
# 30 Doradus & Cl* NGC 2070 MEL 25 & 0.73 & COS/G130M/1291 & LP5 & 2054.400 & 16810 \\
# 30 Doradus & Cl* NGC 2070 MEL 47 & 0.82 & STIS/E140M/1425 & 0.2x0.2 & 2728.000 & 15629 \\
# 30 Doradus & BAT99 114 & 0.20 & COS/G130M/1291 & LP5 & 2072.416 & 16812 \\
# 30 Doradus & BAT99 114 & 0.20 & COS/G160M/1611 & LP6 & 2024.096 & 16812 \\
# 30 Doradus & BAT99 113 & 0.28 & COS/G130M/1291 & LP5 & 2062.400 & 16812 \\
# 30 Doradus & BAT99 113 & 0.28 & COS/G160M/1611 & LP6 & 2004.032 & 16812 \\
# 30 Doradus & Cl* NGC 2070 MEL 55 & 1.86 & COS/G130M/1291 & LP5 & 4774.368 & 16815 \\
# 30 Doradus & Cl* NGC 2070 MEL 55 & 1.86 & COS/G160M/1611 & LP6 & 4410.784 & 16815 \\
# \bottomrule
# \end{tabular}

# %%
region_order = [
    "SMC N66A",
    "SMC N81",
    "SMC N88A",
    "SMC N90",
    "30 Doradus",
    "LMC N11B",
]

df["Region"] = pd.Categorical(df["Region"], categories = region_order, ordered = True)

df = df.sort_values(
    by = ["Region", "Target", "Angular Separation"]
).reset_index(drop = True)

# %%
cols_to_merge = ["Region", "Target", "Angular Separation"]

mask = df.duplicated(subset = cols_to_merge)

df_merged = df.copy()

for c in cols_to_merge:
    df_merged[c] = df_merged[c].astype("string")

df_merged.loc[mask, cols_to_merge] = ""

# %%
def df_to_latex_with_target_hlines(df):
    lines = []
    prev_target = None

    for _, row in df.iterrows():
        curr_target = row["Target"]
        if prev_target is not None and curr_target != "" and curr_target != prev_target:
            lines.append(r"\hline")
        line = " & ".join(
            "" if pd.isna(v) or v == "" else f"{v:.2f}" if isinstance(v, float) else str(v)
            for v in row
        ) + r" \\"
        lines.append(line)
        prev_target = curr_target if curr_target != "" else prev_target

    return "\n".join(lines)

# %%
body = df_to_latex_with_target_hlines(df_merged)

latex = rf"""
\begin{{tabular}}{{l l r l l r r}}
\hline
{body}
\hline
\end{{tabular}}
"""

print(latex)
# Out:
# \begin{tabular}{l l r l l r r}
# \hline
# SMC N66A & Cl* NGC 346 ELS 22 & 1.2 & COS/G130M/1291 & LP1 & 360.000 & 11625 \\
#  &  &  & COS/G130M/1327 & LP1 & 360.032 & 11625 \\
#  &  &  & COS/G160M/1577 & LP1 & 560.032 & 11625 \\
#  &  &  & COS/G160M/1623 & LP1 & 560.032 & 11625 \\
# \hline
# SMC N66A & Cl* NGC 346 ELS 50 & 1.69 & COS/G130M/1096 & LP2 & 9965.762 & 16103 \\
#  &  &  & COS/G130M/1291 & LP1 & 335.008 & 11625 \\
#  &  &  & COS/G130M/1327 & LP1 & 334.016 & 11625 \\
#  &  &  & COS/G160M/1623 & LP1 & 600.192 & 11625 \\
# \hline
# SMC N66A & Cl* NGC 346 ELS 51 & 0.53 & COS/G130M/1096 & LP2 & 9959.808 & 16103 \\
#  &  &  & COS/G130M/1291 & LP1 & 360.032 & 11625 \\
#  &  &  & COS/G130M/1327 & LP1 & 360.032 & 11625 \\
#  &  &  & COS/G160M/1577 & LP1 & 648.224 & 11625 \\
#  &  &  & COS/G160M/1623 & LP1 & 648.224 & 11625 \\
# \hline
# SMC N66A & Cl* NGC 346 ELS 7 & 0.54 & STIS/E140M/1425 & 0.2x0.2 & 5400.000 & 7437 \\
# \hline
# SMC N66A & Cl* NGC 346 MPG 782 & 2.49 & COS/G130M/1096 & LP2 & 10611.616 & 16371 \\
#  &  &  & COS/G130M/1291 & LP5 & 959.456 & 16371 \\
# \hline
# SMC N66A & Cl* NGC 346 NMC 17 & 0.18 & STIS/E140M/1425 & 0.2x0.2 & 9360.000 & 7437 \\
# \hline
# SMC N66A & Cl* NGC 346 NMC 28 & 0.24 & STIS/E140M/1425 & 0.2x0.2 & 6000.00 & 7437 \\
#  &  &  & COS/G130M/1096 & LP2 & 4394.784 & 16013 \\
# \hline
# SMC N66A & Cl* NGC 346 SSN 25 & 0.77 & STIS/E140M/1425 & 0.2x0.2 & 2707.000 & 15837 \\
# \hline
# SMC N66A & Cl* NGC 346 SSN 7 & 0.24 & STIS/E140M/1425 & 0.2x0.2 & 2210.200 & 16805 \\
# \hline
# SMC N66A & Cl* NGC 346 W 3 & 0.33 & STIS/E140M/1425 & 0.2x0.2 & 2215.200 & 16098 \\
#  &  &  & STIS/E140M/1425 & 0.2x0.2 & 2567.200 & 16098 \\
#  &  &  & STIS/E140M/1425 & 0.2x0.2 & 2700.000 & 7437 \\
# \hline
# SMC N66A & Cl* NGC 346 W 4 & 0.33 & STIS/E140M/1425 & 0.2x0.2 & 2707.000 & 15837 \\
# \hline
# SMC N66A & HD 5980 & 1.86 & STIS/E140M/1425 & 0.2x0.2 & 2028.000 & 14476 \\
#  &  &  & STIS/E140M/1425 & 0.2x0.2 & 2070.000 & 13373 \\
#  &  &  & STIS/E140M/1425 & 0.2x0.2 & 2548.000 & 11623 \\
#  &  &  & STIS/E140M/1425 & 0.2x0.2 & 2608.000 & 13373 \\
#  &  &  & STIS/E140M/1425 & 0.2x0.2 & 2627.000 & 11623 \\
#  &  &  & STIS/E140M/1425 & 0.2x0.2 & 2776.000 & 9094 \\
#  &  &  & STIS/E140M/1425 & 0.2x0.2 & 2837.000 & 14476 \\
#  &  &  & STIS/E140M/1425 & 0.2x0.2 & 3236.000 & 7480 \\
#  &  &  & STIS/E230M/1978 & 0.2x0.2 & 1609.000 & 9094 \\
#  &  &  & STIS/E230M/2707 & 0.2x0.2 & 1300.000 & 9094 \\
# \hline
# SMC N66A & SK 80 & 2.11 & STIS/E140M/1425 & 0.2x0.2 & 1200.000 & 9434 \\
# \hline
# SMC N81 & AzV 446 & 2.33 & COS/G130M/1291 & LP1 & 323.008 & 11625 \\
#  &  &  & COS/G130M/1327 & LP1 & 323.040 & 11625 \\
#  &  &  & COS/G160M/1577 & LP1 & 630.208 & 11625 \\
#  &  &  & COS/G160M/1623 & LP1 & 620.192 & 11625 \\
# \hline
# SMC N88A & 2dFS 3694 & 1.93 & COS/G130M/1291 & LP4 & 1534.400 & 16101 \\
#  &  &  & COS/G160M/1611 & LP4 & 2336.032 & 16101 \\
# \hline
# SMC N90 & SK 183 & 0.41 & STIS/E140M/1425 & 0.2x0.2 & 2707.000 & 15837 \\
#  &  &  & COS/G130M/1096 & LP2 & 1736.064 & 16808 \\
#  &  &  & COS/G130M/1096 & LP2 & 1736.096 & 17295 \\
# \hline
# 30 Doradus & BAT99 113 & 0.28 & COS/G130M/1291 & LP5 & 2062.400 & 16812 \\
#  &  &  & COS/G160M/1611 & LP6 & 2004.032 & 16812 \\
# \hline
# 30 Doradus & BAT99 114 & 0.2 & COS/G130M/1291 & LP5 & 2072.416 & 16812 \\
#  &  &  & COS/G160M/1611 & LP6 & 2024.096 & 16812 \\
# \hline
# 30 Doradus & Brey 77 & 0.14 & STIS/E140M/1425 & 0.2x0.2 & 2192.200 & 16090 \\
#  &  &  & STIS/E140M/1425 & 0.2x0.2 & 2638.199 & 16090 \\
#  &  &  & STIS/E140M/1425 & 0.2x0.2 & 2638.200 & 16090 \\
# \hline
# 30 Doradus & Cl* NGC 2070 MEL 25 & 0.73 & COS/G130M/1291 & LP5 & 2054.400 & 16810 \\
# \hline
# 30 Doradus & Cl* NGC 2070 MEL 47 & 0.82 & STIS/E140M/1425 & 0.2x0.2 & 2728.000 & 15629 \\
# \hline
# 30 Doradus & Cl* NGC 2070 MEL 55 & 1.86 & COS/G130M/1291 & LP5 & 4774.368 & 16815 \\
#  &  &  & COS/G160M/1611 & LP6 & 4410.784 & 16815 \\
# \hline
# 30 Doradus & Cl* NGC 2070 MH 57 & 0.2 & COS/G130M/1291 & LP4 & 2040.384 & 16093 \\
#  &  &  & COS/G160M/1611 & LP4 & 2080.064 & 16093 \\
# \hline
# 30 Doradus & RMC 140 & 0.83 & STIS/E140M/1425 & 0.2x0.2 & 2670.000 & 16272 \\
# \hline
# LMC N11B & BI 42 & 0.94 & STIS/E140M/1425 & 0.2x0.2 & 2240.000 & 14675 \\
#  &  &  & STIS/E140M/1425 & 0.2x0.2 & 2750.000 & 14675 \\
#  &  &  & STIS/E140M/1425 & 0.2x0.2 & 2778.000 & 14675 \\
#  &  &  & STIS/E230M/1978 & 0.2x0.2 & 2240.000 & 14675 \\
#  &  &  & STIS/E230M/1978 & 0.2x0.2 & 2730.000 & 14675 \\
# \hline
# LMC N11B & BRRG 75 & 1.03 & STIS/E140M/1425 & 0.2x0.2 & 2192.200 & 16820 \\
#  &  &  & STIS/E140M/1425 & 0.2x0.2 & 2548.200 & 16820 \\
# \hline
# LMC N11B & PGMW 3053 & 1.08 & COS/G130M/1291 & LP4 & 475.232 & 16095 \\
# \hline
# LMC N11B & PGMW 3058 & 1.06 & COS/G130M/1291 & LP4 & 2066.368 & 16319 \\
#  &  &  & COS/G160M/1611 & LP4 & 1996.096 & 16319 \\
# \hline
# LMC N11B & PGMW 3100 & 0.99 & COS/G130M/1291 & LP4 & 1990.400 & 16094 \\
#  &  &  & COS/G160M/1611 & LP4 & 1968.096 & 16094 \\
# \hline
# LMC N11B & PGMW 3120 & 0.59 & STIS/E140M/1425 & 0.2x0.06 & 2291.000 & 8320 \\
#  &  &  & STIS/E140M/1425 & 0.2x0.06 & 3152.000 & 8320 \\
#  &  &  & STIS/E230M/1978 & 0.2x0.2 & 1570.000 & 14675 \\
#  &  &  & STIS/E230M/1978 & 0.2x0.2 & 2240.000 & 14675 \\
# \hline
# LMC N11B & PGMW 3168 & 0.33 & COS/G130M/1291 & LP5 & 1970.400 & 16818 \\
#  &  &  & COS/G160M/1611 & LP6 & 1964.032 & 16818 \\
# \hline
# LMC N11B & PGMW 3204 & 0.77 & STIS/E140M/1425 & 0.2x0.2 & 2176.200 & 16815 \\
#  &  &  & STIS/E140M/1425 & 0.2x0.2 & 2548.198 & 16815 \\
#  &  &  & STIS/E140M/1425 & 0.2x0.2 & 2548.199 & 16815 \\
# \hline
# LMC N11B & [L72] LH 10-3061 & 1.26 & COS/G130M/1291 & LP5 & 2066.368 & 16811 \\
#  &  &  & COS/G160M/1611 & LP6 & 1996.096 & 16811 \\
# \hline
# \end{tabular}

# %%
# END
