# %%
import os
import glob
import numpy as np
import pandas as pd
import astropy.units as u
import matplotlib.pyplot as plt

from pathlib import Path
from astropy.io import fits
from astropy.wcs import WCS
from astroquery.simbad import Simbad
from matplotlib.patches import Rectangle
from astroquery.hips2fits import hips2fits
from astropy.coordinates import SkyCoord, Angle

font = {'family' : 'gill sans',
         'size'   : 12,
         'serif':  'cmr10'
         }

plt.rc('font', **font)
plt.rc('axes', unicode_minus = False)

# %%
hdul = fits.open('/Users/billyli/Documents/float-for-morrow/LMC/30 Doradus/RMC 140/E140M_1425_0.2x0.2_2670.000_16272/oec159010_x1d.fits')
hdul.info()
R = float(hdul[0].header["SPECRES"])
print(R)
# Out:
# Filename: /Users/billyli/Documents/float-for-morrow/LMC/30 Doradus/RMC 140/E140M_1425_0.2x0.2_2670.000_16272/oec159010_x1d.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     298   ()
#   1  SCI           1 BinTableHDU    158   44R x 19C   [1I, 1I, 1024D, 1024E, 1024E, 1024E, 1024E, 1024E, 1024E, 1024I, 1E, 1E, 1I, 1E, 1E, 1E, 1E, 1024E, 1E]
# 45800.0

# %%
main_directory = Path().resolve()

# %%
def snr_from_spectra(path, Cenwave, Instrument):

    if Cenwave == 1096:

        wave = 1100

    elif Cenwave == 1291 or Cenwave == 1327:

        wave = 1292

    elif Cenwave == 1611 or Cenwave == 1577 or Cenwave == 1623:

        wave = 1630

    elif Cenwave == 1425:

        wave = 1420

    elif Cenwave == 1978:

        wave = 2002

    elif Cenwave == 2707:

        wave = 2800
    
    with fits.open(path) as hdul:
        data = hdul[1].data

        wl = data["WAVELENGTH"]
        flux = data["FLUX"]
        err = data["ERROR"]

        header = hdul[0].header
        R = float(header["SPECRES"])
        dl_pix = float(np.nanmedian(np.diff(wl)))
        dl_res = np.nanmedian(wl) / R

        npix = dl_res / dl_pix
        
        mask = (np.abs(wl - wave) < 0.5) & np.isfinite(flux) & np.isfinite(err) & (err > 0)
        snr = flux[mask] / err[mask] * np.sqrt(npix)

        return float(np.median(snr))

def query_simbad(target_name):
    result = Simbad().query_object(target_name)
    ra_deg = float(result["ra"][0])
    dec_deg = float(result["dec"][0])
    coord = SkyCoord(ra = ra_deg * u.deg, dec = dec_deg * u.deg, frame = "icrs")
    ra_str = coord.ra.to_string(unit = u.hourangle, sep = " ", pad = True, precision = 3, alwayssign = False)
    dec_str = coord.dec.to_string(unit = u.deg, sep = " ", pad = True, precision = 2, alwayssign = True)
    if dec_str.startswith("+"):
        dec_str = dec_str[1:]
    return f"{ra_str}", f"{dec_str}"

# %%
def parse_directory(target_directory, dirname, galaxy_name, region_name, target_name, angular_separation, target_id): # different with some other functions I wrote
    
    parts = dirname.split("_")

    Grating = parts[0]
    Cenwave = int(parts[1])
    T_exp = str(parts[3])
    PID = int(parts[4])

    RA, DEC = query_simbad(target_name)

    if Grating.startswith("G"):
        
        Instrument = "COS"
        LP = parts[2]

        for file in os.listdir(os.path.join(target_directory, dirname)):
            if file.endswith("_x1dsum.fits"):
                path = os.path.join(target_directory, dirname, file)

        snr = snr_from_spectra(path, Cenwave, Instrument)

        return {
            # "Galaxy": galaxy_name, 
            "ID": target_id,
            "Region": region_name, 
            "Target": target_name, 
            "RA": RA, 
            "DEC": DEC, 
            "Angular Separation": round(angular_separation, 2), 
            "Instrument/Grating/Cenwave": Instrument + "/" + Grating + "/" + str(Cenwave), 
            # "LP/Aperture": LP,  
            "T_exp": str(T_exp), 
            "SNR": snr, 
            "PID": str(PID), 
        }
        
    else:
        
        Instrument = "STIS"
        Aperture = parts[2]

        path = sorted(glob.glob(os.path.join(target_directory, dirname, "*_x1d.fits")))[0]
        snr = snr_from_spectra(path, Cenwave, Instrument)
        
        return {
            # "Galaxy": galaxy_name, 
            "ID": target_id, 
            "Region": region_name, 
            "Target": target_name, 
            "RA": RA, 
            "DEC": DEC, 
            "Angular Separation": round(angular_separation, 2), 
            "Instrument/Grating/Cenwave": Instrument + "/" + Grating + "/" + str(Cenwave), 
            # "LP/Aperture": Aperture, 
            "T_exp": str(T_exp), 
            "SNR": snr, 
            "PID": str(PID), 
        }

# %%
records = []

for galaxy_name in os.listdir(main_directory):
    galaxy_path = main_directory / galaxy_name
    if galaxy_path.name.startswith(".") or not galaxy_path.is_dir():
        continue
        
    for region_name in os.listdir(galaxy_path):
        region_path = galaxy_path / region_name
        if region_path.name.startswith(".") or not region_path.is_dir():
            continue

        region = Simbad.query_object(region_name)
        ra_region = region["ra"][0]
        dec_region = region["dec"][0]

        if region_name == "SMC N88A": 

            coord_region = SkyCoord('01h24m08.3s', '−73d09m04.6s', frame = 'icrs')

        if region_name == "SMC N90": 

            coord_region = SkyCoord('01h29m36.1s', '−73d33m51.9s', frame = 'icrs')

        if region_name == "SMC N66A": 

            coord_region = SkyCoord('00h59m14.3s', '-72d11m02.8s', frame = 'icrs')

        if region_name == "SMC N81": 

            coord_region = SkyCoord('01h09m12.8s', '−73d11m36.90s', frame = 'icrs')

        if region_name == "LMC N11B": 

            coord_region = SkyCoord('04h56m46.9s', '−66d24m37.9s', frame = 'icrs')

        if region_name == "30 Doradus": 

            coord_region = SkyCoord('05h38m53.6s', '-69d05m07.4s', frame = 'icrs')

        index = 1
        
        for target_name in sorted(os.listdir(region_path)):

            if region_name == "SMC N88A": 

                code_prefix = "C"
    
            if region_name == "SMC N90": 
    
                code_prefix = "D"
    
            if region_name == "SMC N66A": 
    
                code_prefix = "A"
    
            if region_name == "SMC N81": 
    
                code_prefix = "B"
    
            if region_name == "LMC N11B": 
    
                code_prefix = "F"
    
            if region_name == "30 Doradus": 
    
                code_prefix = "E"
            
            target_path = region_path / target_name
            if target_path.name.startswith("unused") or target_path.name.startswith(".") or not target_path.is_dir():
                continue

            target_id = code_prefix + str(index)

            index += 1

            code_file = target_path / "code.txt"
            with open(code_file, "w") as f:
                f.write(target_id)

            target = Simbad.query_object(target_name)
            ra_target = target["ra"][0]
            dec_target = target["dec"][0]
            coord_target = SkyCoord(ra_target, dec_target, unit = (u.deg, u.deg), frame = "icrs")

            angular_separation = coord_region.separation(coord_target).arcmin

            spectra_directories = sorted([d for d in os.listdir(target_path) if d.startswith("G") or d.startswith("E")])

            for d in spectra_directories:
                info = parse_directory(target_path, d, galaxy_name, region_name, target_name, angular_separation, target_id)
                records.append(info)

df = pd.DataFrame.from_records(records)

# %%
df
# Out:
#     ID      Region               Target            RA           DEC  \
# 0   C1    SMC N88A            2dFS 3694  01 24 34.445  -73 09 08.88
# 1   C1    SMC N88A            2dFS 3694  01 24 34.445  -73 09 08.88
# 2   D1     SMC N90               SK 183  01 29 24.548  -73 33 16.35
# 3   D1     SMC N90               SK 183  01 29 24.548  -73 33 16.35
# 4   D1     SMC N90               SK 183  01 29 24.548  -73 33 16.35
# ..  ..         ...                  ...           ...           ...
# 77  E6  30 Doradus  Cl* NGC 2070 MEL 55  05 38 33.975  -69 04 21.23
# 78  E6  30 Doradus  Cl* NGC 2070 MEL 55  05 38 33.975  -69 04 21.23
# 79  E7  30 Doradus   Cl* NGC 2070 MH 57  05 38 40.216  -69 05 59.92
# 80  E7  30 Doradus   Cl* NGC 2070 MH 57  05 38 40.216  -69 05 59.92
# 81  E8  30 Doradus              RMC 140  05 38 41.616  -69 05 13.96
#
#     Angular Separation Instrument/Grating/Cenwave     T_exp        SNR    PID
# ...

# %%
df.to_csv("table.csv", index = False)

# %%
region_order = [
    "SMC N66A",
    "SMC N81",
    "SMC N88A",
    "SMC N90",
    "30 Doradus",
    "LMC N11B",
]

df["Region"] = pd.Categorical(df["Region"], categories = region_order, ordered = True)

df = df.sort_values(
    by = ["Region", "Target", "Angular Separation"]
).reset_index(drop = True)

# %%
cols_to_merge = ["ID", "Target", "Region", "Angular Separation", "RA", "DEC"]

mask = df.duplicated(subset = cols_to_merge)

df_merged = df.copy()

for c in cols_to_merge:
    df_merged[c] = df_merged[c].astype("string")

df_merged.loc[mask, cols_to_merge] = ""

# %%
def df_to_latex(df):
    lines = []
    prev_target = None

    for _, row in df.iterrows():
        curr_target = row["Target"]
        # if prev_target is not None and curr_target != "" and curr_target != prev_target:
            # lines.append(r"\hline")
        line = " & ".join(
            "" if pd.isna(v) or v == "" else f"{v:.2f}" if isinstance(v, float) else str(v)
            for v in row
        ) + r" \\"
        lines.append(line)
        prev_target = curr_target if curr_target != "" else prev_target

    return "\n".join(lines)

# %%
def df_to_latex_combine_lp_aperture(df):
    df = df.copy()

    igc = "Instrument/Grating/Cenwave"
    lp  = "LP/Aperture"
    new = "Instrument/Grating/Cenwave/LP"

    combined = (df[igc].fillna("").astype(str) + "/" + df[lp].fillna("").astype(str)).str.strip("/")
    insert_at = df.columns.get_loc(igc)
    df = df.drop(columns = [igc, lp])

    df.insert(insert_at, new, combined)

    lines = []
    for _, row in df.iterrows():
        line = " & ".join(
            "" if pd.isna(v) or v == ""
            else f"{v:.2f}" if isinstance(v, float)
            else str(v)
            for v in row
        ) + r" \\"
        lines.append(line)

    return "\n".join(lines)

# %%
body = df_to_latex(df_merged)

latex = rf"""
\startdata
{body}
\enddata
\label{{tab:sightlines}}
\end{{deluxetable}}
"""

print(latex)
# Out:
# \startdata
# A1 & SMC N66A & Cl* NGC 346 ELS 22 & 00 59 18.618 & -72 11 09.89 & 0.35 & COS/G130M/1291 & 360.000 & 27.03 & 11625 \\
#  &  &  &  &  &  & COS/G130M/1327 & 360.032 & 28.34 & 11625 \\
#  &  &  &  &  &  & COS/G160M/1577 & 560.032 & 15.81 & 11625 \\
#  &  &  &  &  &  & COS/G160M/1623 & 560.032 & 14.97 & 11625 \\
# A2 & SMC N66A & Cl* NGC 346 ELS 50 & 00 58 55.221 & -72 09 06.69 & 2.42 & COS/G130M/1096 & 9965.762 & 20.82 & 16103 \\
#  &  &  &  &  &  & COS/G130M/1291 & 335.008 & 22.14 & 11625 \\
#  &  &  &  &  &  & COS/G130M/1327 & 334.016 & 22.95 & 11625 \\
#  &  &  &  &  &  & COS/G160M/1623 & 600.192 & 13.09 & 11625 \\
# A3 & SMC N66A & Cl* NGC 346 ELS 51 & 00 59 08.697 & -72 10 14.14 & 0.92 & COS/G130M/1096 & 9959.808 & 19.22 & 16103 \\
#  &  &  &  &  &  & COS/G130M/1291 & 360.032 & 21.99 & 11625 \\
#  &  &  &  &  &  & COS/G130M/1327 & 360.032 & 22.67 & 11625 \\
#  &  &  &  &  &  & COS/G160M/1577 & 648.224 & 13.66 & 11625 \\
# ...

# %%
# END
